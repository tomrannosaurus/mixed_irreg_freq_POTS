# %%
################################################################################
# GRU-D - Factorial Experiment (Simulated Data, no threshold sweep)
################################################################################

# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Imports and Setup
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# !pip install rpy2==3.5.1 --quiet

import itertools
import time
import torch
import numpy as np
import pandas as pd
import os
import math

from sklearn.metrics import roc_curve, auc

from google.colab import drive
drive.mount('/content/drive')

# %load_ext rpy2.ipython
from rpy2.robjects import pandas2ri
import rpy2.robjects as ro
pandas2ri.activate()

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import copy

from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for rpy2 (setup.py) ... done
# Mounted at /content/drive

# %%
################################################################################
#  DGP script path and load
################################################################################
# %%R
source("drive/MyDrive/sim_dgp.R")

# %%
import numpy as np

def create_grud_format_pivot(df_vars, df_outcomes, feature_list, max_time_steps=300):
    """
    Build (X, mask, delta, y) for GRU-D by pivoting each subject's data (time,variable->value)
    into a consistent wide format, computing sorted time steps + deltas, then padding/truncating
    the final sequences. If all subjects' actual sequences are shorter than max_time_steps,
    we dynamically reduce to that actual max length.

    :param df_vars:       DataFrame with columns [ID, time, variable, value]
    :param df_outcomes:   DataFrame with columns [ID, time, Y] (plus possibly 'true_prob')
    :param feature_list:  List of feature names, e.g. ["X1", "X2", "X3", ...]
    :param max_time_steps: The absolute maximum sequence length we allow to keep;
                           if the actual largest sequence among all subjects is smaller,
                           we use the smaller length to avoid excess zero-padding.
    :return: X, mask, delta, y (all np.ndarrays), with shapes:
             - X.shape     = (N, final_time_steps, p)
             - mask.shape  = (N, final_time_steps, p)
             - delta.shape = (N, final_time_steps, p)
             - y.shape     = (N,)
    """

    # first pass: gather each subject's sequence, store in lists
    feature_list = sorted(feature_list)

    subject_ids = df_vars['ID'].unique()
    subject_ids.sort()
    p = len(feature_list)

    X_list = []
    mask_list = []
    delta_list = []
    y_list = []

    for sid in subject_ids:
        df_sub = df_vars[df_vars['ID'] == sid].copy()
        df_sub_out = df_outcomes[df_outcomes['ID'] == sid]

        if len(df_sub_out) == 0:
            continue

        y_val = df_sub_out['Y'].values[0]

        wide_df = df_sub.pivot_table(index='time', columns='variable', values='value')
        wide_df = wide_df.sort_index().reset_index()

        wide_df = wide_df.reindex(columns=['time'] + feature_list)

        time_vals = wide_df['time'].values
        feature_vals = wide_df[feature_list].values

        if len(time_vals) == 0:
            continue

        delta_time = np.diff(time_vals, prepend=time_vals[0])
        delta_time = np.where(delta_time == 0, 1.0, delta_time)

        mask_vals = ~np.isnan(feature_vals)
        mask_vals = mask_vals.astype(float)

        feature_vals = np.nan_to_num(feature_vals, nan=0.0)

        delta_vals = np.tile(delta_time.reshape(-1, 1), (1, p))

        X_list.append(feature_vals)
        mask_list.append(mask_vals)
        delta_list.append(delta_vals)
        y_list.append(y_val)

    # Second pass: find the actual max sequence length across all subjects
    if len(X_list) == 0:
        return (np.array([]), np.array([]), np.array([]), np.array([]))

    largest_actual_len = max(x.shape[0] for x in X_list)
    final_time_steps = min(largest_actual_len, max_time_steps)

    # Third pass: allocate arrays with final_time_steps, then pad/truncate
    N = len(X_list)
    X_out = np.zeros((N, final_time_steps, p), dtype=float)
    M_out = np.zeros((N, final_time_steps, p), dtype=float)
    D_out = np.zeros((N, final_time_steps, p), dtype=float)
    Y_out = np.array(y_list).astype(int)

    for i in range(N):
        seq_len = X_list[i].shape[0]
        use_len = min(seq_len, final_time_steps)

        X_out[i, :use_len, :] = X_list[i][:use_len, :]
        M_out[i, :use_len, :] = mask_list[i][:use_len, :]
        D_out[i, :use_len, :] = delta_list[i][:use_len, :]

    return X_out, M_out, D_out, Y_out

# %%
import math

class GRUD(nn.Module):
    def __init__(
        self,
        input_size,
        hidden_size,
        output_size=1,
        x_mean=None,
        dropout=0.0,
        dropout_type='mloss',
    ):
        """
        input_size: Dimensionality of the features (D).
        hidden_size: Dimensionality of the hidden state (H).
        output_size: Usually 1 for binary classification.
        x_mean: If given, must be a 1D tensor of shape (D,) containing the mean of each feature.
        """
        super(GRUD, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout = dropout
        self.dropout_type = dropout_type

        if x_mean is None:
            self.register_buffer("x_mean", torch.zeros(input_size))
        else:
            if isinstance(x_mean, np.ndarray):
                x_mean = torch.from_numpy(x_mean).float()
            self.register_buffer("x_mean", x_mean)


        # --------------------------
        # Define the "decay" linear layers
        #    W_dg_x:  (D -> D),   W_dg_h: (D -> H).
        #    For compute gamma_x(t) and gamma_h(t) from Delta_t
        # --------------------------
        self.W_dg_x = nn.Linear(input_size, input_size, bias=True)
        self.W_dg_h = nn.Linear(input_size, hidden_size, bias=True)

        # --------------------------
        # GRU gates: z, r, h_tilde
        #    We keep the "m_t" gate terms as in Che et al.
        # --------------------------
        self.w_xz = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.w_hz = nn.Parameter(torch.Tensor(hidden_size, hidden_size))
        self.w_mz = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.b_z  = nn.Parameter(torch.Tensor(hidden_size))

        self.w_xr = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.w_hr = nn.Parameter(torch.Tensor(hidden_size, hidden_size))
        self.w_mr = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.b_r  = nn.Parameter(torch.Tensor(hidden_size))

        self.w_xh = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.w_hh = nn.Parameter(torch.Tensor(hidden_size, hidden_size))
        self.w_mh = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.b_h  = nn.Parameter(torch.Tensor(hidden_size))

        self.w_hy = nn.Parameter(torch.Tensor(hidden_size, output_size))
        self.b_y  = nn.Parameter(torch.Tensor(output_size))

        self.reset_parameters()

    def reset_parameters(self):
        stdv = 1.0 / math.sqrt(self.hidden_size)
        for p in self.parameters():
            nn.init.uniform_(p, -stdv, stdv)

    def forward(self, X, M, Delta):
        """
        X:     (batch_size, T, D)   - raw features
        M:     (batch_size, T, D)   - mask (1 if observed, 0 if missing)
        Delta: (batch_size, T, D)   - time since last observation for each feature
        Returns:
            (batch_size,) or (batch_size, 1) if output_size=1
        """
        batch_size, T, D = X.size()
        H = self.hidden_size

        h = X.new_zeros(batch_size, H)
        x_hat = X.new_zeros(batch_size, D)

        dropout_layer = nn.Dropout(self.dropout)

        for t in range(T):
            x_t = X[:, t, :]
            m_t = M[:, t, :]
            d_t = Delta[:, t, :]

            # ----------------------------------------
            # Compute gamma_x(t) and gamma_h(t)
            #    gamma_x: (batch_size, D)
            #    gamma_h: (batch_size, H)
            # ----------------------------------------
            gamma_x_t = torch.exp(-F.relu(self.W_dg_x(d_t)))
            gamma_h_t = torch.exp(-F.relu(self.W_dg_h(d_t)))

            # ----------------------------------------
            # Update x_hat(t)
            #    x_hat(t) = m_t * x_t  + (1-m_t)* [ gamma_x_t*x_hat(t-1) + (1-gamma_x_t)* x_mean ]
            # ----------------------------------------
            current_x_mean = self.x_mean.to(x_hat.device)
            x_hat = m_t * x_t + (1 - m_t) * (gamma_x_t * x_hat + (1 - gamma_x_t) * current_x_mean)


            # ----------------------------------------
            # Decay hidden state: h(t-1) -> gamma_h(t) * h(t-1)
            # ----------------------------------------
            h = gamma_h_t * h

            # ----------------------------------------
            # Standard GRU gating on the imputed input x_hat(t)
            # ----------------------------------------
            z = torch.sigmoid(
                x_hat @ self.w_xz + h @ self.w_hz + m_t @ self.w_mz + self.b_z
            )

            r = torch.sigmoid(
                x_hat @ self.w_xr + h @ self.w_hr + m_t @ self.w_mr + self.b_r
            )

            h_tilde = torch.tanh(
                x_hat @ self.w_xh + (r * h) @ self.w_hh + m_t @ self.w_mh + self.b_h
            )

            if self.dropout > 0:
                if self.dropout_type == 'mloss':
                    h_tilde = dropout_layer(h_tilde)
                elif self.dropout_type == 'Gal':
                    h = dropout_layer(h)

            h = (1 - z) * h + z * h_tilde

        y_out = h @ self.w_hy + self.b_y
        y_out = torch.sigmoid(y_out)
        return y_out.squeeze(-1)

# %%
class SimDataset(Dataset):
    def __init__(self, X, mask, delta, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.M = torch.tensor(mask, dtype=torch.float32)
        self.D = torch.tensor(delta, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.M[idx], self.D[idx], self.y[idx]

# %%
################################################################################
# Configuration for the sim data
################################################################################
class SimDataConfig:
    def __init__(self, p):
        self.feature_list   = [f"X{i+1}" for i in range(p)]
        # GRU-D hyperparams
        self.rnn_hidden_size = 32
        self.batch_size      = 32
        self.epochs         = 60
        self.patience       = 15
        self.learning_rate  = 1e-3
        self.max_t_steps    = 50

# %%
def run_single_scenario(
    N, p,
    regularity,
    missing_prop,
    num_sync_groups,
    process_types,
    use_lags,
    block_missing=True,
    block_length=1.5,
    outcome_time=10,
    master_seed=511
):
    """
    1) Simulate data in R.
    2) 70/15/15 split => train/val/test.
    3) Train GRU-D with PyPOTS's built-in early stopping.
    4) Evaluate on test set => standard metrics from PyPOTS (no threshold sweep).
    """
    # Simulate data in R
    ro.r.assign("N", N)
    ro.r.assign("p", p)
    ro.r.assign("regularity", regularity)
    ro.r.assign("missing_prop", missing_prop)
    ro.r.assign("num_sync_groups", num_sync_groups)

    if isinstance(process_types, list):
        ro.r.assign("process_types", ro.StrVector(process_types))
    else:
        ro.r.assign("process_types", ro.StrVector([process_types]*p))

    ro.r.assign("use_lags", use_lags)
    ro.r.assign("block_missing", block_missing)
    ro.r.assign("block_length", block_length)
    ro.r.assign("outcome_time", outcome_time)
    ro.r.assign("master_seed", master_seed)

    ro.r('''
        sim_dataset <- simulate_experiment_dataset(
          N            = N,
          p            = p,
          freq_min     = 0.1,
          freq_max     = 50.0,
          regularity   = regularity,
          num_sync_groups = num_sync_groups,
          process_types = process_types,
          missing_prop = missing_prop,
          block_missing = block_missing,
          block_length  = block_length,
          outcome_time  = outcome_time,
          beta          = c(0, seq(-1, 1, length.out = 10)),
          use_lags      = use_lags,
          lag_hours     = ifelse(use_lags, 2, 0),
          master_seed   = master_seed
        )
    ''')

    df_vars_r     = ro.r('sim_dataset$vars_long')
    df_outcomes_r = ro.r('sim_dataset$outcome_df')

    df_vars     = df_vars_r
    df_outcomes = df_outcomes_r

    df_vars["ID"]       = df_vars["ID"].astype(int)
    df_vars["time"]     = df_vars["time"].astype(float)
    df_outcomes["ID"]   = df_outcomes["ID"].astype(int)
    df_outcomes["time"] = df_outcomes["time"].astype(float)

    mean_true_prob = df_outcomes["true_prob"].mean()
    prop_positive  = df_outcomes["Y"].mean()

    # 70/15/15 split
    config = SimDataConfig(p)


    X_all, mask_all, delta_all, y_all = create_grud_format_pivot(
    df_vars, df_outcomes, config.feature_list, max_time_steps=config.max_t_steps
    )

    N_total = len(X_all)
    idx = np.arange(N_total)
    np.random.seed(master_seed)
    np.random.shuffle(idx)

    N_train = int(0.70 * N_total)
    N_val   = int(0.15 * N_total)
    N_test  = N_total - N_train - N_val

    train_idx = idx[:N_train]
    val_idx   = idx[N_train:N_train+N_val]
    test_idx  = idx[N_train+N_val:]

    X_train    = X_all[train_idx]
    mask_train = mask_all[train_idx]
    delta_train= delta_all[train_idx]
    y_train    = y_all[train_idx]

    X_val      = X_all[val_idx]
    mask_val   = mask_all[val_idx]
    delta_val  = delta_all[val_idx]
    y_val      = y_all[val_idx]

    X_test     = X_all[test_idx]
    mask_test  = mask_all[test_idx]
    delta_test = delta_all[test_idx]
    y_test     = y_all[test_idx]

    train_dataset = SimDataset(X_train, mask_train, delta_train, y_train)
    val_dataset   = SimDataset(X_val, mask_val, delta_val, y_val)
    test_dataset  = SimDataset(X_test, mask_test, delta_test, y_test)

    train_loader = DataLoader(train_dataset, batch_size=config.batch_size, shuffle=True, num_workers=0)
    val_loader   = DataLoader(val_dataset, batch_size=config.batch_size, shuffle=False, num_workers=0)
    test_loader  = DataLoader(test_dataset, batch_size=config.batch_size, shuffle=False, num_workers=0)

    # train Custom GRU-D w/ Manual Early Stopping
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    n_features = X_train.shape[2]

    train_mask_flat = mask_train.reshape(-1, n_features)
    train_X_flat = X_train.reshape(-1, n_features)
    x_train_means = np.zeros(n_features)
    for feat_idx in range(n_features):
        masked_vals = train_X_flat[train_mask_flat[:, feat_idx].astype(bool), feat_idx]
        if len(masked_vals) > 0:
            x_train_means[feat_idx] = np.mean(masked_vals)

    model = GRUD(
        input_size=n_features,
        hidden_size=config.rnn_hidden_size,
        output_size=1,
        x_mean=x_train_means,
        dropout=0.05,
        dropout_type='mloss'
    ).to(device)

    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)

    epochs = config.epochs
    patience = config.patience
    best_val_auc = 0.0
    epochs_no_improve = 0
    best_model_weights = copy.deepcopy(model.state_dict())

    print(f"Starting training for {epochs} epochs with patience {patience}...")
    for epoch in range(1, epochs + 1):
        #  Training Phase
        model.train()
        train_loss_list = []
        train_preds_list = []
        train_truth_list = []

        for Xb, Mb, Db, yb in train_loader:
            Xb, Mb, Db, yb = Xb.to(device), Mb.to(device), Db.to(device), yb.to(device)

            optimizer.zero_grad()
            outputs = model(Xb, Mb, Db)
            loss = criterion(outputs, yb)
            loss.backward()
            optimizer.step()

            train_loss_list.append(loss.item())
            train_preds_list.append(outputs.detach().cpu().numpy())
            train_truth_list.append(yb.detach().cpu().numpy())

        train_loss = np.mean(train_loss_list)
        train_preds_epoch = np.concatenate(train_preds_list)
        train_truth_epoch = np.concatenate(train_truth_list)
        try:
            train_auc = roc_auc_score(train_truth_epoch, train_preds_epoch)
        except ValueError:
            train_auc = 0.5

        #  Validation Phase
        model.eval()
        val_loss_list = []
        val_preds_list = []
        val_truth_list = []
        with torch.no_grad():
            for Xb, Mb, Db, yb in val_loader:
                Xb, Mb, Db, yb = Xb.to(device), Mb.to(device), Db.to(device), yb.to(device)
                outputs = model(Xb, Mb, Db)
                loss = criterion(outputs, yb)
                val_loss_list.append(loss.item())
                val_preds_list.append(outputs.cpu().numpy())
                val_truth_list.append(yb.cpu().numpy())

        val_loss = np.mean(val_loss_list)
        val_preds_epoch = np.concatenate(val_preds_list)
        val_truth_epoch = np.concatenate(val_truth_list)
        try:
            val_auc = roc_auc_score(val_truth_epoch, val_preds_epoch)
        except ValueError:
            val_auc = 0.5

        print(f"Epoch [{epoch}/{epochs}] Train Loss: {train_loss:.4f}, Train AUC: {train_auc:.4f} | Val Loss: {val_loss:.4f}, Val AUC: {val_auc:.4f}")

        #  Early Stopping Check
        if val_auc > best_val_auc:
            best_val_auc = val_auc
            best_model_weights = copy.deepcopy(model.state_dict())
            epochs_no_improve = 0
            print(f"  -> New best validation AUC: {best_val_auc:.4f}")
        else:
            epochs_no_improve += 1
            print(f"  -> Validation AUC did not improve. ({epochs_no_improve}/{patience})")

        if epochs_no_improve >= patience:
            print(f"Early stopping triggered after epoch {epoch}.")
            break

    print(f"Finished training. Loading best model with Val AUC: {best_val_auc:.4f}")
    model.load_state_dict(best_model_weights)

    #Evaluate on test set
    model.eval()
    test_preds_list = []
    test_truth_list = []
    with torch.no_grad():
        for Xb, Mb, Db, yb in test_loader:
            Xb, Mb, Db, yb = Xb.to(device), Mb.to(device), Db.to(device), yb.to(device)
            outputs = model(Xb, Mb, Db)
            test_preds_list.append(outputs.cpu().numpy())
            test_truth_list.append(yb.cpu().numpy())

    y_pred_prob_test = np.concatenate(test_preds_list)
    y_true_test = np.concatenate(test_truth_list)

    test_auc = roc_auc_score(y_true_test, y_pred_prob_test)

    threshold = 0.5
    y_pred_test = (y_pred_prob_test >= threshold).astype(int)

    test_accuracy = accuracy_score(y_true_test, y_pred_test)
    test_prec = precision_score(y_true_test, y_pred_test, zero_division=0)
    test_rec = recall_score(y_true_test, y_pred_test, zero_division=0)
    test_f1 = f1_score(y_true_test, y_pred_test, zero_division=0)
    test_loss = float('nan')

    results_dict = {
        "test_loss":      test_loss,
        "auc":            test_auc,
        "accuracy":       test_accuracy,
        "precision":      test_prec,
        "recall":         test_rec,
        "f1":             test_f1,
        "mean_true_prob": float(mean_true_prob),
        "prop_positive":  float(prop_positive)
    }

    return results_dict

# %%
################################################################################
#Main Factorial Loop (new version)
################################################################################

import math

Ns = [200, 1000]
regularities = [0.2, 0.8]
missing_props = [0.1, 0.4]
sync_pattern_values = [1, "p"]
process_type_values = ["homogeneous", "mixed"]
outcome_dep_values = ["direct", "lagged"]

scenario_grid = list(itertools.product(
    Ns,
    regularities,
    missing_props,
    sync_pattern_values,
    process_type_values,
    outcome_dep_values
))

all_results = []
overall_start = time.time()

for scenario in scenario_grid:
    (N,
     regularity,
     missing_prop,
     sync_pattern,
     process_type_flag,
     outcome_dep) = scenario

    p = 10
    if process_type_flag == "homogeneous":
        process_types = ["ar1"]*p
    else:
        repeats = math.ceil(p/3)
        big_array = (["ar1","rw","seasonal"]*repeats)[:p]
        process_types = big_array

    if sync_pattern == "p":
        num_sync_groups = max(1, int(round(math.sqrt(p))))
    else:
        num_sync_groups = 1

    use_lags = (outcome_dep=="lagged")

    print("===================================================================")
    print(f"Scenario => N={N}, reg={regularity}, missing={missing_prop}, "
          f"sync={sync_pattern}, process={process_type_flag}, outcome={outcome_dep}")
    print("===================================================================")

    start_time = time.time()
    results_dict = run_single_scenario(
        N=N,
        p=p,
        regularity=regularity,
        missing_prop=missing_prop,
        num_sync_groups=num_sync_groups,
        process_types=process_types,
        use_lags=use_lags,
        block_missing=True,
        block_length=1.5,
        outcome_time=10,
        master_seed=511
    )
    runtime = time.time() - start_time

    scenario_result = {
        "N":              N,
        "regularity":     regularity,
        "missing_prop":   missing_prop,
        "sync_pattern":   sync_pattern,
        "process_type":   process_type_flag,
        "outcome_dep":    outcome_dep,
        "test_loss":      results_dict["test_loss"],
        "auc":            results_dict["auc"],
        "accuracy":       results_dict["accuracy"],
        "precision":      results_dict["precision"],
        "recall":         results_dict["recall"],
        "f1":             results_dict["f1"],
        "runtime_sec":    runtime,
        "mean_true_prob": results_dict["mean_true_prob"],
        "prop_positive":  results_dict["prop_positive"]
    }
    all_results.append(scenario_result)

overall_runtime = time.time() - overall_start
print(f"\nAll scenarios completed in {overall_runtime/60:.2f} minutes.\n")

df_results = pd.DataFrame(all_results)
df_results.sort_values(by=["N","regularity","missing_prop"], inplace=True)
print(df_results)

df_results.to_csv("drive/MyDrive/grud_factorial_results_long.csv", index=False)
print("\nResults saved to grud_factorial_results_long.csv")
# Out:
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=1, process=homogeneous, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.7141, Train AUC: 0.4595 | Val Loss: 0.7043, Val AUC: 0.5600
#   -> New best validation AUC: 0.5600
# Epoch [2/60] Train Loss: 0.7013, Train AUC: 0.4949 | Val Loss: 0.6880, Val AUC: 0.5600
#   -> Validation AUC did not improve. (1/15)
# Epoch [3/60] Train Loss: 0.6931, Train AUC: 0.5277 | Val Loss: 0.6801, Val AUC: 0.5500
#   -> Validation AUC did not improve. (2/15)
# Epoch [4/60] Train Loss: 0.6831, Train AUC: 0.5498 | Val Loss: 0.6821, Val AUC: 0.4600
#   -> Validation AUC did not improve. (3/15)
# Epoch [5/60] Train Loss: 0.6844, Train AUC: 0.5714 | Val Loss: 0.6699, Val AUC: 0.5250
#   -> Validation AUC did not improve. (4/15)
# Epoch [6/60] Train Loss: 0.6800, Train AUC: 0.5988 | Val Loss: 0.6726, Val AUC: 0.4550
#   -> Validation AUC did not improve. (5/15)
# Epoch [7/60] Train Loss: 0.6792, Train AUC: 0.6337 | Val Loss: 0.6674, Val AUC: 0.4800
#   -> Validation AUC did not improve. (6/15)
# Epoch [8/60] Train Loss: 0.6716, Train AUC: 0.6178 | Val Loss: 0.6667, Val AUC: 0.4950
#   -> Validation AUC did not improve. (7/15)
# Epoch [9/60] Train Loss: 0.6755, Train AUC: 0.6162 | Val Loss: 0.6678, Val AUC: 0.5200
#   -> Validation AUC did not improve. (8/15)
# Epoch [10/60] Train Loss: 0.6642, Train AUC: 0.6650 | Val Loss: 0.6729, Val AUC: 0.4650
#   -> Validation AUC did not improve. (9/15)
# Epoch [11/60] Train Loss: 0.6677, Train AUC: 0.6632 | Val Loss: 0.6711, Val AUC: 0.4650
#   -> Validation AUC did not improve. (10/15)
# Epoch [12/60] Train Loss: 0.6677, Train AUC: 0.6757 | Val Loss: 0.6743, Val AUC: 0.4900
#   -> Validation AUC did not improve. (11/15)
# Epoch [13/60] Train Loss: 0.6606, Train AUC: 0.6741 | Val Loss: 0.6777, Val AUC: 0.4800
#   -> Validation AUC did not improve. (12/15)
# Epoch [14/60] Train Loss: 0.6505, Train AUC: 0.6912 | Val Loss: 0.6790, Val AUC: 0.5200
#   -> Validation AUC did not improve. (13/15)
# Epoch [15/60] Train Loss: 0.6587, Train AUC: 0.7124 | Val Loss: 0.6821, Val AUC: 0.5250
#   -> Validation AUC did not improve. (14/15)
# Epoch [16/60] Train Loss: 0.6437, Train AUC: 0.7137 | Val Loss: 0.6924, Val AUC: 0.5250
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 16.
# Finished training. Loading best model with Val AUC: 0.5600
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=1, process=homogeneous, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6873, Train AUC: 0.4802 | Val Loss: 0.7913, Val AUC: 0.2700
#   -> New best validation AUC: 0.2700
# Epoch [2/60] Train Loss: 0.6638, Train AUC: 0.5622 | Val Loss: 0.7867, Val AUC: 0.2950
#   -> New best validation AUC: 0.2950
# Epoch [3/60] Train Loss: 0.6756, Train AUC: 0.5773 | Val Loss: 0.7884, Val AUC: 0.2650
#   -> Validation AUC did not improve. (1/15)
# Epoch [4/60] Train Loss: 0.6680, Train AUC: 0.6107 | Val Loss: 0.7946, Val AUC: 0.2900
#   -> Validation AUC did not improve. (2/15)
# Epoch [5/60] Train Loss: 0.6720, Train AUC: 0.5997 | Val Loss: 0.7887, Val AUC: 0.3150
#   -> New best validation AUC: 0.3150
# Epoch [6/60] Train Loss: 0.6640, Train AUC: 0.6426 | Val Loss: 0.7877, Val AUC: 0.3150
#   -> New best validation AUC: 0.3150
# Epoch [7/60] Train Loss: 0.6532, Train AUC: 0.6343 | Val Loss: 0.7736, Val AUC: 0.3450
#   -> New best validation AUC: 0.3450
# Epoch [8/60] Train Loss: 0.6556, Train AUC: 0.6635 | Val Loss: 0.7885, Val AUC: 0.3250
#   -> Validation AUC did not improve. (1/15)
# Epoch [9/60] Train Loss: 0.6451, Train AUC: 0.6800 | Val Loss: 0.7904, Val AUC: 0.3600
#   -> New best validation AUC: 0.3600
# Epoch [10/60] Train Loss: 0.6495, Train AUC: 0.6726 | Val Loss: 0.7967, Val AUC: 0.3300
#   -> Validation AUC did not improve. (1/15)
# Epoch [11/60] Train Loss: 0.6399, Train AUC: 0.6908 | Val Loss: 0.7994, Val AUC: 0.3550
#   -> Validation AUC did not improve. (2/15)
# Epoch [12/60] Train Loss: 0.6375, Train AUC: 0.7024 | Val Loss: 0.8010, Val AUC: 0.3750
#   -> New best validation AUC: 0.3750
# Epoch [13/60] Train Loss: 0.6221, Train AUC: 0.7104 | Val Loss: 0.8059, Val AUC: 0.3700
#   -> Validation AUC did not improve. (1/15)
# Epoch [14/60] Train Loss: 0.6388, Train AUC: 0.7056 | Val Loss: 0.8178, Val AUC: 0.3800
#   -> New best validation AUC: 0.3800
# Epoch [15/60] Train Loss: 0.6248, Train AUC: 0.7151 | Val Loss: 0.8260, Val AUC: 0.3700
#   -> Validation AUC did not improve. (1/15)
# Epoch [16/60] Train Loss: 0.6170, Train AUC: 0.7263 | Val Loss: 0.8197, Val AUC: 0.3850
#   -> New best validation AUC: 0.3850
# Epoch [17/60] Train Loss: 0.6155, Train AUC: 0.7250 | Val Loss: 0.8149, Val AUC: 0.3650
#   -> Validation AUC did not improve. (1/15)
# Epoch [18/60] Train Loss: 0.5855, Train AUC: 0.7373 | Val Loss: 0.8219, Val AUC: 0.3950
#   -> New best validation AUC: 0.3950
# Epoch [19/60] Train Loss: 0.5843, Train AUC: 0.7527 | Val Loss: 0.8427, Val AUC: 0.3950
#   -> Validation AUC did not improve. (1/15)
# Epoch [20/60] Train Loss: 0.6035, Train AUC: 0.7502 | Val Loss: 0.8677, Val AUC: 0.4100
#   -> New best validation AUC: 0.4100
# Epoch [21/60] Train Loss: 0.5865, Train AUC: 0.7580 | Val Loss: 0.8724, Val AUC: 0.4050
#   -> Validation AUC did not improve. (1/15)
# Epoch [22/60] Train Loss: 0.5780, Train AUC: 0.7721 | Val Loss: 0.8652, Val AUC: 0.4250
#   -> New best validation AUC: 0.4250
# Epoch [23/60] Train Loss: 0.5668, Train AUC: 0.7878 | Val Loss: 0.8839, Val AUC: 0.4200
#   -> Validation AUC did not improve. (1/15)
# Epoch [24/60] Train Loss: 0.5471, Train AUC: 0.7958 | Val Loss: 0.9138, Val AUC: 0.4100
#   -> Validation AUC did not improve. (2/15)
# Epoch [25/60] Train Loss: 0.5326, Train AUC: 0.8043 | Val Loss: 0.8937, Val AUC: 0.4300
#   -> New best validation AUC: 0.4300
# Epoch [26/60] Train Loss: 0.5533, Train AUC: 0.8195 | Val Loss: 0.9248, Val AUC: 0.4050
#   -> Validation AUC did not improve. (1/15)
# Epoch [27/60] Train Loss: 0.5152, Train AUC: 0.8324 | Val Loss: 0.9123, Val AUC: 0.4450
#   -> New best validation AUC: 0.4450
# Epoch [28/60] Train Loss: 0.4953, Train AUC: 0.8442 | Val Loss: 0.9334, Val AUC: 0.4250
#   -> Validation AUC did not improve. (1/15)
# Epoch [29/60] Train Loss: 0.4813, Train AUC: 0.8506 | Val Loss: 0.9622, Val AUC: 0.4100
#   -> Validation AUC did not improve. (2/15)
# Epoch [30/60] Train Loss: 0.4593, Train AUC: 0.8594 | Val Loss: 0.9742, Val AUC: 0.4250
#   -> Validation AUC did not improve. (3/15)
# Epoch [31/60] Train Loss: 0.4460, Train AUC: 0.8709 | Val Loss: 0.9949, Val AUC: 0.4600
#   -> New best validation AUC: 0.4600
# Epoch [32/60] Train Loss: 0.4652, Train AUC: 0.8823 | Val Loss: 1.0295, Val AUC: 0.4550
#   -> Validation AUC did not improve. (1/15)
# Epoch [33/60] Train Loss: 0.4224, Train AUC: 0.8859 | Val Loss: 1.0187, Val AUC: 0.4700
#   -> New best validation AUC: 0.4700
# Epoch [34/60] Train Loss: 0.4063, Train AUC: 0.9133 | Val Loss: 0.9832, Val AUC: 0.4550
#   -> Validation AUC did not improve. (1/15)
# Epoch [35/60] Train Loss: 0.4303, Train AUC: 0.9026 | Val Loss: 1.0122, Val AUC: 0.4700
#   -> New best validation AUC: 0.4700
# Epoch [36/60] Train Loss: 0.4037, Train AUC: 0.9159 | Val Loss: 1.0585, Val AUC: 0.4500
#   -> Validation AUC did not improve. (1/15)
# Epoch [37/60] Train Loss: 0.3838, Train AUC: 0.9362 | Val Loss: 1.0813, Val AUC: 0.4300
#   -> Validation AUC did not improve. (2/15)
# Epoch [38/60] Train Loss: 0.3550, Train AUC: 0.9360 | Val Loss: 1.0515, Val AUC: 0.4300
#   -> Validation AUC did not improve. (3/15)
# Epoch [39/60] Train Loss: 0.3525, Train AUC: 0.9393 | Val Loss: 1.0693, Val AUC: 0.4400
#   -> Validation AUC did not improve. (4/15)
# Epoch [40/60] Train Loss: 0.3348, Train AUC: 0.9518 | Val Loss: 1.1513, Val AUC: 0.4550
#   -> Validation AUC did not improve. (5/15)
# Epoch [41/60] Train Loss: 0.2917, Train AUC: 0.9615 | Val Loss: 1.1415, Val AUC: 0.4550
#   -> Validation AUC did not improve. (6/15)
# Epoch [42/60] Train Loss: 0.2909, Train AUC: 0.9556 | Val Loss: 1.1019, Val AUC: 0.4850
#   -> New best validation AUC: 0.4850
# Epoch [43/60] Train Loss: 0.2808, Train AUC: 0.9628 | Val Loss: 1.1444, Val AUC: 0.4750
#   -> Validation AUC did not improve. (1/15)
# Epoch [44/60] Train Loss: 0.2425, Train AUC: 0.9729 | Val Loss: 1.2322, Val AUC: 0.4700
#   -> Validation AUC did not improve. (2/15)
# Epoch [45/60] Train Loss: 0.2407, Train AUC: 0.9740 | Val Loss: 1.2295, Val AUC: 0.4800
#   -> Validation AUC did not improve. (3/15)
# Epoch [46/60] Train Loss: 0.2193, Train AUC: 0.9782 | Val Loss: 1.2045, Val AUC: 0.5050
#   -> New best validation AUC: 0.5050
# Epoch [47/60] Train Loss: 0.1923, Train AUC: 0.9841 | Val Loss: 1.2537, Val AUC: 0.4900
#   -> Validation AUC did not improve. (1/15)
# Epoch [48/60] Train Loss: 0.2034, Train AUC: 0.9846 | Val Loss: 1.3704, Val AUC: 0.5050
#   -> Validation AUC did not improve. (2/15)
# Epoch [49/60] Train Loss: 0.1727, Train AUC: 0.9867 | Val Loss: 1.3412, Val AUC: 0.5100
#   -> New best validation AUC: 0.5100
# Epoch [50/60] Train Loss: 0.1547, Train AUC: 0.9865 | Val Loss: 1.4353, Val AUC: 0.4600
#   -> Validation AUC did not improve. (1/15)
# Epoch [51/60] Train Loss: 0.1647, Train AUC: 0.9894 | Val Loss: 1.4644, Val AUC: 0.4950
#   -> Validation AUC did not improve. (2/15)
# Epoch [52/60] Train Loss: 0.1317, Train AUC: 0.9871 | Val Loss: 1.4544, Val AUC: 0.4800
#   -> Validation AUC did not improve. (3/15)
# Epoch [53/60] Train Loss: 0.1381, Train AUC: 0.9924 | Val Loss: 1.6042, Val AUC: 0.4700
#   -> Validation AUC did not improve. (4/15)
# Epoch [54/60] Train Loss: 0.1110, Train AUC: 0.9918 | Val Loss: 1.6668, Val AUC: 0.4550
#   -> Validation AUC did not improve. (5/15)
# Epoch [55/60] Train Loss: 0.1782, Train AUC: 0.9911 | Val Loss: 1.5314, Val AUC: 0.5150
#   -> New best validation AUC: 0.5150
# Epoch [56/60] Train Loss: 0.1130, Train AUC: 0.9941 | Val Loss: 1.5258, Val AUC: 0.5300
#   -> New best validation AUC: 0.5300
# Epoch [57/60] Train Loss: 0.0987, Train AUC: 0.9970 | Val Loss: 1.6489, Val AUC: 0.5100
#   -> Validation AUC did not improve. (1/15)
# Epoch [58/60] Train Loss: 0.0956, Train AUC: 0.9953 | Val Loss: 1.5579, Val AUC: 0.5450
#   -> New best validation AUC: 0.5450
# Epoch [59/60] Train Loss: 0.0767, Train AUC: 0.9992 | Val Loss: 1.4775, Val AUC: 0.5650
#   -> New best validation AUC: 0.5650
# Epoch [60/60] Train Loss: 0.0891, Train AUC: 0.9983 | Val Loss: 1.5580, Val AUC: 0.5300
#   -> Validation AUC did not improve. (1/15)
# Finished training. Loading best model with Val AUC: 0.5650
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=1, process=mixed, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6596, Train AUC: 0.7308 | Val Loss: 0.6417, Val AUC: 0.7593
#   -> New best validation AUC: 0.7593
# Epoch [2/60] Train Loss: 0.6210, Train AUC: 0.7579 | Val Loss: 0.6238, Val AUC: 0.7546
#   -> Validation AUC did not improve. (1/15)
# Epoch [3/60] Train Loss: 0.6016, Train AUC: 0.7649 | Val Loss: 0.6082, Val AUC: 0.7546
#   -> Validation AUC did not improve. (2/15)
# Epoch [4/60] Train Loss: 0.5895, Train AUC: 0.7792 | Val Loss: 0.5938, Val AUC: 0.7731
#   -> New best validation AUC: 0.7731
# Epoch [5/60] Train Loss: 0.5721, Train AUC: 0.7821 | Val Loss: 0.5763, Val AUC: 0.7778
#   -> New best validation AUC: 0.7778
# Epoch [6/60] Train Loss: 0.5482, Train AUC: 0.7911 | Val Loss: 0.5571, Val AUC: 0.7917
#   -> New best validation AUC: 0.7917
# Epoch [7/60] Train Loss: 0.5501, Train AUC: 0.7955 | Val Loss: 0.5384, Val AUC: 0.8148
#   -> New best validation AUC: 0.8148
# Epoch [8/60] Train Loss: 0.5668, Train AUC: 0.7988 | Val Loss: 0.5296, Val AUC: 0.8287
#   -> New best validation AUC: 0.8287
# Epoch [9/60] Train Loss: 0.5115, Train AUC: 0.8079 | Val Loss: 0.5065, Val AUC: 0.8333
#   -> New best validation AUC: 0.8333
# Epoch [10/60] Train Loss: 0.5144, Train AUC: 0.8168 | Val Loss: 0.5023, Val AUC: 0.8565
#   -> New best validation AUC: 0.8565
# Epoch [11/60] Train Loss: 0.5026, Train AUC: 0.8232 | Val Loss: 0.4906, Val AUC: 0.8426
#   -> Validation AUC did not improve. (1/15)
# Epoch [12/60] Train Loss: 0.5089, Train AUC: 0.8205 | Val Loss: 0.4861, Val AUC: 0.8519
#   -> Validation AUC did not improve. (2/15)
# Epoch [13/60] Train Loss: 0.5016, Train AUC: 0.8228 | Val Loss: 0.4894, Val AUC: 0.8426
#   -> Validation AUC did not improve. (3/15)
# Epoch [14/60] Train Loss: 0.4969, Train AUC: 0.8284 | Val Loss: 0.4846, Val AUC: 0.8657
#   -> New best validation AUC: 0.8657
# Epoch [15/60] Train Loss: 0.5191, Train AUC: 0.8325 | Val Loss: 0.4816, Val AUC: 0.8519
#   -> Validation AUC did not improve. (1/15)
# Epoch [16/60] Train Loss: 0.5034, Train AUC: 0.8319 | Val Loss: 0.4841, Val AUC: 0.8565
#   -> Validation AUC did not improve. (2/15)
# Epoch [17/60] Train Loss: 0.4824, Train AUC: 0.8408 | Val Loss: 0.4847, Val AUC: 0.8519
#   -> Validation AUC did not improve. (3/15)
# Epoch [18/60] Train Loss: 0.4797, Train AUC: 0.8408 | Val Loss: 0.4866, Val AUC: 0.8472
#   -> Validation AUC did not improve. (4/15)
# Epoch [19/60] Train Loss: 0.4601, Train AUC: 0.8488 | Val Loss: 0.4895, Val AUC: 0.8426
#   -> Validation AUC did not improve. (5/15)
# Epoch [20/60] Train Loss: 0.5008, Train AUC: 0.8474 | Val Loss: 0.4992, Val AUC: 0.8241
#   -> Validation AUC did not improve. (6/15)
# Epoch [21/60] Train Loss: 0.4542, Train AUC: 0.8459 | Val Loss: 0.4904, Val AUC: 0.8287
#   -> Validation AUC did not improve. (7/15)
# Epoch [22/60] Train Loss: 0.4722, Train AUC: 0.8534 | Val Loss: 0.4982, Val AUC: 0.8287
#   -> Validation AUC did not improve. (8/15)
# Epoch [23/60] Train Loss: 0.4474, Train AUC: 0.8557 | Val Loss: 0.5049, Val AUC: 0.8241
#   -> Validation AUC did not improve. (9/15)
# Epoch [24/60] Train Loss: 0.5309, Train AUC: 0.8623 | Val Loss: 0.4947, Val AUC: 0.8148
#   -> Validation AUC did not improve. (10/15)
# Epoch [25/60] Train Loss: 0.4353, Train AUC: 0.8728 | Val Loss: 0.5092, Val AUC: 0.8194
#   -> Validation AUC did not improve. (11/15)
# Epoch [26/60] Train Loss: 0.4765, Train AUC: 0.8703 | Val Loss: 0.4941, Val AUC: 0.8287
#   -> Validation AUC did not improve. (12/15)
# Epoch [27/60] Train Loss: 0.4448, Train AUC: 0.8811 | Val Loss: 0.5118, Val AUC: 0.8287
#   -> Validation AUC did not improve. (13/15)
# Epoch [28/60] Train Loss: 0.4446, Train AUC: 0.8790 | Val Loss: 0.5131, Val AUC: 0.8148
#   -> Validation AUC did not improve. (14/15)
# Epoch [29/60] Train Loss: 0.4480, Train AUC: 0.8803 | Val Loss: 0.5103, Val AUC: 0.8148
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 29.
# Finished training. Loading best model with Val AUC: 0.8657
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=1, process=mixed, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.7098, Train AUC: 0.5124 | Val Loss: 0.6868, Val AUC: 0.4545
#   -> New best validation AUC: 0.4545
# Epoch [2/60] Train Loss: 0.6878, Train AUC: 0.6280 | Val Loss: 0.6618, Val AUC: 0.6316
#   -> New best validation AUC: 0.6316
# Epoch [3/60] Train Loss: 0.6463, Train AUC: 0.7177 | Val Loss: 0.6521, Val AUC: 0.7273
#   -> New best validation AUC: 0.7273
# Epoch [4/60] Train Loss: 0.6431, Train AUC: 0.7463 | Val Loss: 0.6480, Val AUC: 0.7368
#   -> New best validation AUC: 0.7368
# Epoch [5/60] Train Loss: 0.6231, Train AUC: 0.7552 | Val Loss: 0.6351, Val AUC: 0.7225
#   -> Validation AUC did not improve. (1/15)
# Epoch [6/60] Train Loss: 0.6127, Train AUC: 0.7667 | Val Loss: 0.6291, Val AUC: 0.7464
#   -> New best validation AUC: 0.7464
# Epoch [7/60] Train Loss: 0.5807, Train AUC: 0.7725 | Val Loss: 0.6315, Val AUC: 0.7416
#   -> Validation AUC did not improve. (1/15)
# Epoch [8/60] Train Loss: 0.5748, Train AUC: 0.7771 | Val Loss: 0.6215, Val AUC: 0.7560
#   -> New best validation AUC: 0.7560
# Epoch [9/60] Train Loss: 0.5980, Train AUC: 0.7678 | Val Loss: 0.6389, Val AUC: 0.7129
#   -> Validation AUC did not improve. (1/15)
# Epoch [10/60] Train Loss: 0.5579, Train AUC: 0.7785 | Val Loss: 0.6294, Val AUC: 0.7368
#   -> Validation AUC did not improve. (2/15)
# Epoch [11/60] Train Loss: 0.5630, Train AUC: 0.7829 | Val Loss: 0.6337, Val AUC: 0.7273
#   -> Validation AUC did not improve. (3/15)
# Epoch [12/60] Train Loss: 0.5586, Train AUC: 0.7862 | Val Loss: 0.6314, Val AUC: 0.7321
#   -> Validation AUC did not improve. (4/15)
# Epoch [13/60] Train Loss: 0.5490, Train AUC: 0.7990 | Val Loss: 0.6335, Val AUC: 0.7416
#   -> Validation AUC did not improve. (5/15)
# Epoch [14/60] Train Loss: 0.5484, Train AUC: 0.7943 | Val Loss: 0.6232, Val AUC: 0.7560
#   -> New best validation AUC: 0.7560
# Epoch [15/60] Train Loss: 0.5366, Train AUC: 0.8033 | Val Loss: 0.6282, Val AUC: 0.7416
#   -> Validation AUC did not improve. (1/15)
# Epoch [16/60] Train Loss: 0.5494, Train AUC: 0.8046 | Val Loss: 0.6337, Val AUC: 0.7560
#   -> Validation AUC did not improve. (2/15)
# Epoch [17/60] Train Loss: 0.5450, Train AUC: 0.8085 | Val Loss: 0.6419, Val AUC: 0.7416
#   -> Validation AUC did not improve. (3/15)
# Epoch [18/60] Train Loss: 0.5351, Train AUC: 0.8081 | Val Loss: 0.6420, Val AUC: 0.7512
#   -> Validation AUC did not improve. (4/15)
# Epoch [19/60] Train Loss: 0.5221, Train AUC: 0.8139 | Val Loss: 0.6475, Val AUC: 0.7512
#   -> Validation AUC did not improve. (5/15)
# Epoch [20/60] Train Loss: 0.5304, Train AUC: 0.8234 | Val Loss: 0.6423, Val AUC: 0.7512
#   -> Validation AUC did not improve. (6/15)
# Epoch [21/60] Train Loss: 0.5099, Train AUC: 0.8224 | Val Loss: 0.6536, Val AUC: 0.7512
#   -> Validation AUC did not improve. (7/15)
# Epoch [22/60] Train Loss: 0.5242, Train AUC: 0.8317 | Val Loss: 0.6599, Val AUC: 0.7368
#   -> Validation AUC did not improve. (8/15)
# Epoch [23/60] Train Loss: 0.4894, Train AUC: 0.8325 | Val Loss: 0.6517, Val AUC: 0.7512
#   -> Validation AUC did not improve. (9/15)
# Epoch [24/60] Train Loss: 0.4920, Train AUC: 0.8447 | Val Loss: 0.6528, Val AUC: 0.7560
#   -> Validation AUC did not improve. (10/15)
# Epoch [25/60] Train Loss: 0.4880, Train AUC: 0.8410 | Val Loss: 0.6446, Val AUC: 0.7416
#   -> Validation AUC did not improve. (11/15)
# Epoch [26/60] Train Loss: 0.5092, Train AUC: 0.8406 | Val Loss: 0.6351, Val AUC: 0.7560
#   -> Validation AUC did not improve. (12/15)
# Epoch [27/60] Train Loss: 0.4768, Train AUC: 0.8457 | Val Loss: 0.6213, Val AUC: 0.7512
#   -> Validation AUC did not improve. (13/15)
# Epoch [28/60] Train Loss: 0.4991, Train AUC: 0.8565 | Val Loss: 0.6255, Val AUC: 0.7608
#   -> New best validation AUC: 0.7608
# Epoch [29/60] Train Loss: 0.4589, Train AUC: 0.8681 | Val Loss: 0.6094, Val AUC: 0.7799
#   -> New best validation AUC: 0.7799
# Epoch [30/60] Train Loss: 0.4594, Train AUC: 0.8743 | Val Loss: 0.6265, Val AUC: 0.7608
#   -> Validation AUC did not improve. (1/15)
# Epoch [31/60] Train Loss: 0.4497, Train AUC: 0.8807 | Val Loss: 0.6367, Val AUC: 0.7703
#   -> Validation AUC did not improve. (2/15)
# Epoch [32/60] Train Loss: 0.4516, Train AUC: 0.8852 | Val Loss: 0.6572, Val AUC: 0.7512
#   -> Validation AUC did not improve. (3/15)
# Epoch [33/60] Train Loss: 0.4232, Train AUC: 0.8950 | Val Loss: 0.6465, Val AUC: 0.7703
#   -> Validation AUC did not improve. (4/15)
# Epoch [34/60] Train Loss: 0.4186, Train AUC: 0.8958 | Val Loss: 0.6964, Val AUC: 0.7225
#   -> Validation AUC did not improve. (5/15)
# Epoch [35/60] Train Loss: 0.4326, Train AUC: 0.8974 | Val Loss: 0.6873, Val AUC: 0.7273
#   -> Validation AUC did not improve. (6/15)
# Epoch [36/60] Train Loss: 0.4038, Train AUC: 0.9090 | Val Loss: 0.6671, Val AUC: 0.7416
#   -> Validation AUC did not improve. (7/15)
# Epoch [37/60] Train Loss: 0.3914, Train AUC: 0.9111 | Val Loss: 0.6634, Val AUC: 0.7273
#   -> Validation AUC did not improve. (8/15)
# Epoch [38/60] Train Loss: 0.4071, Train AUC: 0.9167 | Val Loss: 0.6650, Val AUC: 0.7321
#   -> Validation AUC did not improve. (9/15)
# Epoch [39/60] Train Loss: 0.3959, Train AUC: 0.9218 | Val Loss: 0.6082, Val AUC: 0.7703
#   -> Validation AUC did not improve. (10/15)
# Epoch [40/60] Train Loss: 0.3909, Train AUC: 0.9227 | Val Loss: 0.6146, Val AUC: 0.7608
#   -> Validation AUC did not improve. (11/15)
# Epoch [41/60] Train Loss: 0.3906, Train AUC: 0.9363 | Val Loss: 0.6247, Val AUC: 0.7560
#   -> Validation AUC did not improve. (12/15)
# Epoch [42/60] Train Loss: 0.3514, Train AUC: 0.9413 | Val Loss: 0.5996, Val AUC: 0.8038
#   -> New best validation AUC: 0.8038
# Epoch [43/60] Train Loss: 0.3488, Train AUC: 0.9460 | Val Loss: 0.6500, Val AUC: 0.7512
#   -> Validation AUC did not improve. (1/15)
# Epoch [44/60] Train Loss: 0.3113, Train AUC: 0.9524 | Val Loss: 0.6288, Val AUC: 0.7560
#   -> Validation AUC did not improve. (2/15)
# Epoch [45/60] Train Loss: 0.3070, Train AUC: 0.9551 | Val Loss: 0.6041, Val AUC: 0.7751
#   -> Validation AUC did not improve. (3/15)
# Epoch [46/60] Train Loss: 0.2861, Train AUC: 0.9605 | Val Loss: 0.6290, Val AUC: 0.7703
#   -> Validation AUC did not improve. (4/15)
# Epoch [47/60] Train Loss: 0.2826, Train AUC: 0.9663 | Val Loss: 0.6704, Val AUC: 0.7751
#   -> Validation AUC did not improve. (5/15)
# Epoch [48/60] Train Loss: 0.2616, Train AUC: 0.9696 | Val Loss: 0.6619, Val AUC: 0.7895
#   -> Validation AUC did not improve. (6/15)
# Epoch [49/60] Train Loss: 0.2766, Train AUC: 0.9702 | Val Loss: 0.5953, Val AUC: 0.7895
#   -> Validation AUC did not improve. (7/15)
# Epoch [50/60] Train Loss: 0.2432, Train AUC: 0.9799 | Val Loss: 0.6546, Val AUC: 0.7847
#   -> Validation AUC did not improve. (8/15)
# Epoch [51/60] Train Loss: 0.2515, Train AUC: 0.9808 | Val Loss: 0.6414, Val AUC: 0.7990
#   -> Validation AUC did not improve. (9/15)
# Epoch [52/60] Train Loss: 0.2140, Train AUC: 0.9903 | Val Loss: 0.6329, Val AUC: 0.7847
#   -> Validation AUC did not improve. (10/15)
# Epoch [53/60] Train Loss: 0.2039, Train AUC: 0.9911 | Val Loss: 0.6131, Val AUC: 0.8182
#   -> New best validation AUC: 0.8182
# Epoch [54/60] Train Loss: 0.1751, Train AUC: 0.9950 | Val Loss: 0.5341, Val AUC: 0.8230
#   -> New best validation AUC: 0.8230
# Epoch [55/60] Train Loss: 0.1583, Train AUC: 0.9969 | Val Loss: 0.6154, Val AUC: 0.7990
#   -> Validation AUC did not improve. (1/15)
# Epoch [56/60] Train Loss: 0.1606, Train AUC: 0.9936 | Val Loss: 0.7082, Val AUC: 0.7799
#   -> Validation AUC did not improve. (2/15)
# Epoch [57/60] Train Loss: 0.1428, Train AUC: 0.9983 | Val Loss: 0.6508, Val AUC: 0.7847
#   -> Validation AUC did not improve. (3/15)
# Epoch [58/60] Train Loss: 0.1355, Train AUC: 0.9986 | Val Loss: 0.6731, Val AUC: 0.7990
#   -> Validation AUC did not improve. (4/15)
# Epoch [59/60] Train Loss: 0.1363, Train AUC: 0.9979 | Val Loss: 0.7416, Val AUC: 0.7751
#   -> Validation AUC did not improve. (5/15)
# Epoch [60/60] Train Loss: 0.1206, Train AUC: 0.9981 | Val Loss: 0.8244, Val AUC: 0.7512
#   -> Validation AUC did not improve. (6/15)
# Finished training. Loading best model with Val AUC: 0.8230
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=p, process=homogeneous, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.7103, Train AUC: 0.4088 | Val Loss: 0.6893, Val AUC: 0.6750
#   -> New best validation AUC: 0.6750
# Epoch [2/60] Train Loss: 0.7004, Train AUC: 0.4439 | Val Loss: 0.6878, Val AUC: 0.6250
#   -> Validation AUC did not improve. (1/15)
# Epoch [3/60] Train Loss: 0.6948, Train AUC: 0.4804 | Val Loss: 0.6848, Val AUC: 0.6600
#   -> Validation AUC did not improve. (2/15)
# Epoch [4/60] Train Loss: 0.6912, Train AUC: 0.5085 | Val Loss: 0.6874, Val AUC: 0.6300
#   -> Validation AUC did not improve. (3/15)
# Epoch [5/60] Train Loss: 0.6914, Train AUC: 0.5348 | Val Loss: 0.6784, Val AUC: 0.7050
#   -> New best validation AUC: 0.7050
# Epoch [6/60] Train Loss: 0.6874, Train AUC: 0.5407 | Val Loss: 0.6821, Val AUC: 0.5900
#   -> Validation AUC did not improve. (1/15)
# Epoch [7/60] Train Loss: 0.6835, Train AUC: 0.5744 | Val Loss: 0.6840, Val AUC: 0.5800
#   -> Validation AUC did not improve. (2/15)
# Epoch [8/60] Train Loss: 0.6848, Train AUC: 0.5805 | Val Loss: 0.6859, Val AUC: 0.5000
#   -> Validation AUC did not improve. (3/15)
# Epoch [9/60] Train Loss: 0.6737, Train AUC: 0.6443 | Val Loss: 0.6827, Val AUC: 0.5400
#   -> Validation AUC did not improve. (4/15)
# Epoch [10/60] Train Loss: 0.6692, Train AUC: 0.6570 | Val Loss: 0.6824, Val AUC: 0.5300
#   -> Validation AUC did not improve. (5/15)
# Epoch [11/60] Train Loss: 0.6718, Train AUC: 0.6441 | Val Loss: 0.6836, Val AUC: 0.5150
#   -> Validation AUC did not improve. (6/15)
# Epoch [12/60] Train Loss: 0.6660, Train AUC: 0.6503 | Val Loss: 0.6800, Val AUC: 0.5200
#   -> Validation AUC did not improve. (7/15)
# Epoch [13/60] Train Loss: 0.6672, Train AUC: 0.6747 | Val Loss: 0.6817, Val AUC: 0.5050
#   -> Validation AUC did not improve. (8/15)
# Epoch [14/60] Train Loss: 0.6631, Train AUC: 0.6808 | Val Loss: 0.6809, Val AUC: 0.4850
#   -> Validation AUC did not improve. (9/15)
# Epoch [15/60] Train Loss: 0.6597, Train AUC: 0.6724 | Val Loss: 0.6855, Val AUC: 0.4900
#   -> Validation AUC did not improve. (10/15)
# Epoch [16/60] Train Loss: 0.6582, Train AUC: 0.6757 | Val Loss: 0.6876, Val AUC: 0.4850
#   -> Validation AUC did not improve. (11/15)
# Epoch [17/60] Train Loss: 0.6613, Train AUC: 0.6909 | Val Loss: 0.6859, Val AUC: 0.5100
#   -> Validation AUC did not improve. (12/15)
# Epoch [18/60] Train Loss: 0.6499, Train AUC: 0.6903 | Val Loss: 0.6922, Val AUC: 0.4750
#   -> Validation AUC did not improve. (13/15)
# Epoch [19/60] Train Loss: 0.6531, Train AUC: 0.6829 | Val Loss: 0.6897, Val AUC: 0.4800
#   -> Validation AUC did not improve. (14/15)
# Epoch [20/60] Train Loss: 0.6467, Train AUC: 0.6976 | Val Loss: 0.6970, Val AUC: 0.4750
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 20.
# Finished training. Loading best model with Val AUC: 0.7050
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=p, process=homogeneous, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6967, Train AUC: 0.5429 | Val Loss: 0.6882, Val AUC: 0.5893
#   -> New best validation AUC: 0.5893
# Epoch [2/60] Train Loss: 0.6866, Train AUC: 0.5783 | Val Loss: 0.6860, Val AUC: 0.5446
#   -> Validation AUC did not improve. (1/15)
# Epoch [3/60] Train Loss: 0.6786, Train AUC: 0.6103 | Val Loss: 0.6895, Val AUC: 0.5089
#   -> Validation AUC did not improve. (2/15)
# Epoch [4/60] Train Loss: 0.6716, Train AUC: 0.6418 | Val Loss: 0.6899, Val AUC: 0.5045
#   -> Validation AUC did not improve. (3/15)
# Epoch [5/60] Train Loss: 0.6688, Train AUC: 0.6696 | Val Loss: 0.6855, Val AUC: 0.5268
#   -> Validation AUC did not improve. (4/15)
# Epoch [6/60] Train Loss: 0.6703, Train AUC: 0.6626 | Val Loss: 0.6877, Val AUC: 0.4911
#   -> Validation AUC did not improve. (5/15)
# Epoch [7/60] Train Loss: 0.6493, Train AUC: 0.6979 | Val Loss: 0.6912, Val AUC: 0.5045
#   -> Validation AUC did not improve. (6/15)
# Epoch [8/60] Train Loss: 0.6482, Train AUC: 0.6981 | Val Loss: 0.6895, Val AUC: 0.5268
#   -> Validation AUC did not improve. (7/15)
# Epoch [9/60] Train Loss: 0.6492, Train AUC: 0.7031 | Val Loss: 0.6969, Val AUC: 0.5134
#   -> Validation AUC did not improve. (8/15)
# Epoch [10/60] Train Loss: 0.6307, Train AUC: 0.7184 | Val Loss: 0.6942, Val AUC: 0.5357
#   -> Validation AUC did not improve. (9/15)
# Epoch [11/60] Train Loss: 0.6518, Train AUC: 0.7190 | Val Loss: 0.7056, Val AUC: 0.5045
#   -> Validation AUC did not improve. (10/15)
# Epoch [12/60] Train Loss: 0.6264, Train AUC: 0.7236 | Val Loss: 0.7038, Val AUC: 0.5446
#   -> Validation AUC did not improve. (11/15)
# Epoch [13/60] Train Loss: 0.6234, Train AUC: 0.7346 | Val Loss: 0.7096, Val AUC: 0.5268
#   -> Validation AUC did not improve. (12/15)
# Epoch [14/60] Train Loss: 0.6185, Train AUC: 0.7356 | Val Loss: 0.7147, Val AUC: 0.5179
#   -> Validation AUC did not improve. (13/15)
# Epoch [15/60] Train Loss: 0.6005, Train AUC: 0.7342 | Val Loss: 0.7190, Val AUC: 0.5446
#   -> Validation AUC did not improve. (14/15)
# Epoch [16/60] Train Loss: 0.5962, Train AUC: 0.7433 | Val Loss: 0.7348, Val AUC: 0.5223
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 16.
# Finished training. Loading best model with Val AUC: 0.5893
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=p, process=mixed, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6967, Train AUC: 0.4908 | Val Loss: 0.6869, Val AUC: 0.5972
#   -> New best validation AUC: 0.5972
# Epoch [2/60] Train Loss: 0.6876, Train AUC: 0.5709 | Val Loss: 0.6766, Val AUC: 0.5972
#   -> Validation AUC did not improve. (1/15)
# Epoch [3/60] Train Loss: 0.6812, Train AUC: 0.6140 | Val Loss: 0.6634, Val AUC: 0.6759
#   -> New best validation AUC: 0.6759
# Epoch [4/60] Train Loss: 0.6775, Train AUC: 0.6193 | Val Loss: 0.6616, Val AUC: 0.6574
#   -> Validation AUC did not improve. (1/15)
# Epoch [5/60] Train Loss: 0.6646, Train AUC: 0.6479 | Val Loss: 0.6550, Val AUC: 0.7130
#   -> New best validation AUC: 0.7130
# Epoch [6/60] Train Loss: 0.6657, Train AUC: 0.6319 | Val Loss: 0.6514, Val AUC: 0.6991
#   -> Validation AUC did not improve. (1/15)
# Epoch [7/60] Train Loss: 0.6582, Train AUC: 0.6569 | Val Loss: 0.6518, Val AUC: 0.6435
#   -> Validation AUC did not improve. (2/15)
# Epoch [8/60] Train Loss: 0.6590, Train AUC: 0.6646 | Val Loss: 0.6394, Val AUC: 0.7037
#   -> Validation AUC did not improve. (3/15)
# Epoch [9/60] Train Loss: 0.6530, Train AUC: 0.6695 | Val Loss: 0.6383, Val AUC: 0.6944
#   -> Validation AUC did not improve. (4/15)
# Epoch [10/60] Train Loss: 0.6463, Train AUC: 0.6695 | Val Loss: 0.6330, Val AUC: 0.6991
#   -> Validation AUC did not improve. (5/15)
# Epoch [11/60] Train Loss: 0.6416, Train AUC: 0.6855 | Val Loss: 0.6312, Val AUC: 0.7222
#   -> New best validation AUC: 0.7222
# Epoch [12/60] Train Loss: 0.6325, Train AUC: 0.6893 | Val Loss: 0.6299, Val AUC: 0.6759
#   -> Validation AUC did not improve. (1/15)
# Epoch [13/60] Train Loss: 0.6443, Train AUC: 0.6816 | Val Loss: 0.6338, Val AUC: 0.6991
#   -> Validation AUC did not improve. (2/15)
# Epoch [14/60] Train Loss: 0.6439, Train AUC: 0.6920 | Val Loss: 0.6199, Val AUC: 0.7269
#   -> New best validation AUC: 0.7269
# Epoch [15/60] Train Loss: 0.6371, Train AUC: 0.7006 | Val Loss: 0.6288, Val AUC: 0.6991
#   -> Validation AUC did not improve. (1/15)
# Epoch [16/60] Train Loss: 0.6188, Train AUC: 0.6973 | Val Loss: 0.6264, Val AUC: 0.6991
#   -> Validation AUC did not improve. (2/15)
# Epoch [17/60] Train Loss: 0.6333, Train AUC: 0.7120 | Val Loss: 0.6246, Val AUC: 0.6944
#   -> Validation AUC did not improve. (3/15)
# Epoch [18/60] Train Loss: 0.6236, Train AUC: 0.7089 | Val Loss: 0.6226, Val AUC: 0.6898
#   -> Validation AUC did not improve. (4/15)
# Epoch [19/60] Train Loss: 0.6321, Train AUC: 0.7183 | Val Loss: 0.6211, Val AUC: 0.6944
#   -> Validation AUC did not improve. (5/15)
# Epoch [20/60] Train Loss: 0.6221, Train AUC: 0.7237 | Val Loss: 0.6210, Val AUC: 0.7037
#   -> Validation AUC did not improve. (6/15)
# Epoch [21/60] Train Loss: 0.6148, Train AUC: 0.7294 | Val Loss: 0.6220, Val AUC: 0.7037
#   -> Validation AUC did not improve. (7/15)
# Epoch [22/60] Train Loss: 0.6042, Train AUC: 0.7326 | Val Loss: 0.6290, Val AUC: 0.6898
#   -> Validation AUC did not improve. (8/15)
# Epoch [23/60] Train Loss: 0.5999, Train AUC: 0.7384 | Val Loss: 0.6256, Val AUC: 0.6852
#   -> Validation AUC did not improve. (9/15)
# Epoch [24/60] Train Loss: 0.6165, Train AUC: 0.7382 | Val Loss: 0.6197, Val AUC: 0.7083
#   -> Validation AUC did not improve. (10/15)
# Epoch [25/60] Train Loss: 0.5918, Train AUC: 0.7547 | Val Loss: 0.6250, Val AUC: 0.6944
#   -> Validation AUC did not improve. (11/15)
# Epoch [26/60] Train Loss: 0.5767, Train AUC: 0.7555 | Val Loss: 0.6267, Val AUC: 0.6898
#   -> Validation AUC did not improve. (12/15)
# Epoch [27/60] Train Loss: 0.5764, Train AUC: 0.7682 | Val Loss: 0.6320, Val AUC: 0.6806
#   -> Validation AUC did not improve. (13/15)
# Epoch [28/60] Train Loss: 0.5591, Train AUC: 0.7667 | Val Loss: 0.6158, Val AUC: 0.7037
#   -> Validation AUC did not improve. (14/15)
# Epoch [29/60] Train Loss: 0.5807, Train AUC: 0.7653 | Val Loss: 0.6296, Val AUC: 0.6898
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 29.
# Finished training. Loading best model with Val AUC: 0.7269
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=p, process=mixed, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6890, Train AUC: 0.5755 | Val Loss: 0.6646, Val AUC: 0.7828
#   -> New best validation AUC: 0.7828
# Epoch [2/60] Train Loss: 0.6822, Train AUC: 0.5923 | Val Loss: 0.6621, Val AUC: 0.7692
#   -> Validation AUC did not improve. (1/15)
# Epoch [3/60] Train Loss: 0.6730, Train AUC: 0.6281 | Val Loss: 0.6478, Val AUC: 0.7466
#   -> Validation AUC did not improve. (2/15)
# Epoch [4/60] Train Loss: 0.6765, Train AUC: 0.6273 | Val Loss: 0.6359, Val AUC: 0.7692
#   -> Validation AUC did not improve. (3/15)
# Epoch [5/60] Train Loss: 0.6697, Train AUC: 0.6435 | Val Loss: 0.6280, Val AUC: 0.7647
#   -> Validation AUC did not improve. (4/15)
# Epoch [6/60] Train Loss: 0.6714, Train AUC: 0.6400 | Val Loss: 0.6141, Val AUC: 0.8054
#   -> New best validation AUC: 0.8054
# Epoch [7/60] Train Loss: 0.6558, Train AUC: 0.6637 | Val Loss: 0.6102, Val AUC: 0.8009
#   -> Validation AUC did not improve. (1/15)
# Epoch [8/60] Train Loss: 0.6505, Train AUC: 0.6472 | Val Loss: 0.6006, Val AUC: 0.8100
#   -> New best validation AUC: 0.8100
# Epoch [9/60] Train Loss: 0.6624, Train AUC: 0.6565 | Val Loss: 0.5930, Val AUC: 0.8190
#   -> New best validation AUC: 0.8190
# Epoch [10/60] Train Loss: 0.6633, Train AUC: 0.6546 | Val Loss: 0.6003, Val AUC: 0.7919
#   -> Validation AUC did not improve. (1/15)
# Epoch [11/60] Train Loss: 0.6479, Train AUC: 0.6661 | Val Loss: 0.5973, Val AUC: 0.7964
#   -> Validation AUC did not improve. (2/15)
# Epoch [12/60] Train Loss: 0.6545, Train AUC: 0.6632 | Val Loss: 0.5913, Val AUC: 0.8054
#   -> Validation AUC did not improve. (3/15)
# Epoch [13/60] Train Loss: 0.6548, Train AUC: 0.6859 | Val Loss: 0.5920, Val AUC: 0.8054
#   -> Validation AUC did not improve. (4/15)
# Epoch [14/60] Train Loss: 0.6384, Train AUC: 0.6875 | Val Loss: 0.5884, Val AUC: 0.8054
#   -> Validation AUC did not improve. (5/15)
# Epoch [15/60] Train Loss: 0.6340, Train AUC: 0.6947 | Val Loss: 0.5817, Val AUC: 0.8281
#   -> New best validation AUC: 0.8281
# Epoch [16/60] Train Loss: 0.6284, Train AUC: 0.6861 | Val Loss: 0.5881, Val AUC: 0.7919
#   -> Validation AUC did not improve. (1/15)
# Epoch [17/60] Train Loss: 0.6368, Train AUC: 0.7089 | Val Loss: 0.5817, Val AUC: 0.8054
#   -> Validation AUC did not improve. (2/15)
# Epoch [18/60] Train Loss: 0.6503, Train AUC: 0.7017 | Val Loss: 0.5801, Val AUC: 0.8145
#   -> Validation AUC did not improve. (3/15)
# Epoch [19/60] Train Loss: 0.6280, Train AUC: 0.7064 | Val Loss: 0.5697, Val AUC: 0.8326
#   -> New best validation AUC: 0.8326
# Epoch [20/60] Train Loss: 0.6349, Train AUC: 0.7163 | Val Loss: 0.5728, Val AUC: 0.8100
#   -> Validation AUC did not improve. (1/15)
# Epoch [21/60] Train Loss: 0.6344, Train AUC: 0.7229 | Val Loss: 0.5674, Val AUC: 0.8235
#   -> Validation AUC did not improve. (2/15)
# Epoch [22/60] Train Loss: 0.6263, Train AUC: 0.7257 | Val Loss: 0.5697, Val AUC: 0.8235
#   -> Validation AUC did not improve. (3/15)
# Epoch [23/60] Train Loss: 0.6118, Train AUC: 0.7272 | Val Loss: 0.5684, Val AUC: 0.8009
#   -> Validation AUC did not improve. (4/15)
# Epoch [24/60] Train Loss: 0.6099, Train AUC: 0.7323 | Val Loss: 0.5625, Val AUC: 0.8235
#   -> Validation AUC did not improve. (5/15)
# Epoch [25/60] Train Loss: 0.6198, Train AUC: 0.7465 | Val Loss: 0.5572, Val AUC: 0.8507
#   -> New best validation AUC: 0.8507
# Epoch [26/60] Train Loss: 0.6210, Train AUC: 0.7410 | Val Loss: 0.5640, Val AUC: 0.8190
#   -> Validation AUC did not improve. (1/15)
# Epoch [27/60] Train Loss: 0.6064, Train AUC: 0.7516 | Val Loss: 0.5605, Val AUC: 0.8145
#   -> Validation AUC did not improve. (2/15)
# Epoch [28/60] Train Loss: 0.6273, Train AUC: 0.7580 | Val Loss: 0.5592, Val AUC: 0.8552
#   -> New best validation AUC: 0.8552
# Epoch [29/60] Train Loss: 0.6020, Train AUC: 0.7537 | Val Loss: 0.5658, Val AUC: 0.8326
#   -> Validation AUC did not improve. (1/15)
# Epoch [30/60] Train Loss: 0.5824, Train AUC: 0.7738 | Val Loss: 0.5545, Val AUC: 0.8371
#   -> Validation AUC did not improve. (2/15)
# Epoch [31/60] Train Loss: 0.5902, Train AUC: 0.7751 | Val Loss: 0.5547, Val AUC: 0.8371
#   -> Validation AUC did not improve. (3/15)
# Epoch [32/60] Train Loss: 0.5882, Train AUC: 0.7788 | Val Loss: 0.5522, Val AUC: 0.8281
#   -> Validation AUC did not improve. (4/15)
# Epoch [33/60] Train Loss: 0.5750, Train AUC: 0.7806 | Val Loss: 0.5526, Val AUC: 0.8190
#   -> Validation AUC did not improve. (5/15)
# Epoch [34/60] Train Loss: 0.5882, Train AUC: 0.7854 | Val Loss: 0.5400, Val AUC: 0.8326
#   -> Validation AUC did not improve. (6/15)
# Epoch [35/60] Train Loss: 0.5974, Train AUC: 0.7944 | Val Loss: 0.5527, Val AUC: 0.8190
#   -> Validation AUC did not improve. (7/15)
# Epoch [36/60] Train Loss: 0.5632, Train AUC: 0.8047 | Val Loss: 0.5326, Val AUC: 0.8462
#   -> Validation AUC did not improve. (8/15)
# Epoch [37/60] Train Loss: 0.5668, Train AUC: 0.8096 | Val Loss: 0.5473, Val AUC: 0.8235
#   -> Validation AUC did not improve. (9/15)
# Epoch [38/60] Train Loss: 0.5704, Train AUC: 0.8185 | Val Loss: 0.5330, Val AUC: 0.8462
#   -> Validation AUC did not improve. (10/15)
# Epoch [39/60] Train Loss: 0.5422, Train AUC: 0.8357 | Val Loss: 0.5380, Val AUC: 0.8371
#   -> Validation AUC did not improve. (11/15)
# Epoch [40/60] Train Loss: 0.5604, Train AUC: 0.8409 | Val Loss: 0.5379, Val AUC: 0.8326
#   -> Validation AUC did not improve. (12/15)
# Epoch [41/60] Train Loss: 0.5400, Train AUC: 0.8464 | Val Loss: 0.5376, Val AUC: 0.8190
#   -> Validation AUC did not improve. (13/15)
# Epoch [42/60] Train Loss: 0.5346, Train AUC: 0.8442 | Val Loss: 0.5321, Val AUC: 0.8507
#   -> Validation AUC did not improve. (14/15)
# Epoch [43/60] Train Loss: 0.5146, Train AUC: 0.8604 | Val Loss: 0.5247, Val AUC: 0.8462
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 43.
# Finished training. Loading best model with Val AUC: 0.8552
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=1, process=homogeneous, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6914, Train AUC: 0.4727 | Val Loss: 0.7001, Val AUC: 0.3937
#   -> New best validation AUC: 0.3937
# Epoch [2/60] Train Loss: 0.6855, Train AUC: 0.4969 | Val Loss: 0.7024, Val AUC: 0.2941
#   -> Validation AUC did not improve. (1/15)
# Epoch [3/60] Train Loss: 0.6894, Train AUC: 0.5066 | Val Loss: 0.7040, Val AUC: 0.2941
#   -> Validation AUC did not improve. (2/15)
# Epoch [4/60] Train Loss: 0.6807, Train AUC: 0.5542 | Val Loss: 0.7029, Val AUC: 0.3032
#   -> Validation AUC did not improve. (3/15)
# Epoch [5/60] Train Loss: 0.6790, Train AUC: 0.5918 | Val Loss: 0.7031, Val AUC: 0.3529
#   -> Validation AUC did not improve. (4/15)
# Epoch [6/60] Train Loss: 0.6711, Train AUC: 0.6185 | Val Loss: 0.7015, Val AUC: 0.3439
#   -> Validation AUC did not improve. (5/15)
# Epoch [7/60] Train Loss: 0.6771, Train AUC: 0.6137 | Val Loss: 0.7014, Val AUC: 0.3665
#   -> Validation AUC did not improve. (6/15)
# Epoch [8/60] Train Loss: 0.6691, Train AUC: 0.6313 | Val Loss: 0.7082, Val AUC: 0.3439
#   -> Validation AUC did not improve. (7/15)
# Epoch [9/60] Train Loss: 0.6688, Train AUC: 0.6385 | Val Loss: 0.7056, Val AUC: 0.3665
#   -> Validation AUC did not improve. (8/15)
# Epoch [10/60] Train Loss: 0.6654, Train AUC: 0.6609 | Val Loss: 0.7070, Val AUC: 0.3620
#   -> Validation AUC did not improve. (9/15)
# Epoch [11/60] Train Loss: 0.6648, Train AUC: 0.6720 | Val Loss: 0.7094, Val AUC: 0.3710
#   -> Validation AUC did not improve. (10/15)
# Epoch [12/60] Train Loss: 0.6679, Train AUC: 0.6789 | Val Loss: 0.7125, Val AUC: 0.3484
#   -> Validation AUC did not improve. (11/15)
# Epoch [13/60] Train Loss: 0.6657, Train AUC: 0.6785 | Val Loss: 0.7094, Val AUC: 0.3801
#   -> Validation AUC did not improve. (12/15)
# Epoch [14/60] Train Loss: 0.6482, Train AUC: 0.6983 | Val Loss: 0.7180, Val AUC: 0.3620
#   -> Validation AUC did not improve. (13/15)
# Epoch [15/60] Train Loss: 0.6605, Train AUC: 0.6933 | Val Loss: 0.7184, Val AUC: 0.3575
#   -> Validation AUC did not improve. (14/15)
# Epoch [16/60] Train Loss: 0.6532, Train AUC: 0.6944 | Val Loss: 0.7243, Val AUC: 0.3620
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 16.
# Finished training. Loading best model with Val AUC: 0.3937
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=1, process=homogeneous, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6965, Train AUC: 0.5688 | Val Loss: 0.6947, Val AUC: 0.5244
#   -> New best validation AUC: 0.5244
# Epoch [2/60] Train Loss: 0.6855, Train AUC: 0.6050 | Val Loss: 0.6950, Val AUC: 0.5244
#   -> Validation AUC did not improve. (1/15)
# Epoch [3/60] Train Loss: 0.6819, Train AUC: 0.6083 | Val Loss: 0.6994, Val AUC: 0.5022
#   -> Validation AUC did not improve. (2/15)
# Epoch [4/60] Train Loss: 0.6707, Train AUC: 0.6212 | Val Loss: 0.7014, Val AUC: 0.4978
#   -> Validation AUC did not improve. (3/15)
# Epoch [5/60] Train Loss: 0.6707, Train AUC: 0.6441 | Val Loss: 0.7055, Val AUC: 0.4889
#   -> Validation AUC did not improve. (4/15)
# Epoch [6/60] Train Loss: 0.6677, Train AUC: 0.6505 | Val Loss: 0.7074, Val AUC: 0.4756
#   -> Validation AUC did not improve. (5/15)
# Epoch [7/60] Train Loss: 0.6607, Train AUC: 0.6597 | Val Loss: 0.7177, Val AUC: 0.4489
#   -> Validation AUC did not improve. (6/15)
# Epoch [8/60] Train Loss: 0.6572, Train AUC: 0.6638 | Val Loss: 0.7215, Val AUC: 0.4578
#   -> Validation AUC did not improve. (7/15)
# Epoch [9/60] Train Loss: 0.6548, Train AUC: 0.6710 | Val Loss: 0.7278, Val AUC: 0.4578
#   -> Validation AUC did not improve. (8/15)
# Epoch [10/60] Train Loss: 0.6678, Train AUC: 0.6810 | Val Loss: 0.7289, Val AUC: 0.4756
#   -> Validation AUC did not improve. (9/15)
# Epoch [11/60] Train Loss: 0.6555, Train AUC: 0.6859 | Val Loss: 0.7316, Val AUC: 0.4667
#   -> Validation AUC did not improve. (10/15)
# Epoch [12/60] Train Loss: 0.6573, Train AUC: 0.6900 | Val Loss: 0.7384, Val AUC: 0.4711
#   -> Validation AUC did not improve. (11/15)
# Epoch [13/60] Train Loss: 0.6437, Train AUC: 0.6890 | Val Loss: 0.7366, Val AUC: 0.4889
#   -> Validation AUC did not improve. (12/15)
# Epoch [14/60] Train Loss: 0.6607, Train AUC: 0.6953 | Val Loss: 0.7419, Val AUC: 0.4711
#   -> Validation AUC did not improve. (13/15)
# Epoch [15/60] Train Loss: 0.6641, Train AUC: 0.7005 | Val Loss: 0.7430, Val AUC: 0.4756
#   -> Validation AUC did not improve. (14/15)
# Epoch [16/60] Train Loss: 0.6385, Train AUC: 0.7031 | Val Loss: 0.7477, Val AUC: 0.4667
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 16.
# Finished training. Loading best model with Val AUC: 0.5244
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=1, process=mixed, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.7377, Train AUC: 0.4008 | Val Loss: 0.7384, Val AUC: 0.3795
#   -> New best validation AUC: 0.3795
# Epoch [2/60] Train Loss: 0.7082, Train AUC: 0.4735 | Val Loss: 0.7209, Val AUC: 0.4330
#   -> New best validation AUC: 0.4330
# Epoch [3/60] Train Loss: 0.6895, Train AUC: 0.5763 | Val Loss: 0.6992, Val AUC: 0.5000
#   -> New best validation AUC: 0.5000
# Epoch [4/60] Train Loss: 0.6601, Train AUC: 0.6541 | Val Loss: 0.6886, Val AUC: 0.5625
#   -> New best validation AUC: 0.5625
# Epoch [5/60] Train Loss: 0.6602, Train AUC: 0.6924 | Val Loss: 0.6770, Val AUC: 0.6250
#   -> New best validation AUC: 0.6250
# Epoch [6/60] Train Loss: 0.6437, Train AUC: 0.6980 | Val Loss: 0.6624, Val AUC: 0.6607
#   -> New best validation AUC: 0.6607
# Epoch [7/60] Train Loss: 0.6360, Train AUC: 0.7155 | Val Loss: 0.6598, Val AUC: 0.6518
#   -> Validation AUC did not improve. (1/15)
# Epoch [8/60] Train Loss: 0.6194, Train AUC: 0.7316 | Val Loss: 0.6494, Val AUC: 0.6786
#   -> New best validation AUC: 0.6786
# Epoch [9/60] Train Loss: 0.6393, Train AUC: 0.7433 | Val Loss: 0.6598, Val AUC: 0.6562
#   -> Validation AUC did not improve. (1/15)
# Epoch [10/60] Train Loss: 0.6336, Train AUC: 0.7394 | Val Loss: 0.6562, Val AUC: 0.6562
#   -> Validation AUC did not improve. (2/15)
# Epoch [11/60] Train Loss: 0.6096, Train AUC: 0.7478 | Val Loss: 0.6527, Val AUC: 0.6562
#   -> Validation AUC did not improve. (3/15)
# Epoch [12/60] Train Loss: 0.6041, Train AUC: 0.7516 | Val Loss: 0.6395, Val AUC: 0.6964
#   -> New best validation AUC: 0.6964
# Epoch [13/60] Train Loss: 0.5947, Train AUC: 0.7592 | Val Loss: 0.6524, Val AUC: 0.6562
#   -> Validation AUC did not improve. (1/15)
# Epoch [14/60] Train Loss: 0.6001, Train AUC: 0.7602 | Val Loss: 0.6368, Val AUC: 0.6920
#   -> Validation AUC did not improve. (2/15)
# Epoch [15/60] Train Loss: 0.5820, Train AUC: 0.7673 | Val Loss: 0.6479, Val AUC: 0.6696
#   -> Validation AUC did not improve. (3/15)
# Epoch [16/60] Train Loss: 0.5850, Train AUC: 0.7678 | Val Loss: 0.6464, Val AUC: 0.6786
#   -> Validation AUC did not improve. (4/15)
# Epoch [17/60] Train Loss: 0.5888, Train AUC: 0.7737 | Val Loss: 0.6431, Val AUC: 0.6830
#   -> Validation AUC did not improve. (5/15)
# Epoch [18/60] Train Loss: 0.5830, Train AUC: 0.7704 | Val Loss: 0.6559, Val AUC: 0.6562
#   -> Validation AUC did not improve. (6/15)
# Epoch [19/60] Train Loss: 0.5578, Train AUC: 0.7773 | Val Loss: 0.6556, Val AUC: 0.6696
#   -> Validation AUC did not improve. (7/15)
# Epoch [20/60] Train Loss: 0.5908, Train AUC: 0.7780 | Val Loss: 0.6544, Val AUC: 0.6652
#   -> Validation AUC did not improve. (8/15)
# Epoch [21/60] Train Loss: 0.5664, Train AUC: 0.7924 | Val Loss: 0.6606, Val AUC: 0.6652
#   -> Validation AUC did not improve. (9/15)
# Epoch [22/60] Train Loss: 0.5593, Train AUC: 0.7922 | Val Loss: 0.6430, Val AUC: 0.6920
#   -> Validation AUC did not improve. (10/15)
# Epoch [23/60] Train Loss: 0.5423, Train AUC: 0.8012 | Val Loss: 0.6480, Val AUC: 0.6964
#   -> New best validation AUC: 0.6964
# Epoch [24/60] Train Loss: 0.5411, Train AUC: 0.8051 | Val Loss: 0.6442, Val AUC: 0.6920
#   -> Validation AUC did not improve. (1/15)
# Epoch [25/60] Train Loss: 0.5348, Train AUC: 0.8180 | Val Loss: 0.6552, Val AUC: 0.6875
#   -> Validation AUC did not improve. (2/15)
# Epoch [26/60] Train Loss: 0.5397, Train AUC: 0.8124 | Val Loss: 0.6428, Val AUC: 0.6920
#   -> Validation AUC did not improve. (3/15)
# Epoch [27/60] Train Loss: 0.5400, Train AUC: 0.8151 | Val Loss: 0.6410, Val AUC: 0.7098
#   -> New best validation AUC: 0.7098
# Epoch [28/60] Train Loss: 0.5371, Train AUC: 0.8222 | Val Loss: 0.6600, Val AUC: 0.7009
#   -> Validation AUC did not improve. (1/15)
# Epoch [29/60] Train Loss: 0.5359, Train AUC: 0.8241 | Val Loss: 0.6492, Val AUC: 0.7054
#   -> Validation AUC did not improve. (2/15)
# Epoch [30/60] Train Loss: 0.5123, Train AUC: 0.8282 | Val Loss: 0.6559, Val AUC: 0.7098
#   -> Validation AUC did not improve. (3/15)
# Epoch [31/60] Train Loss: 0.4941, Train AUC: 0.8394 | Val Loss: 0.6494, Val AUC: 0.7098
#   -> Validation AUC did not improve. (4/15)
# Epoch [32/60] Train Loss: 0.5005, Train AUC: 0.8435 | Val Loss: 0.6506, Val AUC: 0.7321
# ...
# Epoch [3/60] Train Loss: 0.6756, Train AUC: 0.5894 | Val Loss: 0.6844, Val AUC: 0.5511
#   -> New best validation AUC: 0.5511
# Epoch [4/60] Train Loss: 0.6749, Train AUC: 0.5877 | Val Loss: 0.6851, Val AUC: 0.5418
#   -> Validation AUC did not improve. (1/15)
# Epoch [5/60] Train Loss: 0.6708, Train AUC: 0.6037 | Val Loss: 0.6867, Val AUC: 0.5335
#   -> Validation AUC did not improve. (2/15)
# Epoch [6/60] Train Loss: 0.6676, Train AUC: 0.6127 | Val Loss: 0.6898, Val AUC: 0.5250
#   -> Validation AUC did not improve. (3/15)
# Epoch [7/60] Train Loss: 0.6659, Train AUC: 0.6171 | Val Loss: 0.6915, Val AUC: 0.5262
#   -> Validation AUC did not improve. (4/15)
# Epoch [8/60] Train Loss: 0.6633, Train AUC: 0.6230 | Val Loss: 0.6891, Val AUC: 0.5337
#   -> Validation AUC did not improve. (5/15)
# Epoch [9/60] Train Loss: 0.6615, Train AUC: 0.6297 | Val Loss: 0.6921, Val AUC: 0.5260
#   -> Validation AUC did not improve. (6/15)
# Epoch [10/60] Train Loss: 0.6590, Train AUC: 0.6361 | Val Loss: 0.6958, Val AUC: 0.5189
#   -> Validation AUC did not improve. (7/15)
# Epoch [11/60] Train Loss: 0.6552, Train AUC: 0.6471 | Val Loss: 0.6917, Val AUC: 0.5287
#   -> Validation AUC did not improve. (8/15)
# Epoch [12/60] Train Loss: 0.6515, Train AUC: 0.6539 | Val Loss: 0.6920, Val AUC: 0.5328
#   -> Validation AUC did not improve. (9/15)
# Epoch [13/60] Train Loss: 0.6473, Train AUC: 0.6660 | Val Loss: 0.6959, Val AUC: 0.5244
#   -> Validation AUC did not improve. (10/15)
# Epoch [14/60] Train Loss: 0.6398, Train AUC: 0.6860 | Val Loss: 0.6881, Val AUC: 0.5450
#   -> Validation AUC did not improve. (11/15)
# Epoch [15/60] Train Loss: 0.6296, Train AUC: 0.7062 | Val Loss: 0.6993, Val AUC: 0.5475
#   -> Validation AUC did not improve. (12/15)
# Epoch [16/60] Train Loss: 0.6237, Train AUC: 0.7151 | Val Loss: 0.7012, Val AUC: 0.5387
#   -> Validation AUC did not improve. (13/15)
# Epoch [17/60] Train Loss: 0.6092, Train AUC: 0.7287 | Val Loss: 0.7029, Val AUC: 0.5509
#   -> Validation AUC did not improve. (14/15)
# Epoch [18/60] Train Loss: 0.5937, Train AUC: 0.7478 | Val Loss: 0.7129, Val AUC: 0.5382
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 18.
# Finished training. Loading best model with Val AUC: 0.5511
# ===================================================================
# Scenario => N=1000, reg=0.8, missing=0.4, sync=p, process=homogeneous, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.7005, Train AUC: 0.5030 | Val Loss: 0.7073, Val AUC: 0.4213
#   -> New best validation AUC: 0.4213
# Epoch [2/60] Train Loss: 0.6912, Train AUC: 0.5337 | Val Loss: 0.7049, Val AUC: 0.4232
#   -> New best validation AUC: 0.4232
# Epoch [3/60] Train Loss: 0.6872, Train AUC: 0.5523 | Val Loss: 0.7071, Val AUC: 0.4180
#   -> Validation AUC did not improve. (1/15)
# Epoch [4/60] Train Loss: 0.6848, Train AUC: 0.5646 | Val Loss: 0.7077, Val AUC: 0.4162
#   -> Validation AUC did not improve. (2/15)
# Epoch [5/60] Train Loss: 0.6819, Train AUC: 0.5837 | Val Loss: 0.7110, Val AUC: 0.4223
#   -> Validation AUC did not improve. (3/15)
# Epoch [6/60] Train Loss: 0.6806, Train AUC: 0.5874 | Val Loss: 0.7151, Val AUC: 0.4245
#   -> New best validation AUC: 0.4245
# Epoch [7/60] Train Loss: 0.6783, Train AUC: 0.5955 | Val Loss: 0.7193, Val AUC: 0.4105
#   -> Validation AUC did not improve. (1/15)
# Epoch [8/60] Train Loss: 0.6752, Train AUC: 0.6065 | Val Loss: 0.7210, Val AUC: 0.4211
#   -> Validation AUC did not improve. (2/15)
# Epoch [9/60] Train Loss: 0.6732, Train AUC: 0.6126 | Val Loss: 0.7265, Val AUC: 0.4053
#   -> Validation AUC did not improve. (3/15)
# Epoch [10/60] Train Loss: 0.6711, Train AUC: 0.6217 | Val Loss: 0.7304, Val AUC: 0.4055
#   -> Validation AUC did not improve. (4/15)
# Epoch [11/60] Train Loss: 0.6674, Train AUC: 0.6269 | Val Loss: 0.7333, Val AUC: 0.4184
#   -> Validation AUC did not improve. (5/15)
# Epoch [12/60] Train Loss: 0.6643, Train AUC: 0.6340 | Val Loss: 0.7358, Val AUC: 0.4175
#   -> Validation AUC did not improve. (6/15)
# Epoch [13/60] Train Loss: 0.6585, Train AUC: 0.6565 | Val Loss: 0.7395, Val AUC: 0.4155
#   -> Validation AUC did not improve. (7/15)
# Epoch [14/60] Train Loss: 0.6497, Train AUC: 0.6718 | Val Loss: 0.7483, Val AUC: 0.4234
#   -> Validation AUC did not improve. (8/15)
# Epoch [15/60] Train Loss: 0.6413, Train AUC: 0.6837 | Val Loss: 0.7574, Val AUC: 0.4324
#   -> New best validation AUC: 0.4324
# Epoch [16/60] Train Loss: 0.6357, Train AUC: 0.6920 | Val Loss: 0.7506, Val AUC: 0.4482
#   -> New best validation AUC: 0.4482
# Epoch [17/60] Train Loss: 0.6279, Train AUC: 0.7042 | Val Loss: 0.7566, Val AUC: 0.4648
#   -> New best validation AUC: 0.4648
# Epoch [18/60] Train Loss: 0.6178, Train AUC: 0.7182 | Val Loss: 0.7555, Val AUC: 0.4844
#   -> New best validation AUC: 0.4844
# Epoch [19/60] Train Loss: 0.6118, Train AUC: 0.7286 | Val Loss: 0.7650, Val AUC: 0.4679
#   -> Validation AUC did not improve. (1/15)
# Epoch [20/60] Train Loss: 0.6021, Train AUC: 0.7394 | Val Loss: 0.7633, Val AUC: 0.4986
#   -> New best validation AUC: 0.4986
# Epoch [21/60] Train Loss: 0.5915, Train AUC: 0.7561 | Val Loss: 0.7773, Val AUC: 0.4943
#   -> Validation AUC did not improve. (1/15)
# Epoch [22/60] Train Loss: 0.5772, Train AUC: 0.7690 | Val Loss: 0.7948, Val AUC: 0.4978
#   -> Validation AUC did not improve. (2/15)
# Epoch [23/60] Train Loss: 0.5681, Train AUC: 0.7807 | Val Loss: 0.8053, Val AUC: 0.5235
#   -> New best validation AUC: 0.5235
# Epoch [24/60] Train Loss: 0.5678, Train AUC: 0.7774 | Val Loss: 0.8035, Val AUC: 0.5126
#   -> Validation AUC did not improve. (1/15)
# Epoch [25/60] Train Loss: 0.5433, Train AUC: 0.8085 | Val Loss: 0.8011, Val AUC: 0.5158
#   -> Validation AUC did not improve. (2/15)
# Epoch [26/60] Train Loss: 0.5382, Train AUC: 0.8027 | Val Loss: 0.8475, Val AUC: 0.5052
#   -> Validation AUC did not improve. (3/15)
# Epoch [27/60] Train Loss: 0.5261, Train AUC: 0.8206 | Val Loss: 0.9013, Val AUC: 0.4828
#   -> Validation AUC did not improve. (4/15)
# Epoch [28/60] Train Loss: 0.5220, Train AUC: 0.8203 | Val Loss: 0.9120, Val AUC: 0.5346
#   -> New best validation AUC: 0.5346
# Epoch [29/60] Train Loss: 0.5247, Train AUC: 0.8199 | Val Loss: 0.8830, Val AUC: 0.4822
#   -> Validation AUC did not improve. (1/15)
# Epoch [30/60] Train Loss: 0.4910, Train AUC: 0.8486 | Val Loss: 0.9353, Val AUC: 0.4970
#   -> Validation AUC did not improve. (2/15)
# Epoch [31/60] Train Loss: 0.4814, Train AUC: 0.8512 | Val Loss: 0.9386, Val AUC: 0.5011
#   -> Validation AUC did not improve. (3/15)
# Epoch [32/60] Train Loss: 0.4657, Train AUC: 0.8624 | Val Loss: 0.9977, Val AUC: 0.4595
#   -> Validation AUC did not improve. (4/15)
# Epoch [33/60] Train Loss: 0.4947, Train AUC: 0.8406 | Val Loss: 1.0112, Val AUC: 0.4557
#   -> Validation AUC did not improve. (5/15)
# Epoch [34/60] Train Loss: 0.4587, Train AUC: 0.8692 | Val Loss: 1.0014, Val AUC: 0.4726
#   -> Validation AUC did not improve. (6/15)
# Epoch [35/60] Train Loss: 0.4439, Train AUC: 0.8781 | Val Loss: 1.0673, Val AUC: 0.4717
#   -> Validation AUC did not improve. (7/15)
# Epoch [36/60] Train Loss: 0.4246, Train AUC: 0.8902 | Val Loss: 1.0360, Val AUC: 0.4751
#   -> Validation AUC did not improve. (8/15)
# Epoch [37/60] Train Loss: 0.4158, Train AUC: 0.8947 | Val Loss: 1.1826, Val AUC: 0.4518
#   -> Validation AUC did not improve. (9/15)
# Epoch [38/60] Train Loss: 0.4046, Train AUC: 0.9025 | Val Loss: 1.1548, Val AUC: 0.4616
#   -> Validation AUC did not improve. (10/15)
# Epoch [39/60] Train Loss: 0.3930, Train AUC: 0.9070 | Val Loss: 1.1395, Val AUC: 0.4758
#   -> Validation AUC did not improve. (11/15)
# Epoch [40/60] Train Loss: 0.3827, Train AUC: 0.9122 | Val Loss: 1.1340, Val AUC: 0.4744
#   -> Validation AUC did not improve. (12/15)
# Epoch [41/60] Train Loss: 0.3614, Train AUC: 0.9234 | Val Loss: 1.1953, Val AUC: 0.4666
#   -> Validation AUC did not improve. (13/15)
# Epoch [42/60] Train Loss: 0.3516, Train AUC: 0.9269 | Val Loss: 1.3242, Val AUC: 0.4575
#   -> Validation AUC did not improve. (14/15)
# Epoch [43/60] Train Loss: 0.3549, Train AUC: 0.9264 | Val Loss: 1.3376, Val AUC: 0.4708
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 43.
# Finished training. Loading best model with Val AUC: 0.5346
# ===================================================================
# Scenario => N=1000, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6719, Train AUC: 0.6166 | Val Loss: 0.6596, Val AUC: 0.6454
#   -> New best validation AUC: 0.6454
# Epoch [2/60] Train Loss: 0.6648, Train AUC: 0.6340 | Val Loss: 0.6614, Val AUC: 0.6395
#   -> Validation AUC did not improve. (1/15)
# Epoch [3/60] Train Loss: 0.6592, Train AUC: 0.6449 | Val Loss: 0.6628, Val AUC: 0.6361
#   -> Validation AUC did not improve. (2/15)
# Epoch [4/60] Train Loss: 0.6579, Train AUC: 0.6482 | Val Loss: 0.6607, Val AUC: 0.6404
#   -> Validation AUC did not improve. (3/15)
# Epoch [5/60] Train Loss: 0.6567, Train AUC: 0.6490 | Val Loss: 0.6655, Val AUC: 0.6312
#   -> Validation AUC did not improve. (4/15)
# Epoch [6/60] Train Loss: 0.6542, Train AUC: 0.6537 | Val Loss: 0.6592, Val AUC: 0.6350
#   -> Validation AUC did not improve. (5/15)
# Epoch [7/60] Train Loss: 0.6547, Train AUC: 0.6526 | Val Loss: 0.6673, Val AUC: 0.6261
#   -> Validation AUC did not improve. (6/15)
# Epoch [8/60] Train Loss: 0.6539, Train AUC: 0.6548 | Val Loss: 0.6636, Val AUC: 0.6329
#   -> Validation AUC did not improve. (7/15)
# Epoch [9/60] Train Loss: 0.6502, Train AUC: 0.6611 | Val Loss: 0.6620, Val AUC: 0.6261
#   -> Validation AUC did not improve. (8/15)
# Epoch [10/60] Train Loss: 0.6483, Train AUC: 0.6654 | Val Loss: 0.6702, Val AUC: 0.6130
#   -> Validation AUC did not improve. (9/15)
# Epoch [11/60] Train Loss: 0.6449, Train AUC: 0.6733 | Val Loss: 0.6723, Val AUC: 0.6063
#   -> Validation AUC did not improve. (10/15)
# Epoch [12/60] Train Loss: 0.6438, Train AUC: 0.6744 | Val Loss: 0.6708, Val AUC: 0.6055
#   -> Validation AUC did not improve. (11/15)
# Epoch [13/60] Train Loss: 0.6415, Train AUC: 0.6786 | Val Loss: 0.6739, Val AUC: 0.5995
#   -> Validation AUC did not improve. (12/15)
# Epoch [14/60] Train Loss: 0.6387, Train AUC: 0.6822 | Val Loss: 0.6766, Val AUC: 0.5966
#   -> Validation AUC did not improve. (13/15)
# Epoch [15/60] Train Loss: 0.6409, Train AUC: 0.6793 | Val Loss: 0.6800, Val AUC: 0.5891
#   -> Validation AUC did not improve. (14/15)
# Epoch [16/60] Train Loss: 0.6347, Train AUC: 0.6889 | Val Loss: 0.6828, Val AUC: 0.5843
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 16.
# Finished training. Loading best model with Val AUC: 0.6454
# ===================================================================
# Scenario => N=1000, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6740, Train AUC: 0.6186 | Val Loss: 0.6616, Val AUC: 0.6346
#   -> New best validation AUC: 0.6346
# Epoch [2/60] Train Loss: 0.6490, Train AUC: 0.6721 | Val Loss: 0.6493, Val AUC: 0.6562
#   -> New best validation AUC: 0.6562
# Epoch [3/60] Train Loss: 0.6393, Train AUC: 0.6842 | Val Loss: 0.6516, Val AUC: 0.6543
#   -> Validation AUC did not improve. (1/15)
# Epoch [4/60] Train Loss: 0.6383, Train AUC: 0.6857 | Val Loss: 0.6506, Val AUC: 0.6584
#   -> New best validation AUC: 0.6584
# Epoch [5/60] Train Loss: 0.6374, Train AUC: 0.6867 | Val Loss: 0.6538, Val AUC: 0.6553
#   -> Validation AUC did not improve. (1/15)
# Epoch [6/60] Train Loss: 0.6360, Train AUC: 0.6913 | Val Loss: 0.6506, Val AUC: 0.6552
#   -> Validation AUC did not improve. (2/15)
# Epoch [7/60] Train Loss: 0.6317, Train AUC: 0.6952 | Val Loss: 0.6520, Val AUC: 0.6559
#   -> Validation AUC did not improve. (3/15)
# Epoch [8/60] Train Loss: 0.6306, Train AUC: 0.6984 | Val Loss: 0.6518, Val AUC: 0.6495
#   -> Validation AUC did not improve. (4/15)
# Epoch [9/60] Train Loss: 0.6282, Train AUC: 0.7020 | Val Loss: 0.6522, Val AUC: 0.6526
#   -> Validation AUC did not improve. (5/15)
# Epoch [10/60] Train Loss: 0.6232, Train AUC: 0.7076 | Val Loss: 0.6606, Val AUC: 0.6448
#   -> Validation AUC did not improve. (6/15)
# Epoch [11/60] Train Loss: 0.6230, Train AUC: 0.7098 | Val Loss: 0.6615, Val AUC: 0.6414
#   -> Validation AUC did not improve. (7/15)
# Epoch [12/60] Train Loss: 0.6195, Train AUC: 0.7152 | Val Loss: 0.6617, Val AUC: 0.6386
#   -> Validation AUC did not improve. (8/15)
# Epoch [13/60] Train Loss: 0.6173, Train AUC: 0.7192 | Val Loss: 0.6587, Val AUC: 0.6408
#   -> Validation AUC did not improve. (9/15)
# Epoch [14/60] Train Loss: 0.6130, Train AUC: 0.7249 | Val Loss: 0.6638, Val AUC: 0.6392
#   -> Validation AUC did not improve. (10/15)
# Epoch [15/60] Train Loss: 0.6106, Train AUC: 0.7284 | Val Loss: 0.6665, Val AUC: 0.6330
#   -> Validation AUC did not improve. (11/15)
# Epoch [16/60] Train Loss: 0.6075, Train AUC: 0.7321 | Val Loss: 0.6718, Val AUC: 0.6283
#   -> Validation AUC did not improve. (12/15)
# Epoch [17/60] Train Loss: 0.6055, Train AUC: 0.7347 | Val Loss: 0.6758, Val AUC: 0.6188
#   -> Validation AUC did not improve. (13/15)
# Epoch [18/60] Train Loss: 0.5962, Train AUC: 0.7486 | Val Loss: 0.6727, Val AUC: 0.6254
#   -> Validation AUC did not improve. (14/15)
# Epoch [19/60] Train Loss: 0.5944, Train AUC: 0.7516 | Val Loss: 0.6806, Val AUC: 0.6137
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 19.
# Finished training. Loading best model with Val AUC: 0.6584
#
# All scenarios completed in 67.64 minutes.
#
#        N  regularity  missing_prop sync_pattern process_type outcome_dep  \
# 0    200         0.2           0.1            1  homogeneous      direct
# 1    200         0.2           0.1            1  homogeneous      lagged
# 2    200         0.2           0.1            1        mixed      direct
# 3    200         0.2           0.1            1        mixed      lagged
# 4    200         0.2           0.1            p  homogeneous      direct
# ..   ...         ...           ...          ...          ...         ...
# 59  1000         0.8           0.4            1        mixed      lagged
# 60  1000         0.8           0.4            p  homogeneous      direct
# 61  1000         0.8           0.4            p  homogeneous      lagged
# 62  1000         0.8           0.4            p        mixed      direct
# 63  1000         0.8           0.4            p        mixed      lagged
#
#     test_loss       auc  accuracy  precision    recall        f1  runtime_sec  \
# 0         NaN  0.461538  0.433333   0.500000  0.235294  0.320000    22.830856
# 1         NaN  0.475556  0.500000   0.500000  0.466667  0.482759    39.825504
# 2         NaN  0.754630  0.766667   0.789474  0.833333  0.810811    22.871852
# 3         NaN  0.598214  0.633333   0.600000  0.642857  0.620690    39.430549
# 4         NaN  0.397321  0.500000   0.520000  0.812500  0.634146    17.632558
# ..        ...       ...       ...        ...       ...       ...          ...
# 59        NaN  0.764800  0.720000   0.714286  0.733333  0.723684   115.313655
# 60        NaN  0.539141  0.546667   0.564516  0.833333  0.673077    75.715583
# 61        NaN  0.497406  0.513333   0.566667  0.419753  0.482270   136.478236
# 62        NaN  0.605263  0.520000   0.526316  0.526316  0.526316    73.133549
# 63        NaN  0.629979  0.606667   0.607595  0.631579  0.619355    82.447644
#
#     mean_true_prob  prop_positive
# 0         0.565822          0.570
# 1         0.513261          0.540
# 2         0.574195          0.570
# 3         0.489164          0.515
# 4         0.504974          0.555
# ..             ...            ...
# 59        0.498998          0.496
# 60        0.546740          0.555
# 61        0.555736          0.536
# 62        0.505665          0.498
# 63        0.517566          0.519
#
# [64 rows x 15 columns]
#
# Results saved to grud_factorial_results_long.csv
