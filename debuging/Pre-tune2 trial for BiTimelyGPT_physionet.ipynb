# %% [markdown]
# # BiTimelyGPT for PhysioNet 2012 Challenge
#
# Pre-tune usage test

# %%
# import libraries
import os
import torch
import numpy as np
import pandas as pd
from torch import nn, optim
from sklearn.metrics import roc_auc_score, average_precision_score, roc_curve, auc
import matplotlib.pyplot as plt
import copy

# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# BiTimelyGPT to path
import sys
sys.path.append('/content/drive/MyDrive/BiTimelyGPT-main/BiTimelyGPT')
# Out:
# Mounted at /content/drive

# %%
# import BiTimelyGPT modules
from data.data_pipeline import physionet_data_pipeline
from models.BiTimelyGPT import BiTimelyGPT
from layers.heads import PretrainHead, ClfHead
from layers.optimization import get_linear_schedule_with_warmup, AdamW

# %%
# define paths to PhysioNet 2012 data in Google Drive
google_drive_folder = '/content/drive/MyDrive/physionet2012/'
set_a_directory = f"{google_drive_folder}/set-a"
set_b_directory = f"{google_drive_folder}/set-b"
set_c_directory = f"{google_drive_folder}/set-c"

outcomes_a_file = f"{set_a_directory}/Outcomes-a.txt"
outcomes_b_file = f"{set_b_directory}/Outcomes-b.txt"
outcomes_c_file = f"{set_c_directory}/Outcomes-c.txt"

# %%
# define PhysioNet configuration
class PhysioNetConfig:
    def __init__(self):
        # define standard features from PhysioNet
        self.feature_list = [
            'Albumin', 'ALP', 'ALT', 'AST', 'Bilirubin', 'BUN', 'Cholesterol',
            'Creatinine', 'DiasABP', 'FiO2', 'GCS', 'Glucose', 'HCO3', 'HCT',
            'HR', 'K', 'Lactate', 'Mg', 'MAP', 'MechVent', 'Na', 'NIDiasABP',
            'NIMAP', 'NISysABP', 'PaCO2', 'PaO2', 'pH', 'Platelets', 'RespRate',
            'SaO2', 'SysABP', 'Temp', 'TropI', 'TropT', 'Urine', 'WBC', 'Age',
            'Gender', 'Height', 'ICUType', 'Weight'
        ]

        # model parameters
        self.num_layers = 8
        self.num_heads = 4
        self.d_model = 144
        self.qk_dim = 144
        self.v_dim = 288
        self.ffn_proj_size = 576
        self.d_ff = 288
        self.dropout = 0.1
        self.n_output = len(self.feature_list)
        self.n_clf_output = 2


        # Pretraining parameters
        self.pretrain_batch_size = 128
        self.pretrain_learning_rate = 1e-4
        self.pretrain_epochs = 32
        self.pretrain_warmup_steps = 500

        # Fine-tuning parameters
        self.finetune_batch_size = 32
        self.finetune_learning_rate = 2e-4
        self.finetune_epochs = 128
        self.finetune_warmup_steps = 1000
        self.gradient_clip = 1.0

        # BiTimelyGPT specific
        self.use_bias_in_msr = False
        self.use_bias_in_mlp = True
        self.use_bias_in_msr_out = False
        self.use_default_gamma = False
        self.forward_impl = 'parallel'
        self.chunk_size = 12
        self.seq_len = 2880
        self.chunk_size = 60
        self.activation = 'gelu'
        self.head_type = 'clf'

        # GPU and optimization settings
        self.use_gpu = torch.cuda.is_available()
        self.use_grad_ckp = True
        self.use_grad_accum = True
        self.accum_steps = 2
        self.use_amp = False
        self.use_multi_gpu = False
        self.devices = '0'

        self.output_retentions = False

# init config
config = PhysioNetConfig()

# %%
# set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# random seeds
torch.manual_seed(42)
np.random.seed(42)

# init base model structure (head will be set later)
model = BiTimelyGPT(configs=config, head_type='pretrain').to(device) # Start with pretrain head
print("Initial model created with Pretrain head.")
# Out:
# Initial model created with Pretrain head.

# %%
# load training data
config.batch_size = config.pretrain_batch_size
train_data_path = set_a_directory
train_outcomes_path = outcomes_a_file
train_dataset, train_loader = physionet_data_pipeline(
    train_data_path,
    train_outcomes_path,
    config,
    split='train'
)

# load validation data
config.batch_size = config.finetune_batch_size # Val/Test use fine-tune batch size
val_data_path = set_b_directory
val_outcomes_path = outcomes_b_file
val_dataset, val_loader = physionet_data_pipeline(
    val_data_path,
    val_outcomes_path,
    config,
    split='val'
)

# load test data (set-c) for final metrics
test_data_path = set_c_directory
test_outcomes_path = outcomes_c_file
test_dataset, test_loader = physionet_data_pipeline(
    test_data_path,
    test_outcomes_path,
    config,
    split='test'
)

# %%
# setup optimizer and scheduler
print("--- Starting Pretraining Phase ---")

pretrain_optimizer = AdamW(
    model.parameters(),
    lr=config.pretrain_learning_rate,
    weight_decay=0.01
)

num_pretraining_steps = len(train_loader) * config.pretrain_epochs
pretrain_scheduler = get_linear_schedule_with_warmup(
   pretrain_optimizer,
   config.pretrain_warmup_steps,
   num_pretraining_steps
)


pretrain_criterion = nn.MSELoss() # loss function


# pretraining loop
for epoch in range(config.pretrain_epochs):
    model.train()
    pretrain_losses = []

    for i, batch_data in enumerate(train_loader):
        batch_x, _, attention_mask = [b.to(device) for b in batch_data]

        if i % config.accum_steps == 0:
            pretrain_optimizer.zero_grad()

        loss = model(batch_x, y=None,
                     retention_mask=attention_mask,
                     forward_impl=config.forward_impl,
                     chunk_size=config.chunk_size)

        if torch.isnan(loss):
             print(f"Warning: NaN loss encountered at pretrain epoch {epoch+1}, batch {i}. Skipping batch.")
             pretrain_optimizer.zero_grad()
             continue

        scaled_loss = loss / config.accum_steps
        scaled_loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), config.gradient_clip)

        if (i + 1) % config.accum_steps == 0 or (i + 1) == len(train_loader):
            pretrain_optimizer.step()
            pretrain_scheduler.step()

        pretrain_losses.append(loss.item())

    avg_pretrain_loss = np.mean(pretrain_losses)
    print(f'Pretrain Epoch {epoch+1}/{config.pretrain_epochs} -- Avg Loss: {avg_pretrain_loss:.4f}')

print("--- Pretraining Phase Complete ---")
# Out:
# --- Starting Pretraining Phase ---
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# Pretrain Epoch 1/32 -- Avg Loss: 71.2771
# Pretrain Epoch 2/32 -- Avg Loss: 70.9904
# Pretrain Epoch 3/32 -- Avg Loss: 69.9825
# Pretrain Epoch 4/32 -- Avg Loss: 67.5676
# Pretrain Epoch 5/32 -- Avg Loss: 64.4703
# Pretrain Epoch 6/32 -- Avg Loss: 59.9116
# Pretrain Epoch 7/32 -- Avg Loss: 55.8649
# Pretrain Epoch 8/32 -- Avg Loss: 50.5019
# Pretrain Epoch 9/32 -- Avg Loss: 46.3577
# Pretrain Epoch 10/32 -- Avg Loss: 44.3348
# Pretrain Epoch 11/32 -- Avg Loss: 42.1638
# Pretrain Epoch 12/32 -- Avg Loss: 40.9703
# Pretrain Epoch 13/32 -- Avg Loss: 40.9525
# Pretrain Epoch 14/32 -- Avg Loss: 39.8047
# Pretrain Epoch 15/32 -- Avg Loss: 39.4914
# Pretrain Epoch 16/32 -- Avg Loss: 40.3852
# Pretrain Epoch 17/32 -- Avg Loss: 40.9605
# Pretrain Epoch 18/32 -- Avg Loss: 41.4323
# Pretrain Epoch 19/32 -- Avg Loss: 42.0598
# Pretrain Epoch 20/32 -- Avg Loss: 40.8396
# Pretrain Epoch 21/32 -- Avg Loss: 41.2700
# Pretrain Epoch 22/32 -- Avg Loss: 42.3835
# Pretrain Epoch 23/32 -- Avg Loss: 42.2428
# Pretrain Epoch 24/32 -- Avg Loss: 41.7509
# Pretrain Epoch 25/32 -- Avg Loss: 42.2906
# Pretrain Epoch 26/32 -- Avg Loss: 42.9588
# Pretrain Epoch 27/32 -- Avg Loss: 43.7000
# Pretrain Epoch 28/32 -- Avg Loss: 43.7369
# Pretrain Epoch 29/32 -- Avg Loss: 43.6330
# Pretrain Epoch 30/32 -- Avg Loss: 43.7850
# Pretrain Epoch 31/32 -- Avg Loss: 44.0410
# Pretrain Epoch 32/32 -- Avg Loss: 43.2766
# --- Pretraining Phase Complete ---

# %%
# --- Switch to Fine-tuning ---
print("--- Switching to Fine-tuning Phase ---")
# Keep the pretrained weights, but replace the head
model.head = ClfHead(config.d_model, config.n_clf_output).to(device)
model.head_type = 'clf' # update model state
print(f"Model head switched to ClfHead for fine-tuning with {config.n_clf_output} outputs.")


# Fine-tuning optimizer setup
optimizer = AdamW(
   model.parameters(),
   lr=config.finetune_learning_rate,
   weight_decay=0.01
)

# Fine-tuning scheduler setup
num_finetune_steps = len(train_loader) * config.finetune_epochs
scheduler = get_linear_schedule_with_warmup(
   optimizer,
   config.finetune_warmup_steps,
   num_finetune_steps
)

criterion = nn.CrossEntropyLoss()
# Out:
# --- Switching to Fine-tuning Phase ---
# Model head switched to ClfHead for fine-tuning with 2 outputs.

# %%
# save paths for best model
best_model_path = os.path.join("best_model_bitimelygpt.pt")

criterion = nn.CrossEntropyLoss()  # loss function

# Track the best AUC
best_val_auc = 0.0

print("--- Starting Fine-tuning Training Loop ---")
for epoch in range(config.finetune_epochs):
    # ------------------
    # Training Phase
    # ------------------
    model.train()
    train_losses = []

    for i, batch_data in enumerate(train_loader):
        batch_x, batch_y, attention_mask = [b.to(device) for b in batch_data] # unpack batch data

        if i % config.accum_steps == 0:
            optimizer.zero_grad() # fine-tuning optimizer

        # --- Forward pass ---
        assert model.head_type == 'clf', "Model head_type should be 'clf' for fine-tuning"

        hidden_states = model.conv_subsampling(batch_x)[0]
        hidden_states = model.input_projection(hidden_states)

        # handle attention_mask subsampling
        if attention_mask.shape[1] > hidden_states.shape[1]:
            attention_mask = attention_mask[:, ::4]
            attention_mask = attention_mask[:, :hidden_states.shape[1]]

        # Pass through Retention Blocks
        for l, block in enumerate(model.blocks):
            block_outputs = block(
                hidden_states,
                retention_mask=attention_mask,
                forward_impl=config.forward_impl,
                chunk_size=config.chunk_size
            )
            hidden_states = block_outputs[0]
            if (l + 1) == model.n_layers:
                hidden_states_PTP = hidden_states

        # --- Classification Head ---
        X = model.ln_f(hidden_states_PTP) # final LayerNorm
        logits = model.head(X) # ClfHead

        # Calculate Classification Loss
        raw_loss = criterion(logits, batch_y)

        # Scale loss and backpropagate
        scaled_loss = raw_loss / config.accum_steps
        scaled_loss.backward()

        # Gradient Clipping
        torch.nn.utils.clip_grad_norm_(model.parameters(), config.gradient_clip)

        # Update weights
        if (i + 1) % config.accum_steps == 0 or (i + 1) == len(train_loader):
            optimizer.step() # fine-tuning optimizer
            scheduler.step() # fine-tuning scheduler

        train_losses.append(raw_loss.item())

    avg_train_loss = np.mean(train_losses)
    print(f'Fine-tune Epoch {epoch+1}/{config.finetune_epochs} -- Train Loss: {avg_train_loss:.4f}')

    # ------------------
    # Validation Phase
    # ------------------
    model.eval()
    val_losses = []

    # collect predicted probabilities & labels for AUC
    all_probs = []
    all_labels = []

    with torch.no_grad():
        for i, batch_data in enumerate(val_loader):
            batch_x, batch_y, attention_mask = [b.to(device) for b in batch_data]

            hidden_states = model.conv_subsampling(batch_x)[0]
            hidden_states = model.input_projection(hidden_states)

            if attention_mask.shape[1] > hidden_states.shape[1]:
                attention_mask = attention_mask[:, ::4]
                attention_mask = attention_mask[:, :hidden_states.shape[1]]

            for l, block in enumerate(model.blocks):
                block_outputs = block(
                    hidden_states,
                    retention_mask=attention_mask,
                    forward_impl=config.forward_impl,
                    chunk_size=config.chunk_size
                )
                hidden_states = block_outputs[0]
                if (l + 1) == model.n_layers:
                    hidden_states_PTP = hidden_states

            X_val = model.ln_f(hidden_states_PTP)
            logits_val = model.head(X_val)

            loss_val = criterion(logits_val, batch_y)
            val_losses.append(loss_val.item())

            # Probability of class=1 for AUC
            probs_val = torch.softmax(logits_val, dim=1)[:, 1]
            all_probs.extend(probs_val.detach().cpu().tolist())
            all_labels.extend(batch_y.detach().cpu().tolist())

    avg_val_loss = np.mean(val_losses)
    print(f'Fine-tune Epoch {epoch+1}/{config.finetune_epochs} -- Validation Loss: {avg_val_loss:.4f}')

    # Calculate AUC (skip if only one class in the batch)
    if len(np.unique(all_labels)) > 1:
        fpr, tpr, thresholds = roc_curve(all_labels, all_probs)
        roc_auc_val = auc(fpr, tpr)
        print(f"Validation AUC: {roc_auc_val:.4f}")
    else:
        print("Validation AUC calculation skipped: Only one class present in this validation set.")
        roc_auc_val = 0.0

    # Save best model by Validation AUC
    if epoch >= 0 and roc_auc_val > best_val_auc:
        best_val_auc = roc_auc_val
        best_val_metrics = {
            'auc': best_val_auc,
            'loss': avg_val_loss
        }
        torch.save({
            'model_state_dict': model.state_dict(),
            'config': config,
            'metrics': best_val_metrics
        }, best_model_path)
        print(f"==> Best fine-tuned model saved to {best_model_path} (AUC: {roc_auc_val:.4f})")
# Out:
# --- Starting Fine-tuning Training Loop ---
# Fine-tune Epoch 1/128 -- Train Loss: 0.7094
# Fine-tune Epoch 1/128 -- Validation Loss: 0.6907
# Validation AUC: 0.5523
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.5523)
# Fine-tune Epoch 2/128 -- Train Loss: 0.6739
# Fine-tune Epoch 2/128 -- Validation Loss: 0.6149
# Validation AUC: 0.5813
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.5813)
# Fine-tune Epoch 3/128 -- Train Loss: 0.5849
# Fine-tune Epoch 3/128 -- Validation Loss: 0.4952
# Validation AUC: 0.5763
# Fine-tune Epoch 4/128 -- Train Loss: 0.4618
# Fine-tune Epoch 4/128 -- Validation Loss: 0.4214
# Validation AUC: 0.5924
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.5924)
# Fine-tune Epoch 5/128 -- Train Loss: 0.4098
# Fine-tune Epoch 5/128 -- Validation Loss: 0.4147
# Validation AUC: 0.5978
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.5978)
# Fine-tune Epoch 6/128 -- Train Loss: 0.4031
# Fine-tune Epoch 6/128 -- Validation Loss: 0.4131
# Validation AUC: 0.5993
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.5993)
# Fine-tune Epoch 7/128 -- Train Loss: 0.4004
# Fine-tune Epoch 7/128 -- Validation Loss: 0.4078
# Validation AUC: 0.6120
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6120)
# Fine-tune Epoch 8/128 -- Train Loss: 0.4006
# Fine-tune Epoch 8/128 -- Validation Loss: 0.4066
# Validation AUC: 0.6176
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6176)
# Fine-tune Epoch 9/128 -- Train Loss: 0.3970
# Fine-tune Epoch 9/128 -- Validation Loss: 0.3997
# Validation AUC: 0.6322
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6322)
# Fine-tune Epoch 10/128 -- Train Loss: 0.3941
# Fine-tune Epoch 10/128 -- Validation Loss: 0.3971
# Validation AUC: 0.6428
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6428)
# Fine-tune Epoch 11/128 -- Train Loss: 0.3928
# Fine-tune Epoch 11/128 -- Validation Loss: 0.3936
# Validation AUC: 0.6502
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6502)
# Fine-tune Epoch 12/128 -- Train Loss: 0.3888
# Fine-tune Epoch 12/128 -- Validation Loss: 0.3978
# Validation AUC: 0.6615
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6615)
# Fine-tune Epoch 13/128 -- Train Loss: 0.3865
# Fine-tune Epoch 13/128 -- Validation Loss: 0.3862
# Validation AUC: 0.6737
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6737)
# Fine-tune Epoch 14/128 -- Train Loss: 0.3802
# Fine-tune Epoch 14/128 -- Validation Loss: 0.3937
# Validation AUC: 0.6716
# Fine-tune Epoch 15/128 -- Train Loss: 0.3777
# Fine-tune Epoch 15/128 -- Validation Loss: 0.3824
# Validation AUC: 0.6939
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6939)
# Fine-tune Epoch 16/128 -- Train Loss: 0.3749
# Fine-tune Epoch 16/128 -- Validation Loss: 0.3843
# Validation AUC: 0.7091
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7091)
# Fine-tune Epoch 17/128 -- Train Loss: 0.3717
# Fine-tune Epoch 17/128 -- Validation Loss: 0.3771
# Validation AUC: 0.7083
# Fine-tune Epoch 18/128 -- Train Loss: 0.3690
# Fine-tune Epoch 18/128 -- Validation Loss: 0.3822
# Validation AUC: 0.6919
# Fine-tune Epoch 19/128 -- Train Loss: 0.3753
# Fine-tune Epoch 19/128 -- Validation Loss: 0.3835
# Validation AUC: 0.7086
# Fine-tune Epoch 20/128 -- Train Loss: 0.3649
# Fine-tune Epoch 20/128 -- Validation Loss: 0.3814
# Validation AUC: 0.7101
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7101)
# Fine-tune Epoch 21/128 -- Train Loss: 0.3627
# Fine-tune Epoch 21/128 -- Validation Loss: 0.3744
# Validation AUC: 0.7148
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7148)
# Fine-tune Epoch 22/128 -- Train Loss: 0.3553
# Fine-tune Epoch 22/128 -- Validation Loss: 0.3776
# Validation AUC: 0.7204
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7204)
# Fine-tune Epoch 23/128 -- Train Loss: 0.3545
# Fine-tune Epoch 23/128 -- Validation Loss: 0.3774
# Validation AUC: 0.7320
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7320)
# Fine-tune Epoch 24/128 -- Train Loss: 0.3534
# Fine-tune Epoch 24/128 -- Validation Loss: 0.3688
# Validation AUC: 0.7328
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7328)
# Fine-tune Epoch 25/128 -- Train Loss: 0.3555
# Fine-tune Epoch 25/128 -- Validation Loss: 0.3791
# Validation AUC: 0.7240
# Fine-tune Epoch 26/128 -- Train Loss: 0.3472
# Fine-tune Epoch 26/128 -- Validation Loss: 0.3899
# Validation AUC: 0.6770
# Fine-tune Epoch 27/128 -- Train Loss: 0.3530
# Fine-tune Epoch 27/128 -- Validation Loss: 0.3664
# Validation AUC: 0.7417
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7417)
# Fine-tune Epoch 28/128 -- Train Loss: 0.3466
# Fine-tune Epoch 28/128 -- Validation Loss: 0.3627
# Validation AUC: 0.7472
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7472)
# Fine-tune Epoch 29/128 -- Train Loss: 0.3399
# Fine-tune Epoch 29/128 -- Validation Loss: 0.3592
# Validation AUC: 0.7527
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7527)
# Fine-tune Epoch 30/128 -- Train Loss: 0.3375
# Fine-tune Epoch 30/128 -- Validation Loss: 0.3673
# Validation AUC: 0.7336
# Fine-tune Epoch 31/128 -- Train Loss: 0.3374
# Fine-tune Epoch 31/128 -- Validation Loss: 0.3695
# Validation AUC: 0.7387
# Fine-tune Epoch 32/128 -- Train Loss: 0.3309
# Fine-tune Epoch 32/128 -- Validation Loss: 0.3788
# Validation AUC: 0.7152
# Fine-tune Epoch 33/128 -- Train Loss: 0.3337
# Fine-tune Epoch 33/128 -- Validation Loss: 0.3656
# Validation AUC: 0.7440
# Fine-tune Epoch 34/128 -- Train Loss: 0.3304
# Fine-tune Epoch 34/128 -- Validation Loss: 0.3711
# Validation AUC: 0.7442
# Fine-tune Epoch 35/128 -- Train Loss: 0.3314
# Fine-tune Epoch 35/128 -- Validation Loss: 0.3619
# Validation AUC: 0.7474
# Fine-tune Epoch 36/128 -- Train Loss: 0.3181
# Fine-tune Epoch 36/128 -- Validation Loss: 0.3906
# Validation AUC: 0.7050
# Fine-tune Epoch 37/128 -- Train Loss: 0.3314
# Fine-tune Epoch 37/128 -- Validation Loss: 0.3634
# Validation AUC: 0.7476
# Fine-tune Epoch 38/128 -- Train Loss: 0.3121
# Fine-tune Epoch 38/128 -- Validation Loss: 0.3714
# Validation AUC: 0.7447
# Fine-tune Epoch 39/128 -- Train Loss: 0.3056
# Fine-tune Epoch 39/128 -- Validation Loss: 0.3940
# Validation AUC: 0.7223
# Fine-tune Epoch 40/128 -- Train Loss: 0.2887
# Fine-tune Epoch 40/128 -- Validation Loss: 0.3965
# Validation AUC: 0.7195
# Fine-tune Epoch 41/128 -- Train Loss: 0.2849
# Fine-tune Epoch 41/128 -- Validation Loss: 0.3837
# Validation AUC: 0.7300
# Fine-tune Epoch 42/128 -- Train Loss: 0.2769
# Fine-tune Epoch 42/128 -- Validation Loss: 0.4128
# Validation AUC: 0.7149
# Fine-tune Epoch 43/128 -- Train Loss: 0.2677
# Fine-tune Epoch 43/128 -- Validation Loss: 0.4087
# Validation AUC: 0.7094
# Fine-tune Epoch 44/128 -- Train Loss: 0.2578
# Fine-tune Epoch 44/128 -- Validation Loss: 0.4487
# Validation AUC: 0.7314
# Fine-tune Epoch 45/128 -- Train Loss: 0.2572
# Fine-tune Epoch 45/128 -- Validation Loss: 0.4409
# Validation AUC: 0.7092
# Fine-tune Epoch 46/128 -- Train Loss: 0.2426
# Fine-tune Epoch 46/128 -- Validation Loss: 0.4313
# Validation AUC: 0.7107
# Fine-tune Epoch 47/128 -- Train Loss: 0.2370
# Fine-tune Epoch 47/128 -- Validation Loss: 0.4787
# Validation AUC: 0.6963
# Fine-tune Epoch 48/128 -- Train Loss: 0.2462
# Fine-tune Epoch 48/128 -- Validation Loss: 0.4695
# Validation AUC: 0.7054
# Fine-tune Epoch 49/128 -- Train Loss: 0.2193
# Fine-tune Epoch 49/128 -- Validation Loss: 0.4807
# Validation AUC: 0.6822
# Fine-tune Epoch 50/128 -- Train Loss: 0.2193
# Fine-tune Epoch 50/128 -- Validation Loss: 0.4741
# Validation AUC: 0.6980
# Fine-tune Epoch 51/128 -- Train Loss: 0.1904
# Fine-tune Epoch 51/128 -- Validation Loss: 0.4836
# Validation AUC: 0.6926
# Fine-tune Epoch 52/128 -- Train Loss: 0.1716
# Fine-tune Epoch 52/128 -- Validation Loss: 0.4638
# Validation AUC: 0.6947
# Fine-tune Epoch 53/128 -- Train Loss: 0.1726
# Fine-tune Epoch 53/128 -- Validation Loss: 0.5046
# Validation AUC: 0.6874
# Fine-tune Epoch 54/128 -- Train Loss: 0.1640
# Fine-tune Epoch 54/128 -- Validation Loss: 0.4890
# Validation AUC: 0.6959
# Fine-tune Epoch 55/128 -- Train Loss: 0.1634
# Fine-tune Epoch 55/128 -- Validation Loss: 0.5007
# Validation AUC: 0.6866
# Fine-tune Epoch 56/128 -- Train Loss: 0.1496
# Fine-tune Epoch 56/128 -- Validation Loss: 0.4935
# Validation AUC: 0.6925
# Fine-tune Epoch 57/128 -- Train Loss: 0.1303
# Fine-tune Epoch 57/128 -- Validation Loss: 0.5473
# Validation AUC: 0.6741
# Fine-tune Epoch 58/128 -- Train Loss: 0.1440
# Fine-tune Epoch 58/128 -- Validation Loss: 0.5598
# Validation AUC: 0.6777
# Fine-tune Epoch 59/128 -- Train Loss: 0.1156
# Fine-tune Epoch 59/128 -- Validation Loss: 0.5519
# Validation AUC: 0.6768
# Fine-tune Epoch 60/128 -- Train Loss: 0.1326
# Fine-tune Epoch 60/128 -- Validation Loss: 0.6059
# Validation AUC: 0.6712
# Fine-tune Epoch 61/128 -- Train Loss: 0.1323
# Fine-tune Epoch 61/128 -- Validation Loss: 0.5957
# Validation AUC: 0.6896
# Fine-tune Epoch 62/128 -- Train Loss: 0.1005
# Fine-tune Epoch 62/128 -- Validation Loss: 0.6216
# Validation AUC: 0.6505
# Fine-tune Epoch 63/128 -- Train Loss: 0.1094
# Fine-tune Epoch 63/128 -- Validation Loss: 0.6258
# Validation AUC: 0.7016
# Fine-tune Epoch 64/128 -- Train Loss: 0.0915
# Fine-tune Epoch 64/128 -- Validation Loss: 0.6246
# Validation AUC: 0.6302
# Fine-tune Epoch 65/128 -- Train Loss: 0.0865
# Fine-tune Epoch 65/128 -- Validation Loss: 0.6926
# Validation AUC: 0.6382
# Fine-tune Epoch 66/128 -- Train Loss: 0.0954
# Fine-tune Epoch 66/128 -- Validation Loss: 0.6910
# Validation AUC: 0.6762
# Fine-tune Epoch 67/128 -- Train Loss: 0.0647
# Fine-tune Epoch 67/128 -- Validation Loss: 0.6467
# Validation AUC: 0.6682
# Fine-tune Epoch 68/128 -- Train Loss: 0.0549
# Fine-tune Epoch 68/128 -- Validation Loss: 0.7170
# Validation AUC: 0.6562
# Fine-tune Epoch 69/128 -- Train Loss: 0.0569
# Fine-tune Epoch 69/128 -- Validation Loss: 0.6973
# Validation AUC: 0.6607
# Fine-tune Epoch 70/128 -- Train Loss: 0.0557
# Fine-tune Epoch 70/128 -- Validation Loss: 0.7124
# Validation AUC: 0.6671
# Fine-tune Epoch 71/128 -- Train Loss: 0.0503
# Fine-tune Epoch 71/128 -- Validation Loss: 0.7510
# Validation AUC: 0.6684
# Fine-tune Epoch 72/128 -- Train Loss: 0.0418
# Fine-tune Epoch 72/128 -- Validation Loss: 0.8103
# Validation AUC: 0.6782
# Fine-tune Epoch 73/128 -- Train Loss: 0.0538
# Fine-tune Epoch 73/128 -- Validation Loss: 0.8128
# Validation AUC: 0.6557
# Fine-tune Epoch 74/128 -- Train Loss: 0.0341
# Fine-tune Epoch 74/128 -- Validation Loss: 0.7738
# Validation AUC: 0.7011
# Fine-tune Epoch 75/128 -- Train Loss: 0.0543
# Fine-tune Epoch 75/128 -- Validation Loss: 0.9076
# Validation AUC: 0.6437
# Fine-tune Epoch 76/128 -- Train Loss: 0.0601
# Fine-tune Epoch 76/128 -- Validation Loss: 0.7369
# Validation AUC: 0.6871
# Fine-tune Epoch 77/128 -- Train Loss: 0.0387
# Fine-tune Epoch 77/128 -- Validation Loss: 0.7796
# Validation AUC: 0.6821
# Fine-tune Epoch 78/128 -- Train Loss: 0.0255
# Fine-tune Epoch 78/128 -- Validation Loss: 0.8326
# Validation AUC: 0.6822
# Fine-tune Epoch 79/128 -- Train Loss: 0.0287
# Fine-tune Epoch 79/128 -- Validation Loss: 0.9188
# Validation AUC: 0.6506
# Fine-tune Epoch 80/128 -- Train Loss: 0.0219
# Fine-tune Epoch 80/128 -- Validation Loss: 0.8916
# Validation AUC: 0.6806
# Fine-tune Epoch 81/128 -- Train Loss: 0.0238
# Fine-tune Epoch 81/128 -- Validation Loss: 0.8635
# Validation AUC: 0.6818
# Fine-tune Epoch 82/128 -- Train Loss: 0.0183
# Fine-tune Epoch 82/128 -- Validation Loss: 0.8556
# Validation AUC: 0.6596
# Fine-tune Epoch 83/128 -- Train Loss: 0.0324
# Fine-tune Epoch 83/128 -- Validation Loss: 0.8865
# Validation AUC: 0.6640
# Fine-tune Epoch 84/128 -- Train Loss: 0.0174
# Fine-tune Epoch 84/128 -- Validation Loss: 0.9915
# Validation AUC: 0.6671
# Fine-tune Epoch 85/128 -- Train Loss: 0.0464
# Fine-tune Epoch 85/128 -- Validation Loss: 0.8904
# Validation AUC: 0.6788
# Fine-tune Epoch 86/128 -- Train Loss: 0.0181
# Fine-tune Epoch 86/128 -- Validation Loss: 0.8980
# Validation AUC: 0.6919
# Fine-tune Epoch 87/128 -- Train Loss: 0.0143
# Fine-tune Epoch 87/128 -- Validation Loss: 0.9235
# Validation AUC: 0.6755
# Fine-tune Epoch 88/128 -- Train Loss: 0.0104
# Fine-tune Epoch 88/128 -- Validation Loss: 0.9579
# Validation AUC: 0.6757
# Fine-tune Epoch 89/128 -- Train Loss: 0.0126
# Fine-tune Epoch 89/128 -- Validation Loss: 0.9882
# Validation AUC: 0.6708
# Fine-tune Epoch 90/128 -- Train Loss: 0.0145
# Fine-tune Epoch 90/128 -- Validation Loss: 0.9872
# Validation AUC: 0.6844
# Fine-tune Epoch 91/128 -- Train Loss: 0.0110
# Fine-tune Epoch 91/128 -- Validation Loss: 0.9954
# Validation AUC: 0.6725
# Fine-tune Epoch 92/128 -- Train Loss: 0.0102
# Fine-tune Epoch 92/128 -- Validation Loss: 1.0408
# Validation AUC: 0.6394
# Fine-tune Epoch 93/128 -- Train Loss: 0.0068
# Fine-tune Epoch 93/128 -- Validation Loss: 1.0319
# Validation AUC: 0.6959
# Fine-tune Epoch 94/128 -- Train Loss: 0.0190
# Fine-tune Epoch 94/128 -- Validation Loss: 1.0726
# Validation AUC: 0.6561
# Fine-tune Epoch 95/128 -- Train Loss: 0.0094
# Fine-tune Epoch 95/128 -- Validation Loss: 1.0249
# Validation AUC: 0.6689
# Fine-tune Epoch 96/128 -- Train Loss: 0.0181
# Fine-tune Epoch 96/128 -- Validation Loss: 1.0232
# Validation AUC: 0.6746
# Fine-tune Epoch 97/128 -- Train Loss: 0.0125
# Fine-tune Epoch 97/128 -- Validation Loss: 1.0315
# Validation AUC: 0.6976
# Fine-tune Epoch 98/128 -- Train Loss: 0.0071
# Fine-tune Epoch 98/128 -- Validation Loss: 1.0028
# Validation AUC: 0.6847
# Fine-tune Epoch 99/128 -- Train Loss: 0.0092
# Fine-tune Epoch 99/128 -- Validation Loss: 1.0876
# Validation AUC: 0.6647
# Fine-tune Epoch 100/128 -- Train Loss: 0.0073
# Fine-tune Epoch 100/128 -- Validation Loss: 1.0551
# Validation AUC: 0.6891
# Fine-tune Epoch 101/128 -- Train Loss: 0.0112
# Fine-tune Epoch 101/128 -- Validation Loss: 1.0984
# Validation AUC: 0.6821
# Fine-tune Epoch 102/128 -- Train Loss: 0.0104
# Fine-tune Epoch 102/128 -- Validation Loss: 1.0762
# Validation AUC: 0.6438
# Fine-tune Epoch 103/128 -- Train Loss: 0.0075
# Fine-tune Epoch 103/128 -- Validation Loss: 1.0533
# Validation AUC: 0.6832
# Fine-tune Epoch 104/128 -- Train Loss: 0.0067
# Fine-tune Epoch 104/128 -- Validation Loss: 1.0281
# Validation AUC: 0.6854
# Fine-tune Epoch 105/128 -- Train Loss: 0.0098
# Fine-tune Epoch 105/128 -- Validation Loss: 1.1140
# Validation AUC: 0.6741
# Fine-tune Epoch 106/128 -- Train Loss: 0.0068
# Fine-tune Epoch 106/128 -- Validation Loss: 1.1010
# Validation AUC: 0.6755
# Fine-tune Epoch 107/128 -- Train Loss: 0.0026
# Fine-tune Epoch 107/128 -- Validation Loss: 1.1015
# Validation AUC: 0.6796
# Fine-tune Epoch 108/128 -- Train Loss: 0.0046
# Fine-tune Epoch 108/128 -- Validation Loss: 1.1441
# Validation AUC: 0.6820
# Fine-tune Epoch 109/128 -- Train Loss: 0.0040
# Fine-tune Epoch 109/128 -- Validation Loss: 1.0932
# Validation AUC: 0.6834
# Fine-tune Epoch 110/128 -- Train Loss: 0.0052
# Fine-tune Epoch 110/128 -- Validation Loss: 1.1600
# Validation AUC: 0.6874
# Fine-tune Epoch 111/128 -- Train Loss: 0.0049
# Fine-tune Epoch 111/128 -- Validation Loss: 1.1444
# Validation AUC: 0.6731
# Fine-tune Epoch 112/128 -- Train Loss: 0.0106
# Fine-tune Epoch 112/128 -- Validation Loss: 1.1936
# Validation AUC: 0.6738
# Fine-tune Epoch 113/128 -- Train Loss: 0.0041
# Fine-tune Epoch 113/128 -- Validation Loss: 1.1635
# Validation AUC: 0.6754
# Fine-tune Epoch 114/128 -- Train Loss: 0.0053
# Fine-tune Epoch 114/128 -- Validation Loss: 1.1577
# Validation AUC: 0.6735
# Fine-tune Epoch 115/128 -- Train Loss: 0.0040
# Fine-tune Epoch 115/128 -- Validation Loss: 1.1457
# Validation AUC: 0.6823
# Fine-tune Epoch 116/128 -- Train Loss: 0.0019
# Fine-tune Epoch 116/128 -- Validation Loss: 1.1565
# Validation AUC: 0.6563
# Fine-tune Epoch 117/128 -- Train Loss: 0.0041
# Fine-tune Epoch 117/128 -- Validation Loss: 1.1144
# Validation AUC: 0.6874
# Fine-tune Epoch 118/128 -- Train Loss: 0.0048
# Fine-tune Epoch 118/128 -- Validation Loss: 1.1756
# Validation AUC: 0.6668
# Fine-tune Epoch 119/128 -- Train Loss: 0.0017
# Fine-tune Epoch 119/128 -- Validation Loss: 1.1774
# Validation AUC: 0.6728
# Fine-tune Epoch 120/128 -- Train Loss: 0.0026
# Fine-tune Epoch 120/128 -- Validation Loss: 1.1944
# Validation AUC: 0.6736
# Fine-tune Epoch 121/128 -- Train Loss: 0.0045
# Fine-tune Epoch 121/128 -- Validation Loss: 1.2548
# Validation AUC: 0.6752
# Fine-tune Epoch 122/128 -- Train Loss: 0.0028
# Fine-tune Epoch 122/128 -- Validation Loss: 1.1081
# Validation AUC: 0.6742
# Fine-tune Epoch 123/128 -- Train Loss: 0.0055
# Fine-tune Epoch 123/128 -- Validation Loss: 1.2303
# Validation AUC: 0.6786
# Fine-tune Epoch 124/128 -- Train Loss: 0.0030
# Fine-tune Epoch 124/128 -- Validation Loss: 1.2276
# Validation AUC: 0.6710
# Fine-tune Epoch 125/128 -- Train Loss: 0.0014
# Fine-tune Epoch 125/128 -- Validation Loss: 1.1574
# Validation AUC: 0.6827
# Fine-tune Epoch 126/128 -- Train Loss: 0.0041
# Fine-tune Epoch 126/128 -- Validation Loss: 1.2281
# Validation AUC: 0.6837
# Fine-tune Epoch 127/128 -- Train Loss: 0.0074
# Fine-tune Epoch 127/128 -- Validation Loss: 1.2258
# Validation AUC: 0.6636
# Fine-tune Epoch 128/128 -- Train Loss: 0.0019
# Fine-tune Epoch 128/128 -- Validation Loss: 1.1595
# Validation AUC: 0.6826

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.calibration import calibration_curve

########################################
# 1) Load Best Model
########################################
best_model_path = os.path.join("best_model_bitimelygpt.pt")

checkpoint = torch.load(best_model_path, map_location=device, weights_only=False)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()
print("Best model loaded from:", best_model_path)

########################################
# 2) Collect predictions on set-c (test_loader)
########################################
all_probs_test = []
all_labels_test = []

with torch.no_grad():
    for batch_data in test_loader:
        batch_x, batch_y, attention_mask = [b.to(device) for b in batch_data]

        # Forward pass (subsampling, blocks, etc.)
        hidden_states = model.conv_subsampling(batch_x)[0]
        hidden_states = model.input_projection(hidden_states)

        # adjust attention mask
        if attention_mask.shape[1] > hidden_states.shape[1]:
            attention_mask = attention_mask[:, ::4]
            attention_mask = attention_mask[:, :hidden_states.shape[1]]

        for l, block in enumerate(model.blocks):
            block_outputs = block(
                hidden_states,
                retention_mask=attention_mask,
                forward_impl=config.forward_impl,
                chunk_size=config.chunk_size
            )
            hidden_states = block_outputs[0]
            if (l + 1) == model.n_layers:
                hidden_states_PTP = hidden_states

        X_test = model.ln_f(hidden_states_PTP) # Apply final LN to the whole sequence
        logits_test = model.head(X_test)      # Apply ClfHead (which includes pooling)

        # Probability of positive class (class index = 1)
        probs_test = torch.softmax(logits_test, dim=1)[:, 1]

        # Collect predictions and labels
        all_probs_test.extend(probs_test.cpu().numpy())
        all_labels_test.extend(batch_y.cpu().numpy())

all_probs_test = np.array(all_probs_test)
all_labels_test = np.array(all_labels_test)
# Out:
# Best model loaded from: best_model_bitimelygpt.pt

# %%
# ---- 1) Compute AUC ----
fpr_test, tpr_test, _ = roc_curve(all_labels_test, all_probs_test)
roc_auc_test = auc(fpr_test, tpr_test)
print(f"Final Test AUC on set-c: {roc_auc_test:.4f}")

# ---- 2) Threshold Sweep to find best F1 ----
threshold_candidates = np.linspace(0.0, 1.0, num=101)
best_thr = 0.0
best_f1_for_sweep = 0.0
best_precision = 0.0
best_recall = 0.0

for thr in threshold_candidates:
    thr_preds = (all_probs_test >= thr).astype(int)
    tp = np.sum((thr_preds == 1) & (all_labels_test == 1))
    fp = np.sum((thr_preds == 1) & (all_labels_test == 0))
    fn = np.sum((thr_preds == 0) & (all_labels_test == 1))
    tn = np.sum((thr_preds == 0) & (all_labels_test == 0))

    prec = tp / (tp + fp + 1e-9)
    rec = tp / (tp + fn + 1e-9)
    f1_score = 2 * prec * rec / (prec + rec + 1e-9)

    if f1_score > best_f1_for_sweep:
        best_f1_for_sweep = f1_score
        best_precision = prec
        best_recall = rec
        best_thr = thr

print(f"==> Final Test Metrics on set-c <==")
print(f"AUC: {roc_auc_test:.4f}")
print(f"Best F1: {best_f1_for_sweep:.4f} at threshold={best_thr:.2f}")
print(f"Precision: {best_precision:.4f}")
print(f"Recall:    {best_recall:.4f}")
# Out:
# Final Test AUC on set-c: 0.7337
# ==> Final Test Metrics on set-c <==
# AUC: 0.7337
# Best F1: 0.3911 at threshold=0.18
# Precision: 0.3008
# Recall:    0.5590

# %%
########################################
# 3) Calibration Plot on set-c
########################################
import pandas as pd
import seaborn as sns

num_cuts = 24
df = pd.DataFrame({"prob": all_probs_test, "label": all_labels_test})

# 1) Bin predictions
df["bin"] = pd.cut(df["prob"], bins=num_cuts, include_lowest=True)

# 2) Group by bin, compute observed fraction, expected fraction, sample size, standard error
grouped = (
    df.groupby("bin")
    .agg(
        observed=("label", "mean"),
        expected=("prob", "mean"),
        n=("label", "count")
    )
    .reset_index()
)

grouped["se"] = np.sqrt(grouped["observed"] * (1 - grouped["observed"]) / grouped["n"])

# 3) Plot observed vs. expected
plt.figure(figsize=(6, 6))
plt.errorbar(
    x=grouped["expected"],
    y=grouped["observed"],
    yerr=1.96 * grouped["se"],
    fmt="o",
    capsize=3,
    label="Binned Data"
)
plt.plot([0, 1], [0, 1], "r--", label="Perfect Calibration")
sns.regplot(
    x="expected",
    y="observed",
    data=grouped,
    scatter=False,
    lowess=True,
    label="Loess Smooth",
    color="black"
)

plt.xlabel("Expected Probability")
plt.ylabel("Observed Fraction")
plt.title("BiTimelyGPT Calibration Plot")
plt.legend(loc="best")
plt.show()
# Out:
# <ipython-input-13-012e26af68cf>:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("bin")

# %%
########################################
# 4) ROC Curve on set-c
########################################
fpr_test, tpr_test, _ = roc_curve(all_labels_test, all_probs_test)
roc_auc_test = auc(fpr_test, tpr_test)

plt.figure(figsize=(6, 6))
sns.lineplot(x=fpr_test, y=tpr_test, color='black', linewidth=2,
             label=f'ROC (AUC = {roc_auc_test:.3f})')
plt.plot([0, 1], [0, 1], 'r--', label='No Skill')
plt.xlabel('False Positive Rate', fontsize=11)
plt.ylabel('True Positive Rate', fontsize=11)
plt.title('BiTimelyGPT ROC Curve', fontsize=13)
plt.legend(loc='lower right')
plt.show()
