# %% [markdown]
# # BiTimelyGPT for PhysioNet 2012 Challenge
#
# Pre-tune usage test

# %%
# import libraries
import os
import torch
import numpy as np
import pandas as pd
from torch import nn, optim
from sklearn.metrics import roc_auc_score, average_precision_score, roc_curve, auc
import matplotlib.pyplot as plt
import copy

# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# BiTimelyGPT to path
import sys
sys.path.append('/content/drive/MyDrive/BiTimelyGPT-main/BiTimelyGPT')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import BiTimelyGPT modules
from data.data_pipeline import physionet_data_pipeline
from models.BiTimelyGPT import BiTimelyGPT
from layers.heads import PretrainHead, ClfHead
from layers.optimization import get_linear_schedule_with_warmup, AdamW

# %%
# define paths to PhysioNet 2012 data in Google Drive
google_drive_folder = '/content/drive/MyDrive/physionet2012/'
set_a_directory = f"{google_drive_folder}/set-a"
set_b_directory = f"{google_drive_folder}/set-b"
set_c_directory = f"{google_drive_folder}/set-c"

outcomes_a_file = f"{set_a_directory}/Outcomes-a.txt"
outcomes_b_file = f"{set_b_directory}/Outcomes-b.txt"
outcomes_c_file = f"{set_c_directory}/Outcomes-c.txt"

# %%
# define PhysioNet configuration
class PhysioNetConfig:
    def __init__(self):
        # define standard features from PhysioNet
        self.feature_list = [
            'Albumin', 'ALP', 'ALT', 'AST', 'Bilirubin', 'BUN', 'Cholesterol',
            'Creatinine', 'DiasABP', 'FiO2', 'GCS', 'Glucose', 'HCO3', 'HCT',
            'HR', 'K', 'Lactate', 'Mg', 'MAP', 'MechVent', 'Na', 'NIDiasABP',
            'NIMAP', 'NISysABP', 'PaCO2', 'PaO2', 'pH', 'Platelets', 'RespRate',
            'SaO2', 'SysABP', 'Temp', 'TropI', 'TropT', 'Urine', 'WBC', 'Age',
            'Gender', 'Height', 'ICUType', 'Weight'
        ]

        # model parameters
        self.num_layers = 8
        self.num_heads = 4
        self.d_model = 144
        self.qk_dim = 144
        self.v_dim = 288
        self.ffn_proj_size = 576
        self.d_ff = 288
        self.dropout = 0.1
        self.n_output = len(self.feature_list)
        self.n_clf_output = 2


        # Pretraining parameters
        self.pretrain_batch_size = 256
        self.pretrain_learning_rate = 1e-4
        self.pretrain_epochs = 24
        self.pretrain_warmup_steps = 500

        # Fine-tuning parameters
        self.finetune_batch_size = 32
        self.finetune_learning_rate = 2e-4
        self.finetune_epochs = 64
        self.finetune_warmup_steps = 1000
        self.gradient_clip = 1.0

        # BiTimelyGPT specific
        self.use_bias_in_msr = False
        self.use_bias_in_mlp = True
        self.use_bias_in_msr_out = False
        self.use_default_gamma = False
        self.forward_impl = 'parallel'
        self.chunk_size = 12
        self.seq_len = 2880
        self.chunk_size = 60
        self.activation = 'gelu'
        self.head_type = 'clf'

        # GPU and optimization settings
        self.use_gpu = torch.cuda.is_available()
        self.use_grad_ckp = True
        self.use_grad_accum = True
        self.accum_steps = 2
        self.use_amp = False
        self.use_multi_gpu = False
        self.devices = '0'

        self.output_retentions = False

# init config
config = PhysioNetConfig()

# %%
# set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# random seeds
torch.manual_seed(42)
np.random.seed(42)

# init base model structure (head will be set later)
model = BiTimelyGPT(configs=config, head_type='pretrain').to(device) # Start with pretrain head
print("Initial model created with Pretrain head.")
# Out:
# Initial model created with Pretrain head.

# %%
# load training data
config.batch_size = config.pretrain_batch_size
train_data_path = set_a_directory
train_outcomes_path = outcomes_a_file
train_dataset, train_loader = physionet_data_pipeline(
    train_data_path,
    train_outcomes_path,
    config,
    split='train'
)

# load validation data
config.batch_size = config.finetune_batch_size # Val/Test use fine-tune batch size
val_data_path = set_b_directory
val_outcomes_path = outcomes_b_file
val_dataset, val_loader = physionet_data_pipeline(
    val_data_path,
    val_outcomes_path,
    config,
    split='val'
)

# load test data (set-c) for final metrics
test_data_path = set_c_directory
test_outcomes_path = outcomes_c_file
test_dataset, test_loader = physionet_data_pipeline(
    test_data_path,
    test_outcomes_path,
    config,
    split='test'
)

# %%
print("--- starting pretraining phase ---")

# pretraining optimizer
pretrain_optimizer = AdamW(
    model.parameters(),
    lr=config.pretrain_learning_rate,
    weight_decay=0.01
)

# calculate total steps
num_pretraining_steps = len(train_loader) * config.pretrain_epochs
pretrain_scheduler = get_linear_schedule_with_warmup(
   pretrain_optimizer,
   config.pretrain_warmup_steps,
   num_pretraining_steps
)

# pretraining loss
pretrain_criterion = nn.MSELoss()

# pretraining loop
for epoch in range(config.pretrain_epochs):
    model.train()
    pretrain_losses = []

    for i, batch_data in enumerate(train_loader):
        batch_x, _, attention_mask = [b.to(device) for b in batch_data] # ignore labels during pretrain

        if i % config.accum_steps == 0:
            pretrain_optimizer.zero_grad()

        # forward pass
        loss = model(batch_x, y=None,
                     retention_mask=None,
                     forward_impl=config.forward_impl,
                     chunk_size=config.chunk_size)

        if torch.isnan(loss):
             print(f"warning: nan loss encountered at pretrain epoch {epoch+1}, batch {i}. skipping batch.")
             pretrain_optimizer.zero_grad() # zero grad for this batch
             continue

        # scale loss and backprop
        scaled_loss = loss / config.accum_steps
        scaled_loss.backward()

        # gradient clipping
        torch.nn.utils.clip_grad_norm_(model.parameters(), config.gradient_clip)

        # update weights
        if (i + 1) % config.accum_steps == 0 or (i + 1) == len(train_loader):
            pretrain_optimizer.step()
            pretrain_scheduler.step()

        pretrain_losses.append(loss.item())

    avg_pretrain_loss = np.mean(pretrain_losses)
    print(f'pretrain epoch {epoch+1}/{config.pretrain_epochs} -- avg loss: {avg_pretrain_loss:.4f}')

print("--- pretraining phase complete ---")
# Out:
# --- Starting Pretraining Phase ---
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# Pretrain Epoch 1/24 -- Avg Loss: 67.1567
# Pretrain Epoch 2/24 -- Avg Loss: 65.4783
# Pretrain Epoch 3/24 -- Avg Loss: 68.5802
# Pretrain Epoch 4/24 -- Avg Loss: 67.1327
# Pretrain Epoch 5/24 -- Avg Loss: 65.6216
# Pretrain Epoch 6/24 -- Avg Loss: 65.0408
# Pretrain Epoch 7/24 -- Avg Loss: 65.8841
# Pretrain Epoch 8/24 -- Avg Loss: 61.4291
# Pretrain Epoch 9/24 -- Avg Loss: 60.7692
# Pretrain Epoch 10/24 -- Avg Loss: 61.2606
# Pretrain Epoch 11/24 -- Avg Loss: 57.3778
# Pretrain Epoch 12/24 -- Avg Loss: 56.2338
# Pretrain Epoch 13/24 -- Avg Loss: 51.4785
# Pretrain Epoch 14/24 -- Avg Loss: 51.0171
# Pretrain Epoch 15/24 -- Avg Loss: 49.6474
# Pretrain Epoch 16/24 -- Avg Loss: 47.3582
# Pretrain Epoch 17/24 -- Avg Loss: 45.5534
# Pretrain Epoch 18/24 -- Avg Loss: 43.0908
# Pretrain Epoch 19/24 -- Avg Loss: 41.5341
# Pretrain Epoch 20/24 -- Avg Loss: 40.1073
# Pretrain Epoch 21/24 -- Avg Loss: 39.8124
# Pretrain Epoch 22/24 -- Avg Loss: 37.3664
# Pretrain Epoch 23/24 -- Avg Loss: 39.2764
# Pretrain Epoch 24/24 -- Avg Loss: 37.9883
# --- Pretraining Phase Complete ---

# %%
# --- switch to fine-tuning ---
print("--- switching to fine-tuning phase ---")
# keep pretrained weights, replace head
model.head = ClfHead(config.d_model, config.n_clf_output).to(device)
model.head_type = 'clf' # update model state
print(f"model head switched to clfhead for fine-tuning with {config.n_clf_output} outputs.")

########################################
# define fine-tuning optimizer, scheduler
########################################
# fine-tuning optimizer
optimizer = AdamW(
   model.parameters(), # includes new head parameters
   lr=config.finetune_learning_rate,
   weight_decay=0.01
)

# fine-tuning scheduler
num_finetune_steps = len(train_loader) * config.finetune_epochs # use fine-tune epochs
scheduler = get_linear_schedule_with_warmup(
   optimizer, # use fine-tuning optimizer
   config.finetune_warmup_steps, # use fine-tune warmup steps
   num_finetune_steps
)

# fine-tuning loss function
criterion = nn.CrossEntropyLoss()
# Out:
# --- Switching to Fine-tuning Phase ---
# Model head switched to ClfHead for fine-tuning with 2 outputs.

# %%
# save paths for best model
best_model_path = os.path.join("best_model_bitimelygpt.pt")

criterion = nn.CrossEntropyLoss()  # loss function

# track best auc over epochs
best_val_auc = 0.0

print("--- starting fine-tuning training loop ---")
for epoch in range(config.finetune_epochs):
    # training phase
    model.train()
    train_losses = []

    for i, batch_data in enumerate(train_loader):
        batch_x, batch_y, attention_mask = [b.to(device) for b in batch_data] # unpack batch data

        if i % config.accum_steps == 0:
            optimizer.zero_grad()

        # forward pass for classification
        assert model.head_type == 'clf', "model head_type should be 'clf' for fine-tuning"

        hidden_states = model.conv_subsampling(batch_x)[0]
        hidden_states = model.input_projection(hidden_states)

        # handle attention_mask subsampling
        if attention_mask.shape[1] > hidden_states.shape[1]:
            attention_mask = attention_mask[:, ::4]
            attention_mask = attention_mask[:, :hidden_states.shape[1]]

        # pass through retention blocks
        for l, block in enumerate(model.blocks):
            block_outputs = block(
                hidden_states,
                retention_mask=attention_mask,
                forward_impl=config.forward_impl,
                chunk_size=config.chunk_size
            )
            hidden_states = block_outputs[0]
            if (l + 1) == model.n_layers:
                hidden_states_PTP = hidden_states

        # classification head
        X = model.ln_f(hidden_states_PTP)  # final LayerNorm
        logits = model.head(X)             # ClfHead (mean-pool + linear)

        # calculate classification loss
        raw_loss = criterion(logits, batch_y)

        # scale loss and backpropagate
        scaled_loss = raw_loss / config.accum_steps
        scaled_loss.backward()

        # gradient clipping
        torch.nn.utils.clip_grad_norm_(model.parameters(), config.gradient_clip)

        # update weights
        if (i + 1) % config.accum_steps == 0 or (i + 1) == len(train_loader):
            optimizer.step()
            scheduler.step()

        train_losses.append(raw_loss.item())

    avg_train_loss = np.mean(train_losses)
    print(f'fine-tune epoch {epoch+1}/{config.finetune_epochs} -- train loss: {avg_train_loss:.4f}')

    # validation phase
    model.eval()
    val_losses = []

    # collect predicted probabilities & labels for auc
    all_probs = []
    all_labels = []

    with torch.no_grad():
        for i, batch_data in enumerate(val_loader):
            batch_x, batch_y, attention_mask = [b.to(device) for b in batch_data]

            hidden_states = model.conv_subsampling(batch_x)[0]
            hidden_states = model.input_projection(hidden_states)

            if attention_mask.shape[1] > hidden_states.shape[1]:
                attention_mask = attention_mask[:, ::4]
                attention_mask = attention_mask[:, :hidden_states.shape[1]]

            for l, block in enumerate(model.blocks):
                block_outputs = block(
                    hidden_states,
                    retention_mask=attention_mask,
                    forward_impl=config.forward_impl,
                    chunk_size=config.chunk_size
                )
                hidden_states = block_outputs[0]
                if (l + 1) == model.n_layers:
                    hidden_states_PTP = hidden_states

            X_val = model.ln_f(hidden_states_PTP)
            logits_val = model.head(X_val)

            loss_val = criterion(logits_val, batch_y)
            val_losses.append(loss_val.item())

            # probability of class=1 for auc
            probs_val = torch.softmax(logits_val, dim=1)[:, 1]
            all_probs.extend(probs_val.detach().cpu().tolist())
            all_labels.extend(batch_y.detach().cpu().tolist())

    avg_val_loss = np.mean(val_losses)
    print(f'fine-tune epoch {epoch+1}/{config.finetune_epochs} -- validation loss: {avg_val_loss:.4f}')

    # calculate auc (skip if only one class in the batch)
    if len(np.unique(all_labels)) > 1:
        fpr, tpr, thresholds = roc_curve(all_labels, all_probs)
        roc_auc_val = auc(fpr, tpr)
        print(f"validation auc: {roc_auc_val:.4f}")
    else:
        print("validation auc calculation skipped: only one class present in this validation set.")
        roc_auc_val = 0.0

    # save best model by validation auc
    if epoch >= 0 and roc_auc_val > best_val_auc:
        best_val_auc = roc_auc_val
        best_val_metrics = {
            'auc': best_val_auc,
            'loss': avg_val_loss
        }
        torch.save({
            'model_state_dict': model.state_dict(),
            'config': config,
            'metrics': best_val_metrics
        }, best_model_path)
        print(f"==> best fine-tuned model saved to {best_model_path} (auc: {roc_auc_val:.4f})")
# Out:
# --- Starting Fine-tuning Training Loop ---
# Fine-tune Epoch 1/64 -- Train Loss: 0.6163
# Fine-tune Epoch 1/64 -- Validation Loss: 0.5795
# Validation AUC: 0.4914
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.4914)
# Fine-tune Epoch 2/64 -- Train Loss: 0.5853
# Fine-tune Epoch 2/64 -- Validation Loss: 0.5335
# Validation AUC: 0.5012
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.5012)
# Fine-tune Epoch 3/64 -- Train Loss: 0.5245
# Fine-tune Epoch 3/64 -- Validation Loss: 0.4728
# Validation AUC: 0.5154
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.5154)
# Fine-tune Epoch 4/64 -- Train Loss: 0.4599
# Fine-tune Epoch 4/64 -- Validation Loss: 0.4238
# Validation AUC: 0.5361
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.5361)
# Fine-tune Epoch 5/64 -- Train Loss: 0.4169
# Fine-tune Epoch 5/64 -- Validation Loss: 0.4066
# Validation AUC: 0.5516
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.5516)
# Fine-tune Epoch 6/64 -- Train Loss: 0.4008
# Fine-tune Epoch 6/64 -- Validation Loss: 0.4100
# Validation AUC: 0.5696
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.5696)
# Fine-tune Epoch 7/64 -- Train Loss: 0.4001
# Fine-tune Epoch 7/64 -- Validation Loss: 0.4061
# Validation AUC: 0.5879
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.5879)
# Fine-tune Epoch 8/64 -- Train Loss: 0.3987
# Fine-tune Epoch 8/64 -- Validation Loss: 0.3993
# Validation AUC: 0.6110
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6110)
# Fine-tune Epoch 9/64 -- Train Loss: 0.3946
# Fine-tune Epoch 9/64 -- Validation Loss: 0.3971
# Validation AUC: 0.6303
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6303)
# Fine-tune Epoch 10/64 -- Train Loss: 0.3896
# Fine-tune Epoch 10/64 -- Validation Loss: 0.3930
# Validation AUC: 0.6455
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6455)
# Fine-tune Epoch 11/64 -- Train Loss: 0.3906
# Fine-tune Epoch 11/64 -- Validation Loss: 0.3903
# Validation AUC: 0.6587
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6587)
# Fine-tune Epoch 12/64 -- Train Loss: 0.3882
# Fine-tune Epoch 12/64 -- Validation Loss: 0.3878
# Validation AUC: 0.6720
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6720)
# Fine-tune Epoch 13/64 -- Train Loss: 0.3799
# Fine-tune Epoch 13/64 -- Validation Loss: 0.3863
# Validation AUC: 0.6760
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6760)
# Fine-tune Epoch 14/64 -- Train Loss: 0.3839
# Fine-tune Epoch 14/64 -- Validation Loss: 0.3835
# Validation AUC: 0.6898
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6898)
# Fine-tune Epoch 15/64 -- Train Loss: 0.3752
# Fine-tune Epoch 15/64 -- Validation Loss: 0.3801
# Validation AUC: 0.6944
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6944)
# Fine-tune Epoch 16/64 -- Train Loss: 0.3703
# Fine-tune Epoch 16/64 -- Validation Loss: 0.3794
# Validation AUC: 0.6969
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.6969)
# Fine-tune Epoch 17/64 -- Train Loss: 0.3647
# Fine-tune Epoch 17/64 -- Validation Loss: 0.3784
# Validation AUC: 0.7008
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7008)
# Fine-tune Epoch 18/64 -- Train Loss: 0.3637
# Fine-tune Epoch 18/64 -- Validation Loss: 0.3768
# Validation AUC: 0.7095
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7095)
# Fine-tune Epoch 19/64 -- Train Loss: 0.3611
# Fine-tune Epoch 19/64 -- Validation Loss: 0.3757
# Validation AUC: 0.7130
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7130)
# Fine-tune Epoch 20/64 -- Train Loss: 0.3605
# Fine-tune Epoch 20/64 -- Validation Loss: 0.3727
# Validation AUC: 0.7188
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7188)
# Fine-tune Epoch 21/64 -- Train Loss: 0.3572
# Fine-tune Epoch 21/64 -- Validation Loss: 0.3723
# Validation AUC: 0.7208
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7208)
# Fine-tune Epoch 22/64 -- Train Loss: 0.3579
# Fine-tune Epoch 22/64 -- Validation Loss: 0.3737
# Validation AUC: 0.7204
# Fine-tune Epoch 23/64 -- Train Loss: 0.3451
# Fine-tune Epoch 23/64 -- Validation Loss: 0.3757
# Validation AUC: 0.7247
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7247)
# Fine-tune Epoch 24/64 -- Train Loss: 0.3425
# Fine-tune Epoch 24/64 -- Validation Loss: 0.3740
# Validation AUC: 0.7207
# Fine-tune Epoch 25/64 -- Train Loss: 0.3401
# Fine-tune Epoch 25/64 -- Validation Loss: 0.3770
# Validation AUC: 0.7203
# Fine-tune Epoch 26/64 -- Train Loss: 0.3428
# Fine-tune Epoch 26/64 -- Validation Loss: 0.3832
# Validation AUC: 0.7130
# Fine-tune Epoch 27/64 -- Train Loss: 0.3387
# Fine-tune Epoch 27/64 -- Validation Loss: 0.3763
# Validation AUC: 0.7232
# Fine-tune Epoch 28/64 -- Train Loss: 0.3460
# Fine-tune Epoch 28/64 -- Validation Loss: 0.4071
# Validation AUC: 0.7183
# Fine-tune Epoch 29/64 -- Train Loss: 0.3314
# Fine-tune Epoch 29/64 -- Validation Loss: 0.3787
# Validation AUC: 0.7236
# Fine-tune Epoch 30/64 -- Train Loss: 0.3207
# Fine-tune Epoch 30/64 -- Validation Loss: 0.3825
# Validation AUC: 0.7229
# Fine-tune Epoch 31/64 -- Train Loss: 0.3206
# Fine-tune Epoch 31/64 -- Validation Loss: 0.3874
# Validation AUC: 0.7214
# Fine-tune Epoch 32/64 -- Train Loss: 0.3148
# Fine-tune Epoch 32/64 -- Validation Loss: 0.3852
# Validation AUC: 0.7169
# Fine-tune Epoch 33/64 -- Train Loss: 0.3153
# Fine-tune Epoch 33/64 -- Validation Loss: 0.3798
# Validation AUC: 0.7322
# ==> Best fine-tuned model saved to best_model_bitimelygpt.pt (AUC: 0.7322)
# Fine-tune Epoch 34/64 -- Train Loss: 0.3146
# Fine-tune Epoch 34/64 -- Validation Loss: 0.3799
# Validation AUC: 0.7257
# Fine-tune Epoch 35/64 -- Train Loss: 0.2986
# Fine-tune Epoch 35/64 -- Validation Loss: 0.3798
# Validation AUC: 0.7266
# Fine-tune Epoch 36/64 -- Train Loss: 0.3002
# Fine-tune Epoch 36/64 -- Validation Loss: 0.3876
# Validation AUC: 0.7203
# Fine-tune Epoch 37/64 -- Train Loss: 0.3150
# Fine-tune Epoch 37/64 -- Validation Loss: 0.4032
# Validation AUC: 0.7180
# Fine-tune Epoch 38/64 -- Train Loss: 0.3049
# Fine-tune Epoch 38/64 -- Validation Loss: 0.4104
# Validation AUC: 0.7203
# Fine-tune Epoch 39/64 -- Train Loss: 0.3006
# Fine-tune Epoch 39/64 -- Validation Loss: 0.3981
# Validation AUC: 0.7209
# Fine-tune Epoch 40/64 -- Train Loss: 0.3156
# Fine-tune Epoch 40/64 -- Validation Loss: 0.3901
# Validation AUC: 0.7242
# Fine-tune Epoch 41/64 -- Train Loss: 0.2949
# Fine-tune Epoch 41/64 -- Validation Loss: 0.4009
# Validation AUC: 0.7235
# Fine-tune Epoch 42/64 -- Train Loss: 0.2739
# Fine-tune Epoch 42/64 -- Validation Loss: 0.4066
# Validation AUC: 0.7098
# Fine-tune Epoch 43/64 -- Train Loss: 0.2741
# Fine-tune Epoch 43/64 -- Validation Loss: 0.4083
# Validation AUC: 0.7268
# Fine-tune Epoch 44/64 -- Train Loss: 0.2977
# Fine-tune Epoch 44/64 -- Validation Loss: 0.4321
# Validation AUC: 0.7019
# Fine-tune Epoch 45/64 -- Train Loss: 0.2790
# Fine-tune Epoch 45/64 -- Validation Loss: 0.4212
# Validation AUC: 0.7180
# Fine-tune Epoch 46/64 -- Train Loss: 0.2708
# Fine-tune Epoch 46/64 -- Validation Loss: 0.4255
# Validation AUC: 0.6780
# Fine-tune Epoch 47/64 -- Train Loss: 0.2551
# Fine-tune Epoch 47/64 -- Validation Loss: 0.4271
# Validation AUC: 0.7146
# Fine-tune Epoch 48/64 -- Train Loss: 0.2734
# Fine-tune Epoch 48/64 -- Validation Loss: 0.4332
# Validation AUC: 0.6941
# Fine-tune Epoch 49/64 -- Train Loss: 0.2484
# Fine-tune Epoch 49/64 -- Validation Loss: 0.4146
# Validation AUC: 0.7143
# Fine-tune Epoch 50/64 -- Train Loss: 0.2299
# Fine-tune Epoch 50/64 -- Validation Loss: 0.4336
# Validation AUC: 0.7009
# Fine-tune Epoch 51/64 -- Train Loss: 0.2115
# Fine-tune Epoch 51/64 -- Validation Loss: 0.4442
# Validation AUC: 0.6928
# Fine-tune Epoch 52/64 -- Train Loss: 0.2093
# Fine-tune Epoch 52/64 -- Validation Loss: 0.4464
# Validation AUC: 0.7034
# Fine-tune Epoch 53/64 -- Train Loss: 0.2084
# Fine-tune Epoch 53/64 -- Validation Loss: 0.4591
# Validation AUC: 0.6924
# Fine-tune Epoch 54/64 -- Train Loss: 0.1973
# Fine-tune Epoch 54/64 -- Validation Loss: 0.4736
# Validation AUC: 0.6838
# Fine-tune Epoch 55/64 -- Train Loss: 0.2029
# Fine-tune Epoch 55/64 -- Validation Loss: 0.4542
# Validation AUC: 0.6955
# Fine-tune Epoch 56/64 -- Train Loss: 0.1920
# Fine-tune Epoch 56/64 -- Validation Loss: 0.4798
# Validation AUC: 0.6850
# Fine-tune Epoch 57/64 -- Train Loss: 0.1843
# Fine-tune Epoch 57/64 -- Validation Loss: 0.4877
# Validation AUC: 0.6881
# Fine-tune Epoch 58/64 -- Train Loss: 0.1861
# Fine-tune Epoch 58/64 -- Validation Loss: 0.4841
# Validation AUC: 0.6738
# Fine-tune Epoch 59/64 -- Train Loss: 0.1532
# Fine-tune Epoch 59/64 -- Validation Loss: 0.5407
# Validation AUC: 0.6879
# Fine-tune Epoch 60/64 -- Train Loss: 0.1784
# Fine-tune Epoch 60/64 -- Validation Loss: 0.4975
# Validation AUC: 0.6832
# Fine-tune Epoch 61/64 -- Train Loss: 0.1538
# Fine-tune Epoch 61/64 -- Validation Loss: 0.4986
# Validation AUC: 0.6792
# Fine-tune Epoch 62/64 -- Train Loss: 0.1450
# Fine-tune Epoch 62/64 -- Validation Loss: 0.5002
# Validation AUC: 0.6862
# Fine-tune Epoch 63/64 -- Train Loss: 0.1458
# Fine-tune Epoch 63/64 -- Validation Loss: 0.5057
# Validation AUC: 0.6646
# Fine-tune Epoch 64/64 -- Train Loss: 0.1257
# Fine-tune Epoch 64/64 -- Validation Loss: 0.5129
# Validation AUC: 0.6891

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.calibration import calibration_curve

########################################
# 1) Load Best Model
########################################
best_model_path = os.path.join("best_model_bitimelygpt.pt")

checkpoint = torch.load(best_model_path, map_location=device, weights_only=False)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()
print("Best model loaded from:", best_model_path)

########################################
# 2) Collect predictions on set-c (test_loader)
########################################
all_probs_test = []
all_labels_test = []

with torch.no_grad():
    for batch_data in test_loader:
        batch_x, batch_y, attention_mask = [b.to(device) for b in batch_data]

        # Forward pass (subsampling, blocks, etc.)
        hidden_states = model.conv_subsampling(batch_x)[0]
        hidden_states = model.input_projection(hidden_states)

        # adjust attention mask
        if attention_mask.shape[1] > hidden_states.shape[1]:
            attention_mask = attention_mask[:, ::4]
            attention_mask = attention_mask[:, :hidden_states.shape[1]]

        for l, block in enumerate(model.blocks):
            block_outputs = block(
                hidden_states,
                retention_mask=attention_mask,
                forward_impl=config.forward_impl,
                chunk_size=config.chunk_size
            )
            hidden_states = block_outputs[0]
            if (l + 1) == model.n_layers:
                hidden_states_PTP = hidden_states

        X_test = model.ln_f(hidden_states_PTP) # Apply final LN to the whole sequence
        logits_test = model.head(X_test)      # Apply ClfHead (which includes pooling)

        # Probability of positive class (class index = 1)
        probs_test = torch.softmax(logits_test, dim=1)[:, 1]

        # Collect predictions and labels
        all_probs_test.extend(probs_test.cpu().numpy())
        all_labels_test.extend(batch_y.cpu().numpy())

all_probs_test = np.array(all_probs_test)
all_labels_test = np.array(all_labels_test)
# Out:
# Best model loaded from: best_model_bitimelygpt.pt

# %%
# ---- 1) Compute AUC ----
fpr_test, tpr_test, _ = roc_curve(all_labels_test, all_probs_test)
roc_auc_test = auc(fpr_test, tpr_test)
print(f"Final Test AUC on set-c: {roc_auc_test:.4f}")

# ---- 2) Threshold Sweep to find best F1 ----
threshold_candidates = np.linspace(0.0, 1.0, num=101)
best_thr = 0.0
best_f1_for_sweep = 0.0
best_precision = 0.0
best_recall = 0.0

for thr in threshold_candidates:
    thr_preds = (all_probs_test >= thr).astype(int)
    tp = np.sum((thr_preds == 1) & (all_labels_test == 1))
    fp = np.sum((thr_preds == 1) & (all_labels_test == 0))
    fn = np.sum((thr_preds == 0) & (all_labels_test == 1))
    tn = np.sum((thr_preds == 0) & (all_labels_test == 0))

    prec = tp / (tp + fp + 1e-9)
    rec = tp / (tp + fn + 1e-9)
    f1_score = 2 * prec * rec / (prec + rec + 1e-9)

    if f1_score > best_f1_for_sweep:
        best_f1_for_sweep = f1_score
        best_precision = prec
        best_recall = rec
        best_thr = thr

print(f"==> Final Test Metrics on set-c <==")
print(f"AUC: {roc_auc_test:.4f}")
print(f"Best F1: {best_f1_for_sweep:.4f} at threshold={best_thr:.2f}")
print(f"Precision: {best_precision:.4f}")
print(f"Recall:    {best_recall:.4f}")
# Out:
# Final Test AUC on set-c: 0.7206
# ==> Final Test Metrics on set-c <==
# AUC: 0.7206
# Best F1: 0.3801 at threshold=0.14
# Precision: 0.2840
# Recall:    0.5744

# %%
########################################
# 3) Calibration Plot on set-c
########################################
import pandas as pd
import seaborn as sns

num_cuts = 24
df = pd.DataFrame({"prob": all_probs_test, "label": all_labels_test})

# 1) Bin predictions
df["bin"] = pd.cut(df["prob"], bins=num_cuts, include_lowest=True)

# 2) Group by bin, compute observed fraction, expected fraction, sample size, standard error
grouped = (
    df.groupby("bin")
    .agg(
        observed=("label", "mean"),
        expected=("prob", "mean"),
        n=("label", "count")
    )
    .reset_index()
)

grouped["se"] = np.sqrt(grouped["observed"] * (1 - grouped["observed"]) / grouped["n"])

# 3) Plot observed vs. expected
plt.figure(figsize=(6, 6))
plt.errorbar(
    x=grouped["expected"],
    y=grouped["observed"],
    yerr=1.96 * grouped["se"],
    fmt="o",
    capsize=3,
    label="Binned Data"
)
plt.plot([0, 1], [0, 1], "r--", label="Perfect Calibration")
sns.regplot(
    x="expected",
    y="observed",
    data=grouped,
    scatter=False,
    lowess=True,
    label="Loess Smooth",
    color="black"
)

plt.xlabel("Expected Probability")
plt.ylabel("Observed Fraction")
plt.title("BiTimelyGPT Calibration Plot")
plt.legend(loc="best")
plt.show()
# Out:
# <ipython-input-27-012e26af68cf>:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("bin")

# %%
########################################
# 4) ROC Curve on set-c
########################################
fpr_test, tpr_test, _ = roc_curve(all_labels_test, all_probs_test)
roc_auc_test = auc(fpr_test, tpr_test)

plt.figure(figsize=(6, 6))
sns.lineplot(x=fpr_test, y=tpr_test, color='black', linewidth=2,
             label=f'ROC (AUC = {roc_auc_test:.3f})')
plt.plot([0, 1], [0, 1], 'r--', label='No Skill')
plt.xlabel('False Positive Rate', fontsize=11)
plt.ylabel('True Positive Rate', fontsize=11)
plt.title('BiTimelyGPT ROC Curve', fontsize=13)
plt.legend(loc='lower right')
plt.show()
