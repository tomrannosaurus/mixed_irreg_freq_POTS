# %%
################################################################################
# GRU-D - Factorial Experiment (Simulated Data, no threshold sweep)
################################################################################

import itertools
import time
import torch
import numpy as np
import pandas as pd
import os
import math

from sklearn.metrics import roc_curve, auc

from google.colab import drive
drive.mount('/content/drive')

# %load_ext rpy2.ipython
from rpy2.robjects import pandas2ri
import rpy2.robjects as ro
pandas2ri.activate()

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import copy

from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
################################################################################
# 2) Define the R DGP script path and load into Colab
################################################################################
# %%R
source("drive/MyDrive/sim_dgp.R")

# %%
import numpy as np

def create_grud_format_pivot(df_vars, df_outcomes, feature_list, max_time_steps=300):
    """
    Build (X, mask, delta, y) for GRU-D by pivoting each subject's data (time,variable->value)
    into a consistent wide format, computing sorted time steps + deltas, then padding/truncating
    the final sequences. If all subjects' actual sequences are shorter than max_time_steps,
    we dynamically reduce to that actual max length.

    :param df_vars:       DataFrame with columns [ID, time, variable, value]
    :param df_outcomes:   DataFrame with columns [ID, time, Y] (plus possibly 'true_prob')
    :param feature_list:  List of feature names, e.g. ["X1", "X2", "X3", ...]
    :param max_time_steps: The absolute maximum sequence length we allow to keep;
                           if the actual largest sequence among all subjects is smaller,
                           we use the smaller length to avoid excess zero-padding.
    :return: X, mask, delta, y (all np.ndarrays), with shapes:
             - X.shape     = (N, final_time_steps, p)
             - mask.shape  = (N, final_time_steps, p)
             - delta.shape = (N, final_time_steps, p)
             - y.shape     = (N,)
    """

    feature_list = sorted(feature_list)

    subject_ids = df_vars['ID'].unique()
    subject_ids.sort()
    p = len(feature_list)

    X_list = []
    mask_list = []
    delta_list = []
    y_list = []

    for sid in subject_ids:
        df_sub = df_vars[df_vars['ID'] == sid].copy()
        df_sub_out = df_outcomes[df_outcomes['ID'] == sid]

        if len(df_sub_out) == 0:
            continue

        y_val = df_sub_out['Y'].values[0]

        wide_df = df_sub.pivot_table(index='time', columns='variable', values='value')
        wide_df = wide_df.sort_index().reset_index()

        wide_df = wide_df.reindex(columns=['time'] + feature_list)

        time_vals = wide_df['time'].values
        feature_vals = wide_df[feature_list].values

        if len(time_vals) == 0:
            continue

        delta_time = np.diff(time_vals, prepend=time_vals[0])
        delta_time = np.where(delta_time == 0, 1.0, delta_time)

        mask_vals = ~np.isnan(feature_vals)
        mask_vals = mask_vals.astype(float)

        feature_vals = np.nan_to_num(feature_vals, nan=0.0)

        delta_vals = np.tile(delta_time.reshape(-1, 1), (1, p))

        X_list.append(feature_vals)
        mask_list.append(mask_vals)
        delta_list.append(delta_vals)
        y_list.append(y_val)

    if len(X_list) == 0:
        return (np.array([]), np.array([]), np.array([]), np.array([]))

    largest_actual_len = max(x.shape[0] for x in X_list)
    final_time_steps = min(largest_actual_len, max_time_steps)

    N = len(X_list)
    X_out = np.zeros((N, final_time_steps, p), dtype=float)
    M_out = np.zeros((N, final_time_steps, p), dtype=float)
    D_out = np.zeros((N, final_time_steps, p), dtype=float)
    Y_out = np.array(y_list).astype(int)

    for i in range(N):
        seq_len = X_list[i].shape[0]
        use_len = min(seq_len, final_time_steps)

        X_out[i, :use_len, :] = X_list[i][:use_len, :]
        M_out[i, :use_len, :] = mask_list[i][:use_len, :]
        D_out[i, :use_len, :] = delta_list[i][:use_len, :]

    return X_out, M_out, D_out, Y_out

# %%
import math

class GRUD(nn.Module):
    def __init__(
        self,
        input_size,
        hidden_size,
        output_size=1,
        x_mean=None,
        dropout=0.0,
        dropout_type='mloss',
    ):
        """
        input_size: Dimensionality of the features (D).
        hidden_size: Dimensionality of the hidden state (H).
        output_size: Usually 1 for binary classification.
        x_mean: If given, must be a 1D tensor of shape (D,) containing the mean of each feature.
        """
        super(GRUD, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout = dropout
        self.dropout_type = dropout_type

        if x_mean is None:
            self.register_buffer("x_mean", torch.zeros(input_size))
        else:
            if isinstance(x_mean, np.ndarray):
                x_mean = torch.from_numpy(x_mean).float()
            self.register_buffer("x_mean", x_mean)


        self.W_dg_x = nn.Linear(input_size, input_size, bias=True)
        self.W_dg_h = nn.Linear(input_size, hidden_size, bias=True)

        self.w_xz = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.w_hz = nn.Parameter(torch.Tensor(hidden_size, hidden_size))
        self.w_mz = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.b_z  = nn.Parameter(torch.Tensor(hidden_size))

        self.w_xr = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.w_hr = nn.Parameter(torch.Tensor(hidden_size, hidden_size))
        self.w_mr = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.b_r  = nn.Parameter(torch.Tensor(hidden_size))

        self.w_xh = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.w_hh = nn.Parameter(torch.Tensor(hidden_size, hidden_size))
        self.w_mh = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.b_h  = nn.Parameter(torch.Tensor(hidden_size))

        self.w_hy = nn.Parameter(torch.Tensor(hidden_size, output_size))
        self.b_y  = nn.Parameter(torch.Tensor(output_size))

        self.reset_parameters()

    def reset_parameters(self):
        stdv = 1.0 / math.sqrt(self.hidden_size)
        for p in self.parameters():
            nn.init.uniform_(p, -stdv, stdv)

    def forward(self, X, M, Delta):
        """
        X:     (batch_size, T, D)   - raw features
        M:     (batch_size, T, D)   - mask (1 if observed, 0 if missing)
        Delta: (batch_size, T, D)   - time since last observation for each feature
        Returns:
            (batch_size,) or (batch_size, 1) if output_size=1
        """
        batch_size, T, D = X.size()
        H = self.hidden_size

        h = X.new_zeros(batch_size, H)
        x_hat = X.new_zeros(batch_size, D)

        dropout_layer = nn.Dropout(self.dropout)

        for t in range(T):
            x_t = X[:, t, :]
            m_t = M[:, t, :]
            d_t = Delta[:, t, :]

            gamma_x_t = torch.exp(-F.relu(self.W_dg_x(d_t)))
            gamma_h_t = torch.exp(-F.relu(self.W_dg_h(d_t)))

            current_x_mean = self.x_mean.to(x_hat.device)
            x_hat = m_t * x_t + (1 - m_t) * (gamma_x_t * x_hat + (1 - gamma_x_t) * current_x_mean)

            h = gamma_h_t * h

            z = torch.sigmoid(
                x_hat @ self.w_xz + h @ self.w_hz + m_t @ self.w_mz + self.b_z
            )

            r = torch.sigmoid(
                x_hat @ self.w_xr + h @ self.w_hr + m_t @ self.w_mr + self.b_r
            )

            h_tilde = torch.tanh(
                x_hat @ self.w_xh + (r * h) @ self.w_hh + m_t @ self.w_mh + self.b_h
            )

            if self.dropout > 0:
                if self.dropout_type == 'mloss':
                    h_tilde = dropout_layer(h_tilde)
                elif self.dropout_type == 'Gal':
                    h = dropout_layer(h)

            h = (1 - z) * h + z * h_tilde

        y_out = h @ self.w_hy + self.b_y
        y_out = torch.sigmoid(y_out)
        return y_out.squeeze(-1)

# %%
class SimDataset(Dataset):
    def __init__(self, X, mask, delta, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.M = torch.tensor(mask, dtype=torch.float32)
        self.D = torch.tensor(delta, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.M[idx], self.D[idx], self.y[idx]

# %%
################################################################################
# 4) Configuration for the sim data
################################################################################
class SimDataConfig:
    def __init__(self, p):
        self.feature_list   = [f"X{i+1}" for i in range(p)]
        # GRU-D hyperparams
        self.rnn_hidden_size = 32
        self.batch_size      = 32
        self.epochs         = 60
        self.patience       = 15
        self.learning_rate  = 1e-3
        self.max_t_steps    = 50

# %%
import numpy as np

def run_single_scenario(
    N, p,
    regularity,
    missing_prop,
    num_sync_groups,
    process_types,
    use_lags,
    block_missing=True,
    block_length=1.5,
    outcome_time=10,
    master_seed=42
):
    """
    1) Simulate data in R.
    2) 70/15/15 split => train/val/test.
    3) Train GRU-D with PyPOTS's built-in early stopping.
    4) Evaluate on test set => standard metrics from PyPOTS (no threshold sweep).
    """
    # ------------------ 1) Simulate data in R ------------------
    ro.r.assign("N", N)
    ro.r.assign("p", p)
    ro.r.assign("regularity", regularity)
    ro.r.assign("missing_prop", missing_prop)
    ro.r.assign("num_sync_groups", num_sync_groups)

    if isinstance(process_types, list):
        ro.r.assign("process_types", ro.StrVector(process_types))
    else:
        ro.r.assign("process_types", ro.StrVector([process_types]*p))

    ro.r.assign("use_lags", use_lags)
    ro.r.assign("block_missing", block_missing)
    ro.r.assign("block_length", block_length)
    ro.r.assign("outcome_time", outcome_time)
    ro.r.assign("master_seed", master_seed)

    ro.r('''
        sim_dataset <- simulate_experiment_dataset(
          N            = N,
          p            = p,
          freq_min     = 0.5,
          freq_max     = 3.0,
          regularity   = regularity,
          num_sync_groups = num_sync_groups,
          process_types = process_types,
          missing_prop = missing_prop,
          block_missing = block_missing,
          block_length  = block_length,
          outcome_time  = outcome_time,
          beta          = c(0, seq(-1, 1, length.out = 30)),
          use_lags      = use_lags,
          lag_hours     = ifelse(use_lags, 2, 0),
          master_seed   = master_seed
        )
    ''')

    df_vars_r     = ro.r('sim_dataset$vars_long')
    df_outcomes_r = ro.r('sim_dataset$outcome_df')

    df_vars     = df_vars_r
    df_outcomes = df_outcomes_r

    df_vars["ID"]       = df_vars["ID"].astype(int)
    df_vars["time"]     = df_vars["time"].astype(float)
    df_outcomes["ID"]   = df_outcomes["ID"].astype(int)
    df_outcomes["time"] = df_outcomes["time"].astype(float)

    mean_true_prob = df_outcomes["true_prob"].mean()
    prop_positive  = df_outcomes["Y"].mean()

    # ------------------ 2) 70/15/15 split ------------------
    config = SimDataConfig(p)


    X_all, mask_all, delta_all, y_all = create_grud_format_pivot(
    df_vars, df_outcomes, config.feature_list, max_time_steps=config.max_t_steps
    )

    N_total = len(X_all)
    idx = np.arange(N_total)
    np.random.seed(master_seed)
    np.random.shuffle(idx)

    N_train = int(0.70 * N_total)
    N_val   = int(0.15 * N_total)
    N_test  = N_total - N_train - N_val

    train_idx = idx[:N_train]
    val_idx   = idx[N_train:N_train+N_val]
    test_idx  = idx[N_train+N_val:]

    X_train    = X_all[train_idx]
    mask_train = mask_all[train_idx]
    delta_train= delta_all[train_idx]
    y_train    = y_all[train_idx]

    X_val      = X_all[val_idx]
    mask_val   = mask_all[val_idx]
    delta_val  = delta_all[val_idx]
    y_val      = y_all[val_idx]

    X_test     = X_all[test_idx]
    mask_test  = mask_all[test_idx]
    delta_test = delta_all[test_idx]
    y_test     = y_all[test_idx]

    # Create PyTorch Datasets
    train_dataset = SimDataset(X_train, mask_train, delta_train, y_train)
    val_dataset   = SimDataset(X_val, mask_val, delta_val, y_val)
    test_dataset  = SimDataset(X_test, mask_test, delta_test, y_test)

    # Create DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=config.batch_size, shuffle=True, num_workers=0)
    val_loader   = DataLoader(val_dataset, batch_size=config.batch_size, shuffle=False, num_workers=0)
    test_loader  = DataLoader(test_dataset, batch_size=config.batch_size, shuffle=False, num_workers=0)


    # ------------------ 3) Train Custom GRU-D with Manual Early Stopping ------------------
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    n_features = X_train.shape[2]

    train_mask_flat = mask_train.reshape(-1, n_features)
    train_X_flat = X_train.reshape(-1, n_features)
    x_train_means = np.zeros(n_features)
    for feat_idx in range(n_features):
        masked_vals = train_X_flat[train_mask_flat[:, feat_idx].astype(bool), feat_idx]
        if len(masked_vals) > 0:
            x_train_means[feat_idx] = np.mean(masked_vals)
        # else: mean remains 0

    model = GRUD(
        input_size=n_features,
        hidden_size=config.rnn_hidden_size,
        output_size=1,
        x_mean=x_train_means,
        dropout=0.05,
        dropout_type='mloss'
    ).to(device)

    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)

    epochs = config.epochs
    patience = config.patience
    best_val_auc = 0.0
    epochs_no_improve = 0
    best_model_weights = copy.deepcopy(model.state_dict())

    print(f"Starting training for {epochs} epochs with patience {patience}...")
    for epoch in range(1, epochs + 1):
        # --- Training Phase ---
        model.train()
        train_loss_list = []
        train_preds_list = []
        train_truth_list = []

        for Xb, Mb, Db, yb in train_loader:
            Xb, Mb, Db, yb = Xb.to(device), Mb.to(device), Db.to(device), yb.to(device)

            optimizer.zero_grad()
            outputs = model(Xb, Mb, Db)
            loss = criterion(outputs, yb)
            loss.backward()
            optimizer.step()

            train_loss_list.append(loss.item())
            train_preds_list.append(outputs.detach().cpu().numpy())
            train_truth_list.append(yb.detach().cpu().numpy())

        train_loss = np.mean(train_loss_list)
        train_preds_epoch = np.concatenate(train_preds_list)
        train_truth_epoch = np.concatenate(train_truth_list)
        # Handle cases with only one class in batch/epoch for AUC
        try:
            train_auc = roc_auc_score(train_truth_epoch, train_preds_epoch)
        except ValueError:
            train_auc = 0.5

        # --- Validation Phase ---
        model.eval()
        val_loss_list = []
        val_preds_list = []
        val_truth_list = []
        with torch.no_grad():
            for Xb, Mb, Db, yb in val_loader:
                Xb, Mb, Db, yb = Xb.to(device), Mb.to(device), Db.to(device), yb.to(device)
                outputs = model(Xb, Mb, Db)
                loss = criterion(outputs, yb)
                val_loss_list.append(loss.item())
                val_preds_list.append(outputs.cpu().numpy())
                val_truth_list.append(yb.cpu().numpy())

        val_loss = np.mean(val_loss_list)
        val_preds_epoch = np.concatenate(val_preds_list)
        val_truth_epoch = np.concatenate(val_truth_list)
        # Handle cases with only one class in batch/epoch for AUC
        try:
            val_auc = roc_auc_score(val_truth_epoch, val_preds_epoch)
        except ValueError:
            val_auc = 0.5

        print(f"Epoch [{epoch}/{epochs}] Train Loss: {train_loss:.4f}, Train AUC: {train_auc:.4f} | Val Loss: {val_loss:.4f}, Val AUC: {val_auc:.4f}")

        # --- Early Stopping Check ---
        if val_auc > best_val_auc:
            best_val_auc = val_auc
            best_model_weights = copy.deepcopy(model.state_dict())
            epochs_no_improve = 0
            print(f"  -> New best validation AUC: {best_val_auc:.4f}")
        else:
            epochs_no_improve += 1
            print(f"  -> Validation AUC did not improve. ({epochs_no_improve}/{patience})")

        if epochs_no_improve >= patience:
            print(f"Early stopping triggered after epoch {epoch}.")
            break

    # Load best model weights found during training
    print(f"Finished training. Loading best model with Val AUC: {best_val_auc:.4f}")
    model.load_state_dict(best_model_weights)


    # ------------------ 4) Evaluate on test set ------------------
    model.eval()
    test_preds_list = []
    test_truth_list = []
    with torch.no_grad():
        for Xb, Mb, Db, yb in test_loader:
            Xb, Mb, Db, yb = Xb.to(device), Mb.to(device), Db.to(device), yb.to(device)
            outputs = model(Xb, Mb, Db)
            test_preds_list.append(outputs.cpu().numpy())
            test_truth_list.append(yb.cpu().numpy())

    y_pred_prob_test = np.concatenate(test_preds_list)
    y_true_test = np.concatenate(test_truth_list)

    # Calculate metrics
    test_auc = roc_auc_score(y_true_test, y_pred_prob_test)

    # Use a standard threshold (0.5) for other metrics, like PyPOTS likely did
    threshold = 0.5
    y_pred_test = (y_pred_prob_test >= threshold).astype(int)

    test_accuracy = accuracy_score(y_true_test, y_pred_test, zero_division=0)
    test_prec = precision_score(y_true_test, y_pred_test, zero_division=0)
    test_rec = recall_score(y_true_test, y_pred_test, zero_division=0)
    test_f1 = f1_score(y_true_test, y_pred_test, zero_division=0)
    test_loss = float('nan')

    results_dict = {
        "test_loss":      test_loss,
        "auc":            test_auc,
        "accuracy":       test_accuracy,
        "precision":      test_prec,
        "recall":         test_rec,
        "f1":             test_f1,
        "mean_true_prob": float(mean_true_prob),
        "prop_positive":  float(prop_positive)
    }

    return results_dict

# %%
################################################################################
# 6) Main Loop: Full Factorial Over the 6 Factors
#    w/ updated sync_pattern logic, no threshold sweep.
################################################################################

Ns = [200, 1000, 10000]
regularities = [0.2, 0.8]
missing_props = [0.1, 0.4]
sync_pattern_values = [1, "p"]
process_type_values = ["homogeneous", "mixed"]
outcome_dep_values = ["direct", "lagged"]

scenario_grid = list(itertools.product(
    Ns,
    regularities,
    missing_props,
    sync_pattern_values,
    process_type_values,
    outcome_dep_values
))

all_results = []
overall_start = time.time()

for scenario in scenario_grid:
    (N,
     regularity,
     missing_prop,
     sync_pattern,
     process_type_flag,
     outcome_dep) = scenario

    p = 30
    if process_type_flag == "homogeneous":
        process_types = ["ar1"]*p
    else:
        repeats = math.ceil(p/3)
        big_array = (["ar1","rw","seasonal"]*repeats)[:p]
        process_types = big_array

    if sync_pattern == "p":
        num_sync_groups = max(1, int(round(p/10)))
    else:
        num_sync_groups = 1

    use_lags = (outcome_dep=="lagged")

    print("===================================================================")
    print(f"Scenario => N={N}, reg={regularity}, missing={missing_prop}, "
          f"sync={sync_pattern}, process={process_type_flag}, outcome={outcome_dep}")
    print("===================================================================")

    start_time = time.time()
    results_dict = run_single_scenario(
        N=N,
        p=p,
        regularity=regularity,
        missing_prop=missing_prop,
        num_sync_groups=num_sync_groups,
        process_types=process_types,
        use_lags=use_lags,
        block_missing=True,
        block_length=1.5,
        outcome_time=10,
        master_seed=42
    )
    runtime = time.time() - start_time

    scenario_result = {
        "N":              N,
        "regularity":     regularity,
        "missing_prop":   missing_prop,
        "sync_pattern":   sync_pattern,
        "process_type":   process_type_flag,
        "outcome_dep":    outcome_dep,
        "test_loss":      results_dict["test_loss"],
        "auc":            results_dict["auc"],
        "accuracy":       results_dict["accuracy"],
        "precision":      results_dict["precision"],
        "recall":         results_dict["recall"],
        "f1":             results_dict["f1"],
        "runtime_sec":    runtime,
        "mean_true_prob": results_dict["mean_true_prob"],
        "prop_positive":  results_dict["prop_positive"]
    }
    all_results.append(scenario_result)

overall_runtime = time.time() - overall_start
print(f"\nAll scenarios completed in {overall_runtime/60:.2f} minutes.\n")

df_results = pd.DataFrame(all_results)
df_results.sort_values(by=["N","regularity","missing_prop"], inplace=True)
print(df_results)

df_results.to_csv("drive/MyDrive/grud_factorial_results_REP0.csv", index=False)
print("\nResults saved to grud_factorial_results_REP0.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
# Epo
#   -> Validation AUC did not improve. (3/15)
# Epoch [11/60] Train Loss: 0.4262, Train AUC: 0.9525 | Val Loss: 0.3922, Val AUC: 0.9809
#   -> New best validation AUC: 0.9809
# Epoch [12/60] Train Loss: 0.3946, Train AUC: 0.9538 | Val Loss: 0.3710, Val AUC: 0.9809
#   -> Validation AUC did not improve. (1/15)
# Epoch [13/60] Train Loss: 0.3689, Train AUC: 0.9586 | Val Loss: 0.3407, Val AUC: 0.9809
#   -> Validation AUC did not improve. (2/15)
# Epoch [14/60] Train Loss: 0.3491, Train AUC: 0.9609 | Val Loss: 0.3133, Val AUC: 0.9904
#   -> New best validation AUC: 0.9904
# Epoch [15/60] Train Loss: 0.3367, Train AUC: 0.9636 | Val Loss: 0.3015, Val AUC: 0.9809
#   -> Validation AUC did not improve. (1/15)
# Epoch [16/60] Train Loss: 0.2979, Train AUC: 0.9661 | Val Loss: 0.2825, Val AUC: 0.9904
#   -> Validation AUC did not improve. (2/15)
# Epoch [17/60] Train Loss: 0.2891, Train AUC: 0.9705 | Val Loss: 0.2632, Val AUC: 0.9904
#   -> Validation AUC did not improve. (3/15)
# Epoch [18/60] Train Loss: 0.2549, Train AUC: 0.9734 | Val Loss: 0.2549, Val AUC: 0.9856
#   -> Validation AUC did not improve. (4/15)
# Epoch [19/60] Train Loss: 0.2360, Train AUC: 0.9709 | Val Loss: 0.2356, Val AUC: 0.9856
#   -> Validation AUC did not improve. (5/15)
# Epoch [20/60] Train Loss: 0.2414, Train AUC: 0.9780 | Val Loss: 0.2288, Val AUC: 0.9809
#   -> Validation AUC did not improve. (6/15)
# Epoch [21/60] Train Loss: 0.1956, Train AUC: 0.9784 | Val Loss: 0.2131, Val AUC: 0.9904
#   -> Validation AUC did not improve. (7/15)
# Epoch [22/60] Train Loss: 0.2014, Train AUC: 0.9820 | Val Loss: 0.2167, Val AUC: 0.9904
#   -> Validation AUC did not improve. (8/15)
# Epoch [23/60] Train Loss: 0.1783, Train AUC: 0.9856 | Val Loss: 0.2273, Val AUC: 0.9856
#   -> Validation AUC did not improve. (9/15)
# Epoch [24/60] Train Loss: 0.1603, Train AUC: 0.9872 | Val Loss: 0.2000, Val AUC: 0.9952
#   -> New best validation AUC: 0.9952
# Epoch [25/60] Train Loss: 0.1435, Train AUC: 0.9895 | Val Loss: 0.1859, Val AUC: 0.9904
#   -> Validation AUC did not improve. (1/15)
# Epoch [26/60] Train Loss: 0.1293, Train AUC: 0.9902 | Val Loss: 0.1760, Val AUC: 1.0000
#   -> New best validation AUC: 1.0000
# Epoch [27/60] Train Loss: 0.1196, Train AUC: 0.9939 | Val Loss: 0.1939, Val AUC: 0.9904
#   -> Validation AUC did not improve. (1/15)
# Epoch [28/60] Train Loss: 0.1070, Train AUC: 0.9958 | Val Loss: 0.2190, Val AUC: 0.9761
#   -> Validation AUC did not improve. (2/15)
# Epoch [29/60] Train Loss: 0.0979, Train AUC: 0.9973 | Val Loss: 0.2185, Val AUC: 0.9761
#   -> Validation AUC did not improve. (3/15)
# Epoch [30/60] Train Loss: 0.0883, Train AUC: 0.9990 | Val Loss: 0.2305, Val AUC: 0.9761
#   -> Validation AUC did not improve. (1/15)
# Epoch [21/60] Train Loss: 0.1343, Train AUC: 0.9996 | Val Loss: 0.2140, Val AUC: 0.9866
#   -> Validation AUC did not improve. (2/15)
# Epoch [22/60] Train Loss: 0.0988, Train AUC: 1.0000 | Val Loss: 0.2139, Val AUC: 0.9866
#   -> Validation AUC did not improve. (3/15)
# Epoch [23/60] Train Loss: 0.0884, Train AUC: 1.0000 | Val Loss: 0.2087, Val AUC: 0.9866
#   -> Validation AUC did not improve. (4/15)
# Epoch [24/60] Train Loss: 0.0772, Train AUC: 1.0000 | Val Loss: 0.1841, Val AUC: 0.9821
#   -> Validation AUC did not improve. (5/15)
# Epoch [25/60] Train Loss: 0.0653, Train AUC: 1.0000 | Val Loss: 0.1710, Val AUC: 0.9821
#   -> Validation AUC did not improve. (6/15)
# Epoch [26/60] Train Loss: 0.0598, Train AUC: 1.0000 | Val Loss: 0.1628, Val AUC: 0.9866
#   -> Validation AUC did not improve. (7/15)
# Epoch [27/60] Train Loss: 0.0483, Train AUC: 1.0000 | Val Loss: 0.1550, Val AUC: 0.9821
#   -> Validation AUC did not improve. (8/15)
# Epoch [28/60] Train Loss: 0.0418, Train AUC: 1.0000 | Val Loss: 0.1531, Val AUC: 0.9821
#   -> Validation AUC did not improve. (9/15)
# Epoch [29/60] Train Loss: 0.0362, Train AUC: 1.0000 | Val Loss: 0.1424, Val AUC: 0.9821
#   -> Validation AUC did not improve. (10/15)
# Epoch [30/60] Train Loss: 0.0333, Train AUC: 1.0000 | Val Loss: 0.1367, Val AUC: 0.9866
#   -> Validation AUC did not improve. (11/15)
# Epoch [31/60] Train Loss: 0.0311, Train AUC: 1.0000 | Val Loss: 0.1433, Val AUC: 0.9821
#   -> Validation AUC did not improve. (12/15)
# Epoch [32/60] Train Loss: 0.0284, Train AUC: 1.0000 | Val Loss: 0.1385, Val AUC: 0.9911
#   -> New best validation AUC: 0.9911
# Epoch [33/60] Train Loss: 0.0382, Train AUC: 1.0000 | Val Loss: 0.1459, Val AUC: 0.9821
#   -> Validation AUC did not improve. (1/15)
# Epoch [34/60] Train Loss: 0.0527, Train AUC: 0.9938 | Val Loss: 0.1569, Val AUC: 0.9866
#   -> Validation AUC did not improve. (2/15)
# Epoch [35/60] Train Loss: 0.0598, Train AUC: 0.9963 | Val Loss: 0.1527, Val AUC: 0.9866
#   -> Validation AUC did not improve. (3/15)
# Epoch [36/60] Train Loss: 0.0347, Train AUC: 1.0000 | Val Loss: 0.1286, Val AUC: 0.9911
#   -> Validation AUC did not improve. (4/15)
# Epoch [37/60] Train Loss: 0.0285, Train AUC: 1.0000 | Val Loss: 0.1048, Val AUC: 0.9955
#   -> New best validation AUC: 0.9955
# Epoch [38/60] Train Loss: 0.0299, Train AUC: 1.0000 | Val Loss: 0.1177, Val AUC: 0.9955
#   -> Validation AUC did not improve. (1/15)
# Epoch [39/60] Train Loss: 0.0255, Train AUC: 1.0000 | Val Loss: 0.1190, Val AUC: 0.9911
#   -> Validation AUC did not improve. (2/15)
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 29.
# Finished training. Loading best model with Val AUC: 0.7500
# ===================================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=p, process=homogeneous, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.7058, Train AUC: 0.5451 | Val Loss: 0.6653, Val AUC: 0.6652
#   -> New best validation AUC: 0.6652
# Epoch [2/60] Train Loss: 0.6780, Train AUC: 0.6207 | Val Loss: 0.6671, Val AUC: 0.6563
#   -> Validation AUC did not improve. (1/15)
# Epoch [3/60] Train Loss: 0.6614, Train AUC: 0.6696 | Val Loss: 0.6667, Val AUC: 0.6384
#   -> Validation AUC did not improve. (2/15)
# Epoch [4/60] Train Loss: 0.6430, Train AUC: 0.7107 | Val Loss: 0.6743, Val AUC: 0.6071
#   -> Validation AUC did not improve. (3/15)
# Epoch [5/60] Train Loss: 0.6239, Train AUC: 0.7457 | Val Loss: 0.6792, Val AUC: 0.5714
#   -> Validation AUC did not improve. (4/15)
# Epoch [6/60] Train Loss: 0.5966, Train AUC: 0.7795 | Val Loss: 0.6758, Val AUC: 0.5714
#   -> Validation AUC did not improve. (5/15)
# Epoch [7/60] Train Loss: 0.5924, Train AUC: 0.8104 | Val Loss: 0.6756, Val AUC: 0.5625
#   -> Validation AUC did not improve. (6/15)
# Epoch [8/60] Train Loss: 0.5792, Train AUC: 0.8299 | Val Loss: 0.6842, Val AUC: 0.5804
#   -> Validation AUC did not improve. (7/15)
# Epoch [9/60] Train Loss: 0.5447, Train AUC: 0.8518 | Val Loss: 0.6809, Val AUC: 0.6161
#   -> Validation AUC did not improve. (8/15)
# Epoch [10/60] Train Loss: 0.5252, Train AUC: 0.8710 | Val Loss: 0.6822, Val AUC: 0.6161
#   -> Validation AUC did not improve. (9/15)
# Epoch [11/60] Train Loss: 0.5075, Train AUC: 0.8867 | Val Loss: 0.6933, Val AUC: 0.6161
#   -> Validation AUC did not improve. (10/15)
# Epoch [12/60] Train Loss: 0.4606, Train AUC: 0.9069 | Val Loss: 0.6944, Val AUC: 0.6295
#   -> Validation AUC did not improve. (11/15)
# Epoch [13/60] Train Loss: 0.4401, Train AUC: 0.9188 | Val Loss: 0.7181, Val AUC: 0.6250
#   -> Validation AUC did not improve. (12/15)
# Epoch [14/60] Train Loss: 0.4169, Train AUC: 0.9322 | Val Loss: 0.7349, Val AUC: 0.6473
#   -> Validation AUC did not improve. (13/15)
# Epoch [15/60] Train Loss: 0.3450, Train AUC: 0.9413 | Val Loss: 0.7597, Val AUC: 0.6339
#   -> Validation AUC did not improve. (14/15)
# Epoch [16/60] Train Loss: 0.3161, Train AUC: 0.9530 | Val Loss: 0.8045, Val AUC: 0.6473
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 16.
# Finished training. Loading best model with Val AUC: 0.6652
# ===================================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=p, process=mixed, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.7419, Train AUC: 0.3879 | Val Loss: 0.6667, Val AUC: 0.6124
#   -> New best validation AUC: 0.6124
# Epoch [2/60] Train Loss: 0.6970, Train AUC: 0.4840 | Val Loss: 0.6574, Val AUC: 0.6316
#   -> New best validation AUC: 0.6316
# Epoch [3/60] Train Loss: 0.6606, Train AUC: 0.5968 | Val Loss: 0.6238, Val AUC: 0.7416
#   -> New best validation AUC: 0.7416
# Epoch [4/60] Train Loss: 0.6146, Train AUC: 0.7047 | Val Loss: 0.6008, Val AUC: 0.8038
#   -> New best validation AUC: 0.8038
# Epoch [5/60] Train Loss: 0.5970, Train AUC: 0.8012 | Val Loss: 0.5894, Val AUC: 0.8421
#   -> New best validation AUC: 0.8421
# Epoch [6/60] Train Loss: 0.5645, Train AUC: 0.8581 | Val Loss: 0.5692, Val AUC: 0.9043
#   -> New best validation AUC: 0.9043
# Epoch [7/60] Train Loss: 0.5438, Train AUC: 0.8970 | Val Loss: 0.5567, Val AUC: 0.9139
#   -> New best validation AUC: 0.9139
# Epoch [8/60] Train Loss: 0.5329, Train AUC: 0.9261 | Val Loss: 0.5313, Val AUC: 0.9378
#   -> New best validation AUC: 0.9378
# Epoch [9/60] Train Loss: 0.4814, Train AUC: 0.9552 | Val Loss: 0.5107, Val AUC: 0.9522
#   -> New best validation AUC: 0.9522
# Epoch [10/60] Train Loss: 0.4444, Train AUC: 0.9674 | Val Loss: 0.4864, Val AUC: 0.9809
#   -> New best validation AUC: 0.9809
# Epoch [11/60] Train Loss: 0.4258, Train AUC: 0.9755 | Val Loss: 0.4658, Val AUC: 0.9569
#   -> Validation AUC did not improve. (1/15)
# Epoch [12/60] Train Loss: 0.3774, Train AUC: 0.9856 | Val Loss: 0.4571, Val AUC: 0.9522
#   -> Validation AUC did not improve. (2/15)
# Epoch [13/60] Train Loss: 0.3414, Train AUC: 0.9874 | Val Loss: 0.4183, Val AUC: 0.9617
#   -> Validation AUC did not improve. (3/15)
# Epoch [14/60] Train Loss: 0.3003, Train AUC: 0.9941 | Val Loss: 0.3942, Val AUC: 0.9617
#   -> Validation AUC did not improve. (4/15)
# Epoch [15/60] Train Loss: 0.2801, Train AUC: 0.9929 | Val Loss: 0.3688, Val AUC: 0.9617
#   -> Validation AUC did not improve. (5/15)
# Epoch [16/60] Train Loss: 0.2462, Train AUC: 0.9931 | Val Loss: 0.3236, Val AUC: 0.9856
#   -> New best validation AUC: 0.9856
# Epoch [17/60] Train Loss: 0.2131, Train AUC: 0.9967 | Val Loss: 0.2964, Val AUC: 0.9856
#   -> Validation AUC did not improve. (1/15)
# Epoch [18/60] Train Loss: 0.1976, Train AUC: 0.9958 | Val Loss: 0.2660, Val AUC: 0.9904
#   -> New best validation AUC: 0.9904
# Epoch [19/60] Train Loss: 0.1650, Train AUC: 0.9977 | Val Loss: 0.2381, Val AUC: 0.9809
#   -> Validation AUC did not improve. (1/15)
# Epoch [20/60] Train Loss: 0.1540, Train AUC: 0.9977 | Val Loss: 0.2218, Val AUC: 0.9856
#   -> Validation AUC did not improve. (2/15)
# Epoch [21/60] Train Loss: 0.1356, Train AUC: 0.9998 | Val Loss: 0.2176, Val AUC: 0.9856
#   -> Validation AUC did not improve. (3/15)
# Epoch [22/60] Train Loss: 0.1080, Train AUC: 0.9998 | Val Loss: 0.2146, Val AUC: 0.9856
#   -> Validation AUC did not improve. (4/15)
# Epoch [23/60] Train Loss: 0.0935, Train AUC: 0.9998 | Val Loss: 0.2148, Val AUC: 0.9809
#   -> Validation AUC did not improve. (5/15)
# Epoch [24/60] Train Loss: 0.0846, Train AUC: 1.0000 | Val Loss: 0.2021, Val AUC: 0.9856
#   -> Validation AUC did not improve. (6/15)
# Epoch [25/60] Train Loss: 0.0740, Train AUC: 1.0000 | Val Loss: 0.2061, Val AUC: 0.9761
#   -> Validation AUC did not improve. (7/15)
# Epoch [26/60] Train Loss: 0.0649, Train AUC: 1.0000 | Val Loss: 0.2238, Val AUC: 0.9809
#   -> Validation AUC did not improve. (8/15)
# Epoch [27/60] Train Loss: 0.0591, Train AUC: 1.0000 | Val Loss: 0.2454, Val AUC: 0.9665
#   -> Validation AUC did not improve. (9/15)
# Epoch [28/60] Train Loss: 0.0542, Train AUC: 1.0000 | Val Loss: 0.2356, Val AUC: 0.9713
#   -> Validation AUC did not improve. (10/15)
# Epoch [29/60] Train Loss: 0.0461, Train AUC: 1.0000 | Val Loss: 0.2335, Val AUC: 0.9713
#   -> Validation AUC did not improve. (11/15)
# Epoch [30/60] Train Loss: 0.0435, Train AUC: 1.0000 | Val Loss: 0.2204, Val AUC: 0.9809
#   -> Validation AUC did not improve. (12/15)
# Epoch [31/60] Train Loss: 0.0386, Train AUC: 1.0000 | Val Loss: 0.2102, Val AUC: 0.9761
#   -> Validation AUC did not improve. (13/15)
# Epoch [32/60] Train Loss: 0.0366, Train AUC: 1.0000 | Val Loss: 0.2218, Val AUC: 0.9713
#   -> Validation AUC did not improve. (14/15)
# Epoch [33/60] Train Loss: 0.0315, Train AUC: 1.0000 | Val Loss: 0.2276, Val AUC: 0.9809
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 33.
# Finished training. Loading best model with Val AUC: 0.9904
# ===================================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=p, process=mixed, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.7336, Train AUC: 0.3774 | Val Loss: 0.7235, Val AUC: 0.3426
#   -> New best validation AUC: 0.3426
# Epoch [2/60] Train Loss: 0.6897, Train AUC: 0.5542 | Val Loss: 0.7029, Val AUC: 0.4306
#   -> New best validation AUC: 0.4306
# Epoch [3/60] Train Loss: 0.6606, Train AUC: 0.6861 | Val Loss: 0.6864, Val AUC: 0.5231
#   -> New best validation AUC: 0.5231
# Epoch [4/60] Train Loss: 0.6404, Train AUC: 0.7910 | Val Loss: 0.6762, Val AUC: 0.6019
#   -> New best validation AUC: 0.6019
# Epoch [5/60] Train Loss: 0.5946, Train AUC: 0.8779 | Val Loss: 0.6596, Val AUC: 0.6481
#   -> New best validation AUC: 0.6481
# Epoch [6/60] Train Loss: 0.5766, Train AUC: 0.9108 | Val Loss: 0.6494, Val AUC: 0.6713
#   -> New best validation AUC: 0.6713
# Epoch [7/60] Train Loss: 0.5424, Train AUC: 0.9177 | Val Loss: 0.6435, Val AUC: 0.7176
#   -> New best validation AUC: 0.7176
# Epoch [8/60] Train Loss: 0.5243, Train AUC: 0.9410 | Val Loss: 0.6471, Val AUC: 0.6852
#   -> Validation AUC did not improve. (1/15)
# Epoch [9/60] Train Loss: 0.4847, Train AUC: 0.9457 | Val Loss: 0.6337, Val AUC: 0.7037
#   -> Validation AUC did not improve. (2/15)
# Epoch [10/60] Train Loss: 0.4800, Train AUC: 0.9506 | Val Loss: 0.6347, Val AUC: 0.7176
#   -> Validation AUC did not improve. (3/15)
# Epoch [11/60] Train Loss: 0.4402, Train AUC: 0.9594 | Val Loss: 0.6156, Val AUC: 0.7407
#   -> New best validation AUC: 0.7407
# Epoch [12/60] Train Loss: 0.4166, Train AUC: 0.9690 | Val Loss: 0.6254, Val AUC: 0.7361
#   -> Validation AUC did not improve. (1/15)
# Epoch [13/60] Train Loss: 0.3802, Train AUC: 0.9722 | Val Loss: 0.6080, Val AUC: 0.7500
#   -> New best validation AUC: 0.7500
# Epoch [14/60] Train Loss: 0.3471, Train AUC: 0.9741 | Val Loss: 0.5899, Val AUC: 0.7593
#   -> New best validation AUC: 0.7593
# Epoch [15/60] Train Loss: 0.3223, Train AUC: 0.9796 | Val Loss: 0.6006, Val AUC: 0.7546
#   -> Validation AUC did not improve. (1/15)
# Epoch [16/60] Train Loss: 0.2874, Train AUC: 0.9831 | Val Loss: 0.5800, Val AUC: 0.7685
#   -> New best validation AUC: 0.7685
# Epoch [17/60] Train Loss: 0.2585, Train AUC: 0.9884 | Val Loss: 0.5960, Val AUC: 0.7731
#   -> New best validation AUC: 0.7731
# Epoch [18/60] Train Loss: 0.2355, Train AUC: 0.9904 | Val Loss: 0.5706, Val AUC: 0.8056
#   -> New best validation AUC: 0.8056
# Epoch [19/60] Train Loss: 0.2019, Train AUC: 0.9924 | Val Loss: 0.5718, Val AUC: 0.8241
#   -> New best validation AUC: 0.8241
# Epoch [20/60] Train Loss: 0.1796, Train AUC: 0.9939 | Val Loss: 0.5664, Val AUC: 0.8194
#   -> Validation AUC did not improve. (1/15)
# Epoch [21/60] Train Loss: 0.1539, Train AUC: 0.9959 | Val Loss: 0.5671, Val AUC: 0.8194
#   -> Validation AUC did not improve. (2/15)
# Epoch [22/60] Train Loss: 0.1345, Train AUC: 0.9976 | Val Loss: 0.5497, Val AUC: 0.8426
#   -> New best validation AUC: 0.8426
# Epoch [23/60] Train Loss: 0.1316, Train AUC: 0.9982 | Val Loss: 0.5615, Val AUC: 0.8426
#   -> Validation AUC did not improve. (1/15)
# Epoch [24/60] Train Loss: 0.0989, Train AUC: 0.9992 | Val Loss: 0.5826, Val AUC: 0.8287
#   -> Validation AUC did not improve. (2/15)
# Epoch [25/60] Train Loss: 0.1014, Train AUC: 0.9994 | Val Loss: 0.5966, Val AUC: 0.8380
#   -> Validation AUC did not improve. (3/15)
# Epoch [26/60] Train Loss: 0.0804, Train AUC: 0.9998 | Val Loss: 0.6263, Val AUC: 0.8287
#   -> Validation AUC did not improve. (4/15)
# Epoch [27/60] Train Loss: 0.0708, Train AUC: 1.0000 | Val Loss: 0.6539, Val AUC: 0.8380
#   -> Validation AUC did not improve. (5/15)
# Epoch [28/60] Train Loss: 0.0841, Train AUC: 0.9947 | Val Loss: 0.6168, Val AUC: 0.8426
#   -> Validation AUC did not improve. (6/15)
# Epoch [29/60] Train Loss: 0.0556, Train AUC: 1.0000 | Val Loss: 0.6561, Val AUC: 0.8241
#   -> Validation AUC did not improve. (7/15)
# Epoch [30/60] Train Loss: 0.0549, Train AUC: 1.0000 | Val Loss: 0.6577, Val AUC: 0.8333
#   -> Validation AUC did not improve. (8/15)
# Epoch [31/60] Train Loss: 0.0685, Train AUC: 1.0000 | Val Loss: 0.6978, Val AUC: 0.8380
#   -> Validation AUC did not improve. (9/15)
# Epoch [32/60] Train Loss: 0.0593, Train AUC: 1.0000 | Val Loss: 0.7084, Val AUC: 0.8380
#   -> Validation AUC did not improve. (10/15)
# Epoch [33/60] Train Loss: 0.0523, Train AUC: 1.0000 | Val Loss: 0.7092, Val AUC: 0.8241
#   -> Validation AUC did not improve. (11/15)
# Epoch [34/60] Train Loss: 0.0445, Train AUC: 1.0000 | Val Loss: 0.6816, Val AUC: 0.8611
#   -> New best validation AUC: 0.8611
# Epoch [35/60] Train Loss: 0.0395, Train AUC: 1.0000 | Val Loss: 0.7043, Val AUC: 0.8287
#   -> Validation AUC did not improve. (1/15)
# Epoch [36/60] Train Loss: 0.0376, Train AUC: 1.0000 | Val Loss: 0.6794, Val AUC: 0.8380
#   -> Validation AUC did not improve. (2/15)
# Epoch [37/60] Train Loss: 0.0368, Train AUC: 1.0000 | Val Loss: 0.6702, Val AUC: 0.8611
#   -> New best validation AUC: 0.8611
# Epoch [38/60] Train Loss: 0.0327, Train AUC: 1.0000 | Val Loss: 0.6924, Val AUC: 0.8472
#   -> Validation AUC did not improve. (1/15)
# Epoch [39/60] Train Loss: 0.0337, Train AUC: 1.0000 | Val Loss: 0.7076, Val AUC: 0.8333
#   -> Validation AUC did not improve. (2/15)
# Epoch [40/60] Train Loss: 0.0279, Train AUC: 1.0000 | Val Loss: 0.7227, Val AUC: 0.8426
#   -> Validation AUC did not improve. (3/15)
# Epoch [41/60] Train Loss: 0.0303, Train AUC: 1.0000 | Val Loss: 0.7380, Val AUC: 0.8565
#   -> Validation AUC did not improve. (4/15)
# Epoch [42/60] Train Loss: 0.0248, Train AUC: 1.0000 | Val Loss: 0.7406, Val AUC: 0.8426
#   -> Validation AUC did not improve. (5/15)
# Epoch [43/60] Train Loss: 0.0238, Train AUC: 1.0000 | Val Loss: 0.7422, Val AUC: 0.8472
#   -> Validation AUC did not improve. (6/15)
# Epoch [44/60] Train Loss: 0.0217, Train AUC: 1.0000 | Val Loss: 0.7250, Val AUC: 0.8519
#   -> Validation AUC did not improve. (7/15)
# Epoch [45/60] Train Loss: 0.0210, Train AUC: 1.0000 | Val Loss: 0.7494, Val AUC: 0.8472
#   -> Validation AUC did not improve. (8/15)
# Epoch [46/60] Train Loss: 0.0194, Train AUC: 1.0000 | Val Loss: 0.7711, Val AUC: 0.8519
#   -> Validation AUC did not improve. (9/15)
# Epoch [47/60] Train Loss: 0.0202, Train AUC: 1.0000 | Val Loss: 0.7697, Val AUC: 0.8472
#   -> Validation AUC did not improve. (10/15)
# Epoch [48/60] Train Loss: 0.0186, Train AUC: 1.0000 | Val Loss: 0.7845, Val AUC: 0.8380
#   -> Validation AUC did not improve. (11/15)
# Epoch [49/60] Train Loss: 0.0162, Train AUC: 1.0000 | Val Loss: 0.7706, Val AUC: 0.8472
#   -> Validation AUC did not improve. (12/15)
# Epoch [50/60] Train Loss: 0.0154, Train AUC: 1.0000 | Val Loss: 0.7806, Val AUC: 0.8426
#   -> Validation AUC did not improve. (13/15)
# Epoch [51/60] Train Loss: 0.0159, Train AUC: 1.0000 | Val Loss: 0.7800, Val AUC: 0.8426
#   -> Validation AUC did not improve. (14/15)
# Epoch [52/60] Train Loss: 0.0154, Train AUC: 1.0000 | Val Loss: 0.7893, Val AUC: 0.8565
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 52.
# Finished training. Loading best model with Val AUC: 0.8611
# ===================================================================
# Scenario => N=200, reg=0.8, missing=0.4, sync=1, process=homogeneous, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.7234, Train AUC: 0.4220 | Val Loss: 0.7432, Val AUC: 0.3348
#   -> New best validation AUC: 0.3348
# Epoch [2/60] Train Loss: 0.7005, Train AUC: 0.5368 | Val Loss: 0.7283, Val AUC: 0.4208
#   -> New best validation AUC: 0.4208
# Epoch [3/60] Train Loss: 0.6815, Train AUC: 0.6528 | Val Loss: 0.7245, Val AUC: 0.4480
#   -> New best validation AUC: 0.4480
# Epoch [4/60] Train Loss: 0.6661, Train AUC: 0.7312 | Val Loss: 0.7214, Val AUC: 0.4570
#   -> New best validation AUC: 0.4570
# Epoch [5/60] Train Loss: 0.6408, Train AUC: 0.8105 | Val Loss: 0.7068, Val AUC: 0.5339
#   -> New best validation AUC: 0.5339
# Epoch [6/60] Train Loss: 0.6265, Train AUC: 0.8576 | Val Loss: 0.7043, Val AUC: 0.4932
#   -> Validation AUC did not improve. (1/15)
# Epoch [7/60] Train Loss: 0.6111, Train AUC: 0.8744 | Val Loss: 0.7003, Val AUC: 0.5475
#   -> New best validation AUC: 0.5475
# Epoch [8/60] Train Loss: 0.5924, Train AUC: 0.8993 | Val Loss: 0.6890, Val AUC: 0.5837
#   -> New best validation AUC: 0.5837
# Epoch [9/60] Train Loss: 0.5578, Train AUC: 0.9103 | Val Loss: 0.6833, Val AUC: 0.5928
#   -> New best validation AUC: 0.5928
# Epoch [10/60] Train Loss: 0.5333, Train AUC: 0.9205 | Val Loss: 0.6841, Val AUC: 0.6063
#   -> New best validation AUC: 0.6063
# Epoch [11/60] Train Loss: 0.5078, Train AUC: 0.9259 | Val Loss: 0.6715, Val AUC: 0.6199
#   -> New best validation AUC: 0.6199
# Epoch [12/60] Train Loss: 0.4593, Train AUC: 0.9348 | Val Loss: 0.6771, Val AUC: 0.6154
#   -> Validation AUC did not improve. (1/15)
# Epoch [13/60] Train Loss: 0.4450, Train AUC: 0.9353 | Val Loss: 0.6744, Val AUC: 0.6244
#   -> New best validation AUC: 0.6244
# Epoch [14/60] Train Loss: 0.4195, Train AUC: 0.9361 | Val Loss: 0.6887, Val AUC: 0.6380
#   -> New best validation AUC: 0.6380
# Epoch [15/60] Train Loss: 0.3561, Train AUC: 0.9453 | Val Loss: 0.7129, Val AUC: 0.6516
#   -> New best validation AUC: 0.6516
# Epoch [16/60] Train Loss: 0.3097, Train AUC: 0.9512 | Val Loss: 0.7242, Val AUC: 0.6606
#   -> New best validation AUC: 0.6606
# ...
# Epoch [21/60] Train Loss: 0.0771, Train AUC: 0.9958 | Val Loss: 0.3985, Val AUC: 0.9577
#   -> Validation AUC did not improve. (13/15)
# Epoch [22/60] Train Loss: 0.0736, Train AUC: 0.9961 | Val Loss: 0.3911, Val AUC: 0.9555
#   -> Validation AUC did not improve. (14/15)
# Epoch [23/60] Train Loss: 0.0659, Train AUC: 0.9967 | Val Loss: 0.4117, Val AUC: 0.9538
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 23.
# Finished training. Loading best model with Val AUC: 0.9633
# ===================================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=p, process=homogeneous, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.5290, Train AUC: 0.8154 | Val Loss: 0.4571, Val AUC: 0.8648
#   -> New best validation AUC: 0.8648
# Epoch [2/60] Train Loss: 0.4269, Train AUC: 0.8838 | Val Loss: 0.4403, Val AUC: 0.8757
#   -> New best validation AUC: 0.8757
# Epoch [3/60] Train Loss: 0.4102, Train AUC: 0.8926 | Val Loss: 0.4341, Val AUC: 0.8774
#   -> New best validation AUC: 0.8774
# Epoch [4/60] Train Loss: 0.3964, Train AUC: 0.8998 | Val Loss: 0.4295, Val AUC: 0.8795
#   -> New best validation AUC: 0.8795
# Epoch [5/60] Train Loss: 0.3879, Train AUC: 0.9040 | Val Loss: 0.4343, Val AUC: 0.8776
#   -> Validation AUC did not improve. (1/15)
# Epoch [6/60] Train Loss: 0.3783, Train AUC: 0.9089 | Val Loss: 0.4310, Val AUC: 0.8783
#   -> Validation AUC did not improve. (2/15)
# Epoch [7/60] Train Loss: 0.3711, Train AUC: 0.9127 | Val Loss: 0.4322, Val AUC: 0.8799
#   -> New best validation AUC: 0.8799
# Epoch [8/60] Train Loss: 0.3626, Train AUC: 0.9164 | Val Loss: 0.4391, Val AUC: 0.8745
#   -> Validation AUC did not improve. (1/15)
# Epoch [9/60] Train Loss: 0.3526, Train AUC: 0.9216 | Val Loss: 0.4538, Val AUC: 0.8721
#   -> Validation AUC did not improve. (2/15)
# Epoch [10/60] Train Loss: 0.3454, Train AUC: 0.9249 | Val Loss: 0.4591, Val AUC: 0.8728
#   -> Validation AUC did not improve. (3/15)
# Epoch [11/60] Train Loss: 0.3372, Train AUC: 0.9286 | Val Loss: 0.4730, Val AUC: 0.8675
#   -> Validation AUC did not improve. (4/15)
# Epoch [12/60] Train Loss: 0.3234, Train AUC: 0.9348 | Val Loss: 0.5051, Val AUC: 0.8611
#   -> Validation AUC did not improve. (5/15)
# Epoch [13/60] Train Loss: 0.3167, Train AUC: 0.9378 | Val Loss: 0.4865, Val AUC: 0.8657
#   -> Validation AUC did not improve. (6/15)
# Epoch [14/60] Train Loss: 0.3095, Train AUC: 0.9405 | Val Loss: 0.5096, Val AUC: 0.8609
#   -> Validation AUC did not improve. (7/15)
# Epoch [15/60] Train Loss: 0.2967, Train AUC: 0.9459 | Val Loss: 0.5334, Val AUC: 0.8581
#   -> Validation AUC did not improve. (8/15)
# Epoch [16/60] Train Loss: 0.2834, Train AUC: 0.9509 | Val Loss: 0.5459, Val AUC: 0.8552
#   -> Validation AUC did not improve. (9/15)
# Epoch [17/60] Train Loss: 0.2885, Train AUC: 0.9494 | Val Loss: 0.5323, Val AUC: 0.8577
#   -> Validation AUC did not improve. (10/15)
# Epoch [18/60] Train Loss: 0.2678, Train AUC: 0.9565 | Val Loss: 0.5646, Val AUC: 0.8540
#   -> Validation AUC did not improve. (11/15)
# Epoch [19/60] Train Loss: 0.2602, Train AUC: 0.9591 | Val Loss: 0.5856, Val AUC: 0.8503
#   -> Validation AUC did not improve. (12/15)
# Epoch [20/60] Train Loss: 0.2461, Train AUC: 0.9640 | Val Loss: 0.5967, Val AUC: 0.8523
#   -> Validation AUC did not improve. (13/15)
# Epoch [21/60] Train Loss: 0.2428, Train AUC: 0.9647 | Val Loss: 0.6108, Val AUC: 0.8482
#   -> Validation AUC did not improve. (14/15)
# Epoch [22/60] Train Loss: 0.2332, Train AUC: 0.9674 | Val Loss: 0.6338, Val AUC: 0.8456
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 22.
# Finished training. Loading best model with Val AUC: 0.8799
# ===================================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=p, process=homogeneous, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.5525, Train AUC: 0.7908 | Val Loss: 0.4853, Val AUC: 0.8488
#   -> New best validation AUC: 0.8488
# Epoch [2/60] Train Loss: 0.4796, Train AUC: 0.8516 | Val Loss: 0.4758, Val AUC: 0.8557
#   -> New best validation AUC: 0.8557
# Epoch [3/60] Train Loss: 0.4669, Train AUC: 0.8606 | Val Loss: 0.4818, Val AUC: 0.8520
#   -> Validation AUC did not improve. (1/15)
# Epoch [4/60] Train Loss: 0.4542, Train AUC: 0.8687 | Val Loss: 0.4709, Val AUC: 0.8585
#   -> New best validation AUC: 0.8585
# Epoch [5/60] Train Loss: 0.4375, Train AUC: 0.8791 | Val Loss: 0.4722, Val AUC: 0.8589
#   -> New best validation AUC: 0.8589
# Epoch [6/60] Train Loss: 0.4229, Train AUC: 0.8875 | Val Loss: 0.4585, Val AUC: 0.8675
#   -> New best validation AUC: 0.8675
# Epoch [7/60] Train Loss: 0.4078, Train AUC: 0.8960 | Val Loss: 0.4672, Val AUC: 0.8653
#   -> Validation AUC did not improve. (1/15)
# Epoch [8/60] Train Loss: 0.3910, Train AUC: 0.9047 | Val Loss: 0.4700, Val AUC: 0.8631
#   -> Validation AUC did not improve. (2/15)
# Epoch [9/60] Train Loss: 0.3822, Train AUC: 0.9092 | Val Loss: 0.4728, Val AUC: 0.8615
#   -> Validation AUC did not improve. (3/15)
# Epoch [10/60] Train Loss: 0.3695, Train AUC: 0.9154 | Val Loss: 0.4766, Val AUC: 0.8648
#   -> Validation AUC did not improve. (4/15)
# Epoch [11/60] Train Loss: 0.3578, Train AUC: 0.9208 | Val Loss: 0.4773, Val AUC: 0.8641
#   -> Validation AUC did not improve. (5/15)
# Epoch [12/60] Train Loss: 0.3533, Train AUC: 0.9229 | Val Loss: 0.4983, Val AUC: 0.8553
#   -> Validation AUC did not improve. (6/15)
# Epoch [13/60] Train Loss: 0.3383, Train AUC: 0.9295 | Val Loss: 0.5000, Val AUC: 0.8564
#   -> Validation AUC did not improve. (7/15)
# Epoch [14/60] Train Loss: 0.3278, Train AUC: 0.9340 | Val Loss: 0.5293, Val AUC: 0.8490
#   -> Validation AUC did not improve. (8/15)
# Epoch [15/60] Train Loss: 0.3197, Train AUC: 0.9372 | Val Loss: 0.5065, Val AUC: 0.8568
#   -> Validation AUC did not improve. (9/15)
# Epoch [16/60] Train Loss: 0.3179, Train AUC: 0.9379 | Val Loss: 0.5264, Val AUC: 0.8533
#   -> Validation AUC did not improve. (10/15)
# Epoch [17/60] Train Loss: 0.3024, Train AUC: 0.9438 | Val Loss: 0.5333, Val AUC: 0.8489
#   -> Validation AUC did not improve. (11/15)
# Epoch [18/60] Train Loss: 0.2925, Train AUC: 0.9476 | Val Loss: 0.5474, Val AUC: 0.8435
#   -> Validation AUC did not improve. (12/15)
# Epoch [19/60] Train Loss: 0.2845, Train AUC: 0.9505 | Val Loss: 0.5611, Val AUC: 0.8452
#   -> Validation AUC did not improve. (13/15)
# Epoch [20/60] Train Loss: 0.2747, Train AUC: 0.9537 | Val Loss: 0.5634, Val AUC: 0.8472
#   -> Validation AUC did not improve. (14/15)
# Epoch [21/60] Train Loss: 0.2634, Train AUC: 0.9574 | Val Loss: 0.5652, Val AUC: 0.8495
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 21.
# Finished training. Loading best model with Val AUC: 0.8675
# ===================================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.4011, Train AUC: 0.9054 | Val Loss: 0.2678, Val AUC: 0.9566
#   -> New best validation AUC: 0.9566
# Epoch [2/60] Train Loss: 0.2458, Train AUC: 0.9636 | Val Loss: 0.2493, Val AUC: 0.9617
#   -> New best validation AUC: 0.9617
# Epoch [3/60] Train Loss: 0.2291, Train AUC: 0.9680 | Val Loss: 0.2433, Val AUC: 0.9640
#   -> New best validation AUC: 0.9640
# Epoch [4/60] Train Loss: 0.2162, Train AUC: 0.9716 | Val Loss: 0.2536, Val AUC: 0.9628
#   -> Validation AUC did not improve. (1/15)
# Epoch [5/60] Train Loss: 0.2045, Train AUC: 0.9746 | Val Loss: 0.2507, Val AUC: 0.9636
#   -> Validation AUC did not improve. (2/15)
# Epoch [6/60] Train Loss: 0.1963, Train AUC: 0.9767 | Val Loss: 0.2426, Val AUC: 0.9650
#   -> New best validation AUC: 0.9650
# Epoch [7/60] Train Loss: 0.1892, Train AUC: 0.9783 | Val Loss: 0.2517, Val AUC: 0.9635
#   -> Validation AUC did not improve. (1/15)
# Epoch [8/60] Train Loss: 0.1809, Train AUC: 0.9800 | Val Loss: 0.2562, Val AUC: 0.9637
#   -> Validation AUC did not improve. (2/15)
# Epoch [9/60] Train Loss: 0.1718, Train AUC: 0.9820 | Val Loss: 0.2582, Val AUC: 0.9629
#   -> Validation AUC did not improve. (3/15)
# Epoch [10/60] Train Loss: 0.1650, Train AUC: 0.9833 | Val Loss: 0.2613, Val AUC: 0.9617
#   -> Validation AUC did not improve. (4/15)
# Epoch [11/60] Train Loss: 0.1597, Train AUC: 0.9844 | Val Loss: 0.2701, Val AUC: 0.9623
#   -> Validation AUC did not improve. (5/15)
# Epoch [12/60] Train Loss: 0.1481, Train AUC: 0.9865 | Val Loss: 0.2778, Val AUC: 0.9605
#   -> Validation AUC did not improve. (6/15)
# Epoch [13/60] Train Loss: 0.1466, Train AUC: 0.9869 | Val Loss: 0.2900, Val AUC: 0.9590
#   -> Validation AUC did not improve. (7/15)
# Epoch [14/60] Train Loss: 0.1355, Train AUC: 0.9887 | Val Loss: 0.3074, Val AUC: 0.9575
#   -> Validation AUC did not improve. (8/15)
# Epoch [15/60] Train Loss: 0.1361, Train AUC: 0.9886 | Val Loss: 0.3069, Val AUC: 0.9561
#   -> Validation AUC did not improve. (9/15)
# Epoch [16/60] Train Loss: 0.1299, Train AUC: 0.9897 | Val Loss: 0.3116, Val AUC: 0.9577
#   -> Validation AUC did not improve. (10/15)
# Epoch [17/60] Train Loss: 0.1241, Train AUC: 0.9906 | Val Loss: 0.3185, Val AUC: 0.9576
#   -> Validation AUC did not improve. (11/15)
# Epoch [18/60] Train Loss: 0.1187, Train AUC: 0.9914 | Val Loss: 0.3636, Val AUC: 0.9535
#   -> Validation AUC did not improve. (12/15)
# Epoch [19/60] Train Loss: 0.1105, Train AUC: 0.9924 | Val Loss: 0.3434, Val AUC: 0.9541
#   -> Validation AUC did not improve. (13/15)
# Epoch [20/60] Train Loss: 0.1014, Train AUC: 0.9937 | Val Loss: 0.3750, Val AUC: 0.9516
#   -> Validation AUC did not improve. (14/15)
# Epoch [21/60] Train Loss: 0.0993, Train AUC: 0.9938 | Val Loss: 0.3973, Val AUC: 0.9502
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 21.
# Finished training. Loading best model with Val AUC: 0.9650
# ===================================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.4062, Train AUC: 0.9033 | Val Loss: 0.2960, Val AUC: 0.9483
#   -> New best validation AUC: 0.9483
# Epoch [2/60] Train Loss: 0.2751, Train AUC: 0.9549 | Val Loss: 0.2899, Val AUC: 0.9500
#   -> New best validation AUC: 0.9500
# Epoch [3/60] Train Loss: 0.2570, Train AUC: 0.9604 | Val Loss: 0.2757, Val AUC: 0.9548
#   -> New best validation AUC: 0.9548
# Epoch [4/60] Train Loss: 0.2446, Train AUC: 0.9640 | Val Loss: 0.2897, Val AUC: 0.9525
#   -> Validation AUC did not improve. (1/15)
# Epoch [5/60] Train Loss: 0.2345, Train AUC: 0.9669 | Val Loss: 0.2790, Val AUC: 0.9539
#   -> Validation AUC did not improve. (2/15)
# Epoch [6/60] Train Loss: 0.2235, Train AUC: 0.9696 | Val Loss: 0.2772, Val AUC: 0.9549
#   -> New best validation AUC: 0.9549
# Epoch [7/60] Train Loss: 0.2135, Train AUC: 0.9723 | Val Loss: 0.2771, Val AUC: 0.9548
#   -> Validation AUC did not improve. (1/15)
# Epoch [8/60] Train Loss: 0.2019, Train AUC: 0.9751 | Val Loss: 0.2864, Val AUC: 0.9549
#   -> New best validation AUC: 0.9549
# Epoch [9/60] Train Loss: 0.1930, Train AUC: 0.9771 | Val Loss: 0.2810, Val AUC: 0.9560
#   -> New best validation AUC: 0.9560
# Epoch [10/60] Train Loss: 0.1813, Train AUC: 0.9797 | Val Loss: 0.3010, Val AUC: 0.9533
#   -> Validation AUC did not improve. (1/15)
# Epoch [11/60] Train Loss: 0.1713, Train AUC: 0.9818 | Val Loss: 0.3186, Val AUC: 0.9510
#   -> Validation AUC did not improve. (2/15)
# Epoch [12/60] Train Loss: 0.1648, Train AUC: 0.9831 | Val Loss: 0.3048, Val AUC: 0.9521
#   -> Validation AUC did not improve. (3/15)
# Epoch [13/60] Train Loss: 0.1575, Train AUC: 0.9845 | Val Loss: 0.3032, Val AUC: 0.9525
#   -> Validation AUC did not improve. (4/15)
# Epoch [14/60] Train Loss: 0.1478, Train AUC: 0.9861 | Val Loss: 0.3175, Val AUC: 0.9503
#   -> Validation AUC did not improve. (5/15)
# Epoch [15/60] Train Loss: 0.1367, Train AUC: 0.9883 | Val Loss: 0.3427, Val AUC: 0.9501
#   -> Validation AUC did not improve. (6/15)
# Epoch [16/60] Train Loss: 0.1339, Train AUC: 0.9884 | Val Loss: 0.3318, Val AUC: 0.9503
#   -> Validation AUC did not improve. (7/15)
# Epoch [17/60] Train Loss: 0.1264, Train AUC: 0.9895 | Val Loss: 0.3256, Val AUC: 0.9504
#   -> Validation AUC did not improve. (8/15)
# Epoch [18/60] Train Loss: 0.1309, Train AUC: 0.9888 | Val Loss: 0.3270, Val AUC: 0.9534
#   -> Validation AUC did not improve. (9/15)
# Epoch [19/60] Train Loss: 0.1166, Train AUC: 0.9910 | Val Loss: 0.3670, Val AUC: 0.9472
#   -> Validation AUC did not improve. (10/15)
# Epoch [20/60] Train Loss: 0.1085, Train AUC: 0.9922 | Val Loss: 0.3604, Val AUC: 0.9475
#   -> Validation AUC did not improve. (11/15)
# Epoch [21/60] Train Loss: 0.1065, Train AUC: 0.9923 | Val Loss: 0.3724, Val AUC: 0.9471
#   -> Validation AUC did not improve. (12/15)
# Epoch [22/60] Train Loss: 0.1051, Train AUC: 0.9926 | Val Loss: 0.3524, Val AUC: 0.9457
#   -> Validation AUC did not improve. (13/15)
# Epoch [23/60] Train Loss: 0.1045, Train AUC: 0.9928 | Val Loss: 0.3709, Val AUC: 0.9502
#   -> Validation AUC did not improve. (14/15)
# Epoch [24/60] Train Loss: 0.0866, Train AUC: 0.9946 | Val Loss: 0.4009, Val AUC: 0.9456
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 24.
# Finished training. Loading best model with Val AUC: 0.9560
#
# All scenarios completed in 491.76 minutes.
#
#         N  regularity  missing_prop sync_pattern process_type outcome_dep  \
# 0     200         0.2           0.1            1  homogeneous      direct
# 1     200         0.2           0.1            1  homogeneous      lagged
# 2     200         0.2           0.1            1        mixed      direct
# 3     200         0.2           0.1            1        mixed      lagged
# 4     200         0.2           0.1            p  homogeneous      direct
# ..    ...         ...           ...          ...          ...         ...
# 91  10000         0.8           0.4            1        mixed      lagged
# 92  10000         0.8           0.4            p  homogeneous      direct
# 93  10000         0.8           0.4            p  homogeneous      lagged
# 94  10000         0.8           0.4            p        mixed      direct
# 95  10000         0.8           0.4            p        mixed      lagged
#
#     test_loss       auc  accuracy  precision    recall        f1  runtime_sec  \
# 0         NaN  0.810000  0.666667   0.750000  0.750000  0.750000    22.599245
# 1         NaN  0.826667  0.733333   0.769231  0.666667  0.714286    27.555321
# 2         NaN  0.973214  0.866667   0.857143  0.857143  0.857143    23.144060
# 3         NaN  0.966507  0.966667   1.000000  0.947368  0.972973    21.564118
# 4         NaN  0.751131  0.733333   0.800000  0.705882  0.750000    27.906574
# ..        ...       ...       ...        ...       ...       ...          ...
# 91        NaN  0.969799  0.912000   0.910798  0.932692  0.921615   698.306484
# 92        NaN  0.886821  0.800000   0.817164  0.811111  0.814126   899.039821
# 93        NaN  0.841651  0.758667   0.772966  0.757069  0.764935   875.069206
# 94        NaN  0.962238  0.882667   0.900256  0.877805  0.888889   880.041260
# 95        NaN  0.954108  0.874000   0.896815  0.866995  0.881653   953.398592
#
#     mean_true_prob  prop_positive
# 0         0.521077         0.5400
# 1         0.521135         0.5300
# 2         0.530967         0.5150
# 3         0.589780         0.6150
# 4         0.562634         0.5700
# ..             ...            ...
# 91        0.547899         0.5491
# 92        0.538326         0.5389
# 93        0.523869         0.5259
# 94        0.527529         0.5265
# 95        0.537647         0.5368
#
# [96 rows x 15 columns]
#
# Results saved to grud_factorial_results_REP0.csv
