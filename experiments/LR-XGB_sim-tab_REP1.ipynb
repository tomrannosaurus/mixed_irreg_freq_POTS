# %%
################################################################################
# install
################################################################################
# !pip install rpy2==3.5.1 xgboost --quiet

import itertools
import time
import math
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, roc_auc_score, average_precision_score,
    precision_score, recall_score, f1_score
)
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier

from google.colab import drive
drive.mount('/content/drive')

# rpy2
import rpy2.robjects as ro
from rpy2.robjects import pandas2ri
pandas2ri.activate()
# %load_ext rpy2.ipython

set_seed = 123
np.random.seed(set_seed)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
################################################################################
# Load R script for simulating data
################################################################################
# %%R
source("drive/MyDrive/sim_dgp.R")

# %%
################################################################################
# A function to call R's simulate_experiment_dataset(...)
################################################################################
def generate_sim_data(
    N=100, p=3,
    regularity=0.2, missing_prop=0.1,
    num_sync_groups=1,
    process_types="ar1", use_lags=False,
    block_missing=True, block_length=1.5,
    outcome_time=10, master_seed=123
):
    """
    Calls R's simulate_experiment_dataset() with the given parameters.
    Returns two Pandas DataFrames: df_vars (long format) & df_outcomes.
    Columns in df_vars => [ID, time, variable, value]
    Columns in df_outcomes => [ID, time, Y, true_prob]
    """
    ro.r.assign("N", N)
    ro.r.assign("p", p)
    ro.r.assign("regularity", regularity)
    ro.r.assign("missing_prop", missing_prop)
    ro.r.assign("num_sync_groups", num_sync_groups)

    if isinstance(process_types, list):
        ro.r.assign("process_types", ro.StrVector(process_types))
    else:
        ro.r.assign("process_types", ro.StrVector([process_types]*p))

    ro.r.assign("use_lags", use_lags)
    ro.r.assign("block_missing", block_missing)
    ro.r.assign("block_length", block_length)
    ro.r.assign("outcome_time", outcome_time)
    ro.r.assign("master_seed", master_seed)

    ro.r('''
        sim_dataset <- simulate_experiment_dataset(
          N            = N,
          p            = p,
          freq_min     = 0.5,
          freq_max     = 3.0,
          regularity   = regularity,
          num_sync_groups = num_sync_groups,
          process_types = process_types,
          missing_prop = missing_prop,
          block_missing = block_missing,
          block_length  = block_length,
          outcome_time  = outcome_time,
          beta          = c(0, seq(-1, 1, length.out = 30)),
          use_lags      = use_lags,
          lag_hours     = ifelse(use_lags, 2, 0),
          master_seed   = master_seed
        )
    ''')

    df_vars_r     = ro.r('sim_dataset$vars_long')
    df_outcomes_r = ro.r('sim_dataset$outcome_df')

    # Convert to pandas
    df_vars     = df_vars_r
    df_outcomes = df_outcomes_r

    # dtypes
    df_vars["ID"]      = df_vars["ID"].astype(int)
    df_vars["time"]    = df_vars["time"].astype(float)
    df_outcomes["ID"]  = df_outcomes["ID"].astype(int)
    df_outcomes["time"]= df_outcomes["time"].astype(float)

    return df_vars, df_outcomes

# %%
################################################################################
# Bin each subject's timeseries into hour-bins up to 'outcome_time'
#    then forward-fill. Then flatten to produce  (outcome_time * p) features.
################################################################################
def bin_and_forward_fill(df_sub, feature_list, outcome_time=10):
    """
    - We bin time into integer hours from 0..(outcome_time-1).
    - If multiple rows occur in the same hour for a feature, we average them.
    - If no row in that hour, we forward-fill from the last hour's value.
    - Finally flatten into shape (outcome_time * p,).
    """
    p = len(feature_list)
    data_arr = np.full((outcome_time, p), np.nan, dtype=float)

    # Round down each row's time to int hour
    df_sub["HourInt"] = df_sub["time"].astype(int)

    # average each feature within each hour
    grouped = df_sub.groupby(["HourInt","variable"])["value"].mean().reset_index()

    for hour in range(outcome_time):
        for feat_idx, feat in enumerate(feature_list):
            row_match = grouped[(grouped["HourInt"]==hour) & (grouped["variable"]==feat)]
            if len(row_match)==1:
                data_arr[hour, feat_idx] = row_match["value"].values[0]
            # else remain NaN

    # forward fill each feature
    for feat_idx in range(p):
        for hour in range(1, outcome_time):
            if np.isnan(data_arr[hour, feat_idx]):
                data_arr[hour, feat_idx] = data_arr[hour-1, feat_idx]
        # if still all NaN => fill with 0.0
        data_arr[:, feat_idx] = np.nan_to_num(data_arr[:, feat_idx], nan=0.0)

    return data_arr.flatten(order="C")


def build_binned_dataset(df_vars, df_outcomes, outcome_time=10):
    """
    For each subject => produce (outcome_time * p) columns + label.
    Return a DataFrame => columns: [ID, label, <f0_h0>, <f1_h0>, ..., <f0_h1>, ...]
    """
    feature_list = sorted(df_vars["variable"].unique())
    subject_ids  = df_vars["ID"].unique()

    rows = []
    for sid in subject_ids:
        sub_df  = df_vars[df_vars["ID"]==sid].copy()
        sub_out = df_outcomes[df_outcomes["ID"]==sid]
        label_val = 0
        if len(sub_out)==1:
            label_val = sub_out["Y"].values[0]

        data_flat = bin_and_forward_fill(sub_df, feature_list, outcome_time=outcome_time)

        row_dict = {"ID": sid, "label": label_val}
        idx=0
        for hour in range(outcome_time):
            for feat_i, feat_name in enumerate(feature_list):
                col_name = f"{feat_name}_h{hour}"
                row_dict[col_name] = data_flat[idx]
                idx+=1

        rows.append(row_dict)

    df_out = pd.DataFrame(rows)
    return df_out

# %%
################################################################################
# run_single_scenario => does entire pipeline for "LogisticRegression" & "XGB"
################################################################################
def run_single_scenario(
    N, p,
    regularity,
    missing_prop,
    num_sync_groups,
    process_types,
    use_lags,
    block_missing=True,
    block_length=1.5,
    outcome_time=10,
    master_seed=123
):
    """
    1) Generate data in R, 2) bin+flatten each subject => (outcome_time * p) features,
    3) 70/15/15 split => train/val/test (though val isn't strictly used in LR/XGB),
    4) Fit LR & XGB, 5) Evaluate on test => gather metrics.

    We'll return TWO entries in a list, one for each model, each a dict of metrics:
      e.g. [
        { 'model':'LR', 'auc':..., 'accuracy':..., etc. },
        { 'model':'XGB', ... }
      ]
    """
    df_vars, df_outcomes = generate_sim_data(
        N=N,
        p=p,
        regularity=regularity,
        missing_prop=missing_prop,
        num_sync_groups=num_sync_groups,
        process_types=process_types,
        use_lags=use_lags,
        block_missing=block_missing,
        block_length=block_length,
        outcome_time=outcome_time,
        master_seed=master_seed
    )

    mean_true_prob = df_outcomes["true_prob"].mean()
    prop_positive  = df_outcomes["Y"].mean()

    df_binned = build_binned_dataset(df_vars, df_outcomes, outcome_time=outcome_time)

    df_binned = df_binned.sample(frac=1.0, random_state=42).reset_index(drop=True)
    N_total = len(df_binned)
    n_train = int(0.70*N_total)
    n_val   = int(0.15*N_total)
    n_test  = N_total - n_train - n_val

    train_df = df_binned.iloc[:n_train].copy()
    val_df   = df_binned.iloc[n_train : n_train + n_val].copy()
    test_df  = df_binned.iloc[n_train + n_val : ].copy()

    X_cols = [c for c in df_binned.columns if c not in ["ID","label"]]

    X_train = train_df[X_cols].values
    y_train = train_df["label"].values

    X_val   = val_df[X_cols].values
    y_val   = val_df["label"].values

    X_test  = test_df[X_cols].values
    y_test  = test_df["label"].values

    results_list = []

    lr_start = time.time()
    lr_model = LogisticRegression(max_iter=2000, random_state=42)
    lr_model.fit(X_train, y_train)
    lr_time = time.time() - lr_start

    y_pred_lr = lr_model.predict(X_test)
    if hasattr(lr_model,"predict_proba"):
        y_prob_lr = lr_model.predict_proba(X_test)[:,1]
        auc_lr    = roc_auc_score(y_test, y_prob_lr)
    else:
        auc_lr    = float('nan')

    acc_lr     = accuracy_score(y_test, y_pred_lr)
    prec_lr    = precision_score(y_test, y_pred_lr, zero_division=0)
    rec_lr     = recall_score(y_test, y_pred_lr, zero_division=0)
    f1_lr      = f1_score(y_test, y_pred_lr, zero_division=0)

    results_list.append({
        "model":         "LR",
        "test_loss":     float('nan'),
        "auc":           auc_lr,
        "accuracy":      acc_lr,
        "precision":     prec_lr,
        "recall":        rec_lr,
        "f1":            f1_lr,
        "runtime_sec":   lr_time,
        "mean_true_prob": float(mean_true_prob),
        "prop_positive":  float(prop_positive),
    })

    xgb_start = time.time()
    xgb = XGBClassifier(
        n_estimators=1000,
        max_depth=6,
        learning_rate=0.1,
        random_state=42,
        eval_metric='logloss',
        early_stopping_rounds=10
    )
    eval_set = [(X_val, y_val)]
    xgb.fit(X_train, y_train, eval_set=eval_set, verbose=False)
    xgb_time = time.time() - xgb_start

    y_pred_xgb = xgb.predict(X_test)
    y_prob_xgb = xgb.predict_proba(X_test)[:,1]

    auc_xgb   = roc_auc_score(y_test, y_prob_xgb)
    acc_xgb   = accuracy_score(y_test, y_pred_xgb)
    prec_xgb  = precision_score(y_test, y_pred_xgb, zero_division=0)
    rec_xgb   = recall_score(y_test, y_pred_xgb, zero_division=0)
    f1_xgb    = f1_score(y_test, y_pred_xgb, zero_division=0)

    results_list.append({
        "model":         "XGB",
        "test_loss":     float('nan'),
        "auc":           auc_xgb,
        "accuracy":      acc_xgb,
        "precision":     prec_xgb,
        "recall":        rec_xgb,
        "f1":            f1_xgb,
        "runtime_sec":    xgb_time,
        "mean_true_prob": float(mean_true_prob),
        "prop_positive":  float(prop_positive),
    })


    return results_list


################################################################################
# Full Factorial Loop + Collect Results
################################################################################

Ns = [200, 1000, 10000]
regularities = [0.2, 0.8]
missing_props = [0.1, 0.4]
sync_pattern_values = [1, "p"]
process_type_values = ["homogeneous", "mixed"]
outcome_dep_values = ["direct", "lagged"]

scenario_grid = list(itertools.product(
    Ns,
    regularities,
    missing_props,
    sync_pattern_values,
    process_type_values,
    outcome_dep_values
))

all_results = []
overall_start = time.time()

for scenario in scenario_grid:
    (N,
     regularity,
     missing_prop,
     sync_pattern,
     process_type_flag,
     outcome_dep) = scenario

    p = 30
    if process_type_flag=="homogeneous":
        process_types = "ar1"
    else:
        repeats = math.ceil(p/3)
        big_array = (["ar1","rw","seasonal"]*repeats)[:p]
        process_types = big_array

    if sync_pattern=="p":
        num_sync_groups = max(1, int(round(p/10)))
    else:
        num_sync_groups = 1

    use_lags = (outcome_dep=="lagged")

    print("===============================================================")
    print(f"Scenario => N={N}, reg={regularity}, missing={missing_prop}, "
          f"sync={sync_pattern}, process={process_type_flag}, outcome={outcome_dep}")
    print("===============================================================")

    start_scenario = time.time()
    results_for_models = run_single_scenario(
        N=N,
        p=p,
        regularity=regularity,
        missing_prop=missing_prop,
        num_sync_groups=num_sync_groups,
        process_types=process_types,
        use_lags=use_lags,
        block_missing=True,
        block_length=1.5,
        outcome_time=10,
        master_seed=123
    )
    scenario_time = time.time() - start_scenario

    for model_result in results_for_models:
        row = {
            "N":              N,
            "regularity":     regularity,
            "missing_prop":   missing_prop,
            "sync_pattern":   sync_pattern,
            "process_type":   process_type_flag,
            "outcome_dep":    outcome_dep,
            "model":          model_result["model"],
            "test_loss":      model_result["test_loss"],
            "auc":            model_result["auc"],
            "accuracy":       model_result["accuracy"],
            "precision":      model_result["precision"],
            "recall":         model_result["recall"],
            "f1":             model_result["f1"],
            "runtime_sec":    model_result["runtime_sec"],
            "mean_true_prob": model_result["mean_true_prob"],
            "prop_positive":  model_result["prop_positive"],
        }
        all_results.append(row)

overall_time = time.time() - overall_start
print(f"\nAll scenarios completed in {overall_time/60:.2f} minutes.\n")

df_results = pd.DataFrame(all_results)
df_results.sort_values(by=["N","regularity","missing_prop","model"], inplace=True)
print(df_results.head(30))

df_results.to_csv("drive/MyDrive/lr_xgb_factorial_results_REP1.csv", index=False)
print("\nResults saved to lr_xgb_factorial_results_REP1.csv")

# %%
################################################################################
# Full Factorial Loop + Collect Results
################################################################################

Ns = [200, 1000, 10000]
regularities = [0.2, 0.8]
missing_props = [0.1, 0.4]
sync_pattern_values = [1, "p"]
process_type_values = ["homogeneous", "mixed"]
outcome_dep_values = ["direct", "lagged"]

scenario_grid = list(itertools.product(
    Ns,
    regularities,
    missing_props,
    sync_pattern_values,
    process_type_values,
    outcome_dep_values
))

all_results = []
overall_start = time.time()

for scenario in scenario_grid:
    (N,
     regularity,
     missing_prop,
     sync_pattern,
     process_type_flag,
     outcome_dep) = scenario

    p = 30
    if process_type_flag=="homogeneous":
        process_types = "ar1"
    else:
        repeats = math.ceil(p/3)
        big_array = (["ar1","rw","seasonal"]*repeats)[:p]
        process_types = big_array

    if sync_pattern=="p":
        num_sync_groups = max(1, int(round(p/10)))
    else:
        num_sync_groups = 1

    use_lags = (outcome_dep=="lagged")

    print("===============================================================")
    print(f"Scenario => N={N}, reg={regularity}, missing={missing_prop}, "
          f"sync={sync_pattern}, process={process_type_flag}, outcome={outcome_dep}")
    print("===============================================================")

    start_scenario = time.time()
    results_for_models = run_single_scenario(
        N=N,
        p=p,
        regularity=regularity,
        missing_prop=missing_prop,
        num_sync_groups=num_sync_groups,
        process_types=process_types,
        use_lags=use_lags,
        block_missing=True,
        block_length=1.5,
        outcome_time=10,
        master_seed=123
    )
    scenario_time = time.time() - start_scenario

    for model_result in results_for_models:
        row = {
            "N":              N,
            "regularity":     regularity,
            "missing_prop":   missing_prop,
            "sync_pattern":   sync_pattern,
            "process_type":   process_type_flag,
            "outcome_dep":    outcome_dep,
            "model":          model_result["model"],
            "test_loss":      model_result["test_loss"],
            "auc":            model_result["auc"],
            "accuracy":       model_result["accuracy"],
            "precision":      model_result["precision"],
            "recall":         model_result["recall"],
            "f1":             model_result["f1"],
            "runtime_sec":    model_result["runtime_sec"],
            "mean_true_prob": model_result["mean_true_prob"],
            "prop_positive":  model_result["prop_positive"],
        }
        all_results.append(row)

overall_time = time.time() - overall_start
print(f"\nAll scenarios completed in {overall_time/60:.2f} minutes.\n")

df_results = pd.DataFrame(all_results)
df_results.sort_values(by=["N","regularity","missing_prop","model"], inplace=True)
print(df_results.head(30))

df_results.to_csv("drive/MyDrive/lr_xgb_factorial_results_REP1.csv", index=False)
print("\nResults saved to lr_xgb_factorial_results_REP1.csv")
# Out:
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=1, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=1, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=1, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=1, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=p, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=p, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=p, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=p, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=1, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=1, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=1, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=1, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=p, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=p, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=p, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=p, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=1, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=1, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=1, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=1, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=p, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=p, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=p, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=p, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.4, sync=1, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.4, sync=1, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.4, sync=1, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.4, sync=1, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.4, sync=p, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.4, sync=p, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=200, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.1, sync=1, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.1, sync=1, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.1, sync=1, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.1, sync=1, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.1, sync=p, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.1, sync=p, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.1, sync=p, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.1, sync=p, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.4, sync=1, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.4, sync=1, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.4, sync=1, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.4, sync=1, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.4, sync=p, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.4, sync=p, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.4, sync=p, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.2, missing=0.4, sync=p, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.1, sync=1, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.1, sync=1, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.1, sync=1, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.1, sync=1, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.1, sync=p, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.1, sync=p, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.1, sync=p, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.1, sync=p, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.4, sync=1, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.4, sync=1, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.4, sync=1, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.4, sync=1, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.4, sync=p, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.4, sync=p, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=1000, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.1, sync=1, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.1, sync=1, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.1, sync=1, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.1, sync=1, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.1, sync=p, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.1, sync=p, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.1, sync=p, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.1, sync=p, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.4, sync=1, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.4, sync=1, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.4, sync=1, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.4, sync=1, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.4, sync=p, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.4, sync=p, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.4, sync=p, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.2, missing=0.4, sync=p, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.1, sync=1, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.1, sync=1, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.1, sync=1, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.1, sync=1, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.1, sync=p, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.1, sync=p, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.1, sync=p, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.1, sync=p, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=1, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=1, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=1, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=1, process=mixed, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=p, process=homogeneous, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=p, process=homogeneous, outcome=lagged
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=direct
# ===============================================================
# ===============================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=lagged
# ===============================================================
#
# All scenarios completed in 672.17 minutes.
#
#       N  regularity  missing_prop sync_pattern process_type outcome_dep model  \
# 0   200         0.2           0.1            1  homogeneous      direct    LR
# 2   200         0.2           0.1            1  homogeneous      lagged    LR
# 4   200         0.2           0.1            1        mixed      direct    LR
# 6   200         0.2           0.1            1        mixed      lagged    LR
# 8   200         0.2           0.1            p  homogeneous      direct    LR
# 10  200         0.2           0.1            p  homogeneous      lagged    LR
# 12  200         0.2           0.1            p        mixed      direct    LR
# 14  200         0.2           0.1            p        mixed      lagged    LR
# 1   200         0.2           0.1            1  homogeneous      direct   XGB
# 3   200         0.2           0.1            1  homogeneous      lagged   XGB
# 5   200         0.2           0.1            1        mixed      direct   XGB
# 7   200         0.2           0.1            1        mixed      lagged   XGB
# 9   200         0.2           0.1            p  homogeneous      direct   XGB
# 11  200         0.2           0.1            p  homogeneous      lagged   XGB
# 13  200         0.2           0.1            p        mixed      direct   XGB
# 15  200         0.2           0.1            p        mixed      lagged   XGB
# 16  200         0.2           0.4            1  homogeneous      direct    LR
# 18  200         0.2           0.4            1  homogeneous      lagged    LR
# 20  200         0.2           0.4            1        mixed      direct    LR
# 22  200         0.2           0.4            1        mixed      lagged    LR
# 24  200         0.2           0.4            p  homogeneous      direct    LR
# 26  200         0.2           0.4            p  homogeneous      lagged    LR
# 28  200         0.2           0.4            p        mixed      direct    LR
# 30  200         0.2           0.4            p        mixed      lagged    LR
# 17  200         0.2           0.4            1  homogeneous      direct   XGB
# 19  200         0.2           0.4            1  homogeneous      lagged   XGB
# 21  200         0.2           0.4            1        mixed      direct   XGB
# 23  200         0.2           0.4            1        mixed      lagged   XGB
# 25  200         0.2           0.4            p  homogeneous      direct   XGB
# 27  200         0.2           0.4            p  homogeneous      lagged   XGB
#
#     test_loss       auc  accuracy  precision    recall        f1  runtime_sec  \
# 0         NaN  0.827751  0.733333   0.600000  0.818182  0.692308     0.003972
# 2         NaN  0.751131  0.766667   0.777778  0.823529  0.800000     0.003840
# 4         NaN  0.877828  0.733333   0.846154  0.647059  0.733333     0.005264
# 6         NaN  0.898148  0.833333   0.809524  0.944444  0.871795     0.006123
# 8         NaN  0.638393  0.633333   0.578947  0.785714  0.666667     0.004143
# 10        NaN  0.847222  0.766667   0.739130  0.944444  0.829268     0.004315
# 12        NaN  0.973214  0.866667   0.777778  1.000000  0.875000     0.006350
# 14        NaN  0.982143  0.733333   0.636364  1.000000  0.777778     0.008609
# 1         NaN  0.736842  0.666667   0.538462  0.636364  0.583333     0.283839
# 3         NaN  0.502262  0.433333   0.500000  0.647059  0.564103     0.105650
# 5         NaN  0.748869  0.733333   0.736842  0.823529  0.777778     0.156589
# 7         NaN  0.828704  0.700000   0.714286  0.833333  0.769231     0.383089
# 9         NaN  0.573661  0.533333   0.500000  0.428571  0.461538     0.113857
# 11        NaN  0.606481  0.600000   0.600000  1.000000  0.750000     0.072195
# 13        NaN  0.763393  0.633333   0.714286  0.357143  0.476190     0.144706
# 15        NaN  0.794643  0.666667   0.600000  0.857143  0.705882     0.158455
# 16        NaN  0.592760  0.566667   0.625000  0.588235  0.606061     0.005420
# 18        NaN  0.809524  0.700000   0.772727  0.809524  0.790698     0.008175
# 20        NaN  0.907407  0.800000   0.687500  0.916667  0.785714     0.011377
# 22        NaN  0.924107  0.833333   0.800000  0.857143  0.827586     0.008863
# 24        NaN  0.678571  0.566667   0.533333  0.571429  0.551724     0.004599
# 26        NaN  0.589286  0.600000   0.562500  0.642857  0.600000     0.004538
# 28        NaN  0.886878  0.866667   0.882353  0.882353  0.882353     0.005700
# 30        NaN  0.877828  0.866667   0.882353  0.882353  0.882353     0.005200
# 17        NaN  0.701357  0.633333   0.650000  0.764706  0.702703     0.177183
# 19        NaN  0.674603  0.600000   0.714286  0.714286  0.714286     0.093047
# 21        NaN  0.689815  0.633333   0.538462  0.583333  0.560000     0.095192
# 23        NaN  0.919643  0.733333   0.636364  1.000000  0.777778     0.284711
# 25        NaN  0.424107  0.566667   0.523810  0.785714  0.628571     0.070797
# 27        NaN  0.602679  0.633333   0.571429  0.857143  0.685714     0.329420
#
#     mean_true_prob  prop_positive
# 0         0.487307          0.490
# 2         0.530274          0.535
# 4         0.514149          0.515
# 6         0.504874          0.510
# 8         0.499697          0.485
# 10        0.581725          0.610
# 12        0.466926          0.440
# 14        0.558230          0.545
# 1         0.487307          0.490
# 3         0.530274          0.535
# 5         0.514149          0.515
# 7         0.504874          0.510
# 9         0.499697          0.485
# 11        0.581725          0.610
# 13        0.466926          0.440
# 15        0.558230          0.545
# 16        0.560734          0.540
# 18        0.598087          0.610
# 20        0.515033          0.510
# 22        0.519920          0.545
# 24        0.525045          0.530
# 26        0.490655          0.495
# 28        0.557440          0.550
# 30        0.525625          0.545
# 17        0.560734          0.540
# 19        0.598087          0.610
# 21        0.515033          0.510
# 23        0.519920          0.545
# 25        0.525045          0.530
# 27        0.490655          0.495
#
# Results saved to lr_xgb_factorial_results_REP1.csv
