# %%
################################################################################
# BiTimelyGPT - Factorial Experiment (Simulated Data)
################################################################################

# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Imports and Setup
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# !pip install rpy2==3.5.1 prettytable

import itertools
import time
import torch
import numpy as np
import pandas as pd
import os
import math

from torch import nn
from torch.utils.data import DataLoader
from sklearn.metrics import roc_curve, auc

# %load_ext rpy2.ipython
from rpy2.robjects import pandas2ri
pandas2ri.activate()

from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/MyDrive/BiTimelyGPT-main/BiTimelyGPT')

from data.data_pipeline import custom_collate
from models.BiTimelyGPT import BiTimelyGPT
from layers.optimization import get_linear_schedule_with_warmup, AdamW

set_seed = 511
torch.manual_seed(set_seed)
np.random.seed(set_seed)
# Out:
# Collecting rpy2==3.5.1
#   Downloading rpy2-3.5.1.tar.gz (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 kB 10.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: prettytable in /usr/local/lib/python3.11/dist-packages (3.16.0)
# Requirement already satisfied: cffi>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from rpy2==3.5.1) (1.17.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from rpy2==3.5.1) (3.1.6)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from rpy2==3.5.1) (2025.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.11/dist-packages (from rpy2==3.5.1) (5.3.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prettytable) (0.2.13)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.10.0->rpy2==3.5.1) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->rpy2==3.5.1) (3.0.2)
# Building wheels for collected packages: rpy2
#   Building wheel for rpy2 (setup.py) ... done
#   Created wheel for rpy2: filename=rpy2-3.5.1-cp311-cp311-linux_x86_64.whl size=314979 sha256=60d557ebc419e5248768961f2da5fae45713b62a82056184adb6a8c601e734de
#   Stored in directory: /root/.cache/pip/wheels/e9/55/d1/47be85a5f3f1e1f4d1e91cb5e3a4dcb40dd72147f184c5a5ef
# Successfully built rpy2
# Installing collected packages: rpy2
#   Attempting uninstall: rpy2
#     Found existing installation: rpy2 3.5.17
#     Uninstalling rpy2-3.5.17:
#       Successfully uninstalled rpy2-3.5.17
# Successfully installed rpy2-3.5.1
# Mounted at /content/drive

# %%
################################################################################
# Define the R DGP script path and load into Colab
################################################################################

# %%R
source("drive/MyDrive/sim_dgp.R")

# %%
################################################################################
# specialized pipeline for Sim Data
################################################################################

class SimulatedDataset(torch.utils.data.Dataset):
    """
    Each item in this dataset is (sequence_tensor, label_tensor),
    where sequence_tensor has shape [T_i, p], label_tensor is 0/1 (LongTensor).
    """
    def __init__(self, samples, labels):
        super().__init__()
        self.samples = samples  # list of FloatTensors (var-length)
        self.labels  = labels   # 1D LongTensor

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        seq = self.samples[idx]
        lbl = self.labels[idx]
        return seq, lbl  # (T_i, p), scalar label


def load_simulated_data(df_vars, df_outcomes, config):
    """
    Builds a list of variable-length sequences + labels from:
      df_vars     => [ID, time, variable, value]
      df_outcomes => [ID, time, Y, true_prob]
    config.feature_list => e.g., ["X1","X2","X3"]
    Returns: samples (list of Tensors) and labels (LongTensor).
    """
    feature_map = {feat: i for i, feat in enumerate(config.feature_list)}

    samples = []
    labels = []

    subject_ids = df_vars["ID"].unique()
    for sid in subject_ids:
        sub_df  = df_vars[df_vars["ID"] == sid].copy()
        sub_out = df_outcomes[df_outcomes["ID"] == sid]

        # label
        if len(sub_out) == 1:
            label_val = sub_out["Y"].values[0]
        else:
            label_val = 0  # fallback if missing

        # sort by time
        sub_df = sub_df.sort_values("time")

        seq_tensors = []
        for t_val, group in sub_df.groupby("time"):
            feats = torch.zeros(len(config.feature_list), dtype=torch.float)
            for _, row in group.iterrows():
                var_name = row["variable"]
                if var_name in feature_map:
                    idx = feature_map[var_name]
                    feats[idx] = row["value"]
            seq_tensors.append(feats)

        if len(seq_tensors) == 0:
            seq_tensor = torch.zeros(1, len(config.feature_list))
        else:
            seq_tensor = torch.stack(seq_tensors, dim=0)

        samples.append(seq_tensor)
        labels.append(label_val)

    labels = torch.tensor(labels, dtype=torch.long)
    return samples, labels


def simulated_data_pipeline(df_vars, df_outcomes, config, train_ratio=0.8, shuffle=True):
    """
    Splits into train/test sets using 'train_ratio'. Returns:
      train_dataset, train_loader, test_dataset, test_loader
    """
    samples, labels = load_simulated_data(df_vars, df_outcomes, config)
    full_dataset    = SimulatedDataset(samples, labels)

    N = len(full_dataset)
    train_size = int(train_ratio * N)
    test_size  = N - train_size

    if shuffle:
        generator = torch.Generator().manual_seed(511)
        train_dataset, test_dataset = torch.utils.data.random_split(
            full_dataset, [train_size, test_size], generator=generator
        )
    else:
        train_dataset, test_dataset = torch.utils.data.random_split(
            full_dataset, [train_size, test_size]
        )

    train_loader = DataLoader(
        train_dataset,
        batch_size=config.batch_size,
        shuffle=True,
        collate_fn=custom_collate
    )
    test_loader = DataLoader(
        test_dataset,
        batch_size=config.batch_size,
        shuffle=False,
        collate_fn=custom_collate
    )
    return train_dataset, train_loader, test_dataset, test_loader

# %%
################################################################################
# Define a Configuration Class for the Model
################################################################################

class SimDataConfig:
    def __init__(self, p):
        # Data characteristics
        self.feature_list = [f"X{i+1}" for i in range(p)]
        self.n_output = len(self.feature_list)
        self.n_clf_output = 2

        # Common Model hyperparameters
        self.num_layers = 6
        self.num_heads = 2
        self.d_model = 64
        self.qk_dim = 64
        self.v_dim = 128
        self.ffn_proj_size = 256
        self.d_ff = 128
        self.dropout = 0.1
        self.activation = 'gelu'

        # BiTimelyGPT specific
        self.use_bias_in_msr = False
        self.use_bias_in_mlp = True
        self.use_bias_in_msr_out = False
        self.use_default_gamma = False
        self.forward_impl = 'parallel'
        self.chunk_size = 12
        self.seq_len = 128

        # Pretraining parameters
        self.pretrain_batch_size = 128
        self.pretrain_learning_rate = 1e-4
        self.pretrain_epochs = 15
        self.pretrain_warmup_steps = 100

        # Fine-tuning parameters
        self.finetune_batch_size = 32
        self.finetune_learning_rate = 2e-4
        self.finetune_epochs = 50
        self.finetune_warmup_steps = 100
        self.gradient_clip = 1.0

        # GPU and optimization settings
        self.use_gpu = torch.cuda.is_available()
        self.use_grad_ckp = False
        self.use_grad_accum = True
        self.accum_steps = 2
        self.use_amp = False
        self.use_multi_gpu = False
        self.devices = '0'

        self.output_retentions = False

# %%
################################################################################
# Utility: Train & Evaluate function with Pretraining + Fine-tuning
################################################################################
import rpy2.robjects as ro
from torch.utils.data import DataLoader, random_split
import math
import numpy as np
import torch
import os
from torch import nn
from layers.optimization import get_linear_schedule_with_warmup, AdamW
from models.BiTimelyGPT import BiTimelyGPT
from layers.heads import ClfHead

def run_single_scenario(
    N, p,
    regularity,
    missing_prop,
    num_sync_groups,
    process_types,
    use_lags,
    block_missing=True,
    block_length=1.5,
    outcome_time=10,
    master_seed=511
):
    """
     Simulate data in R.
     Split into 70% train, 15% val, 15% test.
     Pretrain BiTimelyGPT using a self-supervised objective on the training set.
     Fine-tune the pretrained BiTimelyGPT on the classification task (training set),
       using validation-based early stopping (AUC).
     Evaluate the best fine-tuned model on the test set (Loss, AUC, Acc, Prec, Rec, F1 @ threshold 0.5).
    """
    print(f"\n--- Running Scenario: N={N}, p={p}, reg={regularity}, miss={missing_prop}, sync={num_sync_groups}, lag={use_lags} ---")

    # ------------------ Simulate in R ------------------
    ro.r.assign("N", N)
    ro.r.assign("p", p)
    ro.r.assign("regularity", regularity)
    ro.r.assign("missing_prop", missing_prop)
    ro.r.assign("num_sync_groups", num_sync_groups)
    if isinstance(process_types, list):
        ro.r.assign("process_types", ro.StrVector(process_types))
    else:
        ro.r.assign("process_types", ro.StrVector([process_types]*p))
    ro.r.assign("use_lags", use_lags)
    ro.r.assign("block_missing", block_missing)
    ro.r.assign("block_length", block_length)
    ro.r.assign("outcome_time", outcome_time)
    ro.r.assign("master_seed", master_seed)

    ro.r('''
        sim_dataset <- simulate_experiment_dataset(
          N            = N,
          p            = p,
          freq_min     = 0.1,
          freq_max     = 50.0,
          regularity   = regularity,
          num_sync_groups = num_sync_groups,
          process_types = process_types,
          missing_prop = missing_prop,
          block_missing = block_missing,
          block_length  = block_length,
          outcome_time  = outcome_time,
          beta          = c(0, seq(-1, 1, length.out = 10)),
          use_lags      = use_lags,
          lag_hours     = ifelse(use_lags, 2, 0),
          master_seed   = master_seed
        )
    ''')

    df_vars_r     = ro.r('sim_dataset$vars_long')
    df_outcomes_r = ro.r('sim_dataset$outcome_df')

    df_vars       = df_vars_r
    df_outcomes   = df_outcomes_r

    df_vars["ID"]     = df_vars["ID"].astype(int)
    df_vars["time"]   = df_vars["time"].astype(float)
    df_outcomes["ID"] = df_outcomes["ID"].astype(int)
    df_outcomes["time"]= df_outcomes["time"].astype(float)
    df_outcomes["Y"] = df_outcomes["Y"].astype(int)

    mean_true_prob = df_outcomes["true_prob"].mean()
    prop_positive  = df_outcomes["Y"].mean()
    print(f"Data generated: {len(df_outcomes)} subjects, {prop_positive*100:.1f}% positive cases.")


    # ------------------ Create train/val/test splits (70/15/15) ------------------
    config = SimDataConfig(p)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    samples, labels = load_simulated_data(df_vars, df_outcomes, config)
    full_dataset    = SimulatedDataset(samples, labels)

    N_total = len(full_dataset)
    if N_total < 10:
         print(f"Warning: Very small dataset (N={N_total}). Skipping scenario.")
         return { "test_loss": np.nan, "auc": np.nan, "accuracy": np.nan, "precision": np.nan,
                  "recall": np.nan, "f1": np.nan, "mean_true_prob": mean_true_prob, "prop_positive": prop_positive }

    N_train = int(0.70 * N_total)
    N_val   = int(0.15 * N_total)
    N_test  = N_total - N_train - N_val

    if N_train <= 0 or N_val <= 0 or N_test <= 0:
        print(f"Warning: Insufficient data for standard 70/15/15 split (N={N_total}). Attempting adjusted split.")
        N_train = max(1, N_total - 2)
        N_val = 1 if N_total > 1 else 0
        N_test = 1 if N_total > 2 else 0
        if N_train <= 0 or (N_val + N_test == 0):
             print(f"Error: Cannot create a valid train/val/test split for N={N_total}. Skipping scenario.")
             return { "test_loss": np.nan, "auc": np.nan, "accuracy": np.nan, "precision": np.nan,
                      "recall": np.nan, "f1": np.nan, "mean_true_prob": mean_true_prob, "prop_positive": prop_positive }

    print(f"Splitting data: Train={N_train}, Val={N_val}, Test={N_test}")
    generator = torch.Generator().manual_seed(master_seed)
    train_dataset, val_test_dataset = random_split(full_dataset, [N_train, N_val + N_test], generator=generator)

    if N_val + N_test > 0 :
        val_dataset, test_dataset = random_split(val_test_dataset, [N_val, N_test], generator=generator)
    else:
        val_dataset = torch.utils.data.Subset(val_test_dataset, [])
        test_dataset = torch.utils.data.Subset(val_test_dataset, [])


    train_loader = DataLoader(
        train_dataset, batch_size=config.pretrain_batch_size, shuffle=True,
        num_workers=2, pin_memory=True, collate_fn=custom_collate
    )
    val_loader = DataLoader(
        val_dataset, batch_size=config.finetune_batch_size, shuffle=False,
        num_workers=2, pin_memory=True, collate_fn=custom_collate
    )
    test_loader = DataLoader(
        test_dataset, batch_size=config.finetune_batch_size, shuffle=False,
        num_workers=2, pin_memory=True, collate_fn=custom_collate
    )

    if len(train_loader) == 0:
        print("Error: Training loader is empty. Cannot proceed. Skipping scenario.")
        return { "test_loss": np.nan, "auc": np.nan, "accuracy": np.nan, "precision": np.nan,
                 "recall": np.nan, "f1": np.nan, "mean_true_prob": mean_true_prob, "prop_positive": prop_positive }


    # ------------------ Initialize Model for PRETRAINING ------------------
    model = BiTimelyGPT(configs=config, head_type='pretrain').to(device)
    model.head_type = 'pretrain'
    print(f"Initialized model with Pretrain head. Parameters: {sum(p.numel() for p in model.parameters())}")


    # ------------------ PRETRAINING PHASE ------------------
    print(f"--- Starting Pretraining Phase ({config.pretrain_epochs} epochs) ---")
    pretrain_optimizer = AdamW(
        model.parameters(), lr=config.pretrain_learning_rate, weight_decay=0.01
    )
    num_pretraining_steps = len(train_loader) * config.pretrain_epochs
    pretrain_scheduler = get_linear_schedule_with_warmup(
        pretrain_optimizer, config.pretrain_warmup_steps, num_pretraining_steps
    )

    for epoch in range(config.pretrain_epochs):
        model.train()
        pretrain_losses = []
        pretrain_optimizer.zero_grad()

        for i, (batch_x, _, attention_mask) in enumerate(train_loader):
            batch_x, attention_mask = batch_x.to(device), attention_mask.to(device)

            loss = model(batch_x, y=None, retention_mask=None,
                         forward_impl=config.forward_impl, chunk_size=config.chunk_size)

            if torch.isnan(loss):
                print(f"Warning: NaN loss at pretrain epoch {epoch+1}, batch {i}. Skipping update.")
                continue

            scaled_loss = loss / config.accum_steps
            scaled_loss.backward()

            if (i + 1) % config.accum_steps == 0 or (i + 1) == len(train_loader):
                pretrain_optimizer.step()
                pretrain_scheduler.step()
                pretrain_optimizer.zero_grad()

            pretrain_losses.append(loss.item())

        avg_pretrain_loss = np.mean(pretrain_losses) if pretrain_losses else np.nan
        print(f'Pretrain Epoch {epoch+1}/{config.pretrain_epochs} -- Avg Loss: {avg_pretrain_loss:.4f}')

    print("--- Pretraining Phase Complete ---")

    # ------------------ SWITCH TO FINE-TUNING ------------------
    print(f"--- Switching to Fine-tuning Phase ({config.finetune_epochs} epochs) ---")
    model.head = ClfHead(config.d_model, config.n_clf_output).to(device)
    model.head_type = 'clf'
    print(f"Model head switched to ClfHead. Total params now: {sum(p.numel() for p in model.parameters())}")

    optimizer = AdamW(model.parameters(), lr=config.finetune_learning_rate, weight_decay=0.01)
    num_finetune_steps = len(train_loader) * config.finetune_epochs
    scheduler = get_linear_schedule_with_warmup(
        optimizer, config.finetune_warmup_steps, num_finetune_steps
    )
    criterion = nn.CrossEntropyLoss()

    best_val_auc = -1.0
    patience = 10
    epochs_no_improve = 0
    warmup_epochs = 2
    best_model_path = f"best_model_temp_{master_seed}.pt"

    print("--- Starting Fine-tuning Training Loop ---")
    for epoch in range(config.finetune_epochs):
        # --- Train (Fine-tuning) ---
        model.train()
        train_losses = []
        optimizer.zero_grad()

        for i, (batch_x, batch_y, attention_mask) in enumerate(train_loader):
            batch_x, batch_y, attention_mask = (
                batch_x.to(device), batch_y.to(device), attention_mask.to(device)
            )

            assert model.head_type == 'clf', "Model head_type should be 'clf'"
            hidden_states = model.conv_subsampling(batch_x)[0]
            hidden_states = model.input_projection(hidden_states)
            if attention_mask.shape[1] > hidden_states.shape[1]:
                subsampling_factor = batch_x.shape[1] // hidden_states.shape[1]
                attention_mask = attention_mask[:, ::subsampling_factor]
                attention_mask = attention_mask[:, :hidden_states.shape[1]]

            for block in model.blocks:
                out = block(hidden_states, retention_mask=attention_mask,
                            forward_impl=config.forward_impl, chunk_size=config.chunk_size)
                hidden_states = out[0]

            X = model.ln_f(hidden_states)
            logits = model.head(X)

            loss = criterion(logits, batch_y)
            scaled_loss = loss / config.accum_steps
            scaled_loss.backward()

            if (i + 1) % config.accum_steps == 0 or (i + 1) == len(train_loader):
                torch.nn.utils.clip_grad_norm_(model.parameters(), config.gradient_clip)
                optimizer.step()
                scheduler.step()
                optimizer.zero_grad()

            train_losses.append(loss.item())

        avg_train_loss = np.mean(train_losses) if train_losses else np.nan

        # --- Validation (Fine-tuning) ---
        if len(val_loader) == 0:
            print(f"[Fine-tune Epoch {epoch+1}/{config.finetune_epochs}] TrainLoss={avg_train_loss:.4f}, Skipping Validation (empty loader)")
            if (epoch + 1) % 10 == 0:
                 torch.save(model.state_dict(), best_model_path)
                 print(f"Saved model state at epoch {epoch+1} (no validation set).")
            continue

        model.eval()
        val_probs = []
        val_labels = []
        val_losses = []

        with torch.no_grad():
            for (batch_x, batch_y, attention_mask) in val_loader:
                batch_x, batch_y, attention_mask = (
                    batch_x.to(device), batch_y.to(device), attention_mask.to(device)
                )
                hidden_states = model.conv_subsampling(batch_x)[0]
                hidden_states = model.input_projection(hidden_states)
                if attention_mask.shape[1] > hidden_states.shape[1]:
                    subsampling_factor = batch_x.shape[1] // hidden_states.shape[1]
                    attention_mask = attention_mask[:, ::subsampling_factor]
                    attention_mask = attention_mask[:, :hidden_states.shape[1]]
                for block in model.blocks:
                    out = block(hidden_states, retention_mask=attention_mask,
                                forward_impl=config.forward_impl, chunk_size=config.chunk_size)
                    hidden_states = out[0]
                X_val = model.ln_f(hidden_states)
                logits = model.head(X_val)

                loss_val = criterion(logits, batch_y)
                val_losses.append(loss_val.item())
                probs = torch.softmax(logits, dim=1)[:, 1]
                val_probs.extend(probs.cpu().numpy())
                val_labels.extend(batch_y.cpu().numpy())

        avg_val_loss = np.mean(val_losses) if val_losses else np.nan
        val_auc = np.nan
        if len(np.unique(val_labels)) > 1:
            try:
                fpr_val, tpr_val, _ = roc_curve(val_labels, val_probs)
                val_auc = auc(fpr_val, tpr_val)
            except Exception as e:
                print(f"Warning: Could not calculate validation AUC: {e}")
        else:
             val_auc = 0.0
             print(f"Validation AUC calculation skipped: Only one class present ({np.unique(val_labels)}).")

        print(f"[Fine-tune Epoch {epoch+1}/{config.finetune_epochs}] "
              f"TrainLoss={avg_train_loss:.4f}, ValLoss={avg_val_loss:.4f}, ValAUC={val_auc:.4f}")

        if epoch + 1 > warmup_epochs and not np.isnan(val_auc):
            if val_auc > best_val_auc:
                best_val_auc = val_auc
                epochs_no_improve = 0
                torch.save(model.state_dict(), best_model_path)
                print(f"==> Val AUC improved to {best_val_auc:.4f}. Fine-tuned model saved.")
            else:
                epochs_no_improve += 1
                if epochs_no_improve >= patience:
                    print(f"Early stopping fine-tuning (no val AUC improvement in {patience} epochs).")
                    break

    # ------------------ 6) Load best FINE-TUNED model, Evaluate on TEST ------------------
    print("--- Evaluating best fine-tuned model on Test Set ---")
    if len(test_loader) == 0:
        print("Skipping Test Set evaluation (empty loader).")
        results_dict = { "test_loss": np.nan, "auc": np.nan, "accuracy": np.nan, "precision": np.nan,
                         "recall": np.nan, "f1": np.nan, "mean_true_prob": mean_true_prob, "prop_positive": prop_positive }
        if os.path.exists(best_model_path):
            os.remove(best_model_path)
        return results_dict


    if os.path.exists(best_model_path):
        model.load_state_dict(torch.load(best_model_path))
        print(f"Loaded best fine-tuned model from {best_model_path}")
    else:
        print("Warning: No best fine-tuned model saved (e.g., no validation improvement or no val set). Using the last model state for testing.")
        model.eval()

    all_probs = []
    all_labels = []
    test_losses = []

    with torch.no_grad():
        for (batch_x, batch_y, attention_mask) in test_loader:
            batch_x, batch_y, attention_mask = (
                batch_x.to(device), batch_y.to(device), attention_mask.to(device)
            )
            hidden_states = model.conv_subsampling(batch_x)[0]
            hidden_states = model.input_projection(hidden_states)
            if attention_mask.shape[1] > hidden_states.shape[1]:
                 subsampling_factor = batch_x.shape[1] // hidden_states.shape[1]
                 attention_mask = attention_mask[:, ::subsampling_factor]
                 attention_mask = attention_mask[:, :hidden_states.shape[1]]
            for block in model.blocks:
                out = block(hidden_states, retention_mask=attention_mask,
                            forward_impl=config.forward_impl, chunk_size=config.chunk_size)
                hidden_states = out[0]
            X_test = model.ln_f(hidden_states)
            logits = model.head(X_test)

            loss_test = criterion(logits, batch_y)
            test_losses.append(loss_test.item())
            probs = torch.softmax(logits, dim=1)[:, 1]
            all_probs.extend(probs.cpu().numpy())
            all_labels.extend(batch_y.cpu().numpy())

    avg_test_loss = float(np.mean(test_losses)) if test_losses else 0.0
    test_auc = 0.0
    test_acc = 0.0
    test_prec = 0.0
    test_rec = 0.0
    test_f1 = 0.0

    if all_labels and all_probs:
        try:
            fpr_test, tpr_test, _ = roc_curve(all_labels, all_probs)
            test_auc = auc(fpr_test, tpr_test)

            threshold = 0.5
            preds = (np.array(all_probs) >= threshold).astype(int)
            labels_arr = np.array(all_labels)

            tp = np.sum((preds == 1) & (labels_arr == 1))
            fp = np.sum((preds == 1) & (labels_arr == 0))
            fn = np.sum((preds == 0) & (labels_arr == 1))
            tn = np.sum((preds == 0) & (labels_arr == 0))

            test_prec = tp / (tp + fp + 1e-9)
            test_rec = tp / (tp + fn + 1e-9)
            test_f1 = 2 * test_prec * test_rec / (test_prec + test_rec + 1e-9)
            test_acc = (tp + tn) / len(labels_arr) if len(labels_arr) > 0 else 0.0

        except ValueError as e:
            print(f"Could not calculate test metrics (AUC or others likely failed): {e}")
        except Exception as e:
             print(f"An unexpected error occurred during metric calculation: {e}")

    else:
        print("Skipping test metric calculation: No predictions or labels found.")

    print(f"Test Results: Loss={avg_test_loss:.4f}, AUC={test_auc:.4f}, F1={test_f1:.4f}")

    results_dict = {
        "test_loss":       avg_test_loss if not np.isnan(avg_test_loss) else 0.0,
        "auc":             test_auc,
        "accuracy":        test_acc,
        "precision":       test_prec,
        "recall":          test_rec,
        "f1":              test_f1,
        "mean_true_prob":  float(mean_true_prob) if not np.isnan(mean_true_prob) else 0.0,
        "prop_positive":   float(prop_positive) if not np.isnan(prop_positive) else 0.0
    }

    if os.path.exists(best_model_path):
        os.remove(best_model_path)

    return results_dict

# %%
################################################################################
# 6) Main Loop: Full Factorial Over the 6 Factors (new version)
################################################################################

import math

Ns = [200, 1000]
regularities = [0.2, 0.8]
missing_props = [0.1, 0.4]
sync_pattern_values = [1, "p"]
process_type_values = ["homogeneous", "mixed"]
outcome_dep_values  = ["direct", "lagged"]

scenario_grid = list(itertools.product(
    Ns,
    regularities,
    missing_props,
    sync_pattern_values,
    process_type_values,
    outcome_dep_values
))

all_results = []
overall_start = time.time()

for scenario in scenario_grid:
    (N,
     regularity,
     missing_prop,
     sync_pattern,
     process_type_flag,
     outcome_dep) = scenario

    p = 10
    if process_type_flag == "homogeneous":
        process_types = ["ar1"]*p
    else:
        repeats = math.ceil(p/3)
        big_array = (["ar1","rw","seasonal"] * repeats)[:p]
        process_types = big_array

    if sync_pattern == "p":
        num_sync_groups = max(1, int(round(math.sqrt(p))))
    else:
        num_sync_groups = 1

    if outcome_dep == "direct":
        use_lags = False
    else:
        use_lags = True

    print("===================================================================")
    print(f"Scenario => N={N}, reg={regularity}, missing={missing_prop}, "
          f"sync={sync_pattern}, process={process_type_flag}, outcome={outcome_dep}")
    print("===================================================================")

    start_time = time.time()
    results_dict = run_single_scenario(
        N=N,
        p=p,
        regularity=regularity,
        missing_prop=missing_prop,
        num_sync_groups=num_sync_groups,
        process_types=process_types,
        use_lags=use_lags,
        block_missing=True,
        block_length=1.5,
        outcome_time=10,
        master_seed=511
    )
    runtime = time.time() - start_time

    scenario_result = {
        "N":            N,
        "regularity":   regularity,
        "missing_prop": missing_prop,
        "sync_pattern": sync_pattern,
        "process_type": process_type_flag,
        "outcome_dep":  outcome_dep,
        "test_loss":    results_dict["test_loss"],
        "auc":          results_dict["auc"],
        "accuracy":     results_dict["accuracy"],
        "precision":    results_dict["precision"],
        "recall":       results_dict["recall"],
        "f1":           results_dict["f1"],
        "runtime_sec":  runtime,
        "mean_true_prob": results_dict["mean_true_prob"],
        "prop_positive":  results_dict["prop_positive"]
    }
    all_results.append(scenario_result)

overall_runtime = time.time() - overall_start
print(f"\nAll scenarios completed in {overall_runtime/60:.2f} minutes.\n")

df_results = pd.DataFrame(all_results)
df_results.sort_values(by=["N","regularity","missing_prop"], inplace=True)
print(df_results)

df_results.to_csv("drive/MyDrive/bitimelygpt_factorial_results_long.csv", index=False)
print("\nResults saved to bitimelygpt_factorial_results_long.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
# Model head switched to ClfHead. Total params now: 341818
# --- Starting Fine-tuning Training Loop ---
# [Fine-tune Epoch 1/50] TrainLoss=0.7524, ValLoss=0.7662, ValAUC=0.3259
# [Fine-tune Epoch 2/50] TrainLoss=0.6858, ValLoss=0.7638, ValAUC=0.3348
# [Fine-tune Epoch 3/50] TrainLoss=0.8231, ValLoss=0.7593, ValAUC=0.3259
# ==> Val AUC improved to 0.3259. Fine-tuned model saved.
# [Fine-tune Epoch 4/50] TrainLoss=0.8198, ValLoss=0.7544, ValAUC=0.3348
# ==> Val AUC improved to 0.3348. Fine-tuned model saved.
# [Fine-tune Epoch 5/50] TrainLoss=0.7332, ValLoss=0.7471, ValAUC=0.3616
# ==> Val AUC improved to 0.3616. Fine-tuned model saved.
# [Fine-tune Epoch 6/50] TrainLoss=0.7779, ValLoss=0.7380, ValAUC=0.3705
# ==> Val AUC improved to 0.3705. Fine-tuned model saved.
# [Fine-tune Epoch 7/50] TrainLoss=0.6924, ValLoss=0.7279, ValAUC=0.3839
# ==> Val AUC improved to 0.3839. Fine-tuned model saved.
# [Fine-tune Epoch 8/50] TrainLoss=0.7710, ValLoss=0.7179, ValAUC=0.3973
# ==> Val AUC improved to 0.3973. Fine-tuned model saved.
# [Fine-tune Epoch 9/50] TrainLoss=0.6794, ValLoss=0.7094, ValAUC=0.4062
# ==> Val AUC improved to 0.4062. Fine-tuned model saved.
# [Fine-tune Epoch 10/50] TrainLoss=0.6875, ValLoss=0.7035, ValAUC=0.4107
# ==> Val AUC improved to 0.4107. Fine-tuned model saved.
# [Fine-tune Epoch 11/50] TrainLoss=0.7060, ValLoss=0.6984, ValAUC=0.4196
# ==> Val AUC improved to 0.4196. Fine-tuned model saved.
# [Fine-tune Epoch 12/50] TrainLoss=0.6892, ValLoss=0.6955, ValAUC=0.4554
# ==> Val AUC improved to 0.4554. Fine-tuned model saved.
# [Fine-tune Epoch 13/50] TrainLoss=0.6805, ValLoss=0.6933, ValAUC=0.4777
# ==> Val AUC improved to 0.4777. Fine-tuned model saved.
# [Fine-tune Epoch 14/50] TrainLoss=0.6776, ValLoss=0.6934, ValAUC=0.4777
# [Fine-tune Epoch 15/50] TrainLoss=0.6980, ValLoss=0.6946, ValAUC=0.4955
# ==> Val AUC improved to 0.4955. Fine-tuned model saved.
# [Fine-tune Epoch 16/50] TrainLoss=0.6856, ValLoss=0.6967, ValAUC=0.4420
# [Fine-tune Epoch 17/50] TrainLoss=0.6839, ValLoss=0.6984, ValAUC=0.4330
# [Fine-tune Epoch 18/50] TrainLoss=0.7027, ValLoss=0.6997, ValAUC=0.4286
# [Fine-tune Epoch 19/50] TrainLoss=0.6833, ValLoss=0.6998, ValAUC=0.4241
# [Fine-tune Epoch 20/50] TrainLoss=0.7063, ValLoss=0.7011, ValAUC=0.3929
# [Fine-tune Epoch 21/50] TrainLoss=0.6870, ValLoss=0.7013, ValAUC=0.3839
# [Fine-tune Epoch 22/50] TrainLoss=0.6909, ValLoss=0.7005, ValAUC=0.3795
# [Fine-tune Epoch 23/50] TrainLoss=0.6926, ValLoss=0.6992, ValAUC=0.3884
# [Fine-tune Epoch 24/50] TrainLoss=0.6829, ValLoss=0.6980, ValAUC=0.4062
# [Fine-tune Epoch 25/50] TrainLoss=0.6774, ValLoss=0.6994, ValAUC=0.3929
# Early stopping fine-tuning (no val AUC improvement in 10 epochs).
# --- Evaluating best fine-tuned model on Test Set ---
# Loaded best fine-tuned model from best_model_temp_511.pt
# Test Results: Loss=0.6880, AUC=0.5880, F1=0.5714
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=1, process=mixed, outcome=direct
# ===================================================================
#
# --- Running Scenario: N=200, p=10, reg=0.2, miss=0.1, sync=1, lag=False ---
# Data generated: 200 subjects, 57.0% positive cases.
# Using device: cuda
# Splitting data: Train=140, Val=30, Test=30
# Initialized model with Pretrain head. Parameters: 342338
# --- Starting Pretraining Phase (15 epochs) ---
# Pretrain Epoch 1/15 -- Avg Loss: 3.0696
# Pretrain Epoch 2/15 -- Avg Loss: 1.8578
# Pretrain Epoch 3/15 -- Avg Loss: 2.8742
# Pretrain Epoch 4/15 -- Avg Loss: 2.0892
# Pretrain Epoch 5/15 -- Avg Loss: 1.8000
# Pretrain Epoch 6/15 -- Avg Loss: 1.9704
# Pretrain Epoch 7/15 -- Avg Loss: 2.0687
# Pretrain Epoch 8/15 -- Avg Loss: 2.1966
# Pretrain Epoch 9/15 -- Avg Loss: 2.5000
# Pretrain Epoch 10/15 -- Avg Loss: 2.1532
# Pretrain Epoch 11/15 -- Avg Loss: 2.2263
# Pretrain Epoch 12/15 -- Avg Loss: 2.4209
# Pretrain Epoch 13/15 -- Avg Loss: 2.3036
# Pretrain Epoch 14/15 -- Avg Loss: 2.1093
# Pretrain Epoch 15/15 -- Avg Loss: 1.7082
# --- Pretraining Phase Complete ---
# --- Switching to Fine-tuning Phase (50 epochs) ---
# Model head switched to ClfHead. Total params now: 341818
# --- Starting Fine-tuning Training Loop ---
# [Fine-tune Epoch 1/50] TrainLoss=0.7204, ValLoss=0.7154, ValAUC=0.5511
# [Fine-tune Epoch 2/50] TrainLoss=0.7214, ValLoss=0.7153, ValAUC=0.5511
# [Fine-tune Epoch 3/50] TrainLoss=0.7160, ValLoss=0.7136, ValAUC=0.5511
# ==> Val AUC improved to 0.5511. Fine-tuned model saved.
# [Fine-tune Epoch 4/50] TrainLoss=0.7609, ValLoss=0.7110, ValAUC=0.5556
# ==> Val AUC improved to 0.5556. Fine-tuned model saved.
# [Fine-tune Epoch 5/50] TrainLoss=0.7381, ValLoss=0.7075, ValAUC=0.5644
# ==> Val AUC improved to 0.5644. Fine-tuned model saved.
# [Fine-tune Epoch 6/50] TrainLoss=0.7501, ValLoss=0.7029, ValAUC=0.5822
# ==> Val AUC improved to 0.5822. Fine-tuned model saved.
# [Fine-tune Epoch 7/50] TrainLoss=0.7450, ValLoss=0.6979, ValAUC=0.5911
# ==> Val AUC improved to 0.5911. Fine-tuned model saved.
# [Fine-tune Epoch 8/50] TrainLoss=0.7460, ValLoss=0.6922, ValAUC=0.6000
# ==> Val AUC improved to 0.6000. Fine-tuned model saved.
# [Fine-tune Epoch 9/50] TrainLoss=0.7180, ValLoss=0.6867, ValAUC=0.6178
# ==> Val AUC improved to 0.6178. Fine-tuned model saved.
# [Fine-tune Epoch 10/50] TrainLoss=0.6548, ValLoss=0.6822, ValAUC=0.6178
# [Fine-tune Epoch 11/50] TrainLoss=0.6922, ValLoss=0.6758, ValAUC=0.6222
# ==> Val AUC improved to 0.6222. Fine-tuned model saved.
# [Fine-tune Epoch 12/50] TrainLoss=0.6694, ValLoss=0.6687, ValAUC=0.6311
# ==> Val AUC improved to 0.6311. Fine-tuned model saved.
# [Fine-tune Epoch 13/50] TrainLoss=0.6460, ValLoss=0.6641, ValAUC=0.6578
# ==> Val AUC improved to 0.6578. Fine-tuned model saved.
# [Fine-tune Epoch 14/50] TrainLoss=0.6284, ValLoss=0.6598, ValAUC=0.6622
# ==> Val AUC improved to 0.6622. Fine-tuned model saved.
# [Fine-tune Epoch 15/50] TrainLoss=0.6558, ValLoss=0.6570, ValAUC=0.6622
# [Fine-tune Epoch 16/50] TrainLoss=0.6521, ValLoss=0.6548, ValAUC=0.6800
# ==> Val AUC improved to 0.6800. Fine-tuned model saved.
# [Fine-tune Epoch 17/50] TrainLoss=0.6330, ValLoss=0.6523, ValAUC=0.6756
# [Fine-tune Epoch 18/50] TrainLoss=0.6339, ValLoss=0.6497, ValAUC=0.6933
# ==> Val AUC improved to 0.6933. Fine-tuned model saved.
# [Fine-tune Epoch 19/50] TrainLoss=0.6055, ValLoss=0.6467, ValAUC=0.7067
# ==> Val AUC improved to 0.7067. Fine-tuned model saved.
# [Fine-tune Epoch 20/50] TrainLoss=0.6270, ValLoss=0.6448, ValAUC=0.7111
# ==> Val AUC improved to 0.7111. Fine-tuned model saved.
# [Fine-tune Epoch 21/50] TrainLoss=0.5752, ValLoss=0.6438, ValAUC=0.7156
# ==> Val AUC improved to 0.7156. Fine-tuned model saved.
# [Fine-tune Epoch 22/50] TrainLoss=0.6050, ValLoss=0.6425, ValAUC=0.7244
# ==> Val AUC improved to 0.7244. Fine-tuned model saved.
# [Fine-tune Epoch 23/50] TrainLoss=0.5910, ValLoss=0.6426, ValAUC=0.7333
# ==> Val AUC improved to 0.7333. Fine-tuned model saved.
# [Fine-tune Epoch 24/50] TrainLoss=0.6076, ValLoss=0.6420, ValAUC=0.7378
# ==> Val AUC improved to 0.7378. Fine-tuned model saved.
# [Fine-tune Epoch 25/50] TrainLoss=0.5988, ValLoss=0.6392, ValAUC=0.7378
# [Fine-tune Epoch 26/50] TrainLoss=0.5584, ValLoss=0.6355, ValAUC=0.7422
# ==> Val AUC improved to 0.7422. Fine-tuned model saved.
# [Fine-tune Epoch 27/50] TrainLoss=0.6491, ValLoss=0.6324, ValAUC=0.7422
# [Fine-tune Epoch 28/50] TrainLoss=0.4953, ValLoss=0.6272, ValAUC=0.7511
# ==> Val AUC improved to 0.7511. Fine-tuned model saved.
# [Fine-tune Epoch 29/50] TrainLoss=0.5264, ValLoss=0.6243, ValAUC=0.7556
# ==> Val AUC improved to 0.7556. Fine-tuned model saved.
# [Fine-tune Epoch 30/50] TrainLoss=0.5344, ValLoss=0.6219, ValAUC=0.7511
# [Fine-tune Epoch 31/50] TrainLoss=0.5121, ValLoss=0.6177, ValAUC=0.7556
# [Fine-tune Epoch 32/50] TrainLoss=0.5345, ValLoss=0.6124, ValAUC=0.7422
# [Fine-tune Epoch 33/50] TrainLoss=0.5240, ValLoss=0.6072, ValAUC=0.7422
# [Fine-tune Epoch 34/50] TrainLoss=0.5123, ValLoss=0.6010, ValAUC=0.7467
# [Fine-tune Epoch 35/50] TrainLoss=0.4383, ValLoss=0.5978, ValAUC=0.7467
# [Fine-tune Epoch 36/50] TrainLoss=0.5069, ValLoss=0.5942, ValAUC=0.7467
# [Fine-tune Epoch 37/50] TrainLoss=0.4975, ValLoss=0.5925, ValAUC=0.7378
# [Fine-tune Epoch 38/50] TrainLoss=0.4290, ValLoss=0.5912, ValAUC=0.7378
# [Fine-tune Epoch 39/50] TrainLoss=0.4505, ValLoss=0.5856, ValAUC=0.7467
# Early stopping fine-tuning (no val AUC improvement in 10 epochs).
# --- Evaluating best fine-tuned model on Test Set ---
# Loaded best fine-tuned model from best_model_temp_511.pt
# Test Results: Loss=0.6792, AUC=0.6389, F1=0.7391
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=1, process=mixed, outcome=lagged
# ===================================================================
#
# --- Running Scenario: N=200, p=10, reg=0.2, miss=0.1, sync=1, lag=True ---
# Data generated: 200 subjects, 51.5% positive cases.
# Using device: cuda
# Splitting data: Train=140, Val=30, Test=30
# Initialized model with Pretrain head. Parameters: 342338
# --- Starting Pretraining Phase (15 epochs) ---
# Pretrain Epoch 1/15 -- Avg Loss: 1.0931
# Pretrain Epoch 2/15 -- Avg Loss: 1.1716
# Pretrain Epoch 3/15 -- Avg Loss: 1.4178
# Pretrain Epoch 4/15 -- Avg Loss: 1.1836
# Pretrain Epoch 5/15 -- Avg Loss: 1.2175
# Pretrain Epoch 6/15 -- Avg Loss: 1.2292
# Pretrain Epoch 7/15 -- Avg Loss: 1.3565
# Pretrain Epoch 8/15 -- Avg Loss: 1.2330
# Pretrain Epoch 9/15 -- Avg Loss: 1.2512
# Pretrain Epoch 10/15 -- Avg Loss: 1.1426
# Pretrain Epoch 11/15 -- Avg Loss: 0.9592
# Pretrain Epoch 12/15 -- Avg Loss: 1.0521
# Pretrain Epoch 13/15 -- Avg Loss: 1.0142
# Pretrain Epoch 14/15 -- Avg Loss: 1.0698
# Pretrain Epoch 15/15 -- Avg Loss: 1.1405
# --- Pretraining Phase Complete ---
# --- Switching to Fine-tuning Phase (50 epochs) ---
# Model head switched to ClfHead. Total params now: 341818
# --- Starting Fine-tuning Training Loop ---
# [Fine-tune Epoch 1/50] TrainLoss=0.7060, ValLoss=0.6884, ValAUC=0.5701
# [Fine-tune Epoch 2/50] TrainLoss=0.6797, ValLoss=0.6881, ValAUC=0.5701
# [Fine-tune Epoch 3/50] TrainLoss=0.6551, ValLoss=0.6872, ValAUC=0.5701
# ==> Val AUC improved to 0.5701. Fine-tuned model saved.
# [Fine-tune Epoch 4/50] TrainLoss=0.6631, ValLoss=0.6860, ValAUC=0.5882
# ==> Val AUC improved to 0.5882. Fine-tuned model saved.
# [Fine-tune Epoch 5/50] TrainLoss=0.7372, ValLoss=0.6844, ValAUC=0.5973
# ==> Val AUC improved to 0.5973. Fine-tuned model saved.
# [Fine-tune Epoch 6/50] TrainLoss=0.6851, ValLoss=0.6824, ValAUC=0.5973
# [Fine-tune Epoch 7/50] TrainLoss=0.6947, ValLoss=0.6807, ValAUC=0.6018
# ==> Val AUC improved to 0.6018. Fine-tuned model saved.
# [Fine-tune Epoch 8/50] TrainLoss=0.7293, ValLoss=0.6772, ValAUC=0.6199
# ==> Val AUC improved to 0.6199. Fine-tuned model saved.
# [Fine-tune Epoch 9/50] TrainLoss=0.7346, ValLoss=0.6731, ValAUC=0.6380
# ==> Val AUC improved to 0.6380. Fine-tuned model saved.
# [Fine-tune Epoch 10/50] TrainLoss=0.6620, ValLoss=0.6691, ValAUC=0.6471
# ==> Val AUC improved to 0.6471. Fine-tuned model saved.
# [Fine-tune Epoch 11/50] TrainLoss=0.7108, ValLoss=0.6644, ValAUC=0.6425
# [Fine-tune Epoch 12/50] TrainLoss=0.7028, ValLoss=0.6609, ValAUC=0.6425
# [Fine-tune Epoch 13/50] TrainLoss=0.6484, ValLoss=0.6581, ValAUC=0.6471
# [Fine-tune Epoch 14/50] TrainLoss=0.6614, ValLoss=0.6563, ValAUC=0.6516
# ==> Val AUC improved to 0.6516. Fine-tuned model saved.
# [Fine-tune Epoch 15/50] TrainLoss=0.6550, ValLoss=0.6549, ValAUC=0.6471
# [Fine-tune Epoch 16/50] TrainLoss=0.6489, ValLoss=0.6533, ValAUC=0.6516
# ==> Val AUC improved to 0.6516. Fine-tuned model saved.
# [Fine-tune Epoch 17/50] TrainLoss=0.6366, ValLoss=0.6527, ValAUC=0.6652
# ==> Val AUC improved to 0.6652. Fine-tuned model saved.
# [Fine-tune Epoch 18/50] TrainLoss=0.6809, ValLoss=0.6521, ValAUC=0.6742
# ==> Val AUC improved to 0.6742. Fine-tuned model saved.
# [Fine-tune Epoch 19/50] TrainLoss=0.6091, ValLoss=0.6525, ValAUC=0.6833
# ==> Val AUC improved to 0.6833. Fine-tuned model saved.
# [Fine-tune Epoch 20/50] TrainLoss=0.6058, ValLoss=0.6509, ValAUC=0.6968
# ==> Val AUC improved to 0.6968. Fine-tuned model saved.
# [Fine-tune Epoch 21/50] TrainLoss=0.6572, ValLoss=0.6484, ValAUC=0.7104
# ==> Val AUC improved to 0.7104. Fine-tuned model saved.
# [Fine-tune Epoch 22/50] TrainLoss=0.6119, ValLoss=0.6461, ValAUC=0.7421
# ==> Val AUC improved to 0.7421. Fine-tuned model saved.
# [Fine-tune Epoch 23/50] TrainLoss=0.6013, ValLoss=0.6457, ValAUC=0.7557
# ==> Val AUC improved to 0.7557. Fine-tuned model saved.
# [Fine-tune Epoch 24/50] TrainLoss=0.5766, ValLoss=0.6455, ValAUC=0.7692
# ==> Val AUC improved to 0.7692. Fine-tuned model saved.
# [Fine-tune Epoch 25/50] TrainLoss=0.5720, ValLoss=0.6470, ValAUC=0.7738
# ==> Val AUC improved to 0.7738. Fine-tuned model saved.
# [Fine-tune Epoch 26/50] TrainLoss=0.6005, ValLoss=0.6482, ValAUC=0.7783
# ==> Val AUC improved to 0.7783. Fine-tuned model saved.
# [Fine-tune Epoch 27/50] TrainLoss=0.5529, ValLoss=0.6492, ValAUC=0.7828
# ==> Val AUC improved to 0.7828. Fine-tuned model saved.
# [Fine-tune Epoch 28/50] TrainLoss=0.6277, ValLoss=0.6458, ValAUC=0.7873
# ==> Val AUC improved to 0.7873. Fine-tuned model saved.
# [Fine-tune Epoch 29/50] TrainLoss=0.5830, ValLoss=0.6397, ValAUC=0.7964
# ==> Val AUC improved to 0.7964. Fine-tuned model saved.
# [Fine-tune Epoch 30/50] TrainLoss=0.5461, ValLoss=0.6319, ValAUC=0.7828
# [Fine-tune Epoch 31/50] TrainLoss=0.5560, ValLoss=0.6214, ValAUC=0.7873
# [Fine-tune Epoch 32/50] TrainLoss=0.5269, ValLoss=0.6091, ValAUC=0.7873
# [Fine-tune Epoch 33/50] TrainLoss=0.5457, ValLoss=0.5999, ValAUC=0.7873
# [Fine-tune Epoch 34/50] TrainLoss=0.5542, ValLoss=0.5883, ValAUC=0.7873
# [Fine-tune Epoch 35/50] TrainLoss=0.4623, ValLoss=0.5762, ValAUC=0.8009
# ==> Val AUC improved to 0.8009. Fine-tuned model saved.
# [Fine-tune Epoch 36/50] TrainLoss=0.4910, ValLoss=0.5689, ValAUC=0.8054
# ==> Val AUC improved to 0.8054. Fine-tuned model saved.
# [Fine-tune Epoch 37/50] TrainLoss=0.4534, ValLoss=0.5591, ValAUC=0.8100
# ==> Val AUC improved to 0.8100. Fine-tuned model saved.
# [Fine-tune Epoch 38/50] TrainLoss=0.4391, ValLoss=0.5506, ValAUC=0.8235
# ==> Val AUC improved to 0.8235. Fine-tuned model saved.
# [Fine-tune Epoch 39/50] TrainLoss=0.4596, ValLoss=0.5437, ValAUC=0.8190
# [Fine-tune Epoch 40/50] TrainLoss=0.4926, ValLoss=0.5405, ValAUC=0.8281
# ==> Val AUC improved to 0.8281. Fine-tuned model saved.
# [Fine-tune Epoch 41/50] TrainLoss=0.4299, ValLoss=0.5400, ValAUC=0.8326
# ==> Val AUC improved to 0.8326. Fine-tuned model saved.
# [Fine-tune Epoch 42/50] TrainLoss=0.4770, ValLoss=0.5426, ValAUC=0.8326
# [Fine-tune Epoch 43/50] TrainLoss=0.4146, ValLoss=0.5420, ValAUC=0.8326
# [Fine-tune Epoch 44/50] TrainLoss=0.3984, ValLoss=0.5386, ValAUC=0.8326
# [Fine-tune Epoch 45/50] TrainLoss=0.3965, ValLoss=0.5348, ValAUC=0.8371
# ==> Val AUC improved to 0.8371. Fine-tuned model saved.
# [Fine-tune Epoch 46/50] TrainLoss=0.4046, ValLoss=0.5242, ValAUC=0.8416
# ==> Val AUC improved to 0.8416. Fine-tuned model saved.
# [Fine-tune Epoch 47/50] TrainLoss=0.4614, ValLoss=0.5068, ValAUC=0.8552
# ==> Val AUC improved to 0.8552. Fine-tuned model saved.
# [Fine-tune Epoch 48/50] TrainLoss=0.3599, ValLoss=0.4929, ValAUC=0.8643
# ==> Val AUC improved to 0.8643. Fine-tuned model saved.
# [Fine-tune Epoch 49/50] TrainLoss=0.5331, ValLoss=0.4865, ValAUC=0.8733
# ==> Val AUC improved to 0.8733. Fine-tuned model saved.
# [Fine-tune Epoch 50/50] TrainLoss=0.4415, ValLoss=0.4688, ValAUC=0.8824
# ==> Val AUC improved to 0.8824. Fine-tuned model saved.
# --- Evaluating best fine-tuned model on Test Set ---
# Loaded best fine-tuned model from best_model_temp_511.pt
# Test Results: Loss=0.4385, AUC=0.8824, F1=0.7500
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=p, process=homogeneous, outcome=direct
# ===================================================================
#
# --- Running Scenario: N=200, p=10, reg=0.2, miss=0.1, sync=3, lag=False ---
# Data generated: 200 subjects, 55.5% positive cases.
# Using device: cuda
# Splitting data: Train=140, Val=30, Test=30
# Initialized model with Pretrain head. Parameters: 342338
# --- Starting Pretraining Phase (15 epochs) ---
# Pretrain Epoch 1/15 -- Avg Loss: 0.5088
# Pretrain Epoch 2/15 -- Avg Loss: 0.4997
# Pretrain Epoch 3/15 -- Avg Loss: 0.4932
# Pretrain Epoch 4/15 -- Avg Loss: 0.4924
# Pretrain Epoch 5/15 -- Avg Loss: 0.4843
# Pretrain Epoch 6/15 -- Avg Loss: 0.4697
# Pretrain Epoch 7/15 -- Avg Loss: 0.4621
# Pretrain Epoch 8/15 -- Avg Loss: 0.4455
# Pretrain Epoch 9/15 -- Avg Loss: 0.4317
# Pretrain Epoch 10/15 -- Avg Loss: 0.4137
# Pretrain Epoch 11/15 -- Avg Loss: 0.3977
# Pretrain Epoch 12/15 -- Avg Loss: 0.3743
# Pretrain Epoch 13/15 -- Avg Loss: 0.3553
# Pretrain Epoch 14/15 -- Avg Loss: 0.3351
# Pretrain Epoch 15/15 -- Avg Loss: 0.3148
# --- Pretraining Phase Complete ---
# --- Switching to Fine-tuning Phase (50 epochs) ---
# Model head switched to ClfHead. Total params now: 341818
# --- Starting Fine-tuning Training Loop ---
# [Fine-tune Epoch 1/50] TrainLoss=0.7232, ValLoss=0.7522, ValAUC=0.4578
# [Fine-tune Epoch 2/50] TrainLoss=0.7072, ValLoss=0.7495, ValAUC=0.4800
# [Fine-tune Epoch 3/50] TrainLoss=0.7300, ValLoss=0.7457, ValAUC=0.4711
# ==> Val AUC improved to 0.4711. Fine-tuned model saved.
# [Fine-tune Epoch 4/50] TrainLoss=0.6896, ValLoss=0.7378, ValAUC=0.5067
# ==> Val AUC improved to 0.5067. Fine-tuned model saved.
# [Fine-tune Epoch 5/50] TrainLoss=0.7412, ValLoss=0.7305, ValAUC=0.4978
# [Fine-tune Epoch 6/50] TrainLoss=0.7319, ValLoss=0.7167, ValAUC=0.5556
# ==> Val AUC improved to 0.5556. Fine-tuned model saved.
# [Fine-tune Epoch 7/50] TrainLoss=0.6804, ValLoss=0.7062, ValAUC=0.5867
# ==> Val AUC improved to 0.5867. Fine-tuned model saved.
# [Fine-tune Epoch 8/50] TrainLoss=0.7684, ValLoss=0.6948, ValAUC=0.6222
# ==> Val AUC improved to 0.6222. Fine-tuned model saved.
# [Fine-tune Epoch 9/50] TrainLoss=0.6441, ValLoss=0.6894, ValAUC=0.6400
# ==> Val AUC improved to 0.6400. Fine-tuned model saved.
# [Fine-tune Epoch 10/50] TrainLoss=0.6766, ValLoss=0.6843, ValAUC=0.6444
# ==> Val AUC improved to 0.6444. Fine-tuned model saved.
# [Fine-tune Epoch 11/50] TrainLoss=0.6450, ValLoss=0.6828, ValAUC=0.6178
# [Fine-tune Epoch 12/50] TrainLoss=0.7272, ValLoss=0.6802, ValAUC=0.6133
# [Fine-tune Epoch 13/50] TrainLoss=0.6678, ValLoss=0.6777, ValAUC=0.6222
# [Fine-tune Epoch 14/50] TrainLoss=0.6942, ValLoss=0.6757, ValAUC=0.6578
# ==> Val AUC improved to 0.6578. Fine-tuned model saved.
# [Fine-tune Epoch 15/50] TrainLoss=0.6940, ValLoss=0.6722, ValAUC=0.6622
# ==> Val AUC improved to 0.6622. Fine-tuned model saved.
# [Fine-tune Epoch 16/50] TrainLoss=0.6726, ValLoss=0.6719, ValAUC=0.6622
# [Fine-tune Epoch 17/50] TrainLoss=0.6939, ValLoss=0.6727, ValAUC=0.6578
# [Fine-tune Epoch 18/50] TrainLoss=0.6878, ValLoss=0.6741, ValAUC=0.6578
# [Fine-tune Epoch 19/50] TrainLoss=0.6924, ValLoss=0.6754, ValAUC=0.6533
# [Fine-tune Epoch 20/50] TrainLoss=0.6812, ValLoss=0.6734, ValAUC=0.6622
# [Fine-tune Epoch 21/50] TrainLoss=0.6689, ValLoss=0.6732, ValAUC=0.6578
# [Fine-tune Epoch 22/50] TrainLoss=0.6882, ValLoss=0.6753, ValAUC=0.6667
# ==> Val AUC improved to 0.6667. Fine-tuned model saved.
# [Fine-tune Epoch 23/50] TrainLoss=0.6627, ValLoss=0.6799, ValAUC=0.6622
# [Fine-tune Epoch 24/50] TrainLoss=0.6831, ValLoss=0.6820, ValAUC=0.6622
# [Fine-tune Epoch 25/50] TrainLoss=0.6787, ValLoss=0.6870, ValAUC=0.6667
# [Fine-tune Epoch 26/50] TrainLoss=0.6525, ValLoss=0.6980, ValAUC=0.6667
# ==> Val AUC improved to 0.6667. Fine-tuned model saved.
# [Fine-tune Epoch 27/50] TrainLoss=0.7006, ValLoss=0.7049, ValAUC=0.6622
# [Fine-tune Epoch 28/50] TrainLoss=0.6687, ValLoss=0.7099, ValAUC=0.6622
# [Fine-tune Epoch 29/50] TrainLoss=0.6935, ValLoss=0.7070, ValAUC=0.6622
# [Fine-tune Epoch 30/50] TrainLoss=0.6604, ValLoss=0.7008, ValAUC=0.6622
# [Fine-tune Epoch 31/50] TrainLoss=0.6879, ValLoss=0.6971, ValAUC=0.6622
# [Fine-tune Epoch 32/50] TrainLoss=0.6901, ValLoss=0.6888, ValAUC=0.6622
# [Fine-tune Epoch 33/50] TrainLoss=0.6693, ValLoss=0.6811, ValAUC=0.6622
# [Fine-tune Epoch 34/50] TrainLoss=0.7025, ValLoss=0.6729, ValAUC=0.6667
# [Fine-tune Epoch 35/50] TrainLoss=0.6713, ValLoss=0.6719, ValAUC=0.6533
# [Fine-tune Epoch 36/50] TrainLoss=0.6880, ValLoss=0.6722, ValAUC=0.6444
# Early stopping fine-tuning (no val AUC improvement in 10 epochs).
# --- Evaluating best fine-tuned model on Test Set ---
# Loaded best fine-tuned model from best_model_temp_511.pt
# Test Results: Loss=0.7044, AUC=0.3937, F1=0.7234
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=p, process=homogeneous, outcome=lagged
# ===================================================================
#
# --- Running Scenario: N=200, p=10, reg=0.2, miss=0.1, sync=3, lag=True ---
# Data generated: 200 subjects, 53.0% positive cases.
# Using device: cuda
# Splitting data: Train=140, Val=30, Test=30
# Initialized model with Pretrain head. Parameters: 342338
# --- Starting Pretraining Phase (15 epochs) ---
# Pretrain Epoch 1/15 -- Avg Loss: 0.6601
# Pretrain Epoch 2/15 -- Avg Loss: 0.6553
# Pretrain Epoch 3/15 -- Avg Loss: 0.6578
# Pretrain Epoch 4/15 -- Avg Loss: 0.6518
# Pretrain Epoch 5/15 -- Avg Loss: 0.6386
# Pretrain Epoch 6/15 -- Avg Loss: 0.6314
# Pretrain Epoch 7/15 -- Avg Loss: 0.6224
# Pretrain Epoch 8/15 -- Avg Loss: 0.6085
# Pretrain Epoch 9/15 -- Avg Loss: 0.5911
# Pretrain Epoch 10/15 -- Avg Loss: 0.5739
# Pretrain Epoch 11/15 -- Avg Loss: 0.5493
# Pretrain Epoch 12/15 -- Avg Loss: 0.5425
# Pretrain Epoch 13/15 -- Avg Loss: 0.5177
# Pretrain Epoch 14/15 -- Avg Loss: 0.4956
# Pretrain Epoch 15/15 -- Avg Loss: 0.4773
# --- Pretraining Phase Complete ---
# --- Switching to Fine-tuning Phase (50 epochs) ---
# Model head switched to ClfHead. Total params now: 341818
# --- Starting Fine-tuning Training Loop ---
# [Fine-tune Epoch 1/50] TrainLoss=0.6829, ValLoss=0.6759, ValAUC=0.5928
# [Fine-tune Epoch 2/50] TrainLoss=0.6849, ValLoss=0.6758, ValAUC=0.5928
# [Fine-tune Epoch 3/50] TrainLoss=0.7631, ValLoss=0.6748, ValAUC=0.5973
# ==> Val AUC improved to 0.5973. Fine-tuned model saved.
# [Fine-tune Epoch 4/50] TrainLoss=0.7080, ValLoss=0.6750, ValAUC=0.5905
# [Fine-tune Epoch 5/50] TrainLoss=0.6977, ValLoss=0.6764, ValAUC=0.5928
# [Fine-tune Epoch 6/50] TrainLoss=0.6596, ValLoss=0.6740, ValAUC=0.6109
# ==> Val AUC improved to 0.6109. Fine-tuned model saved.
# [Fine-tune Epoch 7/50] TrainLoss=0.7333, ValLoss=0.6749, ValAUC=0.6199
# ==> Val AUC improved to 0.6199. Fine-tuned model saved.
# [Fine-tune Epoch 8/50] TrainLoss=0.7178, ValLoss=0.6795, ValAUC=0.6063
# [Fine-tune Epoch 9/50] TrainLoss=0.7051, ValLoss=0.6822, ValAUC=0.6199
# [Fine-tune Epoch 10/50] TrainLoss=0.6915, ValLoss=0.6870, ValAUC=0.6335
# ==> Val AUC improved to 0.6335. Fine-tuned model saved.
# [Fine-tune Epoch 11/50] TrainLoss=0.6863, ValLoss=0.6919, ValAUC=0.6290
# [Fine-tune Epoch 12/50] TrainLoss=0.6785, ValLoss=0.6947, ValAUC=0.6290
# [Fine-tune Epoch 13/50] TrainLoss=0.6857, ValLoss=0.6970, ValAUC=0.5928
# [Fine-tune Epoch 14/50] TrainLoss=0.7070, ValLoss=0.6974, ValAUC=0.6018
# [Fine-tune Epoch 15/50] TrainLoss=0.6831, ValLoss=0.6960, ValAUC=0.6290
# [Fine-tune Epoch 16/50] TrainLoss=0.6913, ValLoss=0.6940, ValAUC=0.6109
# [Fine-tune Epoch 17/50] TrainLoss=0.6938, ValLoss=0.6894, ValAUC=0.5837
# [Fine-tune Epoch 18/50] TrainLoss=0.7069, ValLoss=0.6907, ValAUC=0.5701
# [Fine-tune Epoch 19/50] TrainLoss=0.6982, ValLoss=0.6934, ValAUC=0.5113
# [Fine-tune Epoch 20/50] TrainLoss=0.6920, ValLoss=0.6926, ValAUC=0.4977
# Early stopping fine-tuning (no val AUC improvement in 10 epochs).
# --- Evaluating best fine-tuned model on Test Set ---
# Loaded best fine-tuned model from best_model_temp_511.pt
# Test Results: Loss=0.6924, AUC=0.5357, F1=0.2500
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=p, process=mixed, outcome=direct
# ===================================================================
#
# --- Running Scenario: N=200, p=10, reg=0.2, miss=0.1, sync=3, lag=False ---
# Data generated: 200 subjects, 52.5% positive cases.
# Using device: cuda
# Splitting data: Train=140, Val=30, Test=30
# Initialized model with Pretrain head. Parameters: 342338
# --- Starting Pretraining Phase (15 epochs) ---
# Pretrain Epoch 1/15 -- Avg Loss: 1.1538
# Pretrain Epoch 2/15 -- Avg Loss: 1.2132
# Pretrain Epoch 3/15 -- Avg Loss: 1.2508
# Pretrain Epoch 4/15 -- Avg Loss: 1.2942
# Pretrain Epoch 5/15 -- Avg Loss: 1.3396
# Pretrain Epoch 6/15 -- Avg Loss: 1.1793
# Pretrain Epoch 7/15 -- Avg Loss: 1.2920
# Pretrain Epoch 8/15 -- Avg Loss: 1.2588
# Pretrain Epoch 9/15 -- Avg Loss: 1.3811
# Pretrain Epoch 10/15 -- Avg Loss: 1.3479
# Pretrain Epoch 11/15 -- Avg Loss: 1.2961
# Pretrain Epoch 12/15 -- Avg Loss: 1.1313
# Pretrain Epoch 13/15 -- Avg Loss: 1.1176
# Pretrain Epoch 14/15 -- Avg Loss: 1.4311
# Pretrain Epoch 15/15 -- Avg Loss: 1.1199
# --- Pretraining Phase Complete ---
# --- Switching to Fine-tuning Phase (50 epochs) ---
# Model head switched to ClfHead. Total params now: 341818
# --- Starting Fine-tuning Training Loop ---
# [Fine-tune Epoch 1/50] TrainLoss=0.7027, ValLoss=0.7181, ValAUC=0.6172
# [Fine-tune Epoch 2/50] TrainLoss=0.7435, ValLoss=0.7164, ValAUC=0.6172
# [Fine-tune Epoch 3/50] TrainLoss=0.7005, ValLoss=0.7126, ValAUC=0.6172
# ==> Val AUC improved to 0.6172. Fine-tuned model saved.
# [Fine-tune Epoch 4/50] TrainLoss=0.7021, ValLoss=0.7070, ValAUC=0.6268
# ==> Val AUC improved to 0.6268. Fine-tuned model saved.
# [Fine-tune Epoch 5/50] TrainLoss=0.7597, ValLoss=0.6995, ValAUC=0.6220
# [Fine-tune Epoch 6/50] TrainLoss=0.6866, ValLoss=0.6912, ValAUC=0.6459
# ==> Val AUC improved to 0.6459. Fine-tuned model saved.
# [Fine-tune Epoch 7/50] TrainLoss=0.6637, ValLoss=0.6834, ValAUC=0.6459
# [Fine-tune Epoch 8/50] TrainLoss=0.6647, ValLoss=0.6746, ValAUC=0.6459
# [Fine-tune Epoch 9/50] TrainLoss=0.6907, ValLoss=0.6654, ValAUC=0.6555
# ==> Val AUC improved to 0.6555. Fine-tuned model saved.
# [Fine-tune Epoch 10/50] TrainLoss=0.6570, ValLoss=0.6573, ValAUC=0.6651
# ==> Val AUC improved to 0.6651. Fine-tuned model saved.
# [Fine-tune Epoch 11/50] TrainLoss=0.6533, ValLoss=0.6496, ValAUC=0.6794
# ==> Val AUC improved to 0.6794. Fine-tuned model saved.
# [Fine-tune Epoch 12/50] TrainLoss=0.6540, ValLoss=0.6421, ValAUC=0.7081
# ==> Val AUC improved to 0.7081. Fine-tuned model saved.
# [Fine-tune Epoch 13/50] TrainLoss=0.6458, ValLoss=0.6344, ValAUC=0.7177
# ==> Val AUC improved to 0.7177. Fine-tuned model saved.
# [Fine-tune Epoch 14/50] TrainLoss=0.6625, ValLoss=0.6276, ValAUC=0.7416
# ==> Val AUC improved to 0.7416. Fine-tuned model saved.
# [Fine-tune Epoch 15/50] TrainLoss=0.6420, ValLoss=0.6202, ValAUC=0.7512
# ==> Val AUC improved to 0.7512. Fine-tuned model saved.
# [Fine-tune Epoch 16/50] TrainLoss=0.6368, ValLoss=0.6119, ValAUC=0.7512
# [Fine-tune Epoch 17/50] TrainLoss=0.6390, ValLoss=0.6021, ValAUC=0.7703
# ==> Val AUC improved to 0.7703. Fine-tuned model saved.
# [Fine-tune Epoch 18/50] TrainLoss=0.6351, ValLoss=0.5926, ValAUC=0.7895
# ==> Val AUC improved to 0.7895. Fine-tuned model saved.
# [Fine-tune Epoch 19/50] TrainLoss=0.6248, ValLoss=0.5835, ValAUC=0.7943
# ==> Val AUC improved to 0.7943. Fine-tuned model saved.
# [Fine-tune Epoch 20/50] TrainLoss=0.6499, ValLoss=0.5757, ValAUC=0.8038
# ==> Val AUC improved to 0.8038. Fine-tuned model saved.
# [Fine-tune Epoch 21/50] TrainLoss=0.6349, ValLoss=0.5694, ValAUC=0.8134
# ==> Val AUC improved to 0.8134. Fine-tuned model saved.
# [Fine-tune Epoch 22/50] TrainLoss=0.5529, ValLoss=0.5642, ValAUC=0.8086
# [Fine-tune Epoch 23/50] TrainLoss=0.5449, ValLoss=0.5582, ValAUC=0.8134
# ==> Val AUC improved to 0.8134. Fine-tuned model saved.
# [Fine-tune Epoch 24/50] TrainLoss=0.5952, ValLoss=0.5515, ValAUC=0.8134
# [Fine-tune Epoch 25/50] TrainLoss=0.5526, ValLoss=0.5438, ValAUC=0.8182
# ==> Val AUC improved to 0.8182. Fine-tuned model saved.
# [Fine-tune Epoch 26/50] TrainLoss=0.6201, ValLoss=0.5383, ValAUC=0.8373
# ==> Val AUC improved to 0.8373. Fine-tuned model saved.
# [Fine-tune Epoch 27/50] TrainLoss=0.5275, ValLoss=0.5357, ValAUC=0.8325
# [Fine-tune Epoch 28/50] TrainLoss=0.5260, ValLoss=0.5324, ValAUC=0.8325
# [Fine-tune Epoch 29/50] TrainLoss=0.5488, ValLoss=0.5308, ValAUC=0.8373
# [Fine-tune Epoch 30/50] TrainLoss=0.5368, ValLoss=0.5335, ValAUC=0.8517
# ==> Val AUC improved to 0.8517. Fine-tuned model saved.
# [Fine-tune Epoch 31/50] TrainLoss=0.5729, ValLoss=0.5327, ValAUC=0.8517
# [Fine-tune Epoch 32/50] TrainLoss=0.4904, ValLoss=0.5280, ValAUC=0.8517
# [Fine-tune Epoch 33/50] TrainLoss=0.5170, ValLoss=0.5213, ValAUC=0.8517
# ==> Val AUC improved to 0.8517. Fine-tuned model saved.
# [Fine-tune Epoch 34/50] TrainLoss=0.4960, ValLoss=0.5103, ValAUC=0.8565
# ==> Val AUC improved to 0.8565. Fine-tuned model saved.
# [Fine-tune Epoch 35/50] TrainLoss=0.5260, ValLoss=0.5028, ValAUC=0.8612
# ==> Val AUC improved to 0.8612. Fine-tuned model saved.
# [Fine-tune Epoch 36/50] TrainLoss=0.5247, ValLoss=0.4970, ValAUC=0.8565
# [Fine-tune Epoch 37/50] TrainLoss=0.4633, ValLoss=0.4949, ValAUC=0.8612
# [Fine-tune Epoch 38/50] TrainLoss=0.5443, ValLoss=0.4943, ValAUC=0.8612
# [Fine-tune Epoch 39/50] TrainLoss=0.4642, ValLoss=0.4940, ValAUC=0.8565
# [Fine-tune Epoch 40/50] TrainLoss=0.4373, ValLoss=0.4922, ValAUC=0.8565
# [Fine-tune Epoch 41/50] TrainLoss=0.4450, ValLoss=0.4896, ValAUC=0.8565
# [Fine-tune Epoch 42/50] TrainLoss=0.5633, ValLoss=0.4903, ValAUC=0.8565
# [Fine-tune Epoch 43/50] TrainLoss=0.3899, ValLoss=0.4903, ValAUC=0.8612
# [Fine-tune Epoch 44/50] TrainLoss=0.4653, ValLoss=0.4972, ValAUC=0.8612
# [Fine-tune Epoch 45/50] TrainLoss=0.3970, ValLoss=0.5219, ValAUC=0.8469
# Early stopping fine-tuning (no val AUC improvement in 10 epochs).
# --- Evaluating best fine-tuned model on Test Set ---
# Loaded best fine-tuned model from best_model_temp_511.pt
# Test Results: Loss=0.4182, AUC=0.9422, F1=0.8485
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.1, sync=p, process=mixed, outcome=lagged
# ===================================================================
#
# --- Running Scenario: N=200, p=10, reg=0.2, miss=0.1, sync=3, lag=True ---
# Data generated: 200 subjects, 46.5% positive cases.
# Using device: cuda
# Splitting data: Train=140, Val=30, Test=30
# Initialized model with Pretrain head. Parameters: 342338
# --- Starting Pretraining Phase (15 epochs) ---
# Pretrain Epoch 1/15 -- Avg Loss: 0.7396
# Pretrain Epoch 2/15 -- Avg Loss: 0.8528
# Pretrain Epoch 3/15 -- Avg Loss: 0.8760
# Pretrain Epoch 4/15 -- Avg Loss: 0.8094
# Pretrain Epoch 5/15 -- Avg Loss: 0.8233
# Pretrain Epoch 6/15 -- Avg Loss: 0.8806
# Pretrain Epoch 7/15 -- Avg Loss: 0.7601
# Pretrain Epoch 8/15 -- Avg Loss: 0.7445
# Pretrain Epoch 9/15 -- Avg Loss: 0.8253
# Pretrain Epoch 10/15 -- Avg Loss: 0.8292
# Pretrain Epoch 11/15 -- Avg Loss: 0.6995
# Pretrain Epoch 12/15 -- Avg Loss: 0.6982
# Pretrain Epoch 13/15 -- Avg Loss: 0.7400
# Pretrain Epoch 14/15 -- Avg Loss: 0.6955
# Pretrain Epoch 15/15 -- Avg Loss: 0.6623
# --- Pretraining Phase Complete ---
# --- Switching to Fine-tuning Phase (50 epochs) ---
# Model head switched to ClfHead. Total params now: 341818
# --- Starting Fine-tuning Training Loop ---
# [Fine-tune Epoch 1/50] TrainLoss=0.6314, ValLoss=0.7371, ValAUC=0.5249
# [Fine-tune Epoch 2/50] TrainLoss=0.6533, ValLoss=0.7387, ValAUC=0.5249
# [Fine-tune Epoch 3/50] TrainLoss=0.6773, ValLoss=0.7390, ValAUC=0.5204
# ==> Val AUC improved to 0.5204. Fine-tuned model saved.
# [Fine-tune Epoch 4/50] TrainLoss=0.6987, ValLoss=0.7381, ValAUC=0.5158
# [Fine-tune Epoch 5/50] TrainLoss=0.6512, ValLoss=0.7372, ValAUC=0.5249
# ==> Val AUC improved to 0.5249. Fine-tuned model saved.
# [Fine-tune Epoch 6/50] TrainLoss=0.6491, ValLoss=0.7362, ValAUC=0.5566
# ==> Val AUC improved to 0.5566. Fine-tuned model saved.
# [Fine-tune Epoch 7/50] TrainLoss=0.6628, ValLoss=0.7339, ValAUC=0.5656
# ==> Val AUC improved to 0.5656. Fine-tuned model saved.
# [Fine-tune Epoch 8/50] TrainLoss=0.6926, ValLoss=0.7290, ValAUC=0.5837
# ==> Val AUC improved to 0.5837. Fine-tuned model saved.
# [Fine-tune Epoch 9/50] TrainLoss=0.6315, ValLoss=0.7255, ValAUC=0.5792
# [Fine-tune Epoch 10/50] TrainLoss=0.6500, ValLoss=0.7227, ValAUC=0.6109
# ==> Val AUC improved to 0.6109. Fine-tuned model saved.
# [Fine-tune Epoch 11/50] TrainLoss=0.6511, ValLoss=0.7208, ValAUC=0.6425
# ==> Val AUC improved to 0.6425. Fine-tuned model saved.
# [Fine-tune Epoch 12/50] TrainLoss=0.6861, ValLoss=0.7157, ValAUC=0.6742
# ==> Val AUC improved to 0.6742. Fine-tuned model saved.
# [Fine-tune Epoch 13/50] TrainLoss=0.6665, ValLoss=0.7065, ValAUC=0.6923
# ==> Val AUC improved to 0.6923. Fine-tuned model saved.
# [Fine-tune Epoch 14/50] TrainLoss=0.6358, ValLoss=0.6975, ValAUC=0.7240
# ==> Val AUC improved to 0.7240. Fine-tuned model saved.
# [Fine-tune Epoch 15/50] TrainLoss=0.6238, ValLoss=0.6915, ValAUC=0.7376
# ==> Val AUC improved to 0.7376. Fine-tuned model saved.
# [Fine-tune Epoch 16/50] TrainLoss=0.6269, ValLoss=0.6832, ValAUC=0.7376
# [Fine-tune Epoch 17/50] TrainLoss=0.6117, ValLoss=0.6790, ValAUC=0.7376
# [Fine-tune Epoch 18/50] TrainLoss=0.5983, ValLoss=0.6806, ValAUC=0.7285
# [Fine-tune Epoch 19/50] TrainLoss=0.6515, ValLoss=0.6781, ValAUC=0.7285
# [Fine-tune Epoch 20/50] TrainLoss=0.6152, ValLoss=0.6732, ValAUC=0.7376
# [Fine-tune Epoch 21/50] TrainLoss=0.5976, ValLoss=0.6660, ValAUC=0.7421
# ==> Val AUC improved to 0.7421. Fine-tuned model saved.
# [Fine-tune Epoch 22/50] TrainLoss=0.6141, ValLoss=0.6588, ValAUC=0.7466
# ==> Val AUC improved to 0.7466. Fine-tuned model saved.
# [Fine-tune Epoch 23/50] TrainLoss=0.6136, ValLoss=0.6523, ValAUC=0.7557
# ==> Val AUC improved to 0.7557. Fine-tuned model saved.
# [Fine-tune Epoch 24/50] TrainLoss=0.6051, ValLoss=0.6421, ValAUC=0.7557
# [Fine-tune Epoch 25/50] TrainLoss=0.5504, ValLoss=0.6386, ValAUC=0.7557
# [Fine-tune Epoch 26/50] TrainLoss=0.5701, ValLoss=0.6349, ValAUC=0.7692
# ==> Val AUC improved to 0.7692. Fine-tuned model saved.
# [Fine-tune Epoch 27/50] TrainLoss=0.5786, ValLoss=0.6256, ValAUC=0.7738
# ==> Val AUC improved to 0.7738. Fine-tuned model saved.
# [Fine-tune Epoch 28/50] TrainLoss=0.5534, ValLoss=0.6138, ValAUC=0.7783
# ==> Val AUC improved to 0.7783. Fine-tuned model saved.
# [Fine-tune Epoch 29/50] TrainLoss=0.5296, ValLoss=0.6087, ValAUC=0.7783
# ==> Val AUC improved to 0.7783. Fine-tuned model saved.
# [Fine-tune Epoch 30/50] TrainLoss=0.5348, ValLoss=0.6112, ValAUC=0.7828
# ==> Val AUC improved to 0.7828. Fine-tuned model saved.
# [Fine-tune Epoch 31/50] TrainLoss=0.5392, ValLoss=0.6117, ValAUC=0.7783
# [Fine-tune Epoch 32/50] TrainLoss=0.5606, ValLoss=0.6249, ValAUC=0.7738
# [Fine-tune Epoch 33/50] TrainLoss=0.5078, ValLoss=0.6387, ValAUC=0.7738
# [Fine-tune Epoch 34/50] TrainLoss=0.5717, ValLoss=0.6376, ValAUC=0.7692
# [Fine-tune Epoch 35/50] TrainLoss=0.5463, ValLoss=0.6235, ValAUC=0.7783
# [Fine-tune Epoch 36/50] TrainLoss=0.5073, ValLoss=0.6117, ValAUC=0.7783
# [Fine-tune Epoch 37/50] TrainLoss=0.4751, ValLoss=0.6157, ValAUC=0.7738
# [Fine-tune Epoch 38/50] TrainLoss=0.4906, ValLoss=0.6330, ValAUC=0.7828
# [Fine-tune Epoch 39/50] TrainLoss=0.5197, ValLoss=0.6388, ValAUC=0.7828
# [Fine-tune Epoch 40/50] TrainLoss=0.4445, ValLoss=0.6280, ValAUC=0.7873
# ==> Val AUC improved to 0.7873. Fine-tuned model saved.
# [Fine-tune Epoch 41/50] TrainLoss=0.5848, ValLoss=0.6017, ValAUC=0.7828
# [Fine-tune Epoch 42/50] TrainLoss=0.4329, ValLoss=0.5953, ValAUC=0.7783
# [Fine-tune Epoch 43/50] TrainLoss=0.4199, ValLoss=0.6072, ValAUC=0.7919
# ==> Val AUC improved to 0.7919. Fine-tuned model saved.
# [Fine-tune Epoch 44/50] TrainLoss=0.3665, ValLoss=0.6399, ValAUC=0.7828
# [Fine-tune Epoch 45/50] TrainLoss=0.4205, ValLoss=0.6459, ValAUC=0.7873
# [Fine-tune Epoch 46/50] TrainLoss=0.4784, ValLoss=0.6451, ValAUC=0.7964
# ==> Val AUC improved to 0.7964. Fine-tuned model saved.
# [Fine-tune Epoch 47/50] TrainLoss=0.4025, ValLoss=0.6177, ValAUC=0.8009
# ==> Val AUC improved to 0.8009. Fine-tuned model saved.
# [Fine-tune Epoch 48/50] TrainLoss=0.5211, ValLoss=0.5636, ValAUC=0.8054
# ==> Val AUC improved to 0.8054. Fine-tuned model saved.
# [Fine-tune Epoch 49/50] TrainLoss=0.4067, ValLoss=0.5231, ValAUC=0.8009
# [Fine-tune Epoch 50/50] TrainLoss=0.4792, ValLoss=0.5127, ValAUC=0.8009
# --- Evaluating best fine-tuned model on Test Set ---
# Loaded best fine-tuned model from best_model_temp_511.pt
# Test Results: Loss=0.4452, AUC=0.8839, F1=0.8824
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=1, process=homogeneous, outcome=direct
# ===================================================================
#
# --- Running Scenario: N=200, p=10, reg=0.2, miss=0.4, sync=1, lag=False ---
# Data generated: 200 subjects, 57.0% positive cases.
# Using device: cuda
# Splitting data: Train=140, Val=30, Test=30
# Initialized model with Pretrain head. Parameters: 342338
# --- Starting Pretraining Phase (15 epochs) ---
# Pretrain Epoch 1/15 -- Avg Loss: 0.5135
# Pretrain Epoch 2/15 -- Avg Loss: 0.5082
# Pretrain Epoch 3/15 -- Avg Loss: 0.5010
# Pretrain Epoch 4/15 -- Avg Loss: 0.4970
# Pretrain Epoch 5/15 -- Avg Loss: 0.4869
# Pretrain Epoch 6/15 -- Avg Loss: 0.4814
# Pretrain Epoch 7/15 -- Avg Loss: 0.4732
# Pretrain Epoch 8/15 -- Avg Loss: 0.4504
# Pretrain Epoch 9/15 -- Avg Loss: 0.4360
# Pretrain Epoch 10/15 -- Avg Loss: 0.4248
# Pretrain Epoch 11/15 -- Avg Loss: 0.4074
# Pretrain Epoch 12/15 -- Avg Loss: 0.3864
# Pretrain Epoch 13/15 -- Avg Loss: 0.3714
# Pretrain Epoch 14/15 -- Avg Loss: 0.3495
# Pretrain Epoch 15/15 -- Avg Loss: 0.3300
# --- Pretraining Phase Complete ---
# --- Switching to Fine-tuning Phase (50 epochs) ---
# Model head switched to ClfHead. Total params now: 341818
# --- Starting Fine-tuning Training Loop ---
# [Fine-tune Epoch 1/50] TrainLoss=0.6751, ValLoss=0.6989, ValAUC=0.4196
# [Fine-tune Epoch 2/50] TrainLoss=0.6721, ValLoss=0.6989, ValAUC=0.4152
# [Fine-tune Epoch 3/50] TrainLoss=0.7039, ValLoss=0.6999, ValAUC=0.4152
# ==> Val AUC improved to 0.4152. Fine-tuned model saved.
# [Fine-tune Epoch 4/50] TrainLoss=0.6822, ValLoss=0.7039, ValAUC=0.3661
# [Fine-tune Epoch 5/50] TrainLoss=0.6903, ValLoss=0.7015, ValAUC=0.3929
# [Fine-tune Epoch 6/50] TrainLoss=0.6931, ValLoss=0.7003, ValAUC=0.4152
# [Fine-tune Epoch 7/50] TrainLoss=0.6436, ValLoss=0.7012, ValAUC=0.4196
# ==> Val AUC improved to 0.4196. Fine-tuned model saved.
# [Fine-tune Epoch 8/50] TrainLoss=0.6782, ValLoss=0.7041, ValAUC=0.4152
# [Fine-tune Epoch 9/50] TrainLoss=0.7188, ValLoss=0.7033, ValAUC=0.4643
# ==> Val AUC improved to 0.4643. Fine-tuned model saved.
# [Fine-tune Epoch 10/50] TrainLoss=0.6603, ValLoss=0.7029, ValAUC=0.5223
# ==> Val AUC improved to 0.5223. Fine-tuned model saved.
# [Fine-tune Epoch 11/50] TrainLoss=0.7279, ValLoss=0.7086, ValAUC=0.4732
# [Fine-tune Epoch 12/50] TrainLoss=0.7332, ValLoss=0.7120, ValAUC=0.4464
# [Fine-tune Epoch 13/50] TrainLoss=0.6684, ValLoss=0.7110, ValAUC=0.4509
# [Fine-tune Epoch 14/50] TrainLoss=0.6869, ValLoss=0.7105, ValAUC=0.4330
# [Fine-tune Epoch 15/50] TrainLoss=0.7014, ValLoss=0.7100, ValAUC=0.4152
# [Fine-tune Epoch 16/50] TrainLoss=0.6410, ValLoss=0.7132, ValAUC=0.3973
# [Fine-tune Epoch 17/50] TrainLoss=0.7010, ValLoss=0.7207, ValAUC=0.3438
# [Fine-tune Epoch 18/50] TrainLoss=0.6990, ValLoss=0.7152, ValAUC=0.3795
# [Fine-tune Epoch 19/50] TrainLoss=0.6941, ValLoss=0.7184, ValAUC=0.3661
# [Fine-tune Epoch 20/50] TrainLoss=0.6406, ValLoss=0.7159, ValAUC=0.3929
# Early stopping fine-tuning (no val AUC improvement in 10 epochs).
# --- Evaluating best fine-tuned model on Test Set ---
# Loaded best fine-tuned model from best_model_temp_511.pt
# Test Results: Loss=0.7300, AUC=0.4178, F1=0.6667
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=1, process=homogeneous, outcome=lagged
# ===================================================================
#
# --- Running Scenario: N=200, p=10, reg=0.2, miss=0.4, sync=1, lag=True ---
# Data generated: 200 subjects, 52.0% positive cases.
# Using device: cuda
# Splitting data: Train=140, Val=30, Test=30
# Initialized model with Pretrain head. Parameters: 342338
# --- Starting Pretraining Phase (15 epochs) ---
# Pretrain Epoch 1/15 -- Avg Loss: 0.5329
# Pretrain Epoch 2/15 -- Avg Loss: 0.5270
# Pretrain Epoch 3/15 -- Avg Loss: 0.5265
# Pretrain Epoch 4/15 -- Avg Loss: 0.5319
# Pretrain Epoch 5/15 -- Avg Loss: 0.5097
# Pretrain Epoch 6/15 -- Avg Loss: 0.4888
# Pretrain Epoch 7/15 -- Avg Loss: 0.4970
# Pretrain Epoch 8/15 -- Avg Loss: 0.4693
# Pretrain Epoch 9/15 -- Avg Loss: 0.4436
# Pretrain Epoch 10/15 -- Avg Loss: 0.4295
# Pretrain Epoch 11/15 -- Avg Loss: 0.4060
# Pretrain Epoch 12/15 -- Avg Loss: 0.4009
# Pretrain Epoch 13/15 -- Avg Loss: 0.3729
# Pretrain Epoch 14/15 -- Avg Loss: 0.3523
# Pretrain Epoch 15/15 -- Avg Loss: 0.3360
# --- Pretraining Phase Complete ---
# --- Switching to Fine-tuning Phase (50 epochs) ---
# Model head switched to ClfHead. Total params now: 341818
# --- Starting Fine-tuning Training Loop ---
# [Fine-tune Epoch 1/50] TrainLoss=0.7128, ValLoss=0.8246, ValAUC=0.5291
# [Fine-tune Epoch 2/50] TrainLoss=0.7247, ValLoss=0.8210, ValAUC=0.5344
# [Fine-tune Epoch 3/50] TrainLoss=0.7051, ValLoss=0.8158, ValAUC=0.5344
# ==> Val AUC improved to 0.5344. Fine-tuned model saved.
# [Fine-tune Epoch 4/50] TrainLoss=0.7118, ValLoss=0.8076, ValAUC=0.5238
# [Fine-tune Epoch 5/50] TrainLoss=0.6870, ValLoss=0.8016, ValAUC=0.4974
# [Fine-tune Epoch 6/50] TrainLoss=0.7001, ValLoss=0.7934, ValAUC=0.4868
# [Fine-tune Epoch 7/50] TrainLoss=0.7498, ValLoss=0.7788, ValAUC=0.4656
# [Fine-tune Epoch 8/50] TrainLoss=0.6891, ValLoss=0.7644, ValAUC=0.4286
# [Fine-tune Epoch 9/50] TrainLoss=0.6730, ValLoss=0.7520, ValAUC=0.4339
# [Fine-tune Epoch 10/50] TrainLoss=0.6665, ValLoss=0.7426, ValAUC=0.4233
# [Fine-tune Epoch 11/50] TrainLoss=0.6955, ValLoss=0.7422, ValAUC=0.3704
# [Fine-tune Epoch 12/50] TrainLoss=0.6739, ValLoss=0.7397, ValAUC=0.3333
# [Fine-tune Epoch 13/50] TrainLoss=0.6933, ValLoss=0.7320, ValAUC=0.3122
# Early stopping fine-tuning (no val AUC improvement in 10 epochs).
# --- Evaluating best fine-tuned model on Test Set ---
# Loaded best fine-tuned model from best_model_temp_511.pt
# Test Results: Loss=0.7224, AUC=0.5422, F1=0.0000
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=1, process=mixed, outcome=direct
# ===================================================================
#
# --- Running Scenario: N=200, p=10, reg=0.2, miss=0.4, sync=1, lag=False ---
# Data generated: 200 subjects, 50.0% positive cases.
# Using device: cuda
# Splitting data: Train=140, Val=30, Test=30
# Initialized model with Pretrain head. Parameters: 342338
# --- Starting Pretraining Phase (15 epochs) ---
# Pretrain Epoch 1/15 -- Avg Loss: 1.0515
# Pretrain Epoch 2/15 -- Avg Loss: 1.1600
# Pretrain Epoch 3/15 -- Avg Loss: 1.1273
# Pretrain Epoch 4/15 -- Avg Loss: 1.1405
# Pretrain Epoch 5/15 -- Avg Loss: 1.0965
# Pretrain Epoch 6/15 -- Avg Loss: 1.1613
# Pretrain Epoch 7/15 -- Avg Loss: 1.0014
# Pretrain Epoch 8/15 -- Avg Loss: 1.0441
# Pretrain Epoch 9/15 -- Avg Loss: 1.0101
# Pretrain Epoch 10/15 -- Avg Loss: 0.9862
# Pretrain Epoch 11/15 -- Avg Loss: 1.0377
# Pretrain Epoch 12/15 -- Avg Loss: 0.9658
# Pretrain Epoch 13/15 -- Avg Loss: 0.9241
# Pretrain Epoch 14/15 -- Avg Loss: 0.9113
# Pretrain Epoch 15/15 -- Avg Loss: 0.9167
# --- Pretraining Phase Complete ---
# --- Switching to Fine-tuning Phase (50 epochs) ---
# Model head switched to ClfHead. Total params now: 341818
# --- Starting Fine-tuning Training Loop ---
# [Fine-tune Epoch 1/50] TrainLoss=0.7634, ValLoss=0.7866, ValAUC=0.2454
# [Fine-tune Epoch 2/50] TrainLoss=0.7435, ValLoss=0.7854, ValAUC=0.2361
# [Fine-tune Epoch 3/50] TrainLoss=0.7821, ValLoss=0.7846, ValAUC=0.2500
# ==> Val AUC improved to 0.2500. Fine-tuned model saved.
# [Fine-tune Epoch 4/50] TrainLoss=0.7382, ValLoss=0.7822, ValAUC=0.2546
# ==> Val AUC improved to 0.2546. Fine-tuned model saved.
# [Fine-tune Epoch 5/50] TrainLoss=0.7794, ValLoss=0.7787, ValAUC=0.2546
# ==> Val AUC improved to 0.2546. Fine-tuned model saved.
# [Fine-tune Epoch 6/50] TrainLoss=0.7496, ValLoss=0.7746, ValAUC=0.2593
# ==> Val AUC improved to 0.2593. Fine-tuned model saved.
# [Fine-tune Epoch 7/50] TrainLoss=0.7294, ValLoss=0.7711, ValAUC=0.2778
# ==> Val AUC improved to 0.2778. Fine-tuned model saved.
# [Fine-tune Epoch 8/50] TrainLoss=0.7087, ValLoss=0.7659, ValAUC=0.2778
# [Fine-tune Epoch 9/50] TrainLoss=0.7287, ValLoss=0.7586, ValAUC=0.3148
# ==> Val AUC improved to 0.3148. Fine-tuned model saved.
# [Fine-tune Epoch 10/50] TrainLoss=0.7317, ValLoss=0.7511, ValAUC=0.3519
# ==> Val AUC improved to 0.3519. Fine-tuned model saved.
# [Fine-tune Epoch 11/50] TrainLoss=0.7445, ValLoss=0.7438, ValAUC=0.3750
# ==> Val AUC improved to 0.3750. Fine-tuned model saved.
# [Fine-tune Epoch 12/50] TrainLoss=0.7192, ValLoss=0.7353, ValAUC=0.3889
# ==> Val AUC improved to 0.3889. Fine-tuned model saved.
# [Fine-tune Epoch 13/50] TrainLoss=0.7255, ValLoss=0.7287, ValAUC=0.4028
# ==> Val AUC improved to 0.4028. Fine-tuned model saved.
# [Fine-tune Epoch 14/50] TrainLoss=0.6994, ValLoss=0.7202, ValAUC=0.4352
# ==> Val AUC improved to 0.4352. Fine-tuned model saved.
# [Fine-tune Epoch 15/50] TrainLoss=0.6875, ValLoss=0.7124, ValAUC=0.4630
# ==> Val AUC improved to 0.4630. Fine-tuned model saved.
# [Fine-tune Epoch 16/50] TrainLoss=0.6993, ValLoss=0.7040, ValAUC=0.4722
# ==> Val AUC improved to 0.4722. Fine-tuned model saved.
# [Fine-tune Epoch 17/50] TrainLoss=0.6947, ValLoss=0.6961, ValAUC=0.4954
# ==> Val AUC improved to 0.4954. Fine-tuned model saved.
# [Fine-tune Epoch 18/50] TrainLoss=0.6964, ValLoss=0.6877, ValAUC=0.5000
# ==> Val AUC improved to 0.5000. Fine-tuned model saved.
# [Fine-tune Epoch 19/50] TrainLoss=0.6809, ValLoss=0.6772, ValAUC=0.5231
# ==> Val AUC improved to 0.5231. Fine-tuned model saved.
# [Fine-tune Epoch 20/50] TrainLoss=0.6629, ValLoss=0.6700, ValAUC=0.5324
# ==> Val AUC improved to 0.5324. Fine-tuned model saved.
# [Fine-tune Epoch 21/50] TrainLoss=0.6498, ValLoss=0.6613, ValAUC=0.5370
# ==> Val AUC improved to 0.5370. Fine-tuned model saved.
# [Fine-tune Epoch 22/50] TrainLoss=0.6713, ValLoss=0.6520, ValAUC=0.5741
# ==> Val AUC improved to 0.5741. Fine-tuned model saved.
# [Fine-tune Epoch 23/50] TrainLoss=0.6728, ValLoss=0.6424, ValAUC=0.6111
# ==> Val AUC improved to 0.6111. Fine-tuned model saved.
# [Fine-tune Epoch 24/50] TrainLoss=0.6372, ValLoss=0.6291, ValAUC=0.6528
# ==> Val AUC improved to 0.6528. Fine-tuned model saved.
# [Fine-tune Epoch 25/50] TrainLoss=0.6467, ValLoss=0.6174, ValAUC=0.7269
# ==> Val AUC improved to 0.7269. Fine-tuned model saved.
# [Fine-tune Epoch 26/50] TrainLoss=0.6413, ValLoss=0.6054, ValAUC=0.7407
# ==> Val AUC improved to 0.7407. Fine-tuned model saved.
# [Fine-tune Epoch 27/50] TrainLoss=0.6181, ValLoss=0.5952, ValAUC=0.7500
# ==> Val AUC improved to 0.7500. Fine-tuned model saved.
# [Fine-tune Epoch 28/50] TrainLoss=0.6094, ValLoss=0.5820, ValAUC=0.7731
# ==> Val AUC improved to 0.7731. Fine-tuned model saved.
# [Fine-tune Epoch 29/50] TrainLoss=0.5683, ValLoss=0.5691, ValAUC=0.7870
# ==> Val AUC improved to 0.7870. Fine-tuned model saved.
# [Fine-tune Epoch 30/50] TrainLoss=0.5881, ValLoss=0.5581, ValAUC=0.8009
# ==> Val AUC improved to 0.8009. Fine-tuned model saved.
# [Fine-tune Epoch 31/50] TrainLoss=0.6051, ValLoss=0.5474, ValAUC=0.8102
# ==> Val AUC improved to 0.8102. Fine-tuned model saved.
# [Fine-tune Epoch 32/50] TrainLoss=0.6278, ValLoss=0.5373, ValAUC=0.8148
# ==> Val AUC improved to 0.8148. Fine-tuned model saved.
# [Fine-tune Epoch 33/50] TrainLoss=0.6367, ValLoss=0.5285, ValAUC=0.8241
# ==> Val AUC improved to 0.8241. Fine-tuned model saved.
# [Fine-tune Epoch 34/50] TrainLoss=0.5749, ValLoss=0.5204, ValAUC=0.8380
# ==> Val AUC improved to 0.8380. Fine-tuned model saved.
# [Fine-tune Epoch 35/50] TrainLoss=0.5893, ValLoss=0.5144, ValAUC=0.8380
# [Fine-tune Epoch 36/50] TrainLoss=0.6019, ValLoss=0.5082, ValAUC=0.8472
# ==> Val AUC improved to 0.8472. Fine-tuned model saved.
# [Fine-tune Epoch 37/50] TrainLoss=0.5922, ValLoss=0.5042, ValAUC=0.8565
# ==> Val AUC improved to 0.8565. Fine-tuned model saved.
# [Fine-tune Epoch 38/50] TrainLoss=0.6298, ValLoss=0.4994, ValAUC=0.8611
# ==> Val AUC improved to 0.8611. Fine-tuned model saved.
# [Fine-tune Epoch 39/50] TrainLoss=0.5259, ValLoss=0.4917, ValAUC=0.8611
# [Fine-tune Epoch 40/50] TrainLoss=0.5690, ValLoss=0.4821, ValAUC=0.8704
# ==> Val AUC improved to 0.8704. Fine-tuned model saved.
# [Fine-tune Epoch 41/50] TrainLoss=0.5706, ValLoss=0.4736, ValAUC=0.8796
# ==> Val AUC improved to 0.8796. Fine-tuned model saved.
# [Fine-tune Epoch 42/50] TrainLoss=0.5210, ValLoss=0.4632, ValAUC=0.8796
# [Fine-tune Epoch 43/50] TrainLoss=0.5369, ValLoss=0.4537, ValAUC=0.8796
# [Fine-tune Epoch 44/50] TrainLoss=0.4903, ValLoss=0.4425, ValAUC=0.8935
# ==> Val AUC improved to 0.8935. Fine-tuned model saved.
# [Fine-tune Epoch 45/50] TrainLoss=0.4721, ValLoss=0.4311, ValAUC=0.8981
# ...
# [Fine-tune Epoch 22/50] TrainLoss=0.6898, ValLoss=0.6983, ValAUC=0.4316
# [Fine-tune Epoch 23/50] TrainLoss=0.6903, ValLoss=0.6965, ValAUC=0.4307
# [Fine-tune Epoch 24/50] TrainLoss=0.6895, ValLoss=0.6984, ValAUC=0.4323
# [Fine-tune Epoch 25/50] TrainLoss=0.6875, ValLoss=0.6967, ValAUC=0.5020
# [Fine-tune Epoch 26/50] TrainLoss=0.6925, ValLoss=0.6910, ValAUC=0.5344
# [Fine-tune Epoch 27/50] TrainLoss=0.6870, ValLoss=0.6895, ValAUC=0.5433
# Early stopping fine-tuning (no val AUC improvement in 10 epochs).
# --- Evaluating best fine-tuned model on Test Set ---
# Loaded best fine-tuned model from best_model_temp_511.pt
# Test Results: Loss=0.6946, AUC=0.4889, F1=0.5223
# ===================================================================
# Scenario => N=1000, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=direct
# ===================================================================
#
# --- Running Scenario: N=1000, p=10, reg=0.8, miss=0.4, sync=3, lag=False ---
# Data generated: 1000 subjects, 49.8% positive cases.
# Using device: cuda
# Splitting data: Train=700, Val=150, Test=150
# Initialized model with Pretrain head. Parameters: 342338
# --- Starting Pretraining Phase (15 epochs) ---
# Pretrain Epoch 1/15 -- Avg Loss: 0.9966
# Pretrain Epoch 2/15 -- Avg Loss: 1.0058
# Pretrain Epoch 3/15 -- Avg Loss: 0.9817
# Pretrain Epoch 4/15 -- Avg Loss: 0.9407
# Pretrain Epoch 5/15 -- Avg Loss: 0.9159
# Pretrain Epoch 6/15 -- Avg Loss: 0.8653
# Pretrain Epoch 7/15 -- Avg Loss: 0.8104
# Pretrain Epoch 8/15 -- Avg Loss: 0.7310
# Pretrain Epoch 9/15 -- Avg Loss: 0.6762
# Pretrain Epoch 10/15 -- Avg Loss: 0.6289
# Pretrain Epoch 11/15 -- Avg Loss: 0.5364
# Pretrain Epoch 12/15 -- Avg Loss: 0.5056
# Pretrain Epoch 13/15 -- Avg Loss: 0.4431
# Pretrain Epoch 14/15 -- Avg Loss: 0.4161
# Pretrain Epoch 15/15 -- Avg Loss: 0.3880
# --- Pretraining Phase Complete ---
# --- Switching to Fine-tuning Phase (50 epochs) ---
# Model head switched to ClfHead. Total params now: 341818
# --- Starting Fine-tuning Training Loop ---
# [Fine-tune Epoch 1/50] TrainLoss=0.6973, ValLoss=0.6921, ValAUC=0.5588
# [Fine-tune Epoch 2/50] TrainLoss=0.6929, ValLoss=0.6856, ValAUC=0.6143
# [Fine-tune Epoch 3/50] TrainLoss=0.6872, ValLoss=0.6773, ValAUC=0.6895
# ==> Val AUC improved to 0.6895. Fine-tuned model saved.
# [Fine-tune Epoch 4/50] TrainLoss=0.6816, ValLoss=0.6664, ValAUC=0.7600
# ==> Val AUC improved to 0.7600. Fine-tuned model saved.
# [Fine-tune Epoch 5/50] TrainLoss=0.6658, ValLoss=0.6512, ValAUC=0.7755
# ==> Val AUC improved to 0.7755. Fine-tuned model saved.
# [Fine-tune Epoch 6/50] TrainLoss=0.6553, ValLoss=0.6350, ValAUC=0.7843
# ==> Val AUC improved to 0.7843. Fine-tuned model saved.
# [Fine-tune Epoch 7/50] TrainLoss=0.6406, ValLoss=0.6209, ValAUC=0.7986
# ==> Val AUC improved to 0.7986. Fine-tuned model saved.
# [Fine-tune Epoch 8/50] TrainLoss=0.6273, ValLoss=0.6030, ValAUC=0.8046
# ==> Val AUC improved to 0.8046. Fine-tuned model saved.
# [Fine-tune Epoch 9/50] TrainLoss=0.6037, ValLoss=0.5854, ValAUC=0.8093
# ==> Val AUC improved to 0.8093. Fine-tuned model saved.
# [Fine-tune Epoch 10/50] TrainLoss=0.5852, ValLoss=0.5640, ValAUC=0.8302
# ==> Val AUC improved to 0.8302. Fine-tuned model saved.
# [Fine-tune Epoch 11/50] TrainLoss=0.5635, ValLoss=0.5519, ValAUC=0.8136
# [Fine-tune Epoch 12/50] TrainLoss=0.5353, ValLoss=0.5164, ValAUC=0.8466
# ==> Val AUC improved to 0.8466. Fine-tuned model saved.
# [Fine-tune Epoch 13/50] TrainLoss=0.5083, ValLoss=0.4987, ValAUC=0.8505
# ==> Val AUC improved to 0.8505. Fine-tuned model saved.
# [Fine-tune Epoch 14/50] TrainLoss=0.4865, ValLoss=0.4926, ValAUC=0.8521
# ==> Val AUC improved to 0.8521. Fine-tuned model saved.
# [Fine-tune Epoch 15/50] TrainLoss=0.4796, ValLoss=0.4915, ValAUC=0.8571
# ==> Val AUC improved to 0.8571. Fine-tuned model saved.
# [Fine-tune Epoch 16/50] TrainLoss=0.4701, ValLoss=0.5127, ValAUC=0.8571
# [Fine-tune Epoch 17/50] TrainLoss=0.4630, ValLoss=0.4750, ValAUC=0.8621
# ==> Val AUC improved to 0.8621. Fine-tuned model saved.
# [Fine-tune Epoch 18/50] TrainLoss=0.4733, ValLoss=0.4871, ValAUC=0.8605
# [Fine-tune Epoch 19/50] TrainLoss=0.4527, ValLoss=0.4941, ValAUC=0.8657
# ==> Val AUC improved to 0.8657. Fine-tuned model saved.
# [Fine-tune Epoch 20/50] TrainLoss=0.4372, ValLoss=0.4771, ValAUC=0.8682
# ==> Val AUC improved to 0.8682. Fine-tuned model saved.
# [Fine-tune Epoch 21/50] TrainLoss=0.4284, ValLoss=0.4627, ValAUC=0.8748
# ==> Val AUC improved to 0.8748. Fine-tuned model saved.
# [Fine-tune Epoch 22/50] TrainLoss=0.3972, ValLoss=0.4739, ValAUC=0.8748
# [Fine-tune Epoch 23/50] TrainLoss=0.4141, ValLoss=0.4681, ValAUC=0.8768
# ==> Val AUC improved to 0.8768. Fine-tuned model saved.
# [Fine-tune Epoch 24/50] TrainLoss=0.4122, ValLoss=0.4853, ValAUC=0.8721
# [Fine-tune Epoch 25/50] TrainLoss=0.4032, ValLoss=0.4723, ValAUC=0.8764
# [Fine-tune Epoch 26/50] TrainLoss=0.4055, ValLoss=0.4306, ValAUC=0.8925
# ==> Val AUC improved to 0.8925. Fine-tuned model saved.
# [Fine-tune Epoch 27/50] TrainLoss=0.3950, ValLoss=0.4206, ValAUC=0.9034
# ==> Val AUC improved to 0.9034. Fine-tuned model saved.
# [Fine-tune Epoch 28/50] TrainLoss=0.3769, ValLoss=0.4213, ValAUC=0.8973
# [Fine-tune Epoch 29/50] TrainLoss=0.3821, ValLoss=0.4370, ValAUC=0.9005
# [Fine-tune Epoch 30/50] TrainLoss=0.3812, ValLoss=0.4433, ValAUC=0.9005
# [Fine-tune Epoch 31/50] TrainLoss=0.4018, ValLoss=0.4179, ValAUC=0.9202
# ==> Val AUC improved to 0.9202. Fine-tuned model saved.
# [Fine-tune Epoch 32/50] TrainLoss=0.4264, ValLoss=0.3926, ValAUC=0.9114
# [Fine-tune Epoch 33/50] TrainLoss=0.3921, ValLoss=0.4131, ValAUC=0.9104
# [Fine-tune Epoch 34/50] TrainLoss=0.3543, ValLoss=0.4126, ValAUC=0.9059
# [Fine-tune Epoch 35/50] TrainLoss=0.3689, ValLoss=0.4284, ValAUC=0.9034
# [Fine-tune Epoch 36/50] TrainLoss=0.3798, ValLoss=0.4284, ValAUC=0.9071
# [Fine-tune Epoch 37/50] TrainLoss=0.3813, ValLoss=0.4137, ValAUC=0.9118
# [Fine-tune Epoch 38/50] TrainLoss=0.3462, ValLoss=0.3937, ValAUC=0.9155
# [Fine-tune Epoch 39/50] TrainLoss=0.3492, ValLoss=0.4810, ValAUC=0.9207
# ==> Val AUC improved to 0.9207. Fine-tuned model saved.
# [Fine-tune Epoch 40/50] TrainLoss=0.3464, ValLoss=0.3666, ValAUC=0.9220
# ==> Val AUC improved to 0.9220. Fine-tuned model saved.
# [Fine-tune Epoch 41/50] TrainLoss=0.3479, ValLoss=0.5360, ValAUC=0.9038
# [Fine-tune Epoch 42/50] TrainLoss=0.3624, ValLoss=0.4094, ValAUC=0.9143
# [Fine-tune Epoch 43/50] TrainLoss=0.3500, ValLoss=0.4154, ValAUC=0.9205
# [Fine-tune Epoch 44/50] TrainLoss=0.3532, ValLoss=0.4184, ValAUC=0.9221
# ==> Val AUC improved to 0.9221. Fine-tuned model saved.
# [Fine-tune Epoch 45/50] TrainLoss=0.3275, ValLoss=0.4052, ValAUC=0.9180
# [Fine-tune Epoch 46/50] TrainLoss=0.3234, ValLoss=0.4258, ValAUC=0.9157
# [Fine-tune Epoch 47/50] TrainLoss=0.3189, ValLoss=0.4167, ValAUC=0.9155
# [Fine-tune Epoch 48/50] TrainLoss=0.3089, ValLoss=0.3943, ValAUC=0.9245
# ==> Val AUC improved to 0.9245. Fine-tuned model saved.
# [Fine-tune Epoch 49/50] TrainLoss=0.3163, ValLoss=0.3728, ValAUC=0.9302
# ==> Val AUC improved to 0.9302. Fine-tuned model saved.
# [Fine-tune Epoch 50/50] TrainLoss=0.3011, ValLoss=0.3727, ValAUC=0.9271
# --- Evaluating best fine-tuned model on Test Set ---
# Loaded best fine-tuned model from best_model_temp_511.pt
# Test Results: Loss=0.3278, AUC=0.9429, F1=0.8591
# ===================================================================
# Scenario => N=1000, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=lagged
# ===================================================================
#
# --- Running Scenario: N=1000, p=10, reg=0.8, miss=0.4, sync=3, lag=True ---
# Data generated: 1000 subjects, 51.9% positive cases.
# Using device: cuda
# Splitting data: Train=700, Val=150, Test=150
# Initialized model with Pretrain head. Parameters: 342338
# --- Starting Pretraining Phase (15 epochs) ---
# Pretrain Epoch 1/15 -- Avg Loss: 1.2344
# Pretrain Epoch 2/15 -- Avg Loss: 1.2198
# Pretrain Epoch 3/15 -- Avg Loss: 1.1801
# Pretrain Epoch 4/15 -- Avg Loss: 1.1051
# Pretrain Epoch 5/15 -- Avg Loss: 1.0315
# Pretrain Epoch 6/15 -- Avg Loss: 0.9345
# Pretrain Epoch 7/15 -- Avg Loss: 0.8547
# Pretrain Epoch 8/15 -- Avg Loss: 0.7321
# Pretrain Epoch 9/15 -- Avg Loss: 0.6565
# Pretrain Epoch 10/15 -- Avg Loss: 0.5639
# Pretrain Epoch 11/15 -- Avg Loss: 0.5069
# Pretrain Epoch 12/15 -- Avg Loss: 0.4546
# Pretrain Epoch 13/15 -- Avg Loss: 0.4185
# Pretrain Epoch 14/15 -- Avg Loss: 0.3862
# Pretrain Epoch 15/15 -- Avg Loss: 0.3555
# --- Pretraining Phase Complete ---
# --- Switching to Fine-tuning Phase (50 epochs) ---
# Model head switched to ClfHead. Total params now: 341818
# --- Starting Fine-tuning Training Loop ---
# [Fine-tune Epoch 1/50] TrainLoss=0.6871, ValLoss=0.6962, ValAUC=0.5409
# [Fine-tune Epoch 2/50] TrainLoss=0.6926, ValLoss=0.6941, ValAUC=0.5537
# [Fine-tune Epoch 3/50] TrainLoss=0.6880, ValLoss=0.6915, ValAUC=0.5873
# ==> Val AUC improved to 0.5873. Fine-tuned model saved.
# [Fine-tune Epoch 4/50] TrainLoss=0.6845, ValLoss=0.6875, ValAUC=0.6339
# ==> Val AUC improved to 0.6339. Fine-tuned model saved.
# [Fine-tune Epoch 5/50] TrainLoss=0.6822, ValLoss=0.6849, ValAUC=0.6655
# ==> Val AUC improved to 0.6655. Fine-tuned model saved.
# [Fine-tune Epoch 6/50] TrainLoss=0.6762, ValLoss=0.6792, ValAUC=0.6910
# ==> Val AUC improved to 0.6910. Fine-tuned model saved.
# [Fine-tune Epoch 7/50] TrainLoss=0.6664, ValLoss=0.6707, ValAUC=0.7036
# ==> Val AUC improved to 0.7036. Fine-tuned model saved.
# [Fine-tune Epoch 8/50] TrainLoss=0.6569, ValLoss=0.6595, ValAUC=0.7260
# ==> Val AUC improved to 0.7260. Fine-tuned model saved.
# [Fine-tune Epoch 9/50] TrainLoss=0.6504, ValLoss=0.6457, ValAUC=0.7505
# ==> Val AUC improved to 0.7505. Fine-tuned model saved.
# [Fine-tune Epoch 10/50] TrainLoss=0.6348, ValLoss=0.6302, ValAUC=0.7672
# ==> Val AUC improved to 0.7672. Fine-tuned model saved.
# [Fine-tune Epoch 11/50] TrainLoss=0.6141, ValLoss=0.6078, ValAUC=0.7811
# ==> Val AUC improved to 0.7811. Fine-tuned model saved.
# [Fine-tune Epoch 12/50] TrainLoss=0.5983, ValLoss=0.5884, ValAUC=0.8016
# ==> Val AUC improved to 0.8016. Fine-tuned model saved.
# [Fine-tune Epoch 13/50] TrainLoss=0.5838, ValLoss=0.5732, ValAUC=0.8142
# ==> Val AUC improved to 0.8142. Fine-tuned model saved.
# [Fine-tune Epoch 14/50] TrainLoss=0.5643, ValLoss=0.5397, ValAUC=0.8257
# ==> Val AUC improved to 0.8257. Fine-tuned model saved.
# [Fine-tune Epoch 15/50] TrainLoss=0.5536, ValLoss=0.5475, ValAUC=0.8325
# ==> Val AUC improved to 0.8325. Fine-tuned model saved.
# [Fine-tune Epoch 16/50] TrainLoss=0.5544, ValLoss=0.6846, ValAUC=0.8160
# [Fine-tune Epoch 17/50] TrainLoss=0.5495, ValLoss=0.4788, ValAUC=0.8789
# ==> Val AUC improved to 0.8789. Fine-tuned model saved.
# [Fine-tune Epoch 18/50] TrainLoss=0.5207, ValLoss=0.4609, ValAUC=0.8782
# [Fine-tune Epoch 19/50] TrainLoss=0.4810, ValLoss=0.5968, ValAUC=0.8736
# [Fine-tune Epoch 20/50] TrainLoss=0.5078, ValLoss=0.5912, ValAUC=0.8757
# [Fine-tune Epoch 21/50] TrainLoss=0.4897, ValLoss=0.4384, ValAUC=0.8853
# ==> Val AUC improved to 0.8853. Fine-tuned model saved.
# [Fine-tune Epoch 22/50] TrainLoss=0.4983, ValLoss=0.4533, ValAUC=0.8903
# ==> Val AUC improved to 0.8903. Fine-tuned model saved.
# [Fine-tune Epoch 23/50] TrainLoss=0.4677, ValLoss=0.6092, ValAUC=0.8681
# [Fine-tune Epoch 24/50] TrainLoss=0.4594, ValLoss=0.4257, ValAUC=0.8949
# ==> Val AUC improved to 0.8949. Fine-tuned model saved.
# [Fine-tune Epoch 25/50] TrainLoss=0.4818, ValLoss=0.4125, ValAUC=0.9015
# ==> Val AUC improved to 0.9015. Fine-tuned model saved.
# [Fine-tune Epoch 26/50] TrainLoss=0.4437, ValLoss=0.5081, ValAUC=0.8846
# [Fine-tune Epoch 27/50] TrainLoss=0.4301, ValLoss=0.4392, ValAUC=0.8928
# [Fine-tune Epoch 28/50] TrainLoss=0.4219, ValLoss=0.4680, ValAUC=0.8752
# [Fine-tune Epoch 29/50] TrainLoss=0.4128, ValLoss=0.4832, ValAUC=0.8793
# [Fine-tune Epoch 30/50] TrainLoss=0.3937, ValLoss=0.4234, ValAUC=0.8965
# [Fine-tune Epoch 31/50] TrainLoss=0.4136, ValLoss=0.5560, ValAUC=0.8837
# [Fine-tune Epoch 32/50] TrainLoss=0.3915, ValLoss=0.4435, ValAUC=0.8810
# [Fine-tune Epoch 33/50] TrainLoss=0.3773, ValLoss=0.5276, ValAUC=0.8883
# [Fine-tune Epoch 34/50] TrainLoss=0.3712, ValLoss=0.4447, ValAUC=0.8962
# [Fine-tune Epoch 35/50] TrainLoss=0.3597, ValLoss=0.5301, ValAUC=0.9036
# ==> Val AUC improved to 0.9036. Fine-tuned model saved.
# [Fine-tune Epoch 36/50] TrainLoss=0.3593, ValLoss=0.4021, ValAUC=0.9081
# ==> Val AUC improved to 0.9081. Fine-tuned model saved.
# [Fine-tune Epoch 37/50] TrainLoss=0.3665, ValLoss=0.4225, ValAUC=0.9050
# [Fine-tune Epoch 38/50] TrainLoss=0.3501, ValLoss=0.4299, ValAUC=0.8944
# [Fine-tune Epoch 39/50] TrainLoss=0.3417, ValLoss=0.4267, ValAUC=0.8908
# [Fine-tune Epoch 40/50] TrainLoss=0.3429, ValLoss=0.4481, ValAUC=0.9118
# ==> Val AUC improved to 0.9118. Fine-tuned model saved.
# [Fine-tune Epoch 41/50] TrainLoss=0.3206, ValLoss=0.4177, ValAUC=0.9116
# [Fine-tune Epoch 42/50] TrainLoss=0.3161, ValLoss=0.3936, ValAUC=0.9209
# ==> Val AUC improved to 0.9209. Fine-tuned model saved.
# [Fine-tune Epoch 43/50] TrainLoss=0.3129, ValLoss=0.5069, ValAUC=0.9038
# [Fine-tune Epoch 44/50] TrainLoss=0.3193, ValLoss=0.3921, ValAUC=0.9141
# [Fine-tune Epoch 45/50] TrainLoss=0.3414, ValLoss=0.4132, ValAUC=0.9243
# ==> Val AUC improved to 0.9243. Fine-tuned model saved.
# [Fine-tune Epoch 46/50] TrainLoss=0.3043, ValLoss=0.3739, ValAUC=0.9203
# [Fine-tune Epoch 47/50] TrainLoss=0.2932, ValLoss=0.4617, ValAUC=0.9223
# [Fine-tune Epoch 48/50] TrainLoss=0.3414, ValLoss=0.4043, ValAUC=0.9235
# [Fine-tune Epoch 49/50] TrainLoss=0.3072, ValLoss=0.3800, ValAUC=0.9200
# [Fine-tune Epoch 50/50] TrainLoss=0.3025, ValLoss=0.4169, ValAUC=0.9264
# ==> Val AUC improved to 0.9264. Fine-tuned model saved.
# --- Evaluating best fine-tuned model on Test Set ---
# Loaded best fine-tuned model from best_model_temp_511.pt
# Test Results: Loss=0.4986, AUC=0.8627, F1=0.8083
#
# All scenarios completed in 212.14 minutes.
#
#        N  regularity  missing_prop sync_pattern process_type outcome_dep  \
# 0    200         0.2           0.1            1  homogeneous      direct
# 1    200         0.2           0.1            1  homogeneous      lagged
# 2    200         0.2           0.1            1        mixed      direct
# 3    200         0.2           0.1            1        mixed      lagged
# 4    200         0.2           0.1            p  homogeneous      direct
# ..   ...         ...           ...          ...          ...         ...
# 59  1000         0.8           0.4            1        mixed      lagged
# 60  1000         0.8           0.4            p  homogeneous      direct
# 61  1000         0.8           0.4            p  homogeneous      lagged
# 62  1000         0.8           0.4            p        mixed      direct
# 63  1000         0.8           0.4            p        mixed      lagged
#
#     test_loss       auc  accuracy  precision    recall        f1  runtime_sec  \
# 0    0.728673  0.586667  0.500000   0.500000  1.000000  0.666667    73.800822
# 1    0.688005  0.587963  0.600000   0.500000  0.666667  0.571429    72.791339
# 2    0.679202  0.638889  0.600000   0.607143  0.944444  0.739130    77.076372
# 3    0.438480  0.882353  0.733333   0.800000  0.705882  0.750000    80.932844
# 4    0.704394  0.393665  0.566667   0.566667  1.000000  0.723404    89.765034
# ..        ...       ...       ...        ...       ...       ...          ...
# 59   0.256895  0.959438  0.920000   0.929577  0.904110  0.916667   282.888266
# 60   0.698728  0.397746  0.413333   0.457831  0.469136  0.463415   304.655883
# 61   0.694623  0.488941  0.500000   0.554054  0.493976  0.522293   316.125865
# 62   0.327754  0.942933  0.860000   0.864865  0.853333  0.859060   339.107956
# 63   0.498564  0.862734  0.753333   0.715596  0.928571  0.808290   339.113777
#
#     mean_true_prob  prop_positive
# 0         0.565822          0.570
# 1         0.513261          0.540
# 2         0.574195          0.570
# 3         0.489164          0.515
# 4         0.504974          0.555
# ..             ...            ...
# 59        0.498998          0.496
# 60        0.546740          0.555
# 61        0.555736          0.536
# 62        0.505665          0.498
# 63        0.517566          0.519
#
# [64 rows x 15 columns]
#
# Results saved to bitimelygpt_factorial_results_long.csv
