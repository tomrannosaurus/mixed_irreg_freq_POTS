# %%
################################################################################
# GRU-D - Factorial Experiment (Simulated Data, no threshold sweep)
################################################################################

# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Imports and Setup
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# !pip install rpy2==3.5.1 --quiet

import itertools
import time
import torch
import numpy as np
import pandas as pd
import os
import math

from sklearn.metrics import roc_curve, auc

from google.colab import drive
drive.mount('/content/drive')

# %load_ext rpy2.ipython
from rpy2.robjects import pandas2ri
import rpy2.robjects as ro
pandas2ri.activate()


import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import copy

from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for rpy2 (setup.py) ... done
# Mounted at /content/drive

# %%
################################################################################
# Define the R DGP script path and load into Colab
################################################################################
# %%R
source("drive/MyDrive/sim_dgp.R")

# %%
import numpy as np

def create_grud_format_pivot(df_vars, df_outcomes, feature_list, max_time_steps=300):
    """
    Build (X, mask, delta, y) for GRU-D by pivoting each subject's data (time,variable->value)
    into a consistent wide format, computing sorted time steps + deltas, then padding/truncating
    the final sequences. If all subjects' actual sequences are shorter than max_time_steps,
    we dynamically reduce to that actual max length.

    :param df_vars:       DataFrame with columns [ID, time, variable, value]
    :param df_outcomes:   DataFrame with columns [ID, time, Y] (plus possibly 'true_prob')
    :param feature_list:  List of feature names, e.g. ["X1", "X2", "X3", ...]
    :param max_time_steps: The absolute maximum sequence length we allow to keep;
                           if the actual largest sequence among all subjects is smaller,
                           we use the smaller length to avoid excess zero-padding.
    :return: X, mask, delta, y (all np.ndarrays), with shapes:
             - X.shape     = (N, final_time_steps, p)
             - mask.shape  = (N, final_time_steps, p)
             - delta.shape = (N, final_time_steps, p)
             - y.shape     = (N,)
    """

    feature_list = sorted(feature_list)

    subject_ids = df_vars['ID'].unique()
    subject_ids.sort()
    p = len(feature_list)

    X_list = []
    mask_list = []
    delta_list = []
    y_list = []

    # -------------------------------------------------------
    # First pass: gather each subject's sequence, store in lists
    # -------------------------------------------------------
    for sid in subject_ids:
        df_sub = df_vars[df_vars['ID'] == sid].copy()
        df_sub_out = df_outcomes[df_outcomes['ID'] == sid]

        if len(df_sub_out) == 0:
            continue

        y_val = df_sub_out['Y'].values[0]

        wide_df = df_sub.pivot_table(index='time', columns='variable', values='value')
        wide_df = wide_df.sort_index().reset_index()

        wide_df = wide_df.reindex(columns=['time'] + feature_list)

        time_vals = wide_df['time'].values
        feature_vals = wide_df[feature_list].values

        if len(time_vals) == 0:
            continue

        delta_time = np.diff(time_vals, prepend=time_vals[0])
        delta_time = np.where(delta_time == 0, 1.0, delta_time)

        mask_vals = ~np.isnan(feature_vals)
        mask_vals = mask_vals.astype(float)

        feature_vals = np.nan_to_num(feature_vals, nan=0.0)

        delta_vals = np.tile(delta_time.reshape(-1, 1), (1, p))

        X_list.append(feature_vals)
        mask_list.append(mask_vals)
        delta_list.append(delta_vals)
        y_list.append(y_val)

    # -------------------------------------------------------
    # Second pass: find the actual max sequence length across all subjects
    # -------------------------------------------------------
    if len(X_list) == 0:
        return (np.array([]), np.array([]), np.array([]), np.array([]))

    largest_actual_len = max(x.shape[0] for x in X_list)
    final_time_steps = min(largest_actual_len, max_time_steps)

    # -------------------------------------------------------
    # Third pass: allocate arrays with final_time_steps, then pad/truncate
    # -------------------------------------------------------
    N = len(X_list)
    X_out = np.zeros((N, final_time_steps, p), dtype=float)
    M_out = np.zeros((N, final_time_steps, p), dtype=float)
    D_out = np.zeros((N, final_time_steps, p), dtype=float)
    Y_out = np.array(y_list).astype(int)

    for i in range(N):
        seq_len = X_list[i].shape[0]
        use_len = min(seq_len, final_time_steps)

        X_out[i, :use_len, :] = X_list[i][:use_len, :]
        M_out[i, :use_len, :] = mask_list[i][:use_len, :]
        D_out[i, :use_len, :] = delta_list[i][:use_len, :]

    return X_out, M_out, D_out, Y_out

# %%
import math

class GRUD(nn.Module):
    def __init__(
        self,
        input_size,
        hidden_size,
        output_size=1,
        x_mean=None,
        dropout=0.0,
        dropout_type='mloss',
    ):
        """
        input_size: Dimensionality of the features (D).
        hidden_size: Dimensionality of the hidden state (H).
        output_size: Usually 1 for binary classification.
        x_mean: If given, must be a 1D tensor of shape (D,) containing the mean of each feature.
        """
        super(GRUD, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout = dropout
        self.dropout_type = dropout_type

        if x_mean is None:
            self.register_buffer("x_mean", torch.zeros(input_size))
        else:
            if isinstance(x_mean, np.ndarray):
                x_mean = torch.from_numpy(x_mean).float()
            self.register_buffer("x_mean", x_mean)


        # --------------------------
        # Define the "decay" linear layers
        # --------------------------
        self.W_dg_x = nn.Linear(input_size, input_size, bias=True)
        self.W_dg_h = nn.Linear(input_size, hidden_size, bias=True)

        # --------------------------
        # GRU gates: z, r, h_tilde
        # --------------------------
        self.w_xz = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.w_hz = nn.Parameter(torch.Tensor(hidden_size, hidden_size))
        self.w_mz = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.b_z  = nn.Parameter(torch.Tensor(hidden_size))

        self.w_xr = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.w_hr = nn.Parameter(torch.Tensor(hidden_size, hidden_size))
        self.w_mr = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.b_r  = nn.Parameter(torch.Tensor(hidden_size))

        self.w_xh = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.w_hh = nn.Parameter(torch.Tensor(hidden_size, hidden_size))
        self.w_mh = nn.Parameter(torch.Tensor(input_size, hidden_size))
        self.b_h  = nn.Parameter(torch.Tensor(hidden_size))

        self.w_hy = nn.Parameter(torch.Tensor(hidden_size, output_size))
        self.b_y  = nn.Parameter(torch.Tensor(output_size))

        self.reset_parameters()

    def reset_parameters(self):
        stdv = 1.0 / math.sqrt(self.hidden_size)
        for p in self.parameters():
            nn.init.uniform_(p, -stdv, stdv)

    def forward(self, X, M, Delta):
        """
        X:     (batch_size, T, D)   - raw features
        M:     (batch_size, T, D)   - mask (1 if observed, 0 if missing)
        Delta: (batch_size, T, D)   - time since last observation for each feature
        Returns:
            (batch_size,) or (batch_size, 1) if output_size=1
        """
        batch_size, T, D = X.size()
        H = self.hidden_size

        h = X.new_zeros(batch_size, H)
        x_hat = X.new_zeros(batch_size, D)

        dropout_layer = nn.Dropout(self.dropout)

        for t in range(T):
            x_t = X[:, t, :]
            m_t = M[:, t, :]
            d_t = Delta[:, t, :]

            # ----------------------------------------
            # Compute gamma_x(t) and gamma_h(t)
            # ----------------------------------------
            gamma_x_t = torch.exp(-F.relu(self.W_dg_x(d_t)))
            gamma_h_t = torch.exp(-F.relu(self.W_dg_h(d_t)))

            # ----------------------------------------
            # Update x_hat(t)
            # ----------------------------------------
            current_x_mean = self.x_mean.to(x_hat.device)
            x_hat = m_t * x_t + (1 - m_t) * (gamma_x_t * x_hat + (1 - gamma_x_t) * current_x_mean)


            # ----------------------------------------
            # Decay hidden state: h(t-1) -> gamma_h(t) * h(t-1)
            # ----------------------------------------
            h = gamma_h_t * h

            # ----------------------------------------
            # Standard GRU gating on the imputed input x_hat(t)
            # ----------------------------------------
            z = torch.sigmoid(
                x_hat @ self.w_xz + h @ self.w_hz + m_t @ self.w_mz + self.b_z
            )

            r = torch.sigmoid(
                x_hat @ self.w_xr + h @ self.w_hr + m_t @ self.w_mr + self.b_r
            )

            h_tilde = torch.tanh(
                x_hat @ self.w_xh + (r * h) @ self.w_hh + m_t @ self.w_mh + self.b_h
            )

            if self.dropout > 0:
                if self.dropout_type == 'mloss':
                    h_tilde = dropout_layer(h_tilde)
                elif self.dropout_type == 'Gal':
                    h = dropout_layer(h)


            h = (1 - z) * h + z * h_tilde

        y_out = h @ self.w_hy + self.b_y
        y_out = torch.sigmoid(y_out)
        return y_out.squeeze(-1)

# %%
class SimDataset(Dataset):
    def __init__(self, X, mask, delta, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.M = torch.tensor(mask, dtype=torch.float32)
        self.D = torch.tensor(delta, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.M[idx], self.D[idx], self.y[idx]

# %%
################################################################################
# Configuration for the sim data
################################################################################
class SimDataConfig:
    def __init__(self, p):
        self.feature_list   = [f"X{i+1}" for i in range(p)]
        # GRU-D hyperparams
        self.rnn_hidden_size = 32
        self.batch_size      = 32
        self.epochs         = 60
        self.patience       = 15
        self.learning_rate  = 1e-3
        self.max_t_steps    = 50

# %%
def run_single_scenario(
    N, p,
    regularity,
    missing_prop,
    num_sync_groups,
    process_types,
    use_lags,
    block_missing=True,
    block_length=1.5,
    outcome_time=10,
    master_seed=123
):
    """
    1) Simulate data in R.
    2) 70/15/15 split => train/val/test.
    3) Train GRU-D with PyPOTS's built-in early stopping.
    4) Evaluate on test set => standard metrics from PyPOTS (no threshold sweep).
    """
    ro.r.assign("N", N)
    ro.r.assign("p", p)
    ro.r.assign("regularity", regularity)
    ro.r.assign("missing_prop", missing_prop)
    ro.r.assign("num_sync_groups", num_sync_groups)

    if isinstance(process_types, list):
        ro.r.assign("process_types", ro.StrVector(process_types))
    else:
        ro.r.assign("process_types", ro.StrVector([process_types]*p))

    ro.r.assign("use_lags", use_lags)
    ro.r.assign("block_missing", block_missing)
    ro.r.assign("block_length", block_length)
    ro.r.assign("outcome_time", outcome_time)
    ro.r.assign("master_seed", master_seed)

    ro.r('''
        sim_dataset <- simulate_experiment_dataset(
          N            = N,
          p            = p,
          freq_min     = 0.5,
          freq_max     = 3.0,
          regularity   = regularity,
          num_sync_groups = num_sync_groups,
          process_types = process_types,
          missing_prop = missing_prop,
          block_missing = block_missing,
          block_length  = block_length,
          outcome_time  = outcome_time,
          beta          = c(0, seq(-1, 1, length.out = 30)),
          use_lags      = use_lags,
          lag_hours     = ifelse(use_lags, 2, 0),
          master_seed   = master_seed
        )
    ''')

    df_vars_r     = ro.r('sim_dataset$vars_long')
    df_outcomes_r = ro.r('sim_dataset$outcome_df')

    df_vars     = df_vars_r
    df_outcomes = df_outcomes_r

    df_vars["ID"]       = df_vars["ID"].astype(int)
    df_vars["time"]     = df_vars["time"].astype(float)
    df_outcomes["ID"]   = df_outcomes["ID"].astype(int)
    df_outcomes["time"] = df_outcomes["time"].astype(float)

    mean_true_prob = df_outcomes["true_prob"].mean()
    prop_positive  = df_outcomes["Y"].mean()

    config = SimDataConfig(p)


    X_all, mask_all, delta_all, y_all = create_grud_format_pivot(
    df_vars, df_outcomes, config.feature_list, max_time_steps=config.max_t_steps
    )

    N_total = len(X_all)
    idx = np.arange(N_total)
    np.random.seed(master_seed)
    np.random.shuffle(idx)

    N_train = int(0.70 * N_total)
    N_val   = int(0.15 * N_total)
    N_test  = N_total - N_train - N_val

    train_idx = idx[:N_train]
    val_idx   = idx[N_train:N_train+N_val]
    test_idx  = idx[N_train+N_val:]

    X_train    = X_all[train_idx]
    mask_train = mask_all[train_idx]
    delta_train= delta_all[train_idx]
    y_train    = y_all[train_idx]

    X_val      = X_all[val_idx]
    mask_val   = mask_all[val_idx]
    delta_val  = delta_all[val_idx]
    y_val      = y_all[val_idx]

    X_test     = X_all[test_idx]
    mask_test  = mask_all[test_idx]
    delta_test = delta_all[test_idx]
    y_test     = y_all[test_idx]

    # Create PyTorch Datasets
    train_dataset = SimDataset(X_train, mask_train, delta_train, y_train)
    val_dataset   = SimDataset(X_val, mask_val, delta_val, y_val)
    test_dataset  = SimDataset(X_test, mask_test, delta_test, y_test)

    # Create DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=config.batch_size, shuffle=True, num_workers=0)
    val_loader   = DataLoader(val_dataset, batch_size=config.batch_size, shuffle=False, num_workers=0)
    test_loader  = DataLoader(test_dataset, batch_size=config.batch_size, shuffle=False, num_workers=0)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    n_features = X_train.shape[2]

    train_mask_flat = mask_train.reshape(-1, n_features)
    train_X_flat = X_train.reshape(-1, n_features)
    x_train_means = np.zeros(n_features)
    for feat_idx in range(n_features):
        masked_vals = train_X_flat[train_mask_flat[:, feat_idx].astype(bool), feat_idx]
        if len(masked_vals) > 0:
            x_train_means[feat_idx] = np.mean(masked_vals)

    model = GRUD(
        input_size=n_features,
        hidden_size=config.rnn_hidden_size,
        output_size=1,
        x_mean=x_train_means,
        dropout=0.05,
        dropout_type='mloss'
    ).to(device)

    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)

    epochs = config.epochs
    patience = config.patience
    best_val_auc = 0.0
    epochs_no_improve = 0
    best_model_weights = copy.deepcopy(model.state_dict())

    print(f"Starting training for {epochs} epochs with patience {patience}...")
    for epoch in range(1, epochs + 1):
        model.train()
        train_loss_list = []
        train_preds_list = []
        train_truth_list = []

        for Xb, Mb, Db, yb in train_loader:
            Xb, Mb, Db, yb = Xb.to(device), Mb.to(device), Db.to(device), yb.to(device)

            optimizer.zero_grad()
            outputs = model(Xb, Mb, Db)
            loss = criterion(outputs, yb)
            loss.backward()
            optimizer.step()

            train_loss_list.append(loss.item())
            train_preds_list.append(outputs.detach().cpu().numpy())
            train_truth_list.append(yb.detach().cpu().numpy())

        train_loss = np.mean(train_loss_list)
        train_preds_epoch = np.concatenate(train_preds_list)
        train_truth_epoch = np.concatenate(train_truth_list)
        try:
            train_auc = roc_auc_score(train_truth_epoch, train_preds_epoch)
        except ValueError:
            train_auc = 0.5

        model.eval()
        val_loss_list = []
        val_preds_list = []
        val_truth_list = []
        with torch.no_grad():
            for Xb, Mb, Db, yb in val_loader:
                Xb, Mb, Db, yb = Xb.to(device), Mb.to(device), Db.to(device), yb.to(device)
                outputs = model(Xb, Mb, Db)
                loss = criterion(outputs, yb)
                val_loss_list.append(loss.item())
                val_preds_list.append(outputs.cpu().numpy())
                val_truth_list.append(yb.cpu().numpy())

        val_loss = np.mean(val_loss_list)
        val_preds_epoch = np.concatenate(val_preds_list)
        val_truth_epoch = np.concatenate(val_truth_list)
        try:
            val_auc = roc_auc_score(val_truth_epoch, val_preds_epoch)
        except ValueError:
            val_auc = 0.5

        print(f"Epoch [{epoch}/{epochs}] Train Loss: {train_loss:.4f}, Train AUC: {train_auc:.4f} | Val Loss: {val_loss:.4f}, Val AUC: {val_auc:.4f}")

        if val_auc > best_val_auc:
            best_val_auc = val_auc
            best_model_weights = copy.deepcopy(model.state_dict())
            epochs_no_improve = 0
            print(f"  -> New best validation AUC: {best_val_auc:.4f}")
        else:
            epochs_no_improve += 1
            print(f"  -> Validation AUC did not improve. ({epochs_no_improve}/{patience})")

        if epochs_no_improve >= patience:
            print(f"Early stopping triggered after epoch {epoch}.")
            break

    print(f"Finished training. Loading best model with Val AUC: {best_val_auc:.4f}")
    model.load_state_dict(best_model_weights)

    model.eval()
    test_preds_list = []
    test_truth_list = []
    with torch.no_grad():
        for Xb, Mb, Db, yb in test_loader:
            Xb, Mb, Db, yb = Xb.to(device), Mb.to(device), Db.to(device), yb.to(device)
            outputs = model(Xb, Mb, Db)
            test_preds_list.append(outputs.cpu().numpy())
            test_truth_list.append(yb.cpu().numpy())

    y_pred_prob_test = np.concatenate(test_preds_list)
    y_true_test = np.concatenate(test_truth_list)

    test_auc = roc_auc_score(y_true_test, y_pred_prob_test)

    threshold = 0.5
    y_pred_test = (y_pred_prob_test >= threshold).astype(int)

    test_accuracy = accuracy_score(y_true_test, y_pred_test, zero_division=0)
    test_prec = precision_score(y_true_test, y_pred_test, zero_division=0)
    test_rec = recall_score(y_true_test, y_pred_test, zero_division=0)
    test_f1 = f1_score(y_true_test, y_pred_test, zero_division=0)
    test_loss = float('nan')

    results_dict = {
        "test_loss":      test_loss,
        "auc":            test_auc,
        "accuracy":       test_accuracy,
        "precision":      test_prec,
        "recall":         test_rec,
        "f1":             test_f1,
        "mean_true_prob": float(mean_true_prob),
        "prop_positive":  float(prop_positive)
    }

    return results_dict

# %%
################################################################################
# Main Loop: Full Factorial Over the 6 Factors
#    w/ updated sync_pattern logic, no threshold sweep.
################################################################################

Ns = [200, 1000, 10000]
regularities = [0.2, 0.8]
missing_props = [0.1, 0.4]
sync_pattern_values = [1, "p"]
process_type_values = ["homogeneous", "mixed"]
outcome_dep_values = ["direct", "lagged"]

scenario_grid = list(itertools.product(
    Ns,
    regularities,
    missing_props,
    sync_pattern_values,
    process_type_values,
    outcome_dep_values
))

all_results = []
overall_start = time.time()

for scenario in scenario_grid:
    (N,
     regularity,
     missing_prop,
     sync_pattern,
     process_type_flag,
     outcome_dep) = scenario

    p = 30
    if process_type_flag == "homogeneous":
        process_types = ["ar1"]*p
    else:
        repeats = math.ceil(p/3)
        big_array = (["ar1","rw","seasonal"]*repeats)[:p]
        process_types = big_array

    if sync_pattern == "p":
        num_sync_groups = max(1, int(round(p/10)))
    else:
        num_sync_groups = 1

    use_lags = (outcome_dep=="lagged")

    print("===================================================================")
    print(f"Scenario => N={N}, reg={regularity}, missing={missing_prop}, "
          f"sync={sync_pattern}, process={process_type_flag}, outcome={outcome_dep}")
    print("===================================================================")

    start_time = time.time()
    results_dict = run_single_scenario(
        N=N,
        p=p,
        regularity=regularity,
        missing_prop=missing_prop,
        num_sync_groups=num_sync_groups,
        process_types=process_types,
        use_lags=use_lags,
        block_missing=True,
        block_length=1.5,
        outcome_time=10,
        master_seed=123
    )
    runtime = time.time() - start_time

    scenario_result = {
        "N":              N,
        "regularity":     regularity,
        "missing_prop":   missing_prop,
        "sync_pattern":   sync_pattern,
        "process_type":   process_type_flag,
        "outcome_dep":    outcome_dep,
        "test_loss":      results_dict["test_loss"],
        "auc":            results_dict["auc"],
        "accuracy":       results_dict["accuracy"],
        "precision":      results_dict["precision"],
        "recall":         results_dict["recall"],
        "f1":             results_dict["f1"],
        "runtime_sec":    runtime,
        "mean_true_prob": results_dict["mean_true_prob"],
        "prop_positive":  results_dict["prop_positive"]
    }
    all_results.append(scenario_result)

overall_runtime = time.time() - overall_start
print(f"\nAll scenarios completed in {overall_runtime/60:.2f} minutes.\n")
# Out:
# Streaming output truncated to the last 5000 lines.
#   -> Validation AUC did not improve. (5/15)
# Epoch [19/60] Train Loss: 0.3293, Train AUC: 0.9323 | Val Loss: 0.7469, Val AUC: 0.6742
#   -> Validation AUC did not improve. (6/15)
# Epoch [20/60] Train Loss: 0.3238, Train AUC: 0.9407 | Val Loss: 0.7694, Val AUC: 0.6833
#   -> Validation AUC did not improve. (7/15)
# Epoch [21/60] Train Loss: 0.2986, Train AUC: 0.9442 | Val Loss: 0.7829, Val AUC: 0.6787
#   -> Validation AUC did not improve. (8/15)
# Epoch [22/60] Train Loss: 0.2867, Train AUC: 0.9548 | Val Loss: 0.7680, Val AUC: 0.7014
#   -> Validation AUC did not improve. (9/15)
# Epoch [23/60] Train Loss: 0.2933, Train AUC: 0.9577 | Val Loss: 0.7868, Val AUC: 0.6968
#   -> Validation AUC did not improve. (10/15)
# Epoch [24/60] Train Loss: 0.2579, Train AUC: 0.9638 | Val Loss: 0.7478, Val AUC: 0.7195
#   -> Validation AUC did not improve. (11/15)
# Epoch [25/60] Train Loss: 0.2188, Train AUC: 0.9683 | Val Loss: 0.7765, Val AUC: 0.7059
#   -> Validation AUC did not improve. (12/15)
# Epoch [26/60] Train Loss: 0.2064, Train AUC: 0.9742 | Val Loss: 0.7908, Val AUC: 0.7285
#   -> Validation AUC did not improve. (13/15)
# Epoch [27/60] Train Loss: 0.1873, Train AUC: 0.9804 | Val Loss: 0.8212, Val AUC: 0.7195
#   -> Validation AUC did not improve. (14/15)
# Epoch [28/60] Train Loss: 0.1797, Train AUC: 0.9834 | Val Loss: 0.8367, Val AUC: 0.7285
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 28.
# Finished training. Loading best model with Val AUC: 0.7285
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=p, process=mixed, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.7038, Train AUC: 0.4287 | Val Loss: 0.7027, Val AUC: 0.3239
#   -> New best validation AUC: 0.3239
# Epoch [2/60] Train Loss: 0.6822, Train AUC: 0.5618 | Val Loss: 0.6755, Val AUC: 0.4659
#   -> New best validation AUC: 0.4659
# Epoch [3/60] Train Loss: 0.6568, Train AUC: 0.6671 | Val Loss: 0.6586, Val AUC: 0.5966
#   -> New best validation AUC: 0.5966
# Epoch [4/60] Train Loss: 0.6314, Train AUC: 0.7418 | Val Loss: 0.6318, Val AUC: 0.7045
#   -> New best validation AUC: 0.7045
# Epoch [5/60] Train Loss: 0.5955, Train AUC: 0.8045 | Val Loss: 0.6046, Val AUC: 0.8068
#   -> New best validation AUC: 0.8068
# Epoch [6/60] Train Loss: 0.5875, Train AUC: 0.8430 | Val Loss: 0.5911, Val AUC: 0.8409
#   -> New best validation AUC: 0.8409
# Epoch [7/60] Train Loss: 0.5649, Train AUC: 0.8647 | Val Loss: 0.5677, Val AUC: 0.8864
#   -> New best validation AUC: 0.8864
# Epoch [8/60] Train Loss: 0.5463, Train AUC: 0.8843 | Val Loss: 0.5464, Val AUC: 0.9205
#   -> New best validation AUC: 0.9205
# Epoch [9/60] Train Loss: 0.5165, Train AUC: 0.9001 | Val Loss: 0.5313, Val AUC: 0.9205
#   -> Validation AUC did not improve. (1/15)
# Epoch [10/60] Train Loss: 0.4857, Train AUC: 0.9191 | Val Loss: 0.5119, Val AUC: 0.9318
#   -> New best validation AUC: 0.9318
# Epoch [11/60] Train Loss: 0.4609, Train AUC: 0.9312 | Val Loss: 0.4924, Val AUC: 0.9489
#   -> New best validation AUC: 0.9489
# Epoch [12/60] Train Loss: 0.4529, Train AUC: 0.9339 | Val Loss: 0.4678, Val AUC: 0.9602
#   -> New best validation AUC: 0.9602
# Epoch [13/60] Train Loss: 0.4377, Train AUC: 0.9335 | Val Loss: 0.4347, Val AUC: 0.9716
#   -> New best validation AUC: 0.9716
# Epoch [14/60] Train Loss: 0.4106, Train AUC: 0.9423 | Val Loss: 0.4344, Val AUC: 0.9545
#   -> Validation AUC did not improve. (1/15)
# Epoch [15/60] Train Loss: 0.3741, Train AUC: 0.9459 | Val Loss: 0.4148, Val AUC: 0.9545
#   -> Validation AUC did not improve. (2/15)
# Epoch [16/60] Train Loss: 0.3602, Train AUC: 0.9531 | Val Loss: 0.3901, Val AUC: 0.9773
#   -> New best validation AUC: 0.9773
# Epoch [17/60] Train Loss: 0.3285, Train AUC: 0.9584 | Val Loss: 0.3683, Val AUC: 0.9830
#   -> New best validation AUC: 0.9830
# Epoch [18/60] Train Loss: 0.3070, Train AUC: 0.9662 | Val Loss: 0.3434, Val AUC: 0.9886
#   -> New best validation AUC: 0.9886
# Epoch [19/60] Train Loss: 0.2629, Train AUC: 0.9756 | Val Loss: 0.3110, Val AUC: 0.9886
#   -> Validation AUC did not improve. (1/15)
# Epoch [20/60] Train Loss: 0.2459, Train AUC: 0.9805 | Val Loss: 0.2986, Val AUC: 0.9886
#   -> Validation AUC did not improve. (2/15)
# Epoch [21/60] Train Loss: 0.2153, Train AUC: 0.9851 | Val Loss: 0.3009, Val AUC: 0.9886
#   -> Validation AUC did not improve. (3/15)
# Epoch [22/60] Train Loss: 0.2137, Train AUC: 0.9879 | Val Loss: 0.3097, Val AUC: 0.9886
#   -> Validation AUC did not improve. (4/15)
# Epoch [23/60] Train Loss: 0.2114, Train AUC: 0.9875 | Val Loss: 0.3117, Val AUC: 0.9886
#   -> Validation AUC did not improve. (5/15)
# Epoch [24/60] Train Loss: 0.1546, Train AUC: 0.9887 | Val Loss: 0.2768, Val AUC: 0.9886
#   -> Validation AUC did not improve. (6/15)
# Epoch [25/60] Train Loss: 0.1375, Train AUC: 0.9910 | Val Loss: 0.2790, Val AUC: 0.9886
#   -> Validation AUC did not improve. (7/15)
# Epoch [26/60] Train Loss: 0.1295, Train AUC: 0.9916 | Val Loss: 0.2821, Val AUC: 0.9886
#   -> Validation AUC did not improve. (8/15)
# Epoch [27/60] Train Loss: 0.1109, Train AUC: 0.9928 | Val Loss: 0.2736, Val AUC: 0.9943
#   -> New best validation AUC: 0.9943
# Epoch [28/60] Train Loss: 0.1000, Train AUC: 0.9937 | Val Loss: 0.2956, Val AUC: 0.9886
#   -> Validation AUC did not improve. (1/15)
# Epoch [29/60] Train Loss: 0.0940, Train AUC: 0.9945 | Val Loss: 0.2728, Val AUC: 0.9943
#   -> Validation AUC did not improve. (2/15)
# Epoch [30/60] Train Loss: 0.0951, Train AUC: 0.9947 | Val Loss: 0.2481, Val AUC: 0.9943
#   -> Validation AUC did not improve. (3/15)
# Epoch [31/60] Train Loss: 0.0958, Train AUC: 0.9951 | Val Loss: 0.2627, Val AUC: 1.0000
#   -> New best validation AUC: 1.0000
# Epoch [32/60] Train Loss: 0.0727, Train AUC: 0.9961 | Val Loss: 0.2780, Val AUC: 0.9943
#   -> Validation AUC did not improve. (1/15)
# Epoch [33/60] Train Loss: 0.0703, Train AUC: 0.9955 | Val Loss: 0.3103, Val AUC: 0.9886
#   -> Validation AUC did not improve. (2/15)
# Epoch [34/60] Train Loss: 0.0677, Train AUC: 0.9959 | Val Loss: 0.3111, Val AUC: 0.9943
#   -> Validation AUC did not improve. (3/15)
# Epoch [35/60] Train Loss: 0.0605, Train AUC: 0.9957 | Val Loss: 0.3114, Val AUC: 0.9943
#   -> Validation AUC did not improve. (4/15)
# Epoch [36/60] Train Loss: 0.0597, Train AUC: 0.9969 | Val Loss: 0.3196, Val AUC: 0.9943
#   -> Validation AUC did not improve. (5/15)
# Epoch [37/60] Train Loss: 0.1194, Train AUC: 0.9891 | Val Loss: 0.3096, Val AUC: 0.9830
#   -> Validation AUC did not improve. (6/15)
# Epoch [38/60] Train Loss: 0.0762, Train AUC: 0.9926 | Val Loss: 0.3137, Val AUC: 0.9943
#   -> Validation AUC did not improve. (7/15)
# Epoch [39/60] Train Loss: 0.0507, Train AUC: 0.9990 | Val Loss: 0.3123, Val AUC: 1.0000
#   -> Validation AUC did not improve. (8/15)
# Epoch [40/60] Train Loss: 0.0485, Train AUC: 0.9992 | Val Loss: 0.3169, Val AUC: 0.9886
#   -> Validation AUC did not improve. (9/15)
# Epoch [41/60] Train Loss: 0.0438, Train AUC: 0.9996 | Val Loss: 0.3086, Val AUC: 1.0000
#   -> Validation AUC did not improve. (10/15)
# Epoch [42/60] Train Loss: 0.0405, Train AUC: 0.9998 | Val Loss: 0.3103, Val AUC: 0.9886
#   -> Validation AUC did not improve. (11/15)
# Epoch [43/60] Train Loss: 0.0399, Train AUC: 0.9998 | Val Loss: 0.3364, Val AUC: 0.9943
#   -> Validation AUC did not improve. (12/15)
# Epoch [44/60] Train Loss: 0.0382, Train AUC: 0.9998 | Val Loss: 0.3221, Val AUC: 1.0000
#   -> Validation AUC did not improve. (13/15)
# Epoch [45/60] Train Loss: 0.0348, Train AUC: 0.9998 | Val Loss: 0.3130, Val AUC: 1.0000
#   -> Validation AUC did not improve. (14/15)
# Epoch [46/60] Train Loss: 0.0345, Train AUC: 0.9998 | Val Loss: 0.3331, Val AUC: 0.9943
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 46.
# Finished training. Loading best model with Val AUC: 1.0000
# ===================================================================
# Scenario => N=200, reg=0.2, missing=0.4, sync=p, process=mixed, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6689, Train AUC: 0.6252 | Val Loss: 0.6610, Val AUC: 0.6473
#   -> New best validation AUC: 0.6473
# Epoch [2/60] Train Loss: 0.6387, Train AUC: 0.7375 | Val Loss: 0.6314, Val AUC: 0.7143
#   -> New best validation AUC: 0.7143
# Epoch [3/60] Train Loss: 0.6161, Train AUC: 0.8002 | Val Loss: 0.6142, Val AUC: 0.7679
#   -> New best validation AUC: 0.7679
# Epoch [4/60] Train Loss: 0.5799, Train AUC: 0.8512 | Val Loss: 0.5915, Val AUC: 0.8036
#   -> New best validation AUC: 0.8036
# Epoch [5/60] Train Loss: 0.5559, Train AUC: 0.8801 | Val Loss: 0.5725, Val AUC: 0.8259
#   -> New best validation AUC: 0.8259
# Epoch [6/60] Train Loss: 0.5315, Train AUC: 0.9015 | Val Loss: 0.5418, Val AUC: 0.8616
#   -> New best validation AUC: 0.8616
# Epoch [7/60] Train Loss: 0.4998, Train AUC: 0.9122 | Val Loss: 0.5316, Val AUC: 0.8661
#   -> New best validation AUC: 0.8661
# Epoch [8/60] Train Loss: 0.5000, Train AUC: 0.9184 | Val Loss: 0.4970, Val AUC: 0.9062
#   -> New best validation AUC: 0.9062
# Epoch [9/60] Train Loss: 0.4696, Train AUC: 0.9285 | Val Loss: 0.4919, Val AUC: 0.8884
#   -> Validation AUC did not improve. (1/15)
# Epoch [10/60] Train Loss: 0.4410, Train AUC: 0.9338 | Val Loss: 0.4732, Val AUC: 0.9018
#   -> Validation AUC did not improve. (2/15)
# Epoch [11/60] Train Loss: 0.4206, Train AUC: 0.9455 | Val Loss: 0.4397, Val AUC: 0.9241
#   -> New best validation AUC: 0.9241
# Epoch [12/60] Train Loss: 0.3842, Train AUC: 0.9500 | Val Loss: 0.4203, Val AUC: 0.9330
#   -> New best validation AUC: 0.9330
# Epoch [13/60] Train Loss: 0.3872, Train AUC: 0.9509 | Val Loss: 0.4163, Val AUC: 0.9196
#   -> Validation AUC did not improve. (1/15)
# Epoch [14/60] Train Loss: 0.3615, Train AUC: 0.9527 | Val Loss: 0.3942, Val AUC: 0.9330
#   -> Validation AUC did not improve. (2/15)
# Epoch [15/60] Train Loss: 0.3436, Train AUC: 0.9585 | Val Loss: 0.3725, Val AUC: 0.9375
#   -> New best validation AUC: 0.9375
# Epoch [16/60] Train Loss: 0.3449, Train AUC: 0.9605 | Val Loss: 0.3631, Val AUC: 0.9420
#   -> New best validation AUC: 0.9420
# Epoch [17/60] Train Loss: 0.3133, Train AUC: 0.9671 | Val Loss: 0.3500, Val AUC: 0.9420
#   -> New best validation AUC: 0.9420
# Epoch [18/60] Train Loss: 0.2988, Train AUC: 0.9694 | Val Loss: 0.3397, Val AUC: 0.9464
#   -> New best validation AUC: 0.9464
# Epoch [19/60] Train Loss: 0.2671, Train AUC: 0.9776 | Val Loss: 0.3252, Val AUC: 0.9464
#   -> Validation AUC did not improve. (1/15)
# Epoch [20/60] Train Loss: 0.2440, Train AUC: 0.9813 | Val Loss: 0.3116, Val AUC: 0.9598
#   -> New best validation AUC: 0.9598
# Epoch [21/60] Train Loss: 0.2175, Train AUC: 0.9848 | Val Loss: 0.3026, Val AUC: 0.9598
#   -> Validation AUC did not improve. (1/15)
# Epoch [22/60] Train Loss: 0.1906, Train AUC: 0.9910 | Val Loss: 0.2929, Val AUC: 0.9554
#   -> Validation AUC did not improve. (2/15)
# Epoch [23/60] Train Loss: 0.2105, Train AUC: 0.9916 | Val Loss: 0.2872, Val AUC: 0.9554
#   -> Validation AUC did not improve. (3/15)
# Epoch [24/60] Train Loss: 0.1842, Train AUC: 0.9947 | Val Loss: 0.2801, Val AUC: 0.9554
#   -> Validation AUC did not improve. (4/15)
# Epoch [25/60] Train Loss: 0.1521, Train AUC: 0.9957 | Val Loss: 0.2807, Val AUC: 0.9554
#   -> Validation AUC did not improve. (5/15)
# Epoch [26/60] Train Loss: 0.1368, Train AUC: 0.9975 | Val Loss: 0.2734, Val AUC: 0.9643
#   -> New best validation AUC: 0.9643
# Epoch [27/60] Train Loss: 0.1157, Train AUC: 0.9990 | Val Loss: 0.2748, Val AUC: 0.9598
#   -> Validation AUC did not improve. (1/15)
# Epoch [28/60] Train Loss: 0.1032, Train AUC: 0.9992 | Val Loss: 0.2669, Val AUC: 0.9688
#   -> New best validation AUC: 0.9688
# Epoch [29/60] Train Loss: 0.0985, Train AUC: 0.9986 | Val Loss: 0.2604, Val AUC: 0.9688
#   -> Validation AUC did not improve. (1/15)
# Epoch [30/60] Train Loss: 0.0825, Train AUC: 1.0000 | Val Loss: 0.2514, Val AUC: 0.9688
#   -> Validation AUC did not improve. (2/15)
# Epoch [31/60] Train Loss: 0.0796, Train AUC: 0.9998 | Val Loss: 0.2446, Val AUC: 0.9643
#   -> Validation AUC did not improve. (3/15)
# Epoch [32/60] Train Loss: 0.0666, Train AUC: 0.9998 | Val Loss: 0.2628, Val AUC: 0.9598
#   -> Validation AUC did not improve. (4/15)
# Epoch [33/60] Train Loss: 0.0675, Train AUC: 1.0000 | Val Loss: 0.2551, Val AUC: 0.9554
#   -> Validation AUC did not improve. (5/15)
# Epoch [34/60] Train Loss: 0.0610, Train AUC: 0.9996 | Val Loss: 0.2347, Val AUC: 0.9598
#   -> Validation AUC did not improve. (6/15)
# Epoch [35/60] Train Loss: 0.0494, Train AUC: 1.0000 | Val Loss: 0.2446, Val AUC: 0.9643
#   -> Validation AUC did not improve. (7/15)
# Epoch [36/60] Train Loss: 0.0469, Train AUC: 1.0000 | Val Loss: 0.2465, Val AUC: 0.9688
#   -> Validation AUC did not improve. (8/15)
# Epoch [37/60] Train Loss: 0.0422, Train AUC: 1.0000 | Val Loss: 0.2451, Val AUC: 0.9688
#   -> Validation AUC did not improve. (9/15)
# Epoch [38/60] Train Loss: 0.0397, Train AUC: 1.0000 | Val Loss: 0.2487, Val AUC: 0.9688
#   -> Validation AUC did not improve. (10/15)
# Epoch [39/60] Train Loss: 0.0375, Train AUC: 1.0000 | Val Loss: 0.2382, Val AUC: 0.9688
#   -> Validation AUC did not improve. (11/15)
# Epoch [40/60] Train Loss: 0.0350, Train AUC: 1.0000 | Val Loss: 0.2465, Val AUC: 0.9643
#   -> Validation AUC did not improve. (12/15)
# Epoch [41/60] Train Loss: 0.0317, Train AUC: 1.0000 | Val Loss: 0.2391, Val AUC: 0.9688
#   -> Validation AUC did not improve. (13/15)
# Epoch [42/60] Train Loss: 0.0291, Train AUC: 1.0000 | Val Loss: 0.2651, Val AUC: 0.9643
#   -> Validation AUC did not improve. (14/15)
# Epoch [43/60] Train Loss: 0.0265, Train AUC: 1.0000 | Val Loss: 0.2509, Val AUC: 0.9688
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 43.
# Finished training. Loading best model with Val AUC: 0.9688
# ===================================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=1, process=homogeneous, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.7014, Train AUC: 0.5353 | Val Loss: 0.7186, Val AUC: 0.3913
#   -> New best validation AUC: 0.3913
# Epoch [2/60] Train Loss: 0.6736, Train AUC: 0.6314 | Val Loss: 0.7048, Val AUC: 0.4348
#   -> New best validation AUC: 0.4348
# Epoch [3/60] Train Loss: 0.6544, Train AUC: 0.7048 | Val Loss: 0.6899, Val AUC: 0.4969
#   -> New best validation AUC: 0.4969
# Epoch [4/60] Train Loss: 0.6433, Train AUC: 0.7583 | Val Loss: 0.6754, Val AUC: 0.5466
#   -> New best validation AUC: 0.5466
# Epoch [5/60] Train Loss: 0.6256, Train AUC: 0.7994 | Val Loss: 0.6575, Val AUC: 0.5839
#   -> New best validation AUC: 0.5839
# Epoch [6/60] Train Loss: 0.6126, Train AUC: 0.8191 | Val Loss: 0.6420, Val AUC: 0.6335
#   -> New best validation AUC: 0.6335
# Epoch [7/60] Train Loss: 0.5881, Train AUC: 0.8428 | Val Loss: 0.6277, Val AUC: 0.6770
#   -> New best validation AUC: 0.6770
# Epoch [8/60] Train Loss: 0.5727, Train AUC: 0.8554 | Val Loss: 0.6142, Val AUC: 0.6832
#   -> New best validation AUC: 0.6832
# Epoch [9/60] Train Loss: 0.5493, Train AUC: 0.8765 | Val Loss: 0.5959, Val AUC: 0.7205
#   -> New best validation AUC: 0.7205
# Epoch [10/60] Train Loss: 0.5277, Train AUC: 0.8824 | Val Loss: 0.5809, Val AUC: 0.7205
#   -> New best validation AUC: 0.7205
# Epoch [11/60] Train Loss: 0.4985, Train AUC: 0.8990 | Val Loss: 0.5566, Val AUC: 0.7640
#   -> New best validation AUC: 0.7640
# Epoch [12/60] Train Loss: 0.4684, Train AUC: 0.9096 | Val Loss: 0.5307, Val AUC: 0.8012
#   -> New best validation AUC: 0.8012
# Epoch [13/60] Train Loss: 0.4499, Train AUC: 0.9129 | Val Loss: 0.5127, Val AUC: 0.8261
#   -> New best validation AUC: 0.8261
# Epoch [14/60] Train Loss: 0.4143, Train AUC: 0.9250 | Val Loss: 0.4879, Val AUC: 0.8509
#   -> New best validation AUC: 0.8509
# Epoch [15/60] Train Loss: 0.3862, Train AUC: 0.9274 | Val Loss: 0.4576, Val AUC: 0.8571
#   -> New best validation AUC: 0.8571
# Epoch [16/60] Train Loss: 0.3622, Train AUC: 0.9395 | Val Loss: 0.4338, Val AUC: 0.8944
#   -> New best validation AUC: 0.8944
# Epoch [17/60] Train Loss: 0.3355, Train AUC: 0.9456 | Val Loss: 0.4275, Val AUC: 0.8758
#   -> Validation AUC did not improve. (1/15)
# Epoch [18/60] Train Loss: 0.3273, Train AUC: 0.9505 | Val Loss: 0.4013, Val AUC: 0.8882
#   -> Validation AUC did not improve. (2/15)
# Epoch [19/60] Train Loss: 0.2846, Train AUC: 0.9587 | Val Loss: 0.4121, Val AUC: 0.8944
#   -> Validation AUC did not improve. (3/15)
# Epoch [20/60] Train Loss: 0.2618, Train AUC: 0.9638 | Val Loss: 0.4107, Val AUC: 0.9006
#   -> New best validation AUC: 0.9006
# Epoch [21/60] Train Loss: 0.2629, Train AUC: 0.9730 | Val Loss: 0.4080, Val AUC: 0.8882
#   -> Validation AUC did not improve. (1/15)
# Epoch [22/60] Train Loss: 0.2208, Train AUC: 0.9775 | Val Loss: 0.3891, Val AUC: 0.8882
#   -> Validation AUC did not improve. (2/15)
# Epoch [23/60] Train Loss: 0.1965, Train AUC: 0.9830 | Val Loss: 0.3593, Val AUC: 0.9006
#   -> Validation AUC did not improve. (3/15)
# Epoch [24/60] Train Loss: 0.1782, Train AUC: 0.9845 | Val Loss: 0.3589, Val AUC: 0.9068
#   -> New best validation AUC: 0.9068
# Epoch [25/60] Train Loss: 0.1922, Train AUC: 0.9865 | Val Loss: 0.3370, Val AUC: 0.9068
#   -> Validation AUC did not improve. (1/15)
# Epoch [26/60] Train Loss: 0.1671, Train AUC: 0.9890 | Val Loss: 0.3340, Val AUC: 0.9130
#   -> New best validation AUC: 0.9130
# Epoch [27/60] Train Loss: 0.1270, Train AUC: 0.9930 | Val Loss: 0.3211, Val AUC: 0.9193
#   -> New best validation AUC: 0.9193
# Epoch [28/60] Train Loss: 0.0933, Train AUC: 0.9969 | Val Loss: 0.3034, Val AUC: 0.9193
#   -> New best validation AUC: 0.9193
# Epoch [29/60] Train Loss: 0.0799, Train AUC: 0.9971 | Val Loss: 0.2894, Val AUC: 0.9317
#   -> New best validation AUC: 0.9317
# Epoch [30/60] Train Loss: 0.0706, Train AUC: 0.9982 | Val Loss: 0.2923, Val AUC: 0.9255
#   -> Validation AUC did not improve. (1/15)
# Epoch [31/60] Train Loss: 0.0645, Train AUC: 0.9984 | Val Loss: 0.2834, Val AUC: 0.9317
#   -> Validation AUC did not improve. (2/15)
# Epoch [32/60] Train Loss: 0.0604, Train AUC: 0.9984 | Val Loss: 0.2825, Val AUC: 0.9255
#   -> Validation AUC did not improve. (3/15)
# Epoch [33/60] Train Loss: 0.0535, Train AUC: 0.9982 | Val Loss: 0.2948, Val AUC: 0.9379
#   -> New best validation AUC: 0.9379
# Epoch [34/60] Train Loss: 0.0494, Train AUC: 0.9984 | Val Loss: 0.3145, Val AUC: 0.9255
#   -> Validation AUC did not improve. (1/15)
# Epoch [35/60] Train Loss: 0.0414, Train AUC: 0.9992 | Val Loss: 0.3732, Val AUC: 0.9193
#   -> Validation AUC did not improve. (2/15)
# Epoch [36/60] Train Loss: 0.0415, Train AUC: 0.9996 | Val Loss: 0.3501, Val AUC: 0.9379
#   -> Validation AUC did not improve. (3/15)
# Epoch [37/60] Train Loss: 0.0372, Train AUC: 0.9998 | Val Loss: 0.2946, Val AUC: 0.9317
#   -> Validation AUC did not improve. (4/15)
# Epoch [38/60] Train Loss: 0.0448, Train AUC: 0.9994 | Val Loss: 0.5370, Val AUC: 0.9006
#   -> Validation AUC did not improve. (5/15)
# Epoch [39/60] Train Loss: 0.0391, Train AUC: 0.9998 | Val Loss: 0.5640, Val AUC: 0.9130
#   -> Validation AUC did not improve. (6/15)
# Epoch [40/60] Train Loss: 0.0813, Train AUC: 1.0000 | Val Loss: 0.5852, Val AUC: 0.9006
#   -> Validation AUC did not improve. (7/15)
# Epoch [41/60] Train Loss: 0.0369, Train AUC: 1.0000 | Val Loss: 0.4288, Val AUC: 0.9193
#   -> Validation AUC did not improve. (8/15)
# Epoch [42/60] Train Loss: 0.0460, Train AUC: 0.9998 | Val Loss: 0.4044, Val AUC: 0.9130
#   -> Validation AUC did not improve. (9/15)
# Epoch [43/60] Train Loss: 0.0489, Train AUC: 0.9998 | Val Loss: 0.3800, Val AUC: 0.9193
#   -> Validation AUC did not improve. (10/15)
# Epoch [44/60] Train Loss: 0.0369, Train AUC: 1.0000 | Val Loss: 0.4713, Val AUC: 0.9006
#   -> Validation AUC did not improve. (11/15)
# Epoch [45/60] Train Loss: 0.0345, Train AUC: 1.0000 | Val Loss: 0.4589, Val AUC: 0.8944
#   -> Validation AUC did not improve. (12/15)
# Epoch [46/60] Train Loss: 0.0311, Train AUC: 1.0000 | Val Loss: 0.5313, Val AUC: 0.8944
#   -> Validation AUC did not improve. (13/15)
# Epoch [47/60] Train Loss: 0.0319, Train AUC: 1.0000 | Val Loss: 0.4435, Val AUC: 0.9130
#   -> Validation AUC did not improve. (14/15)
# Epoch [48/60] Train Loss: 0.0292, Train AUC: 1.0000 | Val Loss: 0.4565, Val AUC: 0.9130
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 48.
# Finished training. Loading best model with Val AUC: 0.9379
# ===================================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=1, process=homogeneous, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6960, Train AUC: 0.5345 | Val Loss: 0.6945, Val AUC: 0.5113
#   -> New best validation AUC: 0.5113
# Epoch [2/60] Train Loss: 0.6811, Train AUC: 0.5944 | Val Loss: 0.6905, Val AUC: 0.5249
#   -> New best validation AUC: 0.5249
# Epoch [3/60] Train Loss: 0.6614, Train AUC: 0.6803 | Val Loss: 0.6864, Val AUC: 0.5339
#   -> New best validation AUC: 0.5339
# Epoch [4/60] Train Loss: 0.6524, Train AUC: 0.7249 | Val Loss: 0.6862, Val AUC: 0.5294
#   -> Validation AUC did not improve. (1/15)
# Epoch [5/60] Train Loss: 0.6465, Train AUC: 0.7389 | Val Loss: 0.6862, Val AUC: 0.5204
#   -> Validation AUC did not improve. (2/15)
# Epoch [6/60] Train Loss: 0.6359, Train AUC: 0.7701 | Val Loss: 0.6874, Val AUC: 0.5068
#   -> Validation AUC did not improve. (3/15)
# Epoch [7/60] Train Loss: 0.6238, Train AUC: 0.7675 | Val Loss: 0.6870, Val AUC: 0.5158
#   -> Validation AUC did not improve. (4/15)
# Epoch [8/60] Train Loss: 0.6087, Train AUC: 0.8014 | Val Loss: 0.6861, Val AUC: 0.5204
#   -> Validation AUC did not improve. (5/15)
# Epoch [9/60] Train Loss: 0.6045, Train AUC: 0.8029 | Val Loss: 0.6963, Val AUC: 0.5023
#   -> Validation AUC did not improve. (6/15)
# Epoch [10/60] Train Loss: 0.5787, Train AUC: 0.8099 | Val Loss: 0.7031, Val AUC: 0.5113
#   -> Validation AUC did not improve. (7/15)
# Epoch [11/60] Train Loss: 0.5577, Train AUC: 0.8252 | Val Loss: 0.7085, Val AUC: 0.5249
#   -> Validation AUC did not improve. (8/15)
# Epoch [12/60] Train Loss: 0.5655, Train AUC: 0.8230 | Val Loss: 0.7243, Val AUC: 0.5294
#   -> Validation AUC did not improve. (9/15)
# Epoch [13/60] Train Loss: 0.5205, Train AUC: 0.8350 | Val Loss: 0.7392, Val AUC: 0.5204
#   -> Validation AUC did not improve. (10/15)
# Epoch [14/60] Train Loss: 0.5239, Train AUC: 0.8427 | Val Loss: 0.7607, Val AUC: 0.5339
#   -> Validation AUC did not improve. (11/15)
# Epoch [15/60] Train Loss: 0.4887, Train AUC: 0.8643 | Val Loss: 0.7675, Val AUC: 0.5339
#   -> Validation AUC did not improve. (12/15)
# Epoch [16/60] Train Loss: 0.4600, Train AUC: 0.8743 | Val Loss: 0.7869, Val AUC: 0.5566
#   -> New best validation AUC: 0.5566
# Epoch [17/60] Train Loss: 0.4450, Train AUC: 0.8901 | Val Loss: 0.8168, Val AUC: 0.5520
#   -> Validation AUC did not improve. (1/15)
# Epoch [18/60] Train Loss: 0.4172, Train AUC: 0.9058 | Val Loss: 0.8413, Val AUC: 0.5520
#   -> Validation AUC did not improve. (2/15)
# Epoch [19/60] Train Loss: 0.3861, Train AUC: 0.9156 | Val Loss: 0.8808, Val AUC: 0.5611
#   -> New best validation AUC: 0.5611
# Epoch [20/60] Train Loss: 0.3859, Train AUC: 0.9285 | Val Loss: 0.9589, Val AUC: 0.5475
#   -> Validation AUC did not improve. (1/15)
# Epoch [21/60] Train Loss: 0.3142, Train AUC: 0.9436 | Val Loss: 0.9990, Val AUC: 0.5339
#   -> Validation AUC did not improve. (2/15)
# Epoch [22/60] Train Loss: 0.2848, Train AUC: 0.9543 | Val Loss: 1.0420, Val AUC: 0.5249
#   -> Validation AUC did not improve. (3/15)
# Epoch [23/60] Train Loss: 0.2446, Train AUC: 0.9611 | Val Loss: 1.1203, Val AUC: 0.5023
#   -> Validation AUC did not improve. (4/15)
# Epoch [24/60] Train Loss: 0.2123, Train AUC: 0.9674 | Val Loss: 1.2172, Val AUC: 0.4615
#   -> Validation AUC did not improve. (5/15)
# Epoch [25/60] Train Loss: 0.1817, Train AUC: 0.9757 | Val Loss: 1.1892, Val AUC: 0.5068
#   -> Validation AUC did not improve. (6/15)
# Epoch [26/60] Train Loss: 0.1774, Train AUC: 0.9768 | Val Loss: 1.2427, Val AUC: 0.5294
#   -> Validation AUC did not improve. (7/15)
# Epoch [27/60] Train Loss: 0.1795, Train AUC: 0.9834 | Val Loss: 1.2677, Val AUC: 0.5204
#   -> Validation AUC did not improve. (8/15)
# Epoch [28/60] Train Loss: 0.1693, Train AUC: 0.9849 | Val Loss: 1.3223, Val AUC: 0.4932
#   -> Validation AUC did not improve. (9/15)
# Epoch [29/60] Train Loss: 0.1122, Train AUC: 0.9873 | Val Loss: 1.3692, Val AUC: 0.5158
#   -> Validation AUC did not improve. (10/15)
# Epoch [30/60] Train Loss: 0.1025, Train AUC: 0.9865 | Val Loss: 1.4521, Val AUC: 0.5113
#   -> Validation AUC did not improve. (11/15)
# Epoch [31/60] Train Loss: 0.0879, Train AUC: 0.9906 | Val Loss: 1.4406, Val AUC: 0.5385
#   -> Validation AUC did not improve. (12/15)
# Epoch [32/60] Train Loss: 0.0887, Train AUC: 0.9880 | Val Loss: 1.4859, Val AUC: 0.5023
#   -> Validation AUC did not improve. (13/15)
# Epoch [33/60] Train Loss: 0.1190, Train AUC: 0.9867 | Val Loss: 1.5612, Val AUC: 0.5068
#   -> Validation AUC did not improve. (14/15)
# Epoch [34/60] Train Loss: 0.0836, Train AUC: 0.9886 | Val Loss: 1.5182, Val AUC: 0.5520
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 34.
# Finished training. Loading best model with Val AUC: 0.5611
# ===================================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=1, process=mixed, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.7063, Train AUC: 0.5354 | Val Loss: 0.7015, Val AUC: 0.5536
#   -> New best validation AUC: 0.5536
# Epoch [2/60] Train Loss: 0.6522, Train AUC: 0.6867 | Val Loss: 0.6672, Val AUC: 0.6563
#   -> New best validation AUC: 0.6563
# Epoch [3/60] Train Loss: 0.6350, Train AUC: 0.7851 | Val Loss: 0.6686, Val AUC: 0.6473
#   -> Validation AUC did not improve. (1/15)
# Epoch [4/60] Train Loss: 0.6064, Train AUC: 0.8443 | Val Loss: 0.6485, Val AUC: 0.7188
#   -> New best validation AUC: 0.7188
# Epoch [5/60] Train Loss: 0.5775, Train AUC: 0.8781 | Val Loss: 0.6275, Val AUC: 0.7455
#   -> New best validation AUC: 0.7455
# Epoch [6/60] Train Loss: 0.5678, Train AUC: 0.8841 | Val Loss: 0.6090, Val AUC: 0.7902
#   -> New best validation AUC: 0.7902
# Epoch [7/60] Train Loss: 0.5480, Train AUC: 0.8990 | Val Loss: 0.6094, Val AUC: 0.7723
#   -> Validation AUC did not improve. (1/15)
# Epoch [8/60] Train Loss: 0.5268, Train AUC: 0.9092 | Val Loss: 0.5859, Val AUC: 0.8214
#   -> New best validation AUC: 0.8214
# Epoch [9/60] Train Loss: 0.4946, Train AUC: 0.9157 | Val Loss: 0.5692, Val AUC: 0.8438
#   -> New best validation AUC: 0.8438
# Epoch [10/60] Train Loss: 0.4688, Train AUC: 0.9265 | Val Loss: 0.5534, Val AUC: 0.8571
#   -> New best validation AUC: 0.8571
# Epoch [11/60] Train Loss: 0.4491, Train AUC: 0.9312 | Val Loss: 0.5455, Val AUC: 0.8616
#   -> New best validation AUC: 0.8616
# Epoch [12/60] Train Loss: 0.4317, Train AUC: 0.9388 | Val Loss: 0.5242, Val AUC: 0.8839
#   -> New best validation AUC: 0.8839
# Epoch [13/60] Train Loss: 0.3909, Train AUC: 0.9490 | Val Loss: 0.4954, Val AUC: 0.8929
#   -> New best validation AUC: 0.8929
# Epoch [14/60] Train Loss: 0.3700, Train AUC: 0.9508 | Val Loss: 0.4762, Val AUC: 0.9196
#   -> New best validation AUC: 0.9196
# Epoch [15/60] Train Loss: 0.3672, Train AUC: 0.9580 | Val Loss: 0.4510, Val AUC: 0.9330
#   -> New best validation AUC: 0.9330
# Epoch [16/60] Train Loss: 0.3259, Train AUC: 0.9637 | Val Loss: 0.4392, Val AUC: 0.9375
#   -> New best validation AUC: 0.9375
# Epoch [17/60] Train Loss: 0.2608, Train AUC: 0.9686 | Val Loss: 0.4141, Val AUC: 0.9509
#   -> New best validation AUC: 0.9509
# Epoch [18/60] Train Loss: 0.2429, Train AUC: 0.9712 | Val Loss: 0.3813, Val AUC: 0.9554
#   -> New best validation AUC: 0.9554
# Epoch [19/60] Train Loss: 0.2117, Train AUC: 0.9763 | Val Loss: 0.3742, Val AUC: 0.9554
#   -> Validation AUC did not improve. (1/15)
# Epoch [20/60] Train Loss: 0.1899, Train AUC: 0.9822 | Val Loss: 0.3578, Val AUC: 0.9375
#   -> Validation AUC did not improve. (2/15)
# Epoch [21/60] Train Loss: 0.1675, Train AUC: 0.9843 | Val Loss: 0.3332, Val AUC: 0.9509
#   -> Validation AUC did not improve. (3/15)
# Epoch [22/60] Train Loss: 0.1512, Train AUC: 0.9896 | Val Loss: 0.3406, Val AUC: 0.9375
#   -> Validation AUC did not improve. (4/15)
# Epoch [23/60] Train Loss: 0.1342, Train AUC: 0.9916 | Val Loss: 0.3361, Val AUC: 0.9420
#   -> Validation AUC did not improve. (5/15)
# Epoch [24/60] Train Loss: 0.1233, Train AUC: 0.9947 | Val Loss: 0.3423, Val AUC: 0.9241
#   -> Validation AUC did not improve. (6/15)
# Epoch [25/60] Train Loss: 0.1035, Train AUC: 0.9955 | Val Loss: 0.3400, Val AUC: 0.9375
#   -> Validation AUC did not improve. (7/15)
# Epoch [26/60] Train Loss: 0.0882, Train AUC: 0.9976 | Val Loss: 0.3817, Val AUC: 0.9196
#   -> Validation AUC did not improve. (8/15)
# Epoch [27/60] Train Loss: 0.0816, Train AUC: 0.9973 | Val Loss: 0.3686, Val AUC: 0.9196
#   -> Validation AUC did not improve. (9/15)
# Epoch [28/60] Train Loss: 0.0728, Train AUC: 0.9982 | Val Loss: 0.3490, Val AUC: 0.9375
#   -> Validation AUC did not improve. (10/15)
# Epoch [29/60] Train Loss: 0.0644, Train AUC: 0.9988 | Val Loss: 0.3529, Val AUC: 0.9241
#   -> Validation AUC did not improve. (11/15)
# Epoch [30/60] Train Loss: 0.0600, Train AUC: 0.9996 | Val Loss: 0.4266, Val AUC: 0.9018
#   -> Validation AUC did not improve. (12/15)
# Epoch [31/60] Train Loss: 0.0542, Train AUC: 1.0000 | Val Loss: 0.4518, Val AUC: 0.9018
#   -> Validation AUC did not improve. (13/15)
# Epoch [32/60] Train Loss: 0.0446, Train AUC: 1.0000 | Val Loss: 0.4573, Val AUC: 0.9018
#   -> Validation AUC did not improve. (14/15)
# Epoch [33/60] Train Loss: 0.0389, Train AUC: 1.0000 | Val Loss: 0.4972, Val AUC: 0.8973
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 33.
# Finished training. Loading best model with Val AUC: 0.9554
# ===================================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=1, process=mixed, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6556, Train AUC: 0.6332 | Val Loss: 0.6447, Val AUC: 0.6938
#   -> New best validation AUC: 0.6938
# Epoch [2/60] Train Loss: 0.6196, Train AUC: 0.7248 | Val Loss: 0.6183, Val AUC: 0.7368
#   -> New best validation AUC: 0.7368
# Epoch [3/60] Train Loss: 0.5726, Train AUC: 0.7878 | Val Loss: 0.6304, Val AUC: 0.6986
#   -> Validation AUC did not improve. (1/15)
# Epoch [4/60] Train Loss: 0.5337, Train AUC: 0.8452 | Val Loss: 0.5952, Val AUC: 0.7608
#   -> New best validation AUC: 0.7608
# Epoch [5/60] Train Loss: 0.5116, Train AUC: 0.8778 | Val Loss: 0.5870, Val AUC: 0.7656
#   -> New best validation AUC: 0.7656
# Epoch [6/60] Train Loss: 0.4919, Train AUC: 0.9094 | Val Loss: 0.5763, Val AUC: 0.7847
#   -> New best validation AUC: 0.7847
# Epoch [7/60] Train Loss: 0.4779, Train AUC: 0.9243 | Val Loss: 0.5631, Val AUC: 0.8038
#   -> New best validation AUC: 0.8038
# Epoch [8/60] Train Loss: 0.4398, Train AUC: 0.9370 | Val Loss: 0.5626, Val AUC: 0.8086
#   -> New best validation AUC: 0.8086
# Epoch [9/60] Train Loss: 0.4140, Train AUC: 0.9544 | Val Loss: 0.5579, Val AUC: 0.7990
#   -> Validation AUC did not improve. (1/15)
# Epoch [10/60] Train Loss: 0.3971, Train AUC: 0.9621 | Val Loss: 0.5486, Val AUC: 0.8182
#   -> New best validation AUC: 0.8182
# Epoch [11/60] Train Loss: 0.3476, Train AUC: 0.9678 | Val Loss: 0.5482, Val AUC: 0.8038
#   -> Validation AUC did not improve. (1/15)
# Epoch [12/60] Train Loss: 0.3370, Train AUC: 0.9734 | Val Loss: 0.5323, Val AUC: 0.8469
#   -> New best validation AUC: 0.8469
# Epoch [13/60] Train Loss: 0.3371, Train AUC: 0.9764 | Val Loss: 0.5483, Val AUC: 0.8421
#   -> Validation AUC did not improve. (1/15)
# Epoch [14/60] Train Loss: 0.2803, Train AUC: 0.9801 | Val Loss: 0.5385, Val AUC: 0.8421
#   -> Validation AUC did not improve. (2/15)
# Epoch [15/60] Train Loss: 0.2644, Train AUC: 0.9854 | Val Loss: 0.5617, Val AUC: 0.8373
#   -> Validation AUC did not improve. (3/15)
# Epoch [16/60] Train Loss: 0.2471, Train AUC: 0.9860 | Val Loss: 0.5567, Val AUC: 0.8660
#   -> New best validation AUC: 0.8660
# Epoch [17/60] Train Loss: 0.2246, Train AUC: 0.9881 | Val Loss: 0.5647, Val AUC: 0.8517
#   -> Validation AUC did not improve. (1/15)
# Epoch [18/60] Train Loss: 0.1984, Train AUC: 0.9887 | Val Loss: 0.5795, Val AUC: 0.8517
#   -> Validation AUC did not improve. (2/15)
# Epoch [19/60] Train Loss: 0.1761, Train AUC: 0.9914 | Val Loss: 0.6130, Val AUC: 0.8325
#   -> Validation AUC did not improve. (3/15)
# Epoch [20/60] Train Loss: 0.1645, Train AUC: 0.9929 | Val Loss: 0.6378, Val AUC: 0.8421
#   -> Validation AUC did not improve. (4/15)
# Epoch [21/60] Train Loss: 0.1698, Train AUC: 0.9950 | Val Loss: 0.6504, Val AUC: 0.8421
#   -> Validation AUC did not improve. (5/15)
# Epoch [22/60] Train Loss: 0.1212, Train AUC: 0.9954 | Val Loss: 0.6647, Val AUC: 0.8325
#   -> Validation AUC did not improve. (6/15)
# Epoch [23/60] Train Loss: 0.1140, Train AUC: 0.9971 | Val Loss: 0.6901, Val AUC: 0.8373
#   -> Validation AUC did not improve. (7/15)
# Epoch [24/60] Train Loss: 0.1088, Train AUC: 0.9979 | Val Loss: 0.7234, Val AUC: 0.8278
#   -> Validation AUC did not improve. (8/15)
# Epoch [25/60] Train Loss: 0.0954, Train AUC: 0.9990 | Val Loss: 0.7365, Val AUC: 0.8182
#   -> Validation AUC did not improve. (9/15)
# Epoch [26/60] Train Loss: 0.0973, Train AUC: 0.9977 | Val Loss: 0.6984, Val AUC: 0.8469
#   -> Validation AUC did not improve. (10/15)
# Epoch [27/60] Train Loss: 0.0720, Train AUC: 0.9996 | Val Loss: 0.6847, Val AUC: 0.8469
#   -> Validation AUC did not improve. (11/15)
# Epoch [28/60] Train Loss: 0.0726, Train AUC: 0.9998 | Val Loss: 0.7044, Val AUC: 0.8421
#   -> Validation AUC did not improve. (12/15)
# Epoch [29/60] Train Loss: 0.0595, Train AUC: 1.0000 | Val Loss: 0.6800, Val AUC: 0.8421
#   -> Validation AUC did not improve. (13/15)
# Epoch [30/60] Train Loss: 0.0575, Train AUC: 1.0000 | Val Loss: 0.7133, Val AUC: 0.8469
#   -> Validation AUC did not improve. (14/15)
# Epoch [31/60] Train Loss: 0.0469, Train AUC: 1.0000 | Val Loss: 0.6870, Val AUC: 0.8469
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 31.
# Finished training. Loading best model with Val AUC: 0.8660
# ===================================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=p, process=homogeneous, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6915, Train AUC: 0.6010 | Val Loss: 0.6908, Val AUC: 0.5179
#   -> New best validation AUC: 0.5179
# Epoch [2/60] Train Loss: 0.6620, Train AUC: 0.7087 | Val Loss: 0.6770, Val AUC: 0.6250
#   -> New best validation AUC: 0.6250
# Epoch [3/60] Train Loss: 0.6440, Train AUC: 0.7688 | Val Loss: 0.6744, Val AUC: 0.6607
#   -> New best validation AUC: 0.6607
# Epoch [4/60] Train Loss: 0.6283, Train AUC: 0.8324 | Val Loss: 0.6621, Val AUC: 0.7143
#   -> New best validation AUC: 0.7143
# Epoch [5/60] Train Loss: 0.6091, Train AUC: 0.8644 | Val Loss: 0.6561, Val AUC: 0.7143
#   -> Validation AUC did not improve. (1/15)
# Epoch [6/60] Train Loss: 0.5857, Train AUC: 0.8761 | Val Loss: 0.6454, Val AUC: 0.7321
#   -> New best validation AUC: 0.7321
# Epoch [7/60] Train Loss: 0.5735, Train AUC: 0.8864 | Val Loss: 0.6412, Val AUC: 0.7098
#   -> Validation AUC did not improve. (1/15)
# Epoch [8/60] Train Loss: 0.5436, Train AUC: 0.9093 | Val Loss: 0.6359, Val AUC: 0.7054
#   -> Validation AUC did not improve. (2/15)
# Epoch [9/60] Train Loss: 0.5290, Train AUC: 0.9102 | Val Loss: 0.6268, Val AUC: 0.7232
#   -> Validation AUC did not improve. (3/15)
# Epoch [10/60] Train Loss: 0.4809, Train AUC: 0.9179 | Val Loss: 0.6251, Val AUC: 0.7143
#   -> Validation AUC did not improve. (4/15)
# Epoch [11/60] Train Loss: 0.4655, Train AUC: 0.9167 | Val Loss: 0.6239, Val AUC: 0.7009
#   -> Validation AUC did not improve. (5/15)
# Epoch [12/60] Train Loss: 0.4280, Train AUC: 0.9303 | Val Loss: 0.6273, Val AUC: 0.7188
#   -> Validation AUC did not improve. (6/15)
# Epoch [13/60] Train Loss: 0.4305, Train AUC: 0.9288 | Val Loss: 0.6473, Val AUC: 0.7054
#   -> Validation AUC did not improve. (7/15)
# Epoch [14/60] Train Loss: 0.3571, Train AUC: 0.9352 | Val Loss: 0.6819, Val AUC: 0.6964
#   -> Validation AUC did not improve. (8/15)
# Epoch [15/60] Train Loss: 0.3621, Train AUC: 0.9397 | Val Loss: 0.7345, Val AUC: 0.6607
#   -> Validation AUC did not improve. (9/15)
# Epoch [16/60] Train Loss: 0.3140, Train AUC: 0.9432 | Val Loss: 0.7520, Val AUC: 0.6920
#   -> Validation AUC did not improve. (10/15)
# Epoch [17/60] Train Loss: 0.2896, Train AUC: 0.9512 | Val Loss: 0.8089, Val AUC: 0.6429
#   -> Validation AUC did not improve. (11/15)
# Epoch [18/60] Train Loss: 0.3132, Train AUC: 0.9534 | Val Loss: 0.8341, Val AUC: 0.6562
#   -> Validation AUC did not improve. (12/15)
# Epoch [19/60] Train Loss: 0.2419, Train AUC: 0.9579 | Val Loss: 0.8539, Val AUC: 0.6429
#   -> Validation AUC did not improve. (13/15)
# Epoch [20/60] Train Loss: 0.2385, Train AUC: 0.9643 | Val Loss: 0.8837, Val AUC: 0.6429
#   -> Validation AUC did not improve. (14/15)
# Epoch [21/60] Train Loss: 0.2494, Train AUC: 0.9705 | Val Loss: 0.9004, Val AUC: 0.6518
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 21.
# Finished training. Loading best model with Val AUC: 0.7321
# ===================================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=p, process=homogeneous, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6826, Train AUC: 0.5729 | Val Loss: 0.6722, Val AUC: 0.6300
#   -> New best validation AUC: 0.6300
# Epoch [2/60] Train Loss: 0.6716, Train AUC: 0.6454 | Val Loss: 0.6640, Val AUC: 0.7050
#   -> New best validation AUC: 0.7050
# Epoch [3/60] Train Loss: 0.6558, Train AUC: 0.7213 | Val Loss: 0.6630, Val AUC: 0.7050
#   -> Validation AUC did not improve. (1/15)
# Epoch [4/60] Train Loss: 0.6494, Train AUC: 0.7492 | Val Loss: 0.6587, Val AUC: 0.7350
#   -> New best validation AUC: 0.7350
# Epoch [5/60] Train Loss: 0.6419, Train AUC: 0.7918 | Val Loss: 0.6545, Val AUC: 0.7650
#   -> New best validation AUC: 0.7650
# Epoch [6/60] Train Loss: 0.6284, Train AUC: 0.8192 | Val Loss: 0.6495, Val AUC: 0.7600
#   -> Validation AUC did not improve. (1/15)
# Epoch [7/60] Train Loss: 0.6140, Train AUC: 0.8395 | Val Loss: 0.6452, Val AUC: 0.7500
#   -> Validation AUC did not improve. (2/15)
# Epoch [8/60] Train Loss: 0.5934, Train AUC: 0.8597 | Val Loss: 0.6399, Val AUC: 0.7850
#   -> New best validation AUC: 0.7850
# Epoch [9/60] Train Loss: 0.5789, Train AUC: 0.8681 | Val Loss: 0.6401, Val AUC: 0.7600
#   -> Validation AUC did not improve. (1/15)
# Epoch [10/60] Train Loss: 0.5621, Train AUC: 0.8825 | Val Loss: 0.6419, Val AUC: 0.7450
#   -> Validation AUC did not improve. (2/15)
# Epoch [11/60] Train Loss: 0.5394, Train AUC: 0.8952 | Val Loss: 0.6239, Val AUC: 0.7700
#   -> Validation AUC did not improve. (3/15)
# Epoch [12/60] Train Loss: 0.5163, Train AUC: 0.9040 | Val Loss: 0.6346, Val AUC: 0.7750
#   -> Validation AUC did not improve. (4/15)
# Epoch [13/60] Train Loss: 0.4905, Train AUC: 0.9032 | Val Loss: 0.6379, Val AUC: 0.7450
#   -> Validation AUC did not improve. (5/15)
# Epoch [14/60] Train Loss: 0.4792, Train AUC: 0.9093 | Val Loss: 0.6361, Val AUC: 0.7700
#   -> Validation AUC did not improve. (6/15)
# Epoch [15/60] Train Loss: 0.4299, Train AUC: 0.9210 | Val Loss: 0.6234, Val AUC: 0.7550
#   -> Validation AUC did not improve. (7/15)
# Epoch [16/60] Train Loss: 0.3942, Train AUC: 0.9314 | Val Loss: 0.6357, Val AUC: 0.7650
#   -> Validation AUC did not improve. (8/15)
# Epoch [17/60] Train Loss: 0.3672, Train AUC: 0.9404 | Val Loss: 0.6378, Val AUC: 0.7650
#   -> Validation AUC did not improve. (9/15)
# Epoch [18/60] Train Loss: 0.3607, Train AUC: 0.9435 | Val Loss: 0.6493, Val AUC: 0.7700
#   -> Validation AUC did not improve. (10/15)
# Epoch [19/60] Train Loss: 0.3054, Train AUC: 0.9584 | Val Loss: 0.6805, Val AUC: 0.7550
#   -> Validation AUC did not improve. (11/15)
# Epoch [20/60] Train Loss: 0.2624, Train AUC: 0.9674 | Val Loss: 0.6596, Val AUC: 0.7600
#   -> Validation AUC did not improve. (12/15)
# Epoch [21/60] Train Loss: 0.2562, Train AUC: 0.9724 | Val Loss: 0.6662, Val AUC: 0.7700
#   -> Validation AUC did not improve. (13/15)
# Epoch [22/60] Train Loss: 0.2521, Train AUC: 0.9748 | Val Loss: 0.7147, Val AUC: 0.7600
#   -> Validation AUC did not improve. (14/15)
# Epoch [23/60] Train Loss: 0.2106, Train AUC: 0.9789 | Val Loss: 0.7368, Val AUC: 0.7700
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 23.
# Finished training. Loading best model with Val AUC: 0.7850
# ===================================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=p, process=mixed, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6994, Train AUC: 0.5401 | Val Loss: 0.6914, Val AUC: 0.4350
#   -> New best validation AUC: 0.4350
# Epoch [2/60] Train Loss: 0.6619, Train AUC: 0.6135 | Val Loss: 0.6630, Val AUC: 0.5200
#   -> New best validation AUC: 0.5200
# Epoch [3/60] Train Loss: 0.6414, Train AUC: 0.6959 | Val Loss: 0.6653, Val AUC: 0.5150
#   -> Validation AUC did not improve. (1/15)
# Epoch [4/60] Train Loss: 0.6129, Train AUC: 0.7662 | Val Loss: 0.6444, Val AUC: 0.5550
#   -> New best validation AUC: 0.5550
# Epoch [5/60] Train Loss: 0.5928, Train AUC: 0.8035 | Val Loss: 0.6311, Val AUC: 0.6700
#   -> New best validation AUC: 0.6700
# Epoch [6/60] Train Loss: 0.5918, Train AUC: 0.8250 | Val Loss: 0.6269, Val AUC: 0.6650
#   -> Validation AUC did not improve. (1/15)
# Epoch [7/60] Train Loss: 0.5471, Train AUC: 0.8709 | Val Loss: 0.6057, Val AUC: 0.7150
#   -> New best validation AUC: 0.7150
# Epoch [8/60] Train Loss: 0.5167, Train AUC: 0.8939 | Val Loss: 0.5996, Val AUC: 0.7250
#   -> New best validation AUC: 0.7250
# Epoch [9/60] Train Loss: 0.5170, Train AUC: 0.9083 | Val Loss: 0.5902, Val AUC: 0.7700
#   -> New best validation AUC: 0.7700
# Epoch [10/60] Train Loss: 0.4957, Train AUC: 0.9258 | Val Loss: 0.5788, Val AUC: 0.7600
#   -> Validation AUC did not improve. (1/15)
# Epoch [11/60] Train Loss: 0.4705, Train AUC: 0.9371 | Val Loss: 0.5524, Val AUC: 0.8250
#   -> New best validation AUC: 0.8250
# Epoch [12/60] Train Loss: 0.4478, Train AUC: 0.9490 | Val Loss: 0.5477, Val AUC: 0.8200
#   -> Validation AUC did not improve. (1/15)
# Epoch [13/60] Train Loss: 0.4036, Train AUC: 0.9544 | Val Loss: 0.5107, Val AUC: 0.8450
#   -> New best validation AUC: 0.8450
# Epoch [14/60] Train Loss: 0.3794, Train AUC: 0.9650 | Val Loss: 0.5078, Val AUC: 0.8400
#   -> Validation AUC did not improve. (1/15)
# Epoch [15/60] Train Loss: 0.3460, Train AUC: 0.9700 | Val Loss: 0.4998, Val AUC: 0.8450
#   -> Validation AUC did not improve. (2/15)
# Epoch [16/60] Train Loss: 0.3512, Train AUC: 0.9766 | Val Loss: 0.4533, Val AUC: 0.8550
#   -> New best validation AUC: 0.8550
# Epoch [17/60] Train Loss: 0.2992, Train AUC: 0.9801 | Val Loss: 0.4584, Val AUC: 0.8550
#   -> Validation AUC did not improve. (1/15)
# Epoch [18/60] Train Loss: 0.2692, Train AUC: 0.9850 | Val Loss: 0.4371, Val AUC: 0.8600
#   -> New best validation AUC: 0.8600
# Epoch [19/60] Train Loss: 0.2384, Train AUC: 0.9887 | Val Loss: 0.4214, Val AUC: 0.8700
#   -> New best validation AUC: 0.8700
# Epoch [20/60] Train Loss: 0.2167, Train AUC: 0.9926 | Val Loss: 0.4334, Val AUC: 0.8600
#   -> Validation AUC did not improve. (1/15)
# Epoch [21/60] Train Loss: 0.1842, Train AUC: 0.9949 | Val Loss: 0.4433, Val AUC: 0.8500
#   -> Validation AUC did not improve. (2/15)
# Epoch [22/60] Train Loss: 0.1649, Train AUC: 0.9961 | Val Loss: 0.4416, Val AUC: 0.8600
#   -> Validation AUC did not improve. (3/15)
# Epoch [23/60] Train Loss: 0.1490, Train AUC: 0.9986 | Val Loss: 0.4366, Val AUC: 0.8750
#   -> New best validation AUC: 0.8750
# Epoch [24/60] Train Loss: 0.1215, Train AUC: 0.9996 | Val Loss: 0.4792, Val AUC: 0.8550
#   -> Validation AUC did not improve. (1/15)
# Epoch [25/60] Train Loss: 0.1101, Train AUC: 0.9998 | Val Loss: 0.4657, Val AUC: 0.8800
#   -> New best validation AUC: 0.8800
# Epoch [26/60] Train Loss: 0.0980, Train AUC: 0.9996 | Val Loss: 0.5093, Val AUC: 0.8700
#   -> Validation AUC did not improve. (1/15)
# Epoch [27/60] Train Loss: 0.0807, Train AUC: 1.0000 | Val Loss: 0.5277, Val AUC: 0.8700
#   -> Validation AUC did not improve. (2/15)
# Epoch [28/60] Train Loss: 0.0724, Train AUC: 1.0000 | Val Loss: 0.5299, Val AUC: 0.8800
#   -> Validation AUC did not improve. (3/15)
# Epoch [29/60] Train Loss: 0.0632, Train AUC: 1.0000 | Val Loss: 0.5579, Val AUC: 0.8350
#   -> Validation AUC did not improve. (4/15)
# Epoch [30/60] Train Loss: 0.0551, Train AUC: 1.0000 | Val Loss: 0.5829, Val AUC: 0.8450
#   -> Validation AUC did not improve. (5/15)
# Epoch [31/60] Train Loss: 0.0495, Train AUC: 1.0000 | Val Loss: 0.6011, Val AUC: 0.8300
#   -> Validation AUC did not improve. (6/15)
# Epoch [32/60] Train Loss: 0.0439, Train AUC: 1.0000 | Val Loss: 0.6248, Val AUC: 0.8250
#   -> Validation AUC did not improve. (7/15)
# Epoch [33/60] Train Loss: 0.0368, Train AUC: 1.0000 | Val Loss: 0.6558, Val AUC: 0.8300
#   -> Validation AUC did not improve. (8/15)
# Epoch [34/60] Train Loss: 0.0344, Train AUC: 1.0000 | Val Loss: 0.6865, Val AUC: 0.8150
#   -> Validation AUC did not improve. (9/15)
# Epoch [35/60] Train Loss: 0.0293, Train AUC: 1.0000 | Val Loss: 0.7068, Val AUC: 0.8500
#   -> Validation AUC did not improve. (10/15)
# Epoch [36/60] Train Loss: 0.0292, Train AUC: 1.0000 | Val Loss: 0.7342, Val AUC: 0.8350
#   -> Validation AUC did not improve. (11/15)
# Epoch [37/60] Train Loss: 0.0261, Train AUC: 1.0000 | Val Loss: 0.7531, Val AUC: 0.8450
#   -> Validation AUC did not improve. (12/15)
# Epoch [38/60] Train Loss: 0.0260, Train AUC: 1.0000 | Val Loss: 0.7491, Val AUC: 0.8250
#   -> Validation AUC did not improve. (13/15)
# Epoch [39/60] Train Loss: 0.0224, Train AUC: 1.0000 | Val Loss: 0.7795, Val AUC: 0.8350
#   -> Validation AUC did not improve. (14/15)
# Epoch [40/60] Train Loss: 0.0180, Train AUC: 1.0000 | Val Loss: 0.7983, Val AUC: 0.8200
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 40.
# Finished training. Loading best model with Val AUC: 0.8800
# ===================================================================
# Scenario => N=200, reg=0.8, missing=0.1, sync=p, process=mixed, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.6878, Train AUC: 0.6129 | Val Loss: 0.6682, Val AUC: 0.6606
#   -> New best validation AUC: 0.6606
# Epoch [2/60] Train Loss: 0.6566, Train AUC: 0.7136 | Val Loss: 0.6566, Val AUC: 0.6923
#   -> New best validation AUC: 0.6923
# Epoch [3/60] Train Loss: 0.6231, Train AUC: 0.7744 | Val Loss: 0.6499, Val AUC: 0.6968
#   -> New best validation AUC: 0.6968
# Epoch [4/60] Train Loss: 0.6070, Train AUC: 0.8197 | Val Loss: 0.6450, Val AUC: 0.6968
#   -> Validation AUC did not improve. (1/15)
# Epoch [5/60] Train Loss: 0.5761, Train AUC: 0.8519 | Val Loss: 0.6345, Val AUC: 0.7149
#   -> New best validation AUC: 0.7149
# Epoch [6/60] Train Loss: 0.5567, Train AUC: 0.8693 | Val Loss: 0.6112, Val AUC: 0.7511
#   -> New best validation AUC: 0.7511
# Epoch [7/60] Train Loss: 0.5288, Train AUC: 0.8954 | Val Loss: 0.6098, Val AUC: 0.7421
#   -> Validation AUC did not improve. (1/15)
# Epoch [8/60] Train Loss: 0.5293, Train AUC: 0.9042 | Val Loss: 0.6097, Val AUC: 0.7511
#   -> Validation AUC did not improve. (2/15)
# Epoch [9/60] Train Loss: 0.4848, Train AUC: 0.9198 | Val Loss: 0.5871, Val AUC: 0.7692
#   -> New best validation AUC: 0.7692
# Epoch [10/60] Train Loss: 0.4569, Train AUC: 0.9237 | Val Loss: 0.5730, Val AUC: 0.7828
#   -> New best validation AUC: 0.7828
# Epoch [11/60] Train Loss: 0.4474, Train AUC: 0.9354 | Val Loss: 0.5547, Val AUC: 0.7964
#   -> New best validation AUC: 0.7964
# ...
# Epoch [18/60] Train Loss: 0.0984, Train AUC: 0.9938 | Val Loss: 0.3185, Val AUC: 0.9610
#   -> Validation AUC did not improve. (6/15)
# Epoch [19/60] Train Loss: 0.0835, Train AUC: 0.9953 | Val Loss: 0.3568, Val AUC: 0.9573
#   -> Validation AUC did not improve. (7/15)
# Epoch [20/60] Train Loss: 0.0847, Train AUC: 0.9952 | Val Loss: 0.3666, Val AUC: 0.9568
#   -> Validation AUC did not improve. (8/15)
# Epoch [21/60] Train Loss: 0.0759, Train AUC: 0.9961 | Val Loss: 0.3892, Val AUC: 0.9566
#   -> Validation AUC did not improve. (9/15)
# Epoch [22/60] Train Loss: 0.0735, Train AUC: 0.9964 | Val Loss: 0.3627, Val AUC: 0.9584
#   -> Validation AUC did not improve. (10/15)
# Epoch [23/60] Train Loss: 0.0720, Train AUC: 0.9964 | Val Loss: 0.3764, Val AUC: 0.9576
#   -> Validation AUC did not improve. (11/15)
# Epoch [24/60] Train Loss: 0.0596, Train AUC: 0.9973 | Val Loss: 0.4041, Val AUC: 0.9577
#   -> Validation AUC did not improve. (12/15)
# Epoch [25/60] Train Loss: 0.0574, Train AUC: 0.9975 | Val Loss: 0.4251, Val AUC: 0.9560
#   -> Validation AUC did not improve. (13/15)
# Epoch [26/60] Train Loss: 0.0581, Train AUC: 0.9976 | Val Loss: 0.4552, Val AUC: 0.9552
#   -> Validation AUC did not improve. (14/15)
# Epoch [27/60] Train Loss: 0.0557, Train AUC: 0.9977 | Val Loss: 0.4381, Val AUC: 0.9538
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 27.
# Finished training. Loading best model with Val AUC: 0.9667
# ===================================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=p, process=homogeneous, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.5414, Train AUC: 0.8023 | Val Loss: 0.4533, Val AUC: 0.8689
#   -> New best validation AUC: 0.8689
# Epoch [2/60] Train Loss: 0.4309, Train AUC: 0.8817 | Val Loss: 0.4488, Val AUC: 0.8711
#   -> New best validation AUC: 0.8711
# Epoch [3/60] Train Loss: 0.4110, Train AUC: 0.8925 | Val Loss: 0.4423, Val AUC: 0.8747
#   -> New best validation AUC: 0.8747
# Epoch [4/60] Train Loss: 0.3997, Train AUC: 0.8985 | Val Loss: 0.4358, Val AUC: 0.8772
#   -> New best validation AUC: 0.8772
# Epoch [5/60] Train Loss: 0.3913, Train AUC: 0.9027 | Val Loss: 0.4452, Val AUC: 0.8736
#   -> Validation AUC did not improve. (1/15)
# Epoch [6/60] Train Loss: 0.3818, Train AUC: 0.9075 | Val Loss: 0.4496, Val AUC: 0.8720
#   -> Validation AUC did not improve. (2/15)
# Epoch [7/60] Train Loss: 0.3754, Train AUC: 0.9107 | Val Loss: 0.4431, Val AUC: 0.8735
#   -> Validation AUC did not improve. (3/15)
# Epoch [8/60] Train Loss: 0.3679, Train AUC: 0.9144 | Val Loss: 0.4483, Val AUC: 0.8714
#   -> Validation AUC did not improve. (4/15)
# Epoch [9/60] Train Loss: 0.3597, Train AUC: 0.9186 | Val Loss: 0.4691, Val AUC: 0.8653
#   -> Validation AUC did not improve. (5/15)
# Epoch [10/60] Train Loss: 0.3525, Train AUC: 0.9221 | Val Loss: 0.4616, Val AUC: 0.8676
#   -> Validation AUC did not improve. (6/15)
# Epoch [11/60] Train Loss: 0.3431, Train AUC: 0.9259 | Val Loss: 0.4793, Val AUC: 0.8647
#   -> Validation AUC did not improve. (7/15)
# Epoch [12/60] Train Loss: 0.3348, Train AUC: 0.9303 | Val Loss: 0.4999, Val AUC: 0.8616
#   -> Validation AUC did not improve. (8/15)
# Epoch [13/60] Train Loss: 0.3241, Train AUC: 0.9347 | Val Loss: 0.4928, Val AUC: 0.8621
#   -> Validation AUC did not improve. (9/15)
# Epoch [14/60] Train Loss: 0.3200, Train AUC: 0.9367 | Val Loss: 0.5001, Val AUC: 0.8625
#   -> Validation AUC did not improve. (10/15)
# Epoch [15/60] Train Loss: 0.3066, Train AUC: 0.9423 | Val Loss: 0.5203, Val AUC: 0.8560
#   -> Validation AUC did not improve. (11/15)
# Epoch [16/60] Train Loss: 0.3050, Train AUC: 0.9430 | Val Loss: 0.5266, Val AUC: 0.8572
#   -> Validation AUC did not improve. (12/15)
# Epoch [17/60] Train Loss: 0.2937, Train AUC: 0.9477 | Val Loss: 0.5312, Val AUC: 0.8559
#   -> Validation AUC did not improve. (13/15)
# Epoch [18/60] Train Loss: 0.2808, Train AUC: 0.9522 | Val Loss: 0.5533, Val AUC: 0.8555
#   -> Validation AUC did not improve. (14/15)
# Epoch [19/60] Train Loss: 0.2728, Train AUC: 0.9554 | Val Loss: 0.5544, Val AUC: 0.8533
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 19.
# Finished training. Loading best model with Val AUC: 0.8772
# ===================================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=p, process=homogeneous, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.5461, Train AUC: 0.7949 | Val Loss: 0.4764, Val AUC: 0.8531
#   -> New best validation AUC: 0.8531
# Epoch [2/60] Train Loss: 0.4703, Train AUC: 0.8577 | Val Loss: 0.4755, Val AUC: 0.8559
#   -> New best validation AUC: 0.8559
# Epoch [3/60] Train Loss: 0.4593, Train AUC: 0.8648 | Val Loss: 0.4782, Val AUC: 0.8524
#   -> Validation AUC did not improve. (1/15)
# Epoch [4/60] Train Loss: 0.4497, Train AUC: 0.8708 | Val Loss: 0.4776, Val AUC: 0.8550
#   -> Validation AUC did not improve. (2/15)
# Epoch [5/60] Train Loss: 0.4359, Train AUC: 0.8793 | Val Loss: 0.4704, Val AUC: 0.8572
#   -> New best validation AUC: 0.8572
# Epoch [6/60] Train Loss: 0.4228, Train AUC: 0.8867 | Val Loss: 0.4681, Val AUC: 0.8594
#   -> New best validation AUC: 0.8594
# Epoch [7/60] Train Loss: 0.4106, Train AUC: 0.8935 | Val Loss: 0.4770, Val AUC: 0.8557
#   -> Validation AUC did not improve. (1/15)
# Epoch [8/60] Train Loss: 0.3987, Train AUC: 0.8999 | Val Loss: 0.4740, Val AUC: 0.8572
#   -> Validation AUC did not improve. (2/15)
# Epoch [9/60] Train Loss: 0.3830, Train AUC: 0.9078 | Val Loss: 0.4835, Val AUC: 0.8580
#   -> Validation AUC did not improve. (3/15)
# Epoch [10/60] Train Loss: 0.3668, Train AUC: 0.9158 | Val Loss: 0.4854, Val AUC: 0.8581
#   -> Validation AUC did not improve. (4/15)
# Epoch [11/60] Train Loss: 0.3585, Train AUC: 0.9197 | Val Loss: 0.4824, Val AUC: 0.8567
#   -> Validation AUC did not improve. (5/15)
# Epoch [12/60] Train Loss: 0.3389, Train AUC: 0.9283 | Val Loss: 0.4952, Val AUC: 0.8597
#   -> New best validation AUC: 0.8597
# Epoch [13/60] Train Loss: 0.3270, Train AUC: 0.9335 | Val Loss: 0.5169, Val AUC: 0.8532
#   -> Validation AUC did not improve. (1/15)
# Epoch [14/60] Train Loss: 0.3110, Train AUC: 0.9398 | Val Loss: 0.5201, Val AUC: 0.8508
#   -> Validation AUC did not improve. (2/15)
# Epoch [15/60] Train Loss: 0.3013, Train AUC: 0.9437 | Val Loss: 0.5161, Val AUC: 0.8525
#   -> Validation AUC did not improve. (3/15)
# Epoch [16/60] Train Loss: 0.2874, Train AUC: 0.9487 | Val Loss: 0.5427, Val AUC: 0.8533
#   -> Validation AUC did not improve. (4/15)
# Epoch [17/60] Train Loss: 0.2769, Train AUC: 0.9523 | Val Loss: 0.5561, Val AUC: 0.8452
#   -> Validation AUC did not improve. (5/15)
# Epoch [18/60] Train Loss: 0.2655, Train AUC: 0.9562 | Val Loss: 0.5645, Val AUC: 0.8436
#   -> Validation AUC did not improve. (6/15)
# Epoch [19/60] Train Loss: 0.2547, Train AUC: 0.9596 | Val Loss: 0.5748, Val AUC: 0.8462
#   -> Validation AUC did not improve. (7/15)
# Epoch [20/60] Train Loss: 0.2406, Train AUC: 0.9638 | Val Loss: 0.6116, Val AUC: 0.8419
#   -> Validation AUC did not improve. (8/15)
# Epoch [21/60] Train Loss: 0.2345, Train AUC: 0.9656 | Val Loss: 0.6190, Val AUC: 0.8442
#   -> Validation AUC did not improve. (9/15)
# Epoch [22/60] Train Loss: 0.2224, Train AUC: 0.9693 | Val Loss: 0.6194, Val AUC: 0.8380
#   -> Validation AUC did not improve. (10/15)
# Epoch [23/60] Train Loss: 0.2356, Train AUC: 0.9657 | Val Loss: 0.6183, Val AUC: 0.8462
#   -> Validation AUC did not improve. (11/15)
# Epoch [24/60] Train Loss: 0.2051, Train AUC: 0.9738 | Val Loss: 0.6470, Val AUC: 0.8384
#   -> Validation AUC did not improve. (12/15)
# Epoch [25/60] Train Loss: 0.1949, Train AUC: 0.9762 | Val Loss: 0.6804, Val AUC: 0.8379
#   -> Validation AUC did not improve. (13/15)
# Epoch [26/60] Train Loss: 0.1882, Train AUC: 0.9778 | Val Loss: 0.7073, Val AUC: 0.8301
#   -> Validation AUC did not improve. (14/15)
# Epoch [27/60] Train Loss: 0.1793, Train AUC: 0.9798 | Val Loss: 0.7381, Val AUC: 0.8323
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 27.
# Finished training. Loading best model with Val AUC: 0.8597
# ===================================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=direct
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.4023, Train AUC: 0.9049 | Val Loss: 0.2860, Val AUC: 0.9526
#   -> New best validation AUC: 0.9526
# Epoch [2/60] Train Loss: 0.2556, Train AUC: 0.9606 | Val Loss: 0.2526, Val AUC: 0.9614
#   -> New best validation AUC: 0.9614
# Epoch [3/60] Train Loss: 0.2297, Train AUC: 0.9677 | Val Loss: 0.2438, Val AUC: 0.9640
#   -> New best validation AUC: 0.9640
# Epoch [4/60] Train Loss: 0.2147, Train AUC: 0.9719 | Val Loss: 0.2420, Val AUC: 0.9658
#   -> New best validation AUC: 0.9658
# Epoch [5/60] Train Loss: 0.2057, Train AUC: 0.9742 | Val Loss: 0.2390, Val AUC: 0.9661
#   -> New best validation AUC: 0.9661
# Epoch [6/60] Train Loss: 0.1967, Train AUC: 0.9764 | Val Loss: 0.2394, Val AUC: 0.9658
#   -> Validation AUC did not improve. (1/15)
# Epoch [7/60] Train Loss: 0.1892, Train AUC: 0.9782 | Val Loss: 0.2409, Val AUC: 0.9658
#   -> Validation AUC did not improve. (2/15)
# Epoch [8/60] Train Loss: 0.1787, Train AUC: 0.9804 | Val Loss: 0.2488, Val AUC: 0.9650
#   -> Validation AUC did not improve. (3/15)
# Epoch [9/60] Train Loss: 0.1728, Train AUC: 0.9818 | Val Loss: 0.2615, Val AUC: 0.9626
#   -> Validation AUC did not improve. (4/15)
# Epoch [10/60] Train Loss: 0.1631, Train AUC: 0.9837 | Val Loss: 0.2913, Val AUC: 0.9571
#   -> Validation AUC did not improve. (5/15)
# Epoch [11/60] Train Loss: 0.1562, Train AUC: 0.9850 | Val Loss: 0.2713, Val AUC: 0.9609
#   -> Validation AUC did not improve. (6/15)
# Epoch [12/60] Train Loss: 0.1504, Train AUC: 0.9861 | Val Loss: 0.2778, Val AUC: 0.9604
#   -> Validation AUC did not improve. (7/15)
# Epoch [13/60] Train Loss: 0.1459, Train AUC: 0.9870 | Val Loss: 0.2878, Val AUC: 0.9578
#   -> Validation AUC did not improve. (8/15)
# Epoch [14/60] Train Loss: 0.1347, Train AUC: 0.9889 | Val Loss: 0.3177, Val AUC: 0.9551
#   -> Validation AUC did not improve. (9/15)
# Epoch [15/60] Train Loss: 0.1272, Train AUC: 0.9900 | Val Loss: 0.3244, Val AUC: 0.9537
#   -> Validation AUC did not improve. (10/15)
# Epoch [16/60] Train Loss: 0.1207, Train AUC: 0.9911 | Val Loss: 0.3427, Val AUC: 0.9511
#   -> Validation AUC did not improve. (11/15)
# Epoch [17/60] Train Loss: 0.1130, Train AUC: 0.9921 | Val Loss: 0.3405, Val AUC: 0.9539
#   -> Validation AUC did not improve. (12/15)
# Epoch [18/60] Train Loss: 0.1148, Train AUC: 0.9918 | Val Loss: 0.3669, Val AUC: 0.9502
#   -> Validation AUC did not improve. (13/15)
# Epoch [19/60] Train Loss: 0.1114, Train AUC: 0.9922 | Val Loss: 0.3620, Val AUC: 0.9520
#   -> Validation AUC did not improve. (14/15)
# Epoch [20/60] Train Loss: 0.1018, Train AUC: 0.9936 | Val Loss: 0.3408, Val AUC: 0.9548
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 20.
# Finished training. Loading best model with Val AUC: 0.9661
# ===================================================================
# Scenario => N=10000, reg=0.8, missing=0.4, sync=p, process=mixed, outcome=lagged
# ===================================================================
# Using device: cuda
# Starting training for 60 epochs with patience 15...
# Epoch [1/60] Train Loss: 0.3652, Train AUC: 0.9218 | Val Loss: 0.2845, Val AUC: 0.9534
#   -> New best validation AUC: 0.9534
# Epoch [2/60] Train Loss: 0.2696, Train AUC: 0.9563 | Val Loss: 0.2755, Val AUC: 0.9560
#   -> New best validation AUC: 0.9560
# Epoch [3/60] Train Loss: 0.2542, Train AUC: 0.9610 | Val Loss: 0.2690, Val AUC: 0.9575
#   -> New best validation AUC: 0.9575
# Epoch [4/60] Train Loss: 0.2443, Train AUC: 0.9638 | Val Loss: 0.2732, Val AUC: 0.9580
#   -> New best validation AUC: 0.9580
# Epoch [5/60] Train Loss: 0.2330, Train AUC: 0.9671 | Val Loss: 0.2606, Val AUC: 0.9604
#   -> New best validation AUC: 0.9604
# Epoch [6/60] Train Loss: 0.2233, Train AUC: 0.9697 | Val Loss: 0.2576, Val AUC: 0.9610
#   -> New best validation AUC: 0.9610
# Epoch [7/60] Train Loss: 0.2144, Train AUC: 0.9720 | Val Loss: 0.2687, Val AUC: 0.9594
#   -> Validation AUC did not improve. (1/15)
# Epoch [8/60] Train Loss: 0.2043, Train AUC: 0.9743 | Val Loss: 0.2551, Val AUC: 0.9622
#   -> New best validation AUC: 0.9622
# Epoch [9/60] Train Loss: 0.1969, Train AUC: 0.9762 | Val Loss: 0.2525, Val AUC: 0.9626
#   -> New best validation AUC: 0.9626
# Epoch [10/60] Train Loss: 0.1857, Train AUC: 0.9788 | Val Loss: 0.2670, Val AUC: 0.9624
#   -> Validation AUC did not improve. (1/15)
# Epoch [11/60] Train Loss: 0.1770, Train AUC: 0.9806 | Val Loss: 0.2658, Val AUC: 0.9614
#   -> Validation AUC did not improve. (2/15)
# Epoch [12/60] Train Loss: 0.1677, Train AUC: 0.9826 | Val Loss: 0.2567, Val AUC: 0.9641
#   -> New best validation AUC: 0.9641
# Epoch [13/60] Train Loss: 0.1593, Train AUC: 0.9843 | Val Loss: 0.2608, Val AUC: 0.9631
#   -> Validation AUC did not improve. (1/15)
# Epoch [14/60] Train Loss: 0.1519, Train AUC: 0.9857 | Val Loss: 0.2798, Val AUC: 0.9621
#   -> Validation AUC did not improve. (2/15)
# Epoch [15/60] Train Loss: 0.1470, Train AUC: 0.9865 | Val Loss: 0.2609, Val AUC: 0.9641
#   -> New best validation AUC: 0.9641
# Epoch [16/60] Train Loss: 0.1368, Train AUC: 0.9881 | Val Loss: 0.2757, Val AUC: 0.9637
#   -> Validation AUC did not improve. (1/15)
# Epoch [17/60] Train Loss: 0.1327, Train AUC: 0.9889 | Val Loss: 0.2810, Val AUC: 0.9621
#   -> Validation AUC did not improve. (2/15)
# Epoch [18/60] Train Loss: 0.1309, Train AUC: 0.9891 | Val Loss: 0.2886, Val AUC: 0.9620
#   -> Validation AUC did not improve. (3/15)
# Epoch [19/60] Train Loss: 0.1228, Train AUC: 0.9904 | Val Loss: 0.2940, Val AUC: 0.9613
#   -> Validation AUC did not improve. (4/15)
# Epoch [20/60] Train Loss: 0.1150, Train AUC: 0.9916 | Val Loss: 0.2940, Val AUC: 0.9628
#   -> Validation AUC did not improve. (5/15)
# Epoch [21/60] Train Loss: 0.1029, Train AUC: 0.9931 | Val Loss: 0.3217, Val AUC: 0.9581
#   -> Validation AUC did not improve. (6/15)
# Epoch [22/60] Train Loss: 0.1043, Train AUC: 0.9930 | Val Loss: 0.3203, Val AUC: 0.9596
#   -> Validation AUC did not improve. (7/15)
# Epoch [23/60] Train Loss: 0.1286, Train AUC: 0.9896 | Val Loss: 0.3071, Val AUC: 0.9597
#   -> Validation AUC did not improve. (8/15)
# Epoch [24/60] Train Loss: 0.0982, Train AUC: 0.9938 | Val Loss: 0.3138, Val AUC: 0.9601
#   -> Validation AUC did not improve. (9/15)
# Epoch [25/60] Train Loss: 0.0898, Train AUC: 0.9947 | Val Loss: 0.3276, Val AUC: 0.9601
#   -> Validation AUC did not improve. (10/15)
# Epoch [26/60] Train Loss: 0.0829, Train AUC: 0.9955 | Val Loss: 0.3406, Val AUC: 0.9590
#   -> Validation AUC did not improve. (11/15)
# Epoch [27/60] Train Loss: 0.0758, Train AUC: 0.9961 | Val Loss: 0.3966, Val AUC: 0.9539
#   -> Validation AUC did not improve. (12/15)
# Epoch [28/60] Train Loss: 0.0847, Train AUC: 0.9951 | Val Loss: 0.3606, Val AUC: 0.9559
#   -> Validation AUC did not improve. (13/15)
# Epoch [29/60] Train Loss: 0.1181, Train AUC: 0.9910 | Val Loss: 0.4127, Val AUC: 0.9405
#   -> Validation AUC did not improve. (14/15)
# Epoch [30/60] Train Loss: 0.1407, Train AUC: 0.9879 | Val Loss: 0.3233, Val AUC: 0.9560
#   -> Validation AUC did not improve. (15/15)
# Early stopping triggered after epoch 30.
# Finished training. Loading best model with Val AUC: 0.9641
#
# All scenarios completed in 473.84 minutes.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-671a3b184566> in <cell line: 0>()
#      95
#      96 # Optionally save to CSV
# ---> 97 df_results.to_csv("drive/MyDrive/grud_factorial_results_REP1.csv", index=False)
#      98 print("\nResults saved to grud_factorial_results_REP1.csv")
#
# NameError: name 'df_results' is not defined

# %%
# 7) Convert results to a DataFrame and save
df_results = pd.DataFrame(all_results)
df_results.sort_values(by=["N","regularity","missing_prop"], inplace=True)
print(df_results)

df_results.to_csv("drive/MyDrive/grud_factorial_results_REP1.csv", index=False)
print("\nResults saved to grud_factorial_results_REP1.csv")
# Out:
#         N  regularity  missing_prop sync_pattern process_type outcome_dep  \
# 0     200         0.2           0.1            1  homogeneous      direct
# 1     200         0.2           0.1            1  homogeneous      lagged
# 2     200         0.2           0.1            1        mixed      direct
# 3     200         0.2           0.1            1        mixed      lagged
# 4     200         0.2           0.1            p  homogeneous      direct
# ..    ...         ...           ...          ...          ...         ...
# 91  10000         0.8           0.4            1        mixed      lagged
# 92  10000         0.8           0.4            p  homogeneous      direct
# 93  10000         0.8           0.4            p  homogeneous      lagged
# 94  10000         0.8           0.4            p        mixed      direct
# 95  10000         0.8           0.4            p        mixed      lagged
#
#     test_loss       auc  accuracy  precision    recall        f1  runtime_sec  \
# 0         NaN  0.964444  0.866667   0.866667  0.866667  0.866667    29.170093
# 1         NaN  0.521531  0.500000   0.625000  0.526316  0.571429    13.120767
# 2         NaN  0.827751  0.666667   0.909091  0.526316  0.666667    14.639388
# 3         NaN  0.840000  0.700000   0.866667  0.650000  0.742857    22.200539
# 4         NaN  0.737557  0.700000   0.750000  0.461538  0.571429    42.464890
# ..        ...       ...       ...        ...       ...       ...          ...
# 91        NaN  0.966761  0.899333   0.932225  0.881499  0.906153   709.100467
# 92        NaN  0.886980  0.798667   0.804071  0.810256  0.807152   769.320991
# 93        NaN  0.851070  0.774000   0.774970  0.809045  0.791641   974.452661
# 94        NaN  0.970933  0.900000   0.904826  0.895225  0.900000   820.579859
# 95        NaN  0.953779  0.884000   0.898657  0.889964  0.894289  1080.476963
#
#     mean_true_prob  prop_positive
# 0         0.487307         0.4900
# 1         0.530274         0.5350
# 2         0.514149         0.5150
# 3         0.504874         0.5100
# 4         0.499697         0.4850
# ..             ...            ...
# 91        0.534915         0.5351
# 92        0.528876         0.5307
# 93        0.537251         0.5413
# 94        0.532155         0.5297
# 95        0.539760         0.5383
#
# [96 rows x 15 columns]
#
# Results saved to grud_factorial_results_REP1.csv
